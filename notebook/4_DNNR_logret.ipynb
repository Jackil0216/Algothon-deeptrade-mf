# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
import pandas as pd
import json
import datetime
import time
import copy

py_file_location = './drive/My Drive/PrivatePackages'
sys.path.append(os.path.abspath(py_file_location))
from sklearn.model_selection import train_test_split

import JiaoCheng
import NingXiang

# %%
LABEL = 'logret'
MODEL = 'dnnr'

# %%
curated_data = pd.read_csv('./drive/My Drive/LAB/Hackathon/data/curated_data.csv')
curated_data = curated_data.drop(columns=['closePrice', 'closePriceNorm', 'log_ret_normalised_by_day', 'trend', 'stock'])
curated_data['date'] = pd.to_datetime(curated_data['date'])

# %%
curated_data
# Out:
#             date   log_ret  closePrice_min_3  closePrice_max_3  \
# 0     2022-12-31       NaN               NaN               NaN
# 1     2023-01-01 -0.002996               NaN               NaN
# 2     2023-01-02 -0.005516               NaN               NaN
# 3     2023-01-03 -0.004704               NaN               NaN
# 4     2023-01-04 -0.002867               NaN               NaN
# ...          ...       ...               ...               ...
# 12495 2023-09-02 -0.005332             43.11             43.66
# 12496 2023-09-03  0.000232             43.25             43.66
# 12497 2023-09-04  0.012471             43.02             43.61
# 12498 2023-09-05 -0.010150             43.02             43.25
# 12499 2023-09-06  0.004626             43.02             43.57
#
#        closePrice_std_3  closePrice_mean_3  closePrice_slope_3  \
# 0                   NaN                NaN                 NaN
# 1                   NaN                NaN                 NaN
# 2                   NaN                NaN                 NaN
# 3                   NaN                NaN                 NaN
# 4                   NaN                NaN                 NaN
# ...                 ...                ...                 ...
# 12495          0.248328          43.460000            0.011598
# 12496          0.182635          43.506667           -0.009391
# 12497          0.242808          43.293333           -0.013529
# 12498          0.106145          43.100000           -0.005087
# 12499          0.256948          43.206667            0.012785
#
#        closePrice_skew_3  closePrice_abs_diff_mean_3  closePrice_diff_std_3  \
# 0                    NaN                         NaN                    NaN
# 1                    NaN                         NaN                    NaN
# 2                    NaN                         NaN                    NaN
# 3                    NaN                         NaN                    NaN
# 4                    NaN                         NaN                    NaN
# ...                  ...                         ...                    ...
# 12495          -0.685668                       0.300                  0.300
# 12496          -0.667566                       0.205                  0.155
# 12497           0.262017                       0.295                  0.065
# 12498           0.702403                       0.120                  0.120
# 12499           0.706304                       0.275                  0.265
#
#        ...  closePriceNorm_lag_10  log_ret_normalised_by_day_lag_10  \
# 0      ...                    NaN                               NaN
# 1      ...                    NaN                               NaN
# 2      ...                    NaN                               NaN
# 3      ...                    NaN                               NaN
# 4      ...                    NaN                               NaN
# ...    ...                    ...                               ...
# 12495  ...              -0.136102                         -2.032099
# 12496  ...              -0.539073                         -1.515743
# 12497  ...              -0.377885                          0.765811
# 12498  ...              -0.363231                          0.030813
# 12499  ...              -0.326598                          0.102353
#
#        mean_log_ret_lag_1  mean_closePrice_lag_1  mean_closePriceNorm_lag_1  \
# 0                     NaN                    NaN                        NaN
# 1                     NaN                40.6170                   0.241356
# 2                0.000525                40.6472                   0.247020
# 3               -0.000065                40.6172                   0.231342
# 4               -0.000623                40.5886                   0.211599
# ...                   ...                    ...                        ...
# 12495           -0.002123                39.4416                  -0.655234
# 12496           -0.001491                39.3646                  -0.690649
# 12497           -0.001420                39.3096                  -0.716371
# 12498           -0.000048                39.2904                  -0.714126
# 12499           -0.000252                39.2810                  -0.713713
#
#        mean_log_ret_normalised_by_day_lag_1  pos_log_ret_lag_1  \
# 0                                       NaN                NaN
# 1                                       NaN                NaN
# 2                             -4.440892e-18           0.000569
# 3                             -8.881784e-18          -0.001615
# 4                              1.776357e-17          -0.000616
# ...                                     ...                ...
# 12495                          5.773160e-17          -0.003932
# 12496                          4.662937e-17          -0.001368
# 12497                          8.770762e-17          -0.004381
# 12498                         -1.776357e-17          -0.001478
# 12499                          3.552714e-17          -0.002505
#
#        pos_closePrice_lag_1  pos_closePriceNorm_lag_1  \
# 0                       NaN                       NaN
# 1                 33.787500                  0.529432
# 2                 33.838750                  0.535137
# 3                 33.735000                  0.482227
# 4                 33.710000                  0.455742
# ...                     ...                       ...
# 12495             35.979231                 -0.815362
# 12496             35.899231                 -0.860295
# 12497             35.692308                 -0.931225
# 12498             35.616923                 -0.974622
# 12499             35.506154                 -1.026466
#
#        pos_log_ret_normalised_by_day_lag_1
# 0                                      NaN
# 1                                      NaN
# 2                                 0.007178
# 3                                -0.229975
# 4                                 0.001161
# ...                                    ...
# 12495                            -0.320944
# 12496                             0.019382
# 12497                            -0.493615
# 12498                            -0.267420
# 12499                            -0.344069
#
# [12500 rows x 194 columns]

# %%
date = [datetime.datetime(year=2023, month=1, day = 1) + datetime.timedelta(days=i) for i in range(250)]
val_date_start = date[175]
test_date_start = date[175+38]

# %%
function_map = ['min', 'max', 'std', 'mean', 'slope', 'skew', 'abs_diff_mean', 'diff_std', 'sum']

for i in [3, 5, 10, 20]:
    print('Max Lag:', i)

    tmp_curated_data = copy.deepcopy(curated_data)

    for j in range(i+1, 11):
        tmp_curated_data = tmp_curated_data.drop(columns=[f'log_ret_lag_{j}', f'log_ret_normalised_by_day_lag_{j}', f'closePriceNorm_lag_{j}', f'closePrice_lag_{j}'], axis = 1)

    for j in [3, 5, 10, 20]:
        if j > i:

            columns = []
            for col in ['log_ret', 'closePrice', 'closePriceNorm', 'log_ret_normalised_by_day']:
                for func in function_map:
                    columns.append(f'{col}_{func}_{j}')
            tmp_curated_data = tmp_curated_data.drop(columns=columns, axis = 1)

    tmp_curated_data = tmp_curated_data.dropna()

    train = tmp_curated_data[(tmp_curated_data['date'] < val_date_start)]
    val = tmp_curated_data[(tmp_curated_data['date'] < test_date_start) & (tmp_curated_data['date'] >= val_date_start)]
    test = tmp_curated_data[(tmp_curated_data['date'] >= test_date_start)]

    jiaocheng = JiaoCheng.JiaoCheng()

    train_x = train.drop(columns=['date', 'log_ret'], axis = 1)
    train_y = train['log_ret']

    val_x = val.drop(columns=['date', 'log_ret'], axis = 1)
    val_y = val['log_ret']

    test_x = test.drop(columns=['date', 'log_ret'], axis = 1)
    test_y = test['log_ret']

    with open(f'./drive/My Drive/LAB/Hackathon/models/NingXiang_output_{LABEL}_lag_{i}.pickle', 'rb') as f:
        ningxiang_output = pickle.load(f)

    ningxiang_output = list(ningxiang_output.items())
    ningxiang_output = dict(ningxiang_output)

    jiaocheng = JiaoCheng.JiaoCheng()

    from models.DenseNeuralNetwork import DNNR_const_sk as DNNR

    jiaocheng.read_in_model(DNNR, 'Regression')

    jiaocheng.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

    del train_x
    del train_y
    del val_x
    del val_y

    parameter_choices = {
        'n_hidden_layers': (1, 2, 3, 4, 5),
        'alpha': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
        'learning_rate_init': (0.0001, 0.001, 0.01, 0.1),
        'activation': ('relu', 'logistic'),
        'hidden_layer_n_neurons': (10, 20, 30, 40, 50, 60)


    }

    jiaocheng.set_hyperparameters(parameter_choices)

    jiaocheng.set_non_tuneable_hyperparameters({'random_state': 19260817, 'max_iter': 1000, 'learning_rate': 'adaptive', 'batch_size': 'auto'})

    jiaocheng.set_features(ningxiang_output)

    jiaocheng.set_tuning_order(['features', 'activation', 'hidden_layer_n_neurons', 'n_hidden_layers', 'alpha', 'learning_rate_init'])

    jiaocheng.set_hyperparameter_default_values({
      'features': 0,
      'activation': 'logistic',
      'n_hidden_layers': 1,
      'alpha': 0.0001,
      'learning_rate_init': 0.001,
      'hidden_layer_n_neurons': 30}
    )

    try:
        jiaocheng.read_in_tuning_result_df(f'./drive/My Drive/LAB/Hackathon/models/tuning/jiaocheng_{MODEL}_{LABEL}_lag_{i}.csv')
    except:
        pass

    jiaocheng.set_tuning_result_saving_address(f'./drive/My Drive/LAB/Hackathon/models/tuning/jiaocheng_{MODEL}_{LABEL}_lag_{i}.csv')
    jiaocheng.set_best_model_saving_address(f'./drive/My Drive/LAB/Hackathon/models/tmp_models/jiaocheng_{MODEL}_{LABEL}_lag_{i}.pickle')

    jiaocheng.tune()

    jiaocheng.view_best_combo_and_score()

    print('\n\n')
# Out:
# Max Lag: 3
# JiaoCheng Initialised
# JiaoCheng Initialised
# Successfully read in model <class 'models.DenseNeuralNetwork.DNNR_const_sk'>, which is a Regression model
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# Successfully recorded hyperparameter choices
# Successfully recorded non_tuneable_hyperparameter choices
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# Successfully set tuning output address
# Successfully set best model output address
#
# Default combo: [0, 2, 1, 0, 2, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 5)
#
# Trained and Tested combination 1 of 67200: (0, 2, 1, 0, 2, 0), taking 0.25 seconds to get val score of -0.0449
#         Current best combo: (0, 2, 1, 0, 2, 0) with val score -0.0449
# Trained and Tested combination 2 of 67200: (0, 2, 1, 0, 2, 1), taking 0.26 seconds to get val score of -0.0202
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 3 of 67200: (0, 2, 1, 0, 2, 2), taking 0.28 seconds to get val score of -0.0541
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 4 of 67200: (0, 2, 1, 0, 2, 3), taking 0.29 seconds to get val score of -0.0557
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 5 of 67200: (0, 2, 1, 0, 2, 4), taking 0.27 seconds to get val score of -0.0459
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 6 of 67200: (0, 2, 1, 0, 2, 5), taking 0.28 seconds to get val score of -0.1336
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 7 of 67200: (0, 2, 1, 0, 2, 6), taking 0.31 seconds to get val score of -0.5121
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 8 of 67200: (0, 2, 1, 0, 2, 7), taking 0.26 seconds to get val score of -0.0472
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 9 of 67200: (0, 2, 1, 0, 2, 8), taking 0.26 seconds to get val score of -0.0679
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 10 of 67200: (0, 2, 1, 0, 2, 9), taking 0.27 seconds to get val score of -0.0939
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 11 of 67200: (0, 2, 1, 0, 2, 10), taking 0.3 seconds to get val score of -0.1031
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 12 of 67200: (0, 2, 1, 0, 2, 11), taking 0.3 seconds to get val score of -0.138
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 13 of 67200: (0, 2, 1, 0, 2, 12), taking 0.27 seconds to get val score of -0.2465
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 47 of 67200: (0, 2, 1, 0, 2, 46), taking 0.54 seconds to get val score of -2.8665
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 48 of 67200: (0, 2, 1, 0, 2, 47), taking 0.81 seconds to get val score of -2.8647
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 49 of 67200: (0, 2, 1, 0, 2, 48), taking 1.17 seconds to get val score of -1.9311
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 50 of 67200: (0, 2, 1, 0, 2, 49), taking 1.17 seconds to get val score of -2.2014
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 51 of 67200: (0, 2, 1, 0, 2, 50), taking 1.19 seconds to get val score of -2.1084
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 52 of 67200: (0, 2, 1, 0, 2, 51), taking 1.0 seconds to get val score of -3.0824
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 53 of 67200: (0, 2, 1, 0, 2, 52), taking 0.56 seconds to get val score of -0.5191
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 54 of 67200: (0, 2, 1, 0, 2, 53), taking 0.5 seconds to get val score of -1.491
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 55 of 67200: (0, 2, 1, 0, 2, 54), taking 0.67 seconds to get val score of -2.3355
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
# Trained and Tested combination 56 of 67200: (0, 2, 1, 0, 2, 55), taking 0.62 seconds to get val score of -1.0489
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202
#
# Best combo after this hyperparameter: (0, 2, 1, 0, 2, 1) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: activation (index: 3)
#
# Already Trained and Tested combination (0, 2, 1, 0, 2, 1), which had val score of -0.0202
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0202.
#         Has trained 56 of 67200 combinations so far
# Trained and Tested combination 57 of 67200: (0, 2, 1, 1, 2, 1), taking 0.32 seconds to get val score of -0.0135
#         Current best combo: (0, 2, 1, 1, 2, 1) with val score -0.0135
#
# Best combo after this hyperparameter: (0, 2, 1, 1, 2, 1) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: hidden_layer_n_neurons (index: 4)
#
# Trained and Tested combination 58 of 67200: (0, 2, 1, 1, 0, 1), taking 0.35 seconds to get val score of -0.1036
#         Current best combo: (0, 2, 1, 1, 2, 1) with val score -0.0135
# Trained and Tested combination 59 of 67200: (0, 2, 1, 1, 1, 1), taking 0.24 seconds to get val score of -0.0854
#         Current best combo: (0, 2, 1, 1, 2, 1) with val score -0.0135
# Already Trained and Tested combination (0, 2, 1, 1, 2, 1), which had val score of -0.0135
#         Current best combo: (0, 2, 1, 1, 2, 1) with val score -0.0135.
#         Has trained 59 of 67200 combinations so far
# Trained and Tested combination 60 of 67200: (0, 2, 1, 1, 3, 1), taking 0.36 seconds to get val score of -0.0341
#         Current best combo: (0, 2, 1, 1, 2, 1) with val score -0.0135
# Trained and Tested combination 61 of 67200: (0, 2, 1, 1, 4, 1), taking 0.45 seconds to get val score of -0.0925
#         Current best combo: (0, 2, 1, 1, 2, 1) with val score -0.0135
# Trained and Tested combination 62 of 67200: (0, 2, 1, 1, 5, 1), taking 0.44 seconds to get val score of -0.0093
#         Current best combo: (0, 2, 1, 1, 5, 1) with val score -0.0093
#
# Best combo after this hyperparameter: (0, 2, 1, 1, 5, 1) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: n_hidden_layers (index: 0)
#
# Already Trained and Tested combination (0, 2, 1, 1, 5, 1), which had val score of -0.0093
#         Current best combo: (0, 2, 1, 1, 5, 1) with val score -0.0093.
#         Has trained 62 of 67200 combinations so far
# Trained and Tested combination 63 of 67200: (1, 2, 1, 1, 5, 1), taking 0.87 seconds to get val score of -0.0176
#         Current best combo: (0, 2, 1, 1, 5, 1) with val score -0.0093
# Trained and Tested combination 64 of 67200: (2, 2, 1, 1, 5, 1), taking 1.19 seconds to get val score of -0.0133
#         Current best combo: (0, 2, 1, 1, 5, 1) with val score -0.0093
# Trained and Tested combination 65 of 67200: (3, 2, 1, 1, 5, 1), taking 1.59 seconds to get val score of 0.0
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 66 of 67200: (4, 2, 1, 1, 5, 1), taking 3.39 seconds to get val score of -0.7752
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
#
# Best combo after this hyperparameter: (3, 2, 1, 1, 5, 1) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: alpha (index: 1)
#
# Trained and Tested combination 67 of 67200: (3, 0, 1, 1, 5, 1), taking 3.28 seconds to get val score of -0.0375
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 68 of 67200: (3, 1, 1, 1, 5, 1), taking 1.62 seconds to get val score of -0.0377
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Already Trained and Tested combination (3, 2, 1, 1, 5, 1), which had val score of 0.0
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0.
#         Has trained 68 of 67200 combinations so far
# Trained and Tested combination 69 of 67200: (3, 3, 1, 1, 5, 1), taking 1.85 seconds to get val score of -0.0388
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 70 of 67200: (3, 4, 1, 1, 5, 1), taking 2.55 seconds to get val score of -0.1056
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
#
# Best combo after this hyperparameter: (3, 2, 1, 1, 5, 1) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: learning_rate_init (index: 2)
#
# Trained and Tested combination 71 of 67200: (3, 2, 0, 1, 5, 1), taking 1.58 seconds to get val score of -0.0183
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Already Trained and Tested combination (3, 2, 1, 1, 5, 1), which had val score of 0.0
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0.
#         Has trained 71 of 67200 combinations so far
# Trained and Tested combination 72 of 67200: (3, 2, 2, 1, 5, 1), taking 1.65 seconds to get val score of -0.1367
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 73 of 67200: (3, 2, 3, 1, 5, 1), taking 3.53 seconds to get val score of -0.3367
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
#
# Best combo after this hyperparameter: (3, 2, 1, 1, 5, 1) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 2
# Hyperparameter: features (index: 5)
#
# Trained and Tested combination 74 of 67200: (3, 2, 1, 1, 5, 0), taking 2.29 seconds to get val score of -0.0178
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Already Trained and Tested combination (3, 2, 1, 1, 5, 1), which had val score of 0.0
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0.
#         Has trained 74 of 67200 combinations so far
# Trained and Tested combination 75 of 67200: (3, 2, 1, 1, 5, 2), taking 1.86 seconds to get val score of -0.0856
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 76 of 67200: (3, 2, 1, 1, 5, 3), taking 1.62 seconds to get val score of -0.0643
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 77 of 67200: (3, 2, 1, 1, 5, 4), taking 1.61 seconds to get val score of -0.0288
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 78 of 67200: (3, 2, 1, 1, 5, 5), taking 2.14 seconds to get val score of -0.5957
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 79 of 67200: (3, 2, 1, 1, 5, 6), taking 2.73 seconds to get val score of -0.3466
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 80 of 67200: (3, 2, 1, 1, 5, 7), taking 4.36 seconds to get val score of -0.3938
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 81 of 67200: (3, 2, 1, 1, 5, 8), taking 4.11 seconds to get val score of -0.9783
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 82 of 67200: (3, 2, 1, 1, 5, 9), taking 2.01 seconds to get val score of -1.092
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 83 of 67200: (3, 2, 1, 1, 5, 10), taking 1.64 seconds to get val score of -0.4394
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 84 of 67200: (3, 2, 1, 1, 5, 11), taking 3.11 seconds to get val score of -0.6105
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 85 of 67200: (3, 2, 1, 1, 5, 12), taking 3.68 seconds to get val score of -2.2145
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 86 of 67200: (3, 2, 1, 1, 5, 13), taking 1.8 seconds to get val score of -1.961
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 87 of 67200: (3, 2, 1, 1, 5, 14), taking 2.33 seconds to get val score of -2.3447
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 88 of 67200: (3, 2, 1, 1, 5, 15), taking 2.69 seconds to get val score of -41.2801
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 89 of 67200: (3, 2, 1, 1, 5, 16), taking 4.61 seconds to get val score of -3.6351
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 90 of 67200: (3, 2, 1, 1, 5, 17), taking 4.67 seconds to get val score of -47.0882
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 91 of 67200: (3, 2, 1, 1, 5, 18), taking 2.42 seconds to get val score of -228.2581
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 92 of 67200: (3, 2, 1, 1, 5, 19), taking 3.15 seconds to get val score of -22.9707
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 93 of 67200: (3, 2, 1, 1, 5, 20), taking 5.75 seconds to get val score of -9.4729
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 127 of 67200: (3, 2, 1, 1, 5, 54), taking 6.94 seconds to get val score of -4897.7515
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 128 of 67200: (3, 2, 1, 1, 5, 55), taking 7.82 seconds to get val score of -2712.8977
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
#
# Best combo after this hyperparameter: (3, 2, 1, 1, 5, 1) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: activation (index: 3)
#
# Trained and Tested combination 129 of 67200: (3, 2, 1, 0, 5, 1), taking 1.98 seconds to get val score of -0.0007
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Already Trained and Tested combination (3, 2, 1, 1, 5, 1), which had val score of 0.0
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0.
#         Has trained 129 of 67200 combinations so far
#
# Best combo after this hyperparameter: (3, 2, 1, 1, 5, 1) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: hidden_layer_n_neurons (index: 4)
#
# Trained and Tested combination 130 of 67200: (3, 2, 1, 1, 0, 1), taking 0.52 seconds to get val score of -0.0007
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 131 of 67200: (3, 2, 1, 1, 1, 1), taking 0.53 seconds to get val score of -0.0053
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 132 of 67200: (3, 2, 1, 1, 2, 1), taking 0.88 seconds to get val score of -0.6847
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 133 of 67200: (3, 2, 1, 1, 3, 1), taking 1.17 seconds to get val score of -0.128
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Trained and Tested combination 134 of 67200: (3, 2, 1, 1, 4, 1), taking 1.36 seconds to get val score of -0.1353
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0
# Already Trained and Tested combination (3, 2, 1, 1, 5, 1), which had val score of 0.0
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0.
#         Has trained 134 of 67200 combinations so far
#
# Best combo after this hyperparameter: (3, 2, 1, 1, 5, 1) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_hidden_layers (index: 0)
#
# Already Trained and Tested combination (0, 2, 1, 1, 5, 1), which had val score of -0.0093
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0.
#         Has trained 134 of 67200 combinations so far
# Already Trained and Tested combination (1, 2, 1, 1, 5, 1), which had val score of -0.0176
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0.
#         Has trained 134 of 67200 combinations so far
# Already Trained and Tested combination (2, 2, 1, 1, 5, 1), which had val score of -0.0133
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0.
#         Has trained 134 of 67200 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 5, 1), which had val score of 0.0
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0.
#         Has trained 134 of 67200 combinations so far
# Already Trained and Tested combination (4, 2, 1, 1, 5, 1), which had val score of -0.7752
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0.
#         Has trained 134 of 67200 combinations so far
#
# Best combo after this hyperparameter: (3, 2, 1, 1, 5, 1) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: alpha (index: 1)
#
# Already Trained and Tested combination (3, 0, 1, 1, 5, 1), which had val score of -0.0375
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0.
#         Has trained 134 of 67200 combinations so far
# Already Trained and Tested combination (3, 1, 1, 1, 5, 1), which had val score of -0.0377
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0.
#         Has trained 134 of 67200 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 5, 1), which had val score of 0.0
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0.
#         Has trained 134 of 67200 combinations so far
# Already Trained and Tested combination (3, 3, 1, 1, 5, 1), which had val score of -0.0388
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0.
#         Has trained 134 of 67200 combinations so far
# Already Trained and Tested combination (3, 4, 1, 1, 5, 1), which had val score of -0.1056
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0.
#         Has trained 134 of 67200 combinations so far
#
# Best combo after this hyperparameter: (3, 2, 1, 1, 5, 1) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: learning_rate_init (index: 2)
#
# Already Trained and Tested combination (3, 2, 0, 1, 5, 1), which had val score of -0.0183
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0.
#         Has trained 134 of 67200 combinations so far
# Already Trained and Tested combination (3, 2, 1, 1, 5, 1), which had val score of 0.0
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0.
#         Has trained 134 of 67200 combinations so far
# Already Trained and Tested combination (3, 2, 2, 1, 5, 1), which had val score of -0.1367
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0.
#         Has trained 134 of 67200 combinations so far
# Already Trained and Tested combination (3, 2, 3, 1, 5, 1), which had val score of -0.3367
#         Current best combo: (3, 2, 1, 1, 5, 1) with val score 0.0.
#         Has trained 134 of 67200 combinations so far
#
# Best combo after this hyperparameter: (3, 2, 1, 1, 5, 1) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  1.3794672294342725e-05
# Max Test Score:
#  -0.034907
# Max Combo Index:
#  (3, 2, 1, 1, 5, 1) out of [5, 5, 4, 2, 6, 56] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_hidden_layers': 4, 'alpha': 0.0001, 'learning_rate_init': 0.001, 'activation': 'relu', 'hidden_layer_n_neurons': 60, 'features': 1}
# Max Combo Features:
#  ('pos_closePrice_lag_1', 'mean_log_ret_lag_1')
# % Combos Checked: 134 out of 67200 which is 0.19940499999999997%
# Max Score:
#  1.3794672294342725e-05
# Max Test Score:
#  -0.034907
# Max Combo Index:
#  (3, 2, 1, 1, 5, 1) out of [5, 5, 4, 2, 6, 56] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_hidden_layers': 4, 'alpha': 0.0001, 'learning_rate_init': 0.001, 'activation': 'relu', 'hidden_layer_n_neurons': 60, 'features': 1}
# Max Combo Features:
#  ('pos_closePrice_lag_1', 'mean_log_ret_lag_1')
# % Combos Checked: 134 out of 67200 which is 0.19940499999999997%
#
#
#
# Max Lag: 5
# JiaoCheng Initialised
# JiaoCheng Initialised
# Successfully read in model <class 'models.DenseNeuralNetwork.DNNR_const_sk'>, which is a Regression model
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# Successfully recorded hyperparameter choices
# Successfully recorded non_tuneable_hyperparameter choices
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# Successfully set tuning output address
# Successfully set best model output address
#
# Default combo: [0, 2, 1, 0, 2, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 5)
#
# Trained and Tested combination 1 of 120000: (0, 2, 1, 0, 2, 0), taking 0.23 seconds to get val score of -0.0668
#         Current best combo: (0, 2, 1, 0, 2, 0) with val score -0.0668
# Trained and Tested combination 2 of 120000: (0, 2, 1, 0, 2, 1), taking 0.26 seconds to get val score of -0.0372
#         Current best combo: (0, 2, 1, 0, 2, 1) with val score -0.0372
# Trained and Tested combination 3 of 120000: (0, 2, 1, 0, 2, 2), taking 0.27 seconds to get val score of -0.0224
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 4 of 120000: (0, 2, 1, 0, 2, 3), taking 0.25 seconds to get val score of -0.0566
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 5 of 120000: (0, 2, 1, 0, 2, 4), taking 0.29 seconds to get val score of -0.0248
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 6 of 120000: (0, 2, 1, 0, 2, 5), taking 0.27 seconds to get val score of -0.1154
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 7 of 120000: (0, 2, 1, 0, 2, 6), taking 0.36 seconds to get val score of -0.2798
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 8 of 120000: (0, 2, 1, 0, 2, 7), taking 0.44 seconds to get val score of -0.1909
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 9 of 120000: (0, 2, 1, 0, 2, 8), taking 0.43 seconds to get val score of -0.0528
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 10 of 120000: (0, 2, 1, 0, 2, 9), taking 0.48 seconds to get val score of -0.187
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 11 of 120000: (0, 2, 1, 0, 2, 10), taking 0.49 seconds to get val score of -0.2395
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 12 of 120000: (0, 2, 1, 0, 2, 11), taking 0.47 seconds to get val score of -0.4969
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 13 of 120000: (0, 2, 1, 0, 2, 12), taking 0.44 seconds to get val score of -0.0904
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 14 of 120000: (0, 2, 1, 0, 2, 13), taking 0.48 seconds to get val score of -0.4986
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 15 of 120000: (0, 2, 1, 0, 2, 14), taking 0.49 seconds to get val score of -0.7275
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 16 of 120000: (0, 2, 1, 0, 2, 15), taking 0.46 seconds to get val score of -0.4302
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 17 of 120000: (0, 2, 1, 0, 2, 16), taking 0.32 seconds to get val score of -0.4329
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 18 of 120000: (0, 2, 1, 0, 2, 17), taking 0.33 seconds to get val score of -1.217
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 19 of 120000: (0, 2, 1, 0, 2, 18), taking 0.31 seconds to get val score of -0.5943
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 20 of 120000: (0, 2, 1, 0, 2, 19), taking 0.33 seconds to get val score of -1.3234
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 21 of 120000: (0, 2, 1, 0, 2, 20), taking 0.32 seconds to get val score of -0.941
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 22 of 120000: (0, 2, 1, 0, 2, 21), taking 0.32 seconds to get val score of -0.4734
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 23 of 120000: (0, 2, 1, 0, 2, 22), taking 0.3 seconds to get val score of -0.5743
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 24 of 120000: (0, 2, 1, 0, 2, 23), taking 0.34 seconds to get val score of -0.7706
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 25 of 120000: (0, 2, 1, 0, 2, 24), taking 0.38 seconds to get val score of -0.9552
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 26 of 120000: (0, 2, 1, 0, 2, 25), taking 0.34 seconds to get val score of -1.6651
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 27 of 120000: (0, 2, 1, 0, 2, 26), taking 0.32 seconds to get val score of -1.8143
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 28 of 120000: (0, 2, 1, 0, 2, 27), taking 0.35 seconds to get val score of -2.5448
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 29 of 120000: (0, 2, 1, 0, 2, 28), taking 0.36 seconds to get val score of -5.2848
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 63 of 120000: (0, 2, 1, 0, 2, 62), taking 1.39 seconds to get val score of -7.2585
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 64 of 120000: (0, 2, 1, 0, 2, 63), taking 1.23 seconds to get val score of -4.6534
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 65 of 120000: (0, 2, 1, 0, 2, 64), taking 1.23 seconds to get val score of -7.1357
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 66 of 120000: (0, 2, 1, 0, 2, 65), taking 0.59 seconds to get val score of -4.3671
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 67 of 120000: (0, 2, 1, 0, 2, 66), taking 0.61 seconds to get val score of -3.5652
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 68 of 120000: (0, 2, 1, 0, 2, 67), taking 0.67 seconds to get val score of -11.5406
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 69 of 120000: (0, 2, 1, 0, 2, 68), taking 0.65 seconds to get val score of -2.3994
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 70 of 120000: (0, 2, 1, 0, 2, 69), taking 0.56 seconds to get val score of -2.5417
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 71 of 120000: (0, 2, 1, 0, 2, 70), taking 0.6 seconds to get val score of -2.3332
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 72 of 120000: (0, 2, 1, 0, 2, 71), taking 0.68 seconds to get val score of -6.9623
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 73 of 120000: (0, 2, 1, 0, 2, 72), taking 0.58 seconds to get val score of -1.8707
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 74 of 120000: (0, 2, 1, 0, 2, 73), taking 0.67 seconds to get val score of -6.1211
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 75 of 120000: (0, 2, 1, 0, 2, 74), taking 0.74 seconds to get val score of -3.9493
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 76 of 120000: (0, 2, 1, 0, 2, 75), taking 0.62 seconds to get val score of -2.4157
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 77 of 120000: (0, 2, 1, 0, 2, 76), taking 0.61 seconds to get val score of -5.742
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 78 of 120000: (0, 2, 1, 0, 2, 77), taking 0.64 seconds to get val score of -6.5488
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 79 of 120000: (0, 2, 1, 0, 2, 78), taking 0.7 seconds to get val score of -7.3056
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 80 of 120000: (0, 2, 1, 0, 2, 79), taking 1.07 seconds to get val score of -2.8575
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 81 of 120000: (0, 2, 1, 0, 2, 80), taking 1.5 seconds to get val score of -8.2793
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# Trained and Tested combination 82 of 120000: (0, 2, 1, 0, 2, 81), taking 1.46 seconds to get val score of -2.5269
#         Current best combo: (0, 2, 1, 0, 2, 2) with val score -0.0224
# ...
# Already Trained and Tested combination (0, 2, 1, 0, 2, 150), which had val score of -10.8033
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 151), which had val score of -10.6506
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 152), which had val score of -4.4925
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 153), which had val score of -7.0217
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 154), which had val score of -15.6179
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 155), which had val score of -5.5687
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 156), which had val score of -10.3207
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 157), which had val score of -6.9821
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 158), which had val score of -5.8926
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 159), which had val score of -11.4458
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 160), which had val score of -10.2025
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 161), which had val score of -10.3573
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 162), which had val score of -8.8552
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 163), which had val score of -3.7939
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 164), which had val score of -15.4935
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 165), which had val score of -11.925
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 166), which had val score of -9.11
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 167), which had val score of -12.8142
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 168), which had val score of -12.3392
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 169), which had val score of -9.5594
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 170), which had val score of -8.6621
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 171), which had val score of -18.4679
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 172), which had val score of -21.0765
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 173), which had val score of -7.4609
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 174), which had val score of -4.4921
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 175), which had val score of -6.0254
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 176), which had val score of -8.0443
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 177), which had val score of -12.7335
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 178), which had val score of -11.2759
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 179), which had val score of -7.1911
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 180), which had val score of -3.5498
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 181), which had val score of -5.7309
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 182), which had val score of -4.6178
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 183), which had val score of -4.5641
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 184), which had val score of -3.0106
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 185), which had val score of -1.4046
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 186), which had val score of -7.5716
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 187), which had val score of -3.1547
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 188), which had val score of -0.6019
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 189), which had val score of -2.4537
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 190), which had val score of -7.5525
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 191), which had val score of -3.6459
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
#
# Best combo after this hyperparameter: (0, 2, 1, 0, 2, 8) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: activation (index: 3)
#
# Already Trained and Tested combination (0, 2, 1, 0, 2, 8), which had val score of 0.0026
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 1, 2, 8), which had val score of -1.0719
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
#
# Best combo after this hyperparameter: (0, 2, 1, 0, 2, 8) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: hidden_layer_n_neurons (index: 4)
#
# Already Trained and Tested combination (0, 2, 1, 0, 0, 8), which had val score of -0.4346
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 1, 8), which had val score of -0.1554
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 8), which had val score of 0.0026
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 3, 8), which had val score of -0.0149
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 4, 8), which had val score of -0.0221
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 5, 8), which had val score of -0.2929
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
#
# Best combo after this hyperparameter: (0, 2, 1, 0, 2, 8) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_hidden_layers (index: 0)
#
# Already Trained and Tested combination (0, 2, 1, 0, 2, 8), which had val score of 0.0026
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (1, 2, 1, 0, 2, 8), which had val score of -0.0355
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (2, 2, 1, 0, 2, 8), which had val score of -0.0384
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (3, 2, 1, 0, 2, 8), which had val score of -0.0708
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (4, 2, 1, 0, 2, 8), which had val score of -0.0035
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
#
# Best combo after this hyperparameter: (0, 2, 1, 0, 2, 8) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: alpha (index: 1)
#
# Already Trained and Tested combination (0, 0, 1, 0, 2, 8), which had val score of 0.0008
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 1, 1, 0, 2, 8), which had val score of 0.0008
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 8), which had val score of 0.0026
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 3, 1, 0, 2, 8), which had val score of -0.0
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 4, 1, 0, 2, 8), which had val score of -0.0157
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
#
# Best combo after this hyperparameter: (0, 2, 1, 0, 2, 8) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: learning_rate_init (index: 2)
#
# Already Trained and Tested combination (0, 2, 0, 0, 2, 8), which had val score of -0.5456
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 1, 0, 2, 8), which had val score of 0.0026
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 2, 0, 2, 8), which had val score of -0.089
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
# Already Trained and Tested combination (0, 2, 3, 0, 2, 8), which had val score of -0.015
#         Current best combo: (0, 2, 1, 0, 2, 8) with val score 0.0026.
#         Has trained 209 of 230400 combinations so far
#
# Best combo after this hyperparameter: (0, 2, 1, 0, 2, 8) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.0026206488379949544
# Max Test Score:
#  -0.040142
# Max Combo Index:
#  (0, 2, 1, 0, 2, 8) out of [5, 5, 4, 2, 6, 192] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_hidden_layers': 1, 'alpha': 0.0001, 'learning_rate_init': 0.001, 'activation': 'logistic', 'hidden_layer_n_neurons': 30, 'features': 8}
# Max Combo Features:
#  ('pos_closePrice_lag_1', 'mean_log_ret_lag_1', 'log_ret_lag_1', 'log_ret_normalised_by_day_lag_7', 'closePrice_slope_20', 'log_ret_lag_9', 'log_ret_normalised_by_day_lag_3', 'log_ret_lag_8', 'log_ret_normalised_by_day_lag_10')
# % Combos Checked: 209 out of 230400 which is 0.090712%
# Max Score:
#  0.0026206488379949544
# Max Test Score:
#  -0.040142
# Max Combo Index:
#  (0, 2, 1, 0, 2, 8) out of [5, 5, 4, 2, 6, 192] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_hidden_layers': 1, 'alpha': 0.0001, 'learning_rate_init': 0.001, 'activation': 'logistic', 'hidden_layer_n_neurons': 30, 'features': 8}
# Max Combo Features:
#  ('pos_closePrice_lag_1', 'mean_log_ret_lag_1', 'log_ret_lag_1', 'log_ret_normalised_by_day_lag_7', 'closePrice_slope_20', 'log_ret_lag_9', 'log_ret_normalised_by_day_lag_3', 'log_ret_lag_8', 'log_ret_normalised_by_day_lag_10')
# % Combos Checked: 209 out of 230400 which is 0.090712%
