# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os
import pickle
import pandas as pd
import json
import datetime
import time
import copy

py_file_location = './drive/My Drive/PrivatePackages'
sys.path.append(os.path.abspath(py_file_location))
from sklearn.model_selection import train_test_split

import JiaoCheng
import NingXiang

# %%
LABEL = 'trend'
MODEL = 'rfc'

# %%
curated_data = pd.read_csv('./drive/My Drive/LAB/Hackathon/data/curated_data.csv')
curated_data = curated_data.drop(columns=['closePrice', 'closePriceNorm', 'log_ret_normalised_by_day', 'log_ret', 'stock'])
curated_data['date'] = pd.to_datetime(curated_data['date'])

# %%
curated_data
# Out:
#             date  trend  closePrice_min_3  closePrice_max_3  closePrice_std_3  \
# 0     2022-12-31    NaN               NaN               NaN               NaN
# 1     2023-01-01   -1.0               NaN               NaN               NaN
# 2     2023-01-02   -1.0               NaN               NaN               NaN
# 3     2023-01-03   -1.0               NaN               NaN               NaN
# 4     2023-01-04   -1.0               NaN               NaN               NaN
# ...          ...    ...               ...               ...               ...
# 12495 2023-09-02   -1.0             43.11             43.66          0.248328
# 12496 2023-09-03    1.0             43.25             43.66          0.182635
# 12497 2023-09-04    1.0             43.02             43.61          0.242808
# 12498 2023-09-05   -1.0             43.02             43.25          0.106145
# 12499 2023-09-06    1.0             43.02             43.57          0.256948
#
#        closePrice_mean_3  closePrice_slope_3  closePrice_skew_3  \
# 0                    NaN                 NaN                NaN
# 1                    NaN                 NaN                NaN
# 2                    NaN                 NaN                NaN
# 3                    NaN                 NaN                NaN
# 4                    NaN                 NaN                NaN
# ...                  ...                 ...                ...
# 12495          43.460000            0.011598          -0.685668
# 12496          43.506667           -0.009391          -0.667566
# 12497          43.293333           -0.013529           0.262017
# 12498          43.100000           -0.005087           0.702403
# 12499          43.206667            0.012785           0.706304
#
#        closePrice_abs_diff_mean_3  closePrice_diff_std_3  ...  \
# 0                             NaN                    NaN  ...
# 1                             NaN                    NaN  ...
# 2                             NaN                    NaN  ...
# 3                             NaN                    NaN  ...
# 4                             NaN                    NaN  ...
# ...                           ...                    ...  ...
# 12495                       0.300                  0.300  ...
# 12496                       0.205                  0.155  ...
# 12497                       0.295                  0.065  ...
# 12498                       0.120                  0.120  ...
# 12499                       0.275                  0.265  ...
#
#        closePriceNorm_lag_10  log_ret_normalised_by_day_lag_10  \
# 0                        NaN                               NaN
# 1                        NaN                               NaN
# 2                        NaN                               NaN
# 3                        NaN                               NaN
# 4                        NaN                               NaN
# ...                      ...                               ...
# 12495              -0.136102                         -2.032099
# 12496              -0.539073                         -1.515743
# 12497              -0.377885                          0.765811
# 12498              -0.363231                          0.030813
# 12499              -0.326598                          0.102353
#
#        mean_log_ret_lag_1  mean_closePrice_lag_1  mean_closePriceNorm_lag_1  \
# 0                     NaN                    NaN                        NaN
# 1                     NaN                40.6170                   0.241356
# 2                0.000525                40.6472                   0.247020
# 3               -0.000065                40.6172                   0.231342
# 4               -0.000623                40.5886                   0.211599
# ...                   ...                    ...                        ...
# 12495           -0.002123                39.4416                  -0.655234
# 12496           -0.001491                39.3646                  -0.690649
# 12497           -0.001420                39.3096                  -0.716371
# 12498           -0.000048                39.2904                  -0.714126
# 12499           -0.000252                39.2810                  -0.713713
#
#        mean_log_ret_normalised_by_day_lag_1  pos_log_ret_lag_1  \
# 0                                       NaN                NaN
# 1                                       NaN                NaN
# 2                             -4.440892e-18           0.000569
# 3                             -8.881784e-18          -0.001615
# 4                              1.776357e-17          -0.000616
# ...                                     ...                ...
# 12495                          5.773160e-17          -0.003932
# 12496                          4.662937e-17          -0.001368
# 12497                          8.770762e-17          -0.004381
# 12498                         -1.776357e-17          -0.001478
# 12499                          3.552714e-17          -0.002505
#
#        pos_closePrice_lag_1  pos_closePriceNorm_lag_1  \
# 0                       NaN                       NaN
# 1                 33.787500                  0.529432
# 2                 33.838750                  0.535137
# 3                 33.735000                  0.482227
# 4                 33.710000                  0.455742
# ...                     ...                       ...
# 12495             35.979231                 -0.815362
# 12496             35.899231                 -0.860295
# 12497             35.692308                 -0.931225
# 12498             35.616923                 -0.974622
# 12499             35.506154                 -1.026466
#
#        pos_log_ret_normalised_by_day_lag_1
# 0                                      NaN
# 1                                      NaN
# 2                                 0.007178
# 3                                -0.229975
# 4                                 0.001161
# ...                                    ...
# 12495                            -0.320944
# 12496                             0.019382
# 12497                            -0.493615
# 12498                            -0.267420
# 12499                            -0.344069
#
# [12500 rows x 194 columns]

# %%
date = [datetime.datetime(year=2023, month=1, day = 1) + datetime.timedelta(days=i) for i in range(250)]
val_date_start = date[175]
test_date_start = date[175+38]

# %%
function_map = ['min', 'max', 'std', 'mean', 'slope', 'skew', 'abs_diff_mean', 'diff_std', 'sum']

for i in [3, 5, 10, 20]:
    print('Max Lag:', i)

    tmp_curated_data = copy.deepcopy(curated_data)

    for j in range(i+1, 11):
        tmp_curated_data = tmp_curated_data.drop(columns=[f'log_ret_lag_{j}', f'log_ret_normalised_by_day_lag_{j}', f'closePriceNorm_lag_{j}', f'closePrice_lag_{j}'], axis = 1)

    for j in [3, 5, 10, 20]:
        if j > i:

            columns = []
            for col in ['log_ret', 'closePrice', 'closePriceNorm', 'log_ret_normalised_by_day']:
                for func in function_map:
                    columns.append(f'{col}_{func}_{j}')
            tmp_curated_data = tmp_curated_data.drop(columns=columns, axis = 1)

    tmp_curated_data = tmp_curated_data.dropna()

    train = tmp_curated_data[(tmp_curated_data['date'] < val_date_start)]
    val = tmp_curated_data[(tmp_curated_data['date'] < test_date_start) & (tmp_curated_data['date'] >= val_date_start)]
    test = tmp_curated_data[(tmp_curated_data['date'] >= test_date_start)]

    jiaocheng = JiaoCheng.JiaoCheng()

    train_x = train.drop(columns=['date', 'trend'], axis = 1)
    train_y = train['trend']

    val_x = val.drop(columns=['date', 'trend'], axis = 1)
    val_y = val['trend']

    test_x = test.drop(columns=['date', 'trend'], axis = 1)
    test_y = test['trend']

    with open(f'./drive/My Drive/LAB/Hackathon/models/NingXiang_output_{LABEL}_lag_{i}.pickle', 'rb') as f:
        ningxiang_output = pickle.load(f)

    ningxiang_output = list(ningxiang_output.items())
    ningxiang_output = dict(ningxiang_output)

    jiaocheng = JiaoCheng.JiaoCheng()

    from sklearn.ensemble import RandomForestClassifier as RFC

    jiaocheng.read_in_model(RFC, 'Classification')

    jiaocheng.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

    del train_x
    del train_y
    del val_x
    del val_y

    parameter_choices = {
        'n_estimators': (25, 50, 100, 200, 400),
        'criterion': ('gini', 'entropy'),
        'max_features': (0.4, 0.55, 0.7, 0.85),
        'max_samples': (0.4, 0.55, 0.7, 0.85),
        'ccp_alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100)

    }

    jiaocheng.set_hyperparameters(parameter_choices)

    jiaocheng.set_non_tuneable_hyperparameters({'n_jobs': -1, 'random_state': 19260817})

    jiaocheng.set_features(ningxiang_output)

    jiaocheng.set_tuning_order(['features', 'criterion', 'max_features', 'max_samples', 'n_estimators', 'ccp_alpha'])

    jiaocheng.set_hyperparameter_default_values({
        'features': 0,
        'criterion': 'entropy',
        'max_features': 0.7,
        'max_samples': 0.7,
        'n_estimators': 50,
        'ccp_alpha': 0.01}
    )

    try:
        jiaocheng.read_in_tuning_result_df(f'./drive/My Drive/LAB/Hackathon/models/tuning/jiaocheng_{MODEL}_{LABEL}_lag_{i}.csv')
    except:
        pass

    jiaocheng.set_tuning_result_saving_address(f'./drive/My Drive/LAB/Hackathon/models/tuning/jiaocheng_{MODEL}_{LABEL}_lag_{i}.csv')
    jiaocheng.set_best_model_saving_address(f'./drive/My Drive/LAB/Hackathon/models/tmp_models/jiaocheng_{MODEL}_{LABEL}_lag_{i}.pickle')

    jiaocheng.tune()

    jiaocheng.view_best_combo_and_score()

    print('\n\n')
# Out:
# Max Lag: 3
# JiaoCheng Initialised
# JiaoCheng Initialised
# Successfully read in model <class 'sklearn.ensemble._forest.RandomForestClassifier'>, which is a Classification model
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# Successfully recorded hyperparameter choices
# Successfully recorded non_tuneable_hyperparameter choices
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# Successfully set tuning output address
# Successfully set best model output address
#
# Default combo: [1, 0, 2, 2, 2, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 5)
#
# Trained and Tested combination 1 of 62720: (1, 0, 2, 2, 2, 0), taking 0.31 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 2 of 62720: (1, 0, 2, 2, 2, 1), taking 1.17 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 3 of 62720: (1, 0, 2, 2, 2, 2), taking 2.52 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 4 of 62720: (1, 0, 2, 2, 2, 3), taking 1.9 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 5 of 62720: (1, 0, 2, 2, 2, 4), taking 1.65 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 6 of 62720: (1, 0, 2, 2, 2, 5), taking 2.19 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 7 of 62720: (1, 0, 2, 2, 2, 6), taking 1.95 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 8 of 62720: (1, 0, 2, 2, 2, 7), taking 2.31 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 9 of 62720: (1, 0, 2, 2, 2, 8), taking 5.24 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 10 of 62720: (1, 0, 2, 2, 2, 9), taking 2.98 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 11 of 62720: (1, 0, 2, 2, 2, 10), taking 3.01 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 12 of 62720: (1, 0, 2, 2, 2, 11), taking 3.39 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 13 of 62720: (1, 0, 2, 2, 2, 12), taking 5.82 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 14 of 62720: (1, 0, 2, 2, 2, 13), taking 3.77 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 15 of 62720: (1, 0, 2, 2, 2, 14), taking 4.08 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 16 of 62720: (1, 0, 2, 2, 2, 15), taking 6.75 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 17 of 62720: (1, 0, 2, 2, 2, 16), taking 4.92 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination
seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Already Trained and Tested combination (1, 0, 2, 2, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 59 of 62720 combinations so far
# Trained and Tested combination 60 of 62720: (1, 0, 3, 2, 2, 0), taking 0.45 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_samples (index: 3)
#
# Trained and Tested combination 61 of 62720: (1, 0, 2, 0, 2, 0), taking 0.38 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 62 of 62720: (1, 0, 2, 1, 2, 0), taking 0.43 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Already Trained and Tested combination (1, 0, 2, 2, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 62 of 62720 combinations so far
# Trained and Tested combination 63 of 62720: (1, 0, 2, 3, 2, 0), taking 0.51 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: n_estimators (index: 0)
#
# Trained and Tested combination 64 of 62720: (0, 0, 2, 2, 2, 0), taking 0.25 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Already Trained and Tested combination (1, 0, 2, 2, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 64 of 62720 combinations so far
# Trained and Tested combination 65 of 62720: (2, 0, 2, 2, 2, 0), taking 0.57 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 66 of 62720: (3, 0, 2, 2, 2, 0), taking 1.06 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 67 of 62720: (4, 0, 2, 2, 2, 0), taking 2.1 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: ccp_alpha (index: 4)
#
# Trained and Tested combination 68 of 62720: (1, 0, 2, 2, 0, 0), taking 0.3 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 69 of 62720: (1, 0, 2, 2, 1, 0), taking 0.28 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Already Trained and Tested combination (1, 0, 2, 2, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 69 of 62720 combinations so far
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 70 of 62720: (1, 0, 2, 2, 3, 0), taking 0.28 seconds to get val score of 0.5174
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 71 of 62720: (1, 0, 2, 2, 4, 0), taking 0.28 seconds to get val score of 0.5174
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 72 of 62720: (1, 0, 2, 2, 5, 0), taking 0.31 seconds to get val score of 0.5174
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 73 of 62720: (1, 0, 2, 2, 6, 0), taking 0.27 seconds to get val score of 0.5174
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 2
# Hyperparameter: features (index: 5)
#
# Already Trained and Tested combination (1, 0, 2, 2, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 1), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 2), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 3), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 4), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 5), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 6), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 7), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 8), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 9), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 10), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 11), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 12), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 13), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 14), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 15), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 16), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 17), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 18), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 19), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 20), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 21), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 22), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 23), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 24), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 25), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 26), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 27), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 28), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 29), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 30), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 31), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 32), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 33), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 34), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 35), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 36), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 37), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 38), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 39), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 40), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 41), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 42), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 43), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 44), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 45), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 46), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 47), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 48), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 49), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 50), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 51), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 52), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 53), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 54), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 55), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: criterion (index: 1)
#
# Already Trained and Tested combination (1, 0, 2, 2, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_features (index: 2)
#
# Already Trained and Tested combination (1, 0, 0, 2, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 1, 2, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 3, 2, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_samples (index: 3)
#
# Already Trained and Tested combination (1, 0, 2, 0, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 0, 2, 2, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (2, 0, 2, 2, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (3, 0, 2, 2, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (4, 0, 2, 2, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: ccp_alpha (index: 4)
#
# Already Trained and Tested combination (1, 0, 2, 2, 0, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 1, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 0), which had val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 3, 0), which had val score of 0.5174
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 0), which had val score of 0.5174
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 5, 0), which had val score of 0.5174
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 6, 0), which had val score of 0.5174
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521.
#         Has trained 73 of 62720 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.5521052631578948
# Max Test Score:
#  0.542778
# Max Combo Index:
#  (1, 0, 2, 2, 2, 0) out of [5, 2, 4, 4, 7, 56] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 50, 'criterion': 'entropy', 'max_features': 0.7, 'max_samples': 0.7, 'ccp_alpha': 0.01, 'features': 0}
# Max Combo Features:
#  ('mean_log_ret_lag_1',)
# % Combos Checked: 73 out of 62720 which is 0.11639000000000001%
# Max Score:
#  0.5521052631578948
# Max Test Score:
#  0.542778
# Max Combo Index:
#  (1, 0, 2, 2, 2, 0) out of [5, 2, 4, 4, 7, 56] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 50, 'criterion': 'entropy', 'max_features': 0.7, 'max_samples': 0.7, 'ccp_alpha': 0.01, 'features': 0}
# Max Combo Features:
#  ('mean_log_ret_lag_1',)
# % Combos Checked: 73 out of 62720 which is 0.11639000000000001%
#
#
#
# Max Lag: 5
# JiaoCheng Initialised
# JiaoCheng Initialised
# Successfully read in model <class 'sklearn.ensemble._forest.RandomForestClassifier'>, which is a Classification model
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# Successfully recorded hyperparameter choices
# Successfully recorded non_tuneable_hyperparameter choices
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# Successfully set tuning output address
# Successfully set best model output address
#
# Default combo: [1, 0, 2, 2, 2, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 5)
#
# Trained and Tested combination 1 of 112000: (1, 0, 2, 2, 2, 0), taking 0.28 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 2 of 112000: (1, 0, 2, 2, 2, 1), taking 1.07 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 3 of 112000: (1, 0, 2, 2, 2, 2), taking 2.41 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 4 of 112000: (1, 0, 2, 2, 2, 3), taking 2.02 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 5 of 112000: (1, 0, 2, 2, 2, 4), taking 1.6 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 6 of 112000: (1, 0, 2, 2, 2, 5), taking 1.93 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 7 of 112000: (1, 0, 2, 2, 2, 6), taking 1.9 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 8 of 112000: (1, 0, 2, 2, 2, 7), taking 2.3 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 9 of 112000: (1, 0, 2, 2, 2, 8), taking 4.16 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 10 of 112000: (1, 0, 2, 2, 2, 9), taking 3.81 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 11 of 112000: (1, 0, 2, 2, 2, 10), taking 3.06 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 12 of 112000: (1, 0, 2, 2, 2, 11), taking 3.55 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 13 of 112000: (1, 0, 2, 2, 2, 12), taking 7.26 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 14 of 112000: (1, 0, 2, 2, 2, 13), taking 4.93 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 15 of 112000: (1, 0, 2, 2, 2, 14), taking 5.27 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 16 of 112000: (1, 0, 2, 2, 2, 15), taking 5.71 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 17 of 112000: (1, 0, 2, 2, 2, 16), taking 4.65 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 18 of 112000: (1, 0, 2, 2, 2, 17), taking 7.18 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 19 of 112000: (1, 0, 2, 2, 2, 18), taking 5.4 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 20 of 112000: (1, 0, 2, 2, 2, 19), taking 7.8 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 21 of 112000: (1, 0, 2, 2, 2, 20), taking 5.91 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 22 of 112000: (1, 0, 2, 2, 2, 21), taking 7.72 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 23 of 112000: (1, 0, 2, 2, 2, 22), taking 6.81 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 24 of 112000: (1, 0, 2, 2, 2, 23), taking 8.43 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 25 of 112000: (1, 0, 2, 2, 2, 24), taking 6.82 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 26 of 112000: (1, 0, 2, 2, 2, 25), taking 9.42 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 27 of 112000: (1, 0, 2, 2, 2, 26), taking 6.91 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination 28 of 112000: (1, 0, 2, 2, 2, 27), taking 9.73 seconds to get val score of 0.5521
#         Current best combo: (1, 0, 2, 2, 2, 0) with val score 0.5521
# Trained and Tested combination
seconds to get val score of 0.5516
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 303 of 215040: (0, 0, 2, 2, 2, 94), taking 12.08 seconds to get val score of 0.5579
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 304 of 215040: (0, 0, 2, 2, 2, 95), taking 12.27 seconds to get val score of 0.5505
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 305 of 215040: (0, 0, 2, 2, 2, 96), taking 12.16 seconds to get val score of 0.5579
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 306 of 215040: (0, 0, 2, 2, 2, 97), taking 12.6 seconds to get val score of 0.5521
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 307 of 215040: (0, 0, 2, 2, 2, 98), taking 14.09 seconds to get val score of 0.5521
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 308 of 215040: (0, 0, 2, 2, 2, 99), taking 12.49 seconds to get val score of 0.5563
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 309 of 215040: (0, 0, 2, 2, 2, 100), taking 12.49 seconds to get val score of 0.5574
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 310 of 215040: (0, 0, 2, 2, 2, 101), taking 11.23 seconds to get val score of 0.5579
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 311 of 215040: (0, 0, 2, 2, 2, 102), taking 12.6 seconds to get val score of 0.5595
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 312 of 215040: (0, 0, 2, 2, 2, 103), taking 12.7 seconds to get val score of 0.5579
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 313 of 215040: (0, 0, 2, 2, 2, 104), taking 13.2 seconds to get val score of 0.5574
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 314 of 215040: (0, 0, 2, 2, 2, 105), taking 13.71 seconds to get val score of 0.5579
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 315 of 215040: (0, 0, 2, 2, 2, 106), taking 13.6 seconds to get val score of 0.5574
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 316 of 215040: (0, 0, 2, 2, 2, 107), taking 13.45 seconds to get val score of 0.5521
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 317 of 215040: (0, 0, 2, 2, 2, 108), taking 13.86 seconds to get val score of 0.5511
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 318 of 215040: (0, 0, 2, 2, 2, 109), taking 13.87 seconds to get val score of 0.5521
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 319 of 215040: (0, 0, 2, 2, 2, 110), taking 16.01 seconds to get val score of 0.5521
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 320 of 215040: (0, 0, 2, 2, 2, 111), taking 14.15 seconds to get val score of 0.5505
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 321 of 215040: (0, 0, 2, 2, 2, 112), taking 14.41 seconds to get val score of 0.5568
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 322 of 215040: (0, 0, 2, 2, 2, 113), taking 14.15 seconds to get val score of 0.5547
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 323 of 215040: (0, 0, 2, 2, 2, 114), taking 14.58 seconds to get val score of 0.5542
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 324 of 215040: (0, 0, 2, 2, 2, 115), taking 14.79 seconds to get val score of 0.5542
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 325 of 215040: (0, 0, 2, 2, 2, 116), taking 15.16 seconds to get val score of 0.5558
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 326 of 215040: (0, 0, 2, 2, 2, 117), taking 14.67 seconds to get val score of 0.5521
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 327 of 215040: (0, 0, 2, 2, 2, 118), taking 14.59 seconds to get val score of 0.5563
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 328 of 215040: (0, 0, 2, 2, 2, 119), taking 15.15 seconds to get val score of 0.5584
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 329 of 215040: (0, 0, 2, 2, 2, 120), taking 16.66 seconds to get val score of 0.5579
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 330 of 215040: (0, 0, 2, 2, 2, 121), taking 15.01 seconds to get val score of 0.5505
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 331 of 215040: (0, 0, 2, 2, 2, 122), taking 15.14 seconds to get val score of 0.5579
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 332 of 215040: (0, 0, 2, 2, 2, 123), taking 15.79 seconds to get val score of 0.5542
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 333 of 215040: (0, 0, 2, 2, 2, 124), taking 16.26 seconds to get val score of 0.5579
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 334 of 215040: (0, 0, 2, 2, 2, 125), taking 15.67 seconds to get val score of 0.5516
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 335 of 215040: (0, 0, 2, 2, 2, 126), taking 15.6 seconds to get val score of 0.5521
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 336 of 215040: (0, 0, 2, 2, 2, 127), taking 16.06 seconds to get val score of 0.5579
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 337 of 215040: (0, 0, 2, 2, 2, 128), taking 15.63 seconds to get val score of 0.5516
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 338 of 215040: (0, 0, 2, 2, 2, 129), taking 17.03 seconds to get val score of 0.5558
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 339 of 215040: (0, 0, 2, 2, 2, 130), taking 18.06 seconds to get val score of 0.5537
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 340 of 215040: (0, 0, 2, 2, 2, 131), taking 16.01 seconds to get val score of 0.5568
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 341 of 215040: (0, 0, 2, 2, 2, 132), taking 16.58 seconds to get val score of 0.5521
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 342 of 215040: (0, 0, 2, 2, 2, 133), taking 16.91 seconds to get val score of 0.5568
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 343 of 215040: (0, 0, 2, 2, 2, 134), taking 17.12 seconds to get val score of 0.5526
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 344 of 215040: (0, 0, 2, 2, 2, 135), taking 16.95 seconds to get val score of 0.5521
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 345 of 215040: (0, 0, 2, 2, 2, 136), taking 16.81 seconds to get val score of 0.5521
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 346 of 215040: (0, 0, 2, 2, 2, 137), taking 18.12 seconds to get val score of 0.5516
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 347 of 215040: (0, 0, 2, 2, 2, 138), taking 17.44 seconds to get val score of 0.5589
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 348 of 215040: (0, 0, 2, 2, 2, 139), taking 18.58 seconds to get val score of 0.5568
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 349 of 215040: (0, 0, 2, 2, 2, 140), taking 17.17 seconds to get val score of 0.5521
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 350 of 215040: (0, 0, 2, 2, 2, 141), taking 18.85 seconds to get val score of 0.5542
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 351 of 215040: (0, 0, 2, 2, 2, 142), taking 17.51 seconds to get val score of 0.5537
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 352 of 215040: (0, 0, 2, 2, 2, 143), taking 17.55 seconds to get val score of 0.5574
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 353 of 215040: (0, 0, 2, 2, 2, 144), taking 19.4 seconds to get val score of 0.5521
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 354 of 215040: (0, 0, 2, 2, 2, 145), taking 17.91 seconds to get val score of 0.5584
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 355 of 215040: (0, 0, 2, 2, 2, 146), taking 17.79 seconds to get val score of 0.5553
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 356 of 215040: (0, 0, 2, 2, 2, 147), taking 19.15 seconds to get val score of 0.5579
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 357 of 215040: (0, 0, 2, 2, 2, 148), taking 19.89 seconds to get val score of 0.5542
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 358 of 215040: (0, 0, 2, 2, 2, 149), taking 19.66 seconds to get val score of 0.5521
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 359 of 215040: (0, 0, 2, 2, 2, 150), taking 18.3 seconds to get val score of 0.5521
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 360 of 215040: (0, 0, 2, 2, 2, 151), taking 18.69 seconds to get val score of 0.5521
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 361 of 215040: (0, 0, 2, 2, 2, 152), taking 19.93 seconds to get val score of 0.5521
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 362 of 215040: (0, 0, 2, 2, 2, 153), taking 18.77 seconds to get val score of 0.5537
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 363 of 215040: (0, 0, 2, 2, 2, 154), taking 20.6 seconds to get val score of 0.5584
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 364 of 215040: (0, 0, 2, 2, 2, 155), taking 19.16 seconds to get val score of 0.5521
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 365 of 215040: (0, 0, 2, 2, 2, 156), taking 22.39 seconds to get val score of 0.5574
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 366 of 215040: (0, 0, 2, 2, 2, 157), taking 18.93 seconds to get val score of 0.5568
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 367 of 215040: (0, 0, 2, 2, 2, 158), taking 20.76 seconds to get val score of 0.5458
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 368 of 215040: (0, 0, 2, 2, 2, 159), taking 19.41 seconds to get val score of 0.5521
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 369 of 215040: (0, 0, 2, 2, 2, 160), taking 19.77 seconds to get val score of 0.5516
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 370 of 215040: (0, 0, 2, 2, 2, 161), taking 20.52 seconds to get val score of 0.5584
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 371 of 215040: (0, 0, 2, 2, 2, 162), taking 20.76 seconds to get val score of 0.5521
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 372 of 215040: (0, 0, 2, 2, 2, 163), taking 20.47 seconds to get val score of 0.5516
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
# Trained and Tested combination 373 of 215040: (0, 0, 2, 2, 2, 164), taking 23.03 seconds to get val score of 0.5558
#         Current best combo: (0, 0, 2, 2, 2, 92) with val score 0.5595
