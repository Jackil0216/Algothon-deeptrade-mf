# %%
import sys
import os
import pickle
import pandas as pd
import json
import datetime
import time
import copy

py_file_location = '../PrivatePackages'
sys.path.append(os.path.abspath(py_file_location))
from sklearn.model_selection import train_test_split

import JiaoCheng
import NingXiang
# Out:
# /Applications/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
LABEL = 'logret'
MODEL = 'lgbr'

# %%
curated_data = pd.read_csv('../data/curated_data.csv')
curated_data = curated_data.drop(columns=['closePrice', 'closePriceNorm', 'log_ret_normalised_by_day', 'trend', 'stock'])
curated_data['date'] = pd.to_datetime(curated_data['date'])

# %%
date = [datetime.datetime(year=2022, month=12, day = 31) + datetime.timedelta(days=i) for i in range(250)]
val_date_start = date[175]
test_date_start = date[175+38]

# %%
function_map = ['min', 'max', 'std', 'mean', 'slope', 'skew', 'abs_diff_mean', 'diff_std', 'sum']

for i in [3, 5, 10, 20]:
    print('Max Lag:', i)

    tmp_curated_data = copy.deepcopy(curated_data)

    for j in range(i+1, 11):
        tmp_curated_data = tmp_curated_data.drop(columns=[f'log_ret_lag_{j}', f'log_ret_normalised_by_day_lag_{j}', f'closePriceNorm_lag_{j}', f'closePrice_lag_{j}'], axis = 1)
    
    for j in [3, 5, 10, 20]:
        if j > i:

            columns = []
            for col in ['log_ret', 'closePrice', 'closePriceNorm', 'log_ret_normalised_by_day']:
                for func in function_map:
                    columns.append(f'{col}_{func}_{j}')
            tmp_curated_data = tmp_curated_data.drop(columns=columns, axis = 1)

    tmp_curated_data = tmp_curated_data.dropna()

    train = tmp_curated_data[(tmp_curated_data['date'] < val_date_start)]
    val = tmp_curated_data[(tmp_curated_data['date'] < test_date_start) & (tmp_curated_data['date'] >= val_date_start)]

    ningxiang = NingXiang.NingXiang()

    train_x = train.drop(columns=['date', 'log_ret'], axis = 1)
    train_y = train['log_ret']

    val_x = val.drop(columns=['date', 'log_ret'], axis = 1)
    val_y = val['log_ret']

    ningxiang.read_in_train_data(train_x, train_y, val_x, val_y)

    ningxiang.set_model_type('Regression')

    ningxiang_output = ningxiang.get_rf_based_feature_combinations(1, 1, 4)

    ningxiang.export_ningxiang_output(f'../models/NingXiang_output_{LABEL}_lag_{i}')

    ningxiang.show_rf_stats()

    print('\n\n')
# Out:
# Max Lag: 3
# NingXiang Initialised
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Successfully recorded model type: Regression
# Begin fitting Random Forest
# Finished fitting Random Forest
# Successfully set object output address
# {'closePrice_min_3': 0.005606871160625016, 'closePrice_max_3': 0.005198706811675745, 'closePrice_std_3': 0.01762519867950607, 'closePrice_mean_3': 0.004119157727910326, 'closePrice_slope_3': 0.019403295297214344, 'closePrice_skew_3': 0.012516354825811033, 'closePrice_abs_diff_mean_3': 0.014439868468186883, 'closePrice_diff_std_3': 0.019118825120766802, 'closePrice_sum_3': 0.0045711147261671544, 'log_ret_min_3': 0.018955608653840397, 'log_ret_max_3': 0.018781558150264326, 'log_ret_std_3': 0.022083740372631337, 'log_ret_mean_3': 0.012385475430004136, 'log_ret_slope_3': 0.021849100623930525, 'log_ret_skew_3': 0.017296117124976935, 'log_ret_abs_diff_mean_3': 0.01657531658598125, 'log_ret_diff_std_3': 0.018808305465449406, 'log_ret_sum_3': 0.013312747877014754, 'closePriceNorm_min_3': 0.013117890939675025, 'closePriceNorm_max_3': 0.01539123096798315, 'closePriceNorm_std_3': 0.019089942794103767, 'closePriceNorm_mean_3': 0.009586410667632965, 'closePriceNorm_slope_3': 0.019505637191582794, 'closePriceNorm_skew_3': 0.013360247262569467, 'closePriceNorm_abs_diff_mean_3': 0.014055669812032535, 'closePriceNorm_diff_std_3': 0.015165656927750211, 'closePriceNorm_sum_3': 0.009740302813644564, 'log_ret_normalised_by_day_min_3': 0.01929464948641237, 'log_ret_normalised_by_day_max_3': 0.014124818414404156, 'log_ret_normalised_by_day_std_3': 0.019284374800755434, 'log_ret_normalised_by_day_mean_3': 0.013006652319389083, 'log_ret_normalised_by_day_slope_3': 0.01849674217979532, 'log_ret_normalised_by_day_skew_3': 0.016422459299722133, 'log_ret_normalised_by_day_abs_diff_mean_3': 0.018718478049110383, 'log_ret_normalised_by_day_diff_std_3': 0.019757902982192727, 'log_ret_normalised_by_day_sum_3': 0.012625013119949896, 'log_ret_lag_1': 0.033587072661355945, 'closePrice_lag_1': 0.008962812497216545, 'closePriceNorm_lag_1': 0.024737965565567496, 'log_ret_normalised_by_day_lag_1': 0.03427737549251467, 'log_ret_lag_2': 0.020637483817405582, 'closePrice_lag_2': 0.005393695990538353, 'closePriceNorm_lag_2': 0.016108360411335308, 'log_ret_normalised_by_day_lag_2': 0.024082869769187526, 'log_ret_lag_3': 0.02349086568583518, 'closePrice_lag_3': 0.006234394393569105, 'closePriceNorm_lag_3': 0.01787797639310277, 'log_ret_normalised_by_day_lag_3': 0.02354269356353647, 'mean_log_ret_lag_1': 0.04259295904217974, 'mean_closePrice_lag_1': 0.014324569305715565, 'mean_closePriceNorm_lag_1': 0.016605418286301632, 'mean_log_ret_normalised_by_day_lag_1': 0.0, 'pos_log_ret_lag_1': 0.023986176284421713, 'pos_closePrice_lag_1': 0.06367826917600454, 'pos_closePriceNorm_lag_1': 0.027533193330703636, 'pos_log_ret_normalised_by_day_lag_1': 0.028954405202845833}
# Validation score: 0.004747797097055195
#
#
#
# Max Lag: 5
# NingXiang Initialised
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Successfully recorded model type: Regression
# Begin fitting Random Forest
# Finished fitting Random Forest
# Successfully set object output address
# {'closePrice_min_3': 0.0021854689997852137, 'closePrice_max_3': 0.0013204333101236967, 'closePrice_std_3': 0.009865539279670056, 'closePrice_mean_3': 0.0012941055723615733, 'closePrice_slope_3': 0.010303036225284385, 'closePrice_skew_3': 0.00777398528604036, 'closePrice_abs_diff_mean_3': 0.007529932533055299, 'closePrice_diff_std_3': 0.011900220477372674, 'closePrice_sum_3': 0.002050080150850918, 'log_ret_min_3': 0.008424763466437899, 'log_ret_max_3': 0.00906998444218509, 'log_ret_std_3': 0.010248209185373516, 'log_ret_mean_3': 0.006327091929558932, 'log_ret_slope_3': 0.011432844353387143, 'log_ret_skew_3': 0.010709341567506804, 'log_ret_abs_diff_mean_3': 0.009023377809850816, 'log_ret_diff_std_3': 0.01257371010791126, 'log_ret_sum_3': 0.005723907795307308, 'closePriceNorm_min_3': 0.006057565765415033, 'closePriceNorm_max_3': 0.006288208482863055, 'closePriceNorm_std_3': 0.008909116477499415, 'closePriceNorm_mean_3': 0.004159076686253259, 'closePriceNorm_slope_3': 0.014378848577740815, 'closePriceNorm_skew_3': 0.007864254792616343, 'closePriceNorm_abs_diff_mean_3': 0.007893597035762973, 'closePriceNorm_diff_std_3': 0.010478152529572233, 'closePriceNorm_sum_3': 0.003915621324015938, 'log_ret_normalised_by_day_min_3': 0.00739845490146154, 'log_ret_normalised_by_day_max_3': 0.0073769160541593305, 'log_ret_normalised_by_day_std_3': 0.01292908247794196, 'log_ret_normalised_by_day_mean_3': 0.008051177062733825, 'log_ret_normalised_by_day_slope_3': 0.012261321560174605, 'log_ret_normalised_by_day_skew_3': 0.010937823447060659, 'log_ret_normalised_by_day_abs_diff_mean_3': 0.010699493538648299, 'log_ret_normalised_by_day_diff_std_3': 0.012789716194796179, 'log_ret_normalised_by_day_sum_3': 0.007677581906274224, 'closePrice_min_5': 0.001820802409765736, 'closePrice_max_5': 0.001887234964139463, 'closePrice_std_5': 0.012240913484393608, 'closePrice_mean_5': 0.0015835902048465225, 'closePrice_slope_5': 0.01205211244857235, 'closePrice_skew_5': 0.00868793290562384, 'closePrice_abs_diff_mean_5': 0.00970707173629914, 'closePrice_diff_std_5': 0.011474656951044824, 'closePrice_sum_5': 0.001567216746877077, 'log_ret_min_5': 0.009920183109807005, 'log_ret_max_5': 0.012978623245278107, 'log_ret_std_5': 0.011882725643772676, 'log_ret_mean_5': 0.007689100401645162, 'log_ret_slope_5': 0.0159968931188717, 'log_ret_skew_5': 0.010873181095792859, 'log_ret_abs_diff_mean_5': 0.009344906865670646, 'log_ret_diff_std_5': 0.011141398878926756, 'log_ret_sum_5': 0.007966413336826976, 'closePriceNorm_min_5': 0.008419845243474383, 'closePriceNorm_max_5': 0.009249686645988549, 'closePriceNorm_std_5': 0.013162527103659984, 'closePriceNorm_mean_5': 0.003818988133902924, 'closePriceNorm_slope_5': 0.012786601879765838, 'closePriceNorm_skew_5': 0.0077296034230771695, 'closePriceNorm_abs_diff_mean_5': 0.009899891997683095, 'closePriceNorm_diff_std_5': 0.010104732377930145, 'closePriceNorm_sum_5': 0.0034501506578321307, 'log_ret_normalised_by_day_min_5': 0.009913315108437282, 'log_ret_normalised_by_day_max_5': 0.012684896627923783, 'log_ret_normalised_by_day_std_5': 0.01340433550387999, 'log_ret_normalised_by_day_mean_5': 0.008702007638336421, 'log_ret_normalised_by_day_slope_5': 0.01255543842306029, 'log_ret_normalised_by_day_skew_5': 0.012986205543526837, 'log_ret_normalised_by_day_abs_diff_mean_5': 0.009387928389668277, 'log_ret_normalised_by_day_diff_std_5': 0.009513122437133155, 'log_ret_normalised_by_day_sum_5': 0.00993558086558814, 'log_ret_lag_1': 0.022854061438335196, 'closePrice_lag_1': 0.004212576718890509, 'closePriceNorm_lag_1': 0.013855881278500596, 'log_ret_normalised_by_day_lag_1': 0.021927728332920803, 'log_ret_lag_2': 0.011468820079068576, 'closePrice_lag_2': 0.003030427453268665, 'closePriceNorm_lag_2': 0.008128829382450794, 'log_ret_normalised_by_day_lag_2': 0.014988935497440318, 'log_ret_lag_3': 0.015061456345760884, 'closePrice_lag_3': 0.001857063518415875, 'closePriceNorm_lag_3': 0.01154473547485156, 'log_ret_normalised_by_day_lag_3': 0.0154476433 ...
# Validation score: 0.010879574409273007
#
#
#
# Max Lag: 10
# NingXiang Initialised
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Successfully recorded model type: Regression
# Begin fitting Random Forest
# Finished fitting Random Forest
# Successfully set object output address
# {'closePrice_min_3': 0.0006180329300897368, 'closePrice_max_3': 0.00129074505744708, 'closePrice_std_3': 0.005164229997735678, 'closePrice_mean_3': 0.000773817234113465, 'closePrice_slope_3': 0.008043291249656366, 'closePrice_skew_3': 0.004599038492383065, 'closePrice_abs_diff_mean_3': 0.004704235798772797, 'closePrice_diff_std_3': 0.008328159721804597, 'closePrice_sum_3': 0.0005314353655107365, 'log_ret_min_3': 0.007207550619094704, 'log_ret_max_3': 0.0049804279391930245, 'log_ret_std_3': 0.0060629870774512, 'log_ret_mean_3': 0.004556624892138382, 'log_ret_slope_3': 0.008637525470104155, 'log_ret_skew_3': 0.007729037055154796, 'log_ret_abs_diff_mean_3': 0.006174379066410827, 'log_ret_diff_std_3': 0.00735529995080295, 'log_ret_sum_3': 0.004346886781636882, 'closePriceNorm_min_3': 0.004470255511357503, 'closePriceNorm_max_3': 0.00286822087086882, 'closePriceNorm_std_3': 0.006009750093668396, 'closePriceNorm_mean_3': 0.002274820464413992, 'closePriceNorm_slope_3': 0.00968573653364345, 'closePriceNorm_skew_3': 0.004820453367554389, 'closePriceNorm_abs_diff_mean_3': 0.004606789510675012, 'closePriceNorm_diff_std_3': 0.007843667299098488, 'closePriceNorm_sum_3': 0.0017511443429169282, 'log_ret_normalised_by_day_min_3': 0.006006177783551603, 'log_ret_normalised_by_day_max_3': 0.004386721799982408, 'log_ret_normalised_by_day_std_3': 0.006630322610679483, 'log_ret_normalised_by_day_mean_3': 0.0041947190545264385, 'log_ret_normalised_by_day_slope_3': 0.008917255028758227, 'log_ret_normalised_by_day_skew_3': 0.007549218622235779, 'log_ret_normalised_by_day_abs_diff_mean_3': 0.006373374438492747, 'log_ret_normalised_by_day_diff_std_3': 0.007793939181995819, 'log_ret_normalised_by_day_sum_3': 0.005588359113315366, 'closePrice_min_5': 0.000687463334454819, 'closePrice_max_5': 0.0005878764560841265, 'closePrice_std_5': 0.007256065988502029, 'closePrice_mean_5': 0.0005847991364569843, 'closePrice_slope_5': 0.00643217156087207, 'closePrice_skew_5': 0.005859388200819013, 'closePrice_abs_diff_mean_5': 0.004549644981805914, 'closePrice_diff_std_5': 0.007414705766952548, 'closePrice_sum_5': 0.0007421028662946344, 'log_ret_min_5': 0.006358540835622631, 'log_ret_max_5': 0.004385279753440264, 'log_ret_std_5': 0.007152580828783381, 'log_ret_mean_5': 0.00428141471967538, 'log_ret_slope_5': 0.009075512950333698, 'log_ret_skew_5': 0.005540391734902012, 'log_ret_abs_diff_mean_5': 0.005343363054903648, 'log_ret_diff_std_5': 0.005759211688749976, 'log_ret_sum_5': 0.004046716496720547, 'closePriceNorm_min_5': 0.0032121577241385904, 'closePriceNorm_max_5': 0.002638023251911693, 'closePriceNorm_std_5': 0.009154899579357192, 'closePriceNorm_mean_5': 0.0015566140330700825, 'closePriceNorm_slope_5': 0.007518841823153282, 'closePriceNorm_skew_5': 0.0054258157498308065, 'closePriceNorm_abs_diff_mean_5': 0.005548128952103622, 'closePriceNorm_diff_std_5': 0.006381270867980457, 'closePriceNorm_sum_5': 0.0019299110827520106, 'log_ret_normalised_by_day_min_5': 0.005528162255667574, 'log_ret_normalised_by_day_max_5': 0.0047000034326460756, 'log_ret_normalised_by_day_std_5': 0.006940156371003799, 'log_ret_normalised_by_day_mean_5': 0.005346098415497142, 'log_ret_normalised_by_day_slope_5': 0.0072216988897540425, 'log_ret_normalised_by_day_skew_5': 0.006563026346147627, 'log_ret_normalised_by_day_abs_diff_mean_5': 0.00623197033936388, 'log_ret_normalised_by_day_diff_std_5': 0.006788978407427848, 'log_ret_normalised_by_day_sum_5': 0.004604139098289433, 'closePrice_min_10': 0.0009572789867298467, 'closePrice_max_10': 0.0011106136761301682, 'closePrice_std_10': 0.009460656801013557, 'closePrice_mean_10': 0.000612640045953208, 'closePrice_slope_10': 0.01436815570395108, 'closePrice_skew_10': 0.004990001481996418, 'closePrice_abs_diff_mean_10': 0.0067611219254767995, 'closePrice_diff_std_10': 0.005986213386451917, 'closePrice_sum_10': 0.0007656865428413421, 'log_ret_min_10': 0.0072251138152263725, 'log_ret_max_10': 0.006746893807156397, 'log_ret_std_10': 0.0073371202746759555, ...
# Validation score: 0.011886139290877007
#
#
#
# Max Lag: 20
# NingXiang Initialised
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Successfully recorded model type: Regression
# Begin fitting Random Forest
# Finished fitting Random Forest
# Successfully set object output address
# {'closePrice_min_3': 0.0004568325285627399, 'closePrice_max_3': 0.0007510579291530422, 'closePrice_std_3': 0.005468589792391296, 'closePrice_mean_3': 0.001053317252665354, 'closePrice_slope_3': 0.007380794673447672, 'closePrice_skew_3': 0.004082879339640214, 'closePrice_abs_diff_mean_3': 0.003220612928714303, 'closePrice_diff_std_3': 0.005195685378175258, 'closePrice_sum_3': 0.000544165806058822, 'log_ret_min_3': 0.0063375524203702375, 'log_ret_max_3': 0.004456479201207032, 'log_ret_std_3': 0.004738849679412334, 'log_ret_mean_3': 0.003965827007529592, 'log_ret_slope_3': 0.008395812593554491, 'log_ret_skew_3': 0.007240457480801376, 'log_ret_abs_diff_mean_3': 0.005890955711467514, 'log_ret_diff_std_3': 0.007117893435671568, 'log_ret_sum_3': 0.0032141379117215534, 'closePriceNorm_min_3': 0.0022321665576672985, 'closePriceNorm_max_3': 0.0025968018844963327, 'closePriceNorm_std_3': 0.004883169367895996, 'closePriceNorm_mean_3': 0.001258854591183192, 'closePriceNorm_slope_3': 0.007922059941912885, 'closePriceNorm_skew_3': 0.004319412386356596, 'closePriceNorm_abs_diff_mean_3': 0.0030196357198020813, 'closePriceNorm_diff_std_3': 0.0049917443062567, 'closePriceNorm_sum_3': 0.0016082144139203775, 'log_ret_normalised_by_day_min_3': 0.005593020680922686, 'log_ret_normalised_by_day_max_3': 0.0037235346221151985, 'log_ret_normalised_by_day_std_3': 0.004839116956323854, 'log_ret_normalised_by_day_mean_3': 0.00450643443934925, 'log_ret_normalised_by_day_slope_3': 0.0072760911236194985, 'log_ret_normalised_by_day_skew_3': 0.004651104909132691, 'log_ret_normalised_by_day_abs_diff_mean_3': 0.005663850249936945, 'log_ret_normalised_by_day_diff_std_3': 0.008530277715525504, 'log_ret_normalised_by_day_sum_3': 0.004018658491866358, 'closePrice_min_5': 0.0009427708474869266, 'closePrice_max_5': 0.0005455119864870405, 'closePrice_std_5': 0.006207157277514244, 'closePrice_mean_5': 0.0007394049135389709, 'closePrice_slope_5': 0.005062053783922303, 'closePrice_skew_5': 0.004977229440333133, 'closePrice_abs_diff_mean_5': 0.003837977358000411, 'closePrice_diff_std_5': 0.005883213589095361, 'closePrice_sum_5': 0.0003357560382862011, 'log_ret_min_5': 0.006099261121550476, 'log_ret_max_5': 0.003168809306005216, 'log_ret_std_5': 0.005376379602940118, 'log_ret_mean_5': 0.0026877881610165755, 'log_ret_slope_5': 0.009643289131832062, 'log_ret_skew_5': 0.004745670527496624, 'log_ret_abs_diff_mean_5': 0.0036793374322987653, 'log_ret_diff_std_5': 0.004836683064338937, 'log_ret_sum_5': 0.004055623459877479, 'closePriceNorm_min_5': 0.0024586316729398373, 'closePriceNorm_max_5': 0.0032595863753025413, 'closePriceNorm_std_5': 0.006290735614297877, 'closePriceNorm_mean_5': 0.0015421749881577732, 'closePriceNorm_slope_5': 0.006367962569418604, 'closePriceNorm_skew_5': 0.005248786553768813, 'closePriceNorm_abs_diff_mean_5': 0.004796505845678384, 'closePriceNorm_diff_std_5': 0.0039051227950200897, 'closePriceNorm_sum_5': 0.0018336778775951425, 'log_ret_normalised_by_day_min_5': 0.004581571446903124, 'log_ret_normalised_by_day_max_5': 0.004054127484813411, 'log_ret_normalised_by_day_std_5': 0.005549948257649713, 'log_ret_normalised_by_day_mean_5': 0.0038822044243306854, 'log_ret_normalised_by_day_slope_5': 0.007489600119060089, 'log_ret_normalised_by_day_skew_5': 0.0053982273949961575, 'log_ret_normalised_by_day_abs_diff_mean_5': 0.004188058295955458, 'log_ret_normalised_by_day_diff_std_5': 0.004903105733813218, 'log_ret_normalised_by_day_sum_5': 0.003896756257053225, 'closePrice_min_10': 0.00038894982085300664, 'closePrice_max_10': 0.0006250425523512802, 'closePrice_std_10': 0.006358400789817685, 'closePrice_mean_10': 0.0008129336225389334, 'closePrice_slope_10': 0.008783738946870456, 'closePrice_skew_10': 0.0047340846479494185, 'closePrice_abs_diff_mean_10': 0.00432612625764712, 'closePrice_diff_std_10': 0.0042129112684238, 'closePrice_sum_10': 0.0007978468462403501, 'log_ret_min_10': 0.004137702751094156, 'log_ret_max_10': 0.005826763852024336, 'log_ret_std_10': 0.005563 ...
# Validation score: 0.004897923505503443

# %%
function_map = ['min', 'max', 'std', 'mean', 'slope', 'skew', 'abs_diff_mean', 'diff_std', 'sum']

for i in [3, 5, 10, 20]:
    print('Max Lag:', i)

    tmp_curated_data = copy.deepcopy(curated_data)

    for j in range(i+1, 11):
        tmp_curated_data = tmp_curated_data.drop(columns=[f'log_ret_lag_{j}', f'log_ret_normalised_by_day_lag_{j}', f'closePriceNorm_lag_{j}', f'closePrice_lag_{j}'], axis = 1)
    
    for j in [3, 5, 10, 20]:
        if j > i:

            columns = []
            for col in ['log_ret', 'closePrice', 'closePriceNorm', 'log_ret_normalised_by_day']:
                for func in function_map:
                    columns.append(f'{col}_{func}_{j}')
            tmp_curated_data = tmp_curated_data.drop(columns=columns, axis = 1)

    tmp_curated_data = tmp_curated_data.dropna()

    train = tmp_curated_data[(tmp_curated_data['date'] < val_date_start)]
    val = tmp_curated_data[(tmp_curated_data['date'] < test_date_start) & (tmp_curated_data['date'] >= val_date_start)]
    test = tmp_curated_data[(tmp_curated_data['date'] >= test_date_start)]

    jiaocheng = JiaoCheng.JiaoCheng()

    train_x = train.drop(columns=['date', 'log_ret'], axis = 1)
    train_y = train['log_ret']

    val_x = val.drop(columns=['date', 'log_ret'], axis = 1)
    val_y = val['log_ret']
    
    test_x = test.drop(columns=['date', 'log_ret'], axis = 1)
    test_y = test['log_ret']

    with open(f'../models/NingXiang_output_{LABEL}_lag_{i}.pickle', 'rb') as f:
        ningxiang_output = pickle.load(f)

    ningxiang_output = list(ningxiang_output.items())
    ningxiang_output = dict(ningxiang_output)

    jiaocheng = JiaoCheng.JiaoCheng()

    from lightgbm import LGBMRegressor as LGBR

    jiaocheng.read_in_model(LGBR, 'Regression')

    jiaocheng.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

    del train_x
    del train_y
    del val_x
    del val_y

    parameter_choices = {
        'n_estimators': (25, 50, 100, 200, 400),
        'max_depth': (3, 6, 12, 24, 48, 96, 192),
        'subsample': (0.4, 0.55, 0.7, 0.85),
        'colsample_bytree': (0.4, 0.55, 0.7, 0.85),
        'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
        'reg_alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10)

    }

    jiaocheng.set_hyperparameters(parameter_choices)

    jiaocheng.set_non_tuneable_hyperparameters({'random_state': 19260817, 'n_jobs': -1})

    jiaocheng.set_features(ningxiang_output)

    jiaocheng.set_tuning_order(['features', 'max_depth', 'colsample_bytree', 'subsample', 'n_estimators', 'reg_alpha', 'learning_rate'])

    jiaocheng.set_hyperparameter_default_values({
        'features': 0,
        'n_estimators': 50,
        'max_depth': 12,
        'subsample': 0.7,
        'colsample_bytree': 0.7,
        'learning_rate': 0.1,
        'reg_alpha': 0.01}
    )

    try:
        jiaocheng.read_in_tuning_result_df(f'../models/tuning/jiaocheng_{MODEL}_{LABEL}_lag_{i}.csv')
    except:
        pass

    jiaocheng.set_tuning_result_saving_address(f'../models/tuning/jiaocheng_{MODEL}_{LABEL}_lag_{i}.csv')
    jiaocheng.set_best_model_saving_address(f'../models/tmp_models/jiaocheng_{MODEL}_{LABEL}_lag_{i}.pickle')

    jiaocheng.tune()

    jiaocheng.view_best_combo_and_score()

    print('\n\n')
# Out:
# Max Lag: 3
# JiaoCheng Initialised
# JiaoCheng Initialised
# Successfully read in model <class 'lightgbm.sklearn.LGBMRegressor'>, which is a Regression model
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# Successfully recorded hyperparameter choices
# Successfully recorded non_tuneable_hyperparameter choices
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# Successfully read in tuning result of 228 rows
# Successfully set tuning output address
# Successfully set best model output address
#
# Default combo: [1, 2, 2, 2, 4, 2, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 6)
#
# As new Best Combo (1, 2, 2, 2, 4, 2, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 0), which had val score of -0.0155
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 1), which had val score of -0.0176
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 2), which had val score of -0.0217
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 3), which had val score of -0.0268
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 4), which had val score of -0.0203
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 5), which had val score of -0.0218
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 6), which had val score of -0.0507
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 7), which had val score of -0.05
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 8), which had val score of -0.0318
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 9), which had val score of -0.0218
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 10), which had val score of -0.0156
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 11), which had val score of -0.0221
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0155.
#         Has trained 228 of 940800 combinations so far
# As new Best Combo (1, 2, 2, 2, 4, 2, 12) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 12), which had val score of -0.0152
#         Current best combo: (1, 2, 2, 2, 4, 2, 12) with val score -0.0152.
#         Has trained 228 of 940800 combinations so far
# As new Best Combo (1, 2, 2, 2, 4, 2, 13) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 13), which had val score of -0.0148
#         Current best combo: (1, 2, 2, 2, 4, 2, 13) with val score -0.0148.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 14), which had val score of -0.0217
#         Current best combo: (1, 2, 2, 2, 4, 2, 13) with val score -0.0148.
#         Has trained 228 of 940800 combinations so far
# As new Best Combo (1, 2, 2, 2, 4, 2, 15) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 15), which had val score of -0.0135
#         Current best combo: (1, 2, 2, 2, 4, 2, 15) with val score -0.0135.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 16), which had val score of -0.0243
#         Current best combo: (1, 2, 2, 2, 4, 2, 15) with val score -0.0135.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 17), which had val score of -0.03
#         Current best combo: (1, 2, 2, 2, 4, 2, 15) with val score -0.0135.
#         Has trained 228 of 940800 combinations so far
# As new Best Combo (1, 2, 2, 2, 4, 2, 18) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 18), which had val score of -0.0128
#         Current best combo: (1, 2, 2, 2, 4, 2, 18) with val score -0.0128.
#         Has trained 228 of 940800 combinations so far
# As new Best Combo (1, 2, 2, 2, 4, 2, 19) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 19), which had val score of -0.0117
#         Current best combo: (1, 2, 2, 2, 4, 2, 19) with val score -0.0117.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 20), which had val score of -0.0224
#         Current best combo: (1, 2, 2, 2, 4, 2, 19) with val score -0.0117.
#         Has trained 228 of 940800 combinations so far
# As new Best Combo (1, 2, 2, 2, 4, 2, 21) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 21), which had val score of -0.0082
#         Current best combo: (1, 2, 2, 2, 4, 2, 21) with val score -0.0082.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 22), which had val score of -0.023
#         Current best combo: (1, 2, 2, 2, 4, 2, 21) with val score -0.0082.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 23), which had val score of -0.0127
#         Current best combo: (1, 2, 2, 2, 4, 2, 21) with val score -0.0082.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 24), which had val score of -0.0123
#         Current best combo: (1, 2, 2, 2, 4, 2, 21) with val score -0.0082.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 25), which had val score of -0.0101
#         Current best combo: (1, 2, 2, 2, 4, 2, 21) with val score -0.0082.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 26), which had val score of -0.0117
#         Current best combo: (1, 2, 2, 2, 4, 2, 21) with val score -0.0082.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 27), which had val score of -0.0205
#         Current best combo: (1, 2, 2, 2, 4, 2, 21) with val score -0.0082.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 28), which had val score of -0.0139
#         Current best combo: (1, 2, 2, 2, 4, 2, 21) with val score -0.0082.
#         Has trained 228 of 940800 combinations so far
# As new Best Combo (1, 2, 2, 2, 4, 2, 29) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 29), which had val score of -0.0037
#         Current best combo: (1, 2, 2, 2, 4, 2, 29) with val score -0.0037.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 30), which had val score of -0.0078
#         Current best combo: (1, 2, 2, 2, 4, 2, 29) with val score -0.0037.
#         Has trained 228 of 940800 combinations so far
# As new Best Combo (1, 2, 2, 2, 4, 2, 31) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 31), which had val score of 0.0046
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 32), which had val score of -0.022
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 33), which had val score of -0.0139
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 34), which had val score of -0.0062
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 35), which had val score of -0.0098
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 36), which had val score of -0.01
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 37), which had val score of -0.0103
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 38), which had val score of -0.0067
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 39), which had val score of -0.0168
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 40), which had val score of -0.0123
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 41), which had val score of -0.0097
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 42), which had val score of -0.0089
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 43), which had val score of -0.0164
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 44), which had val score of -0.0175
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 45), which had val score of -0.0052
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 46), which had val score of -0.0146
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 47), which had val score of -0.0168
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 48), which had val score of 0.0001
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 49), which had val score of -0.0157
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 50), which had val score of 0.0014
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 51), which had val score of 0.0011
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 52), which had val score of -0.0229
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 53), which had val score of -0.0066
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 54), which had val score of -0.004
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 55), which had val score of -0.0116
#         Current best combo: (1, 2, 2, 2, 4, 2, 31) with val score 0.0046.
#         Has trained 228 of 940800 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 2, 31) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_depth (index: 1)
#
# As new Best Combo (1, 0, 2, 2, 4, 2, 31) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 31), which had val score of 0.0097
#         Current best combo: (1, 0, 2, 2, 4, 2, 31) with val score 0.0097.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 4, 2, 31), which had val score of -0.0028
#         Current best combo: (1, 0, 2, 2, 4, 2, 31) with val score 0.0097.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 31), which had val score of 0.0046
#         Current best combo: (1, 0, 2, 2, 4, 2, 31) with val score 0.0097.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 4, 2, 31), which had val score of -0.0006
#         Current best combo: (1, 0, 2, 2, 4, 2, 31) with val score 0.0097.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 4, 2, 2, 4, 2, 31), which had val score of -0.0006
#         Current best combo: (1, 0, 2, 2, 4, 2, 31) with val score 0.0097.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 5, 2, 2, 4, 2, 31), which had val score of -0.0006
#         Current best combo: (1, 0, 2, 2, 4, 2, 31) with val score 0.0097.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 6, 2, 2, 4, 2, 31), which had val score of -0.0006
#         Current best combo: (1, 0, 2, 2, 4, 2, 31) with val score 0.0097.
#         Has trained 228 of 940800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 4, 2, 31) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: colsample_bytree (index: 3)
#
# Already Trained and Tested combination (1, 0, 2, 0, 4, 2, 31), which had val score of 0.0086
#         Current best combo: (1, 0, 2, 2, 4, 2, 31) with val score 0.0097.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 4, 2, 31), which had val score of 0.0069
#         Current best combo: (1, 0, 2, 2, 4, 2, 31) with val score 0.0097.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 31), which had val score of 0.0097
#         Current best combo: (1, 0, 2, 2, 4, 2, 31) with val score 0.0097.
#         Has trained 228 of 940800 combinations so far
# As new Best Combo (1, 0, 2, 3, 4, 2, 31) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 31), which had val score of 0.0114
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 3, 4, 2, 31) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (1, 0, 0, 3, 4, 2, 31), which had val score of 0.0114
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 1, 3, 4, 2, 31), which had val score of 0.0114
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 31), which had val score of 0.0114
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 3, 3, 4, 2, 31), which had val score of 0.0114
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 3, 4, 2, 31) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 0, 2, 3, 4, 2, 31), which had val score of 0.011
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 31), which had val score of 0.0114
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (2, 0, 2, 3, 4, 2, 31), which had val score of 0.0012
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (3, 0, 2, 3, 4, 2, 31), which had val score of -0.0164
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (4, 0, 2, 3, 4, 2, 31), which had val score of -0.0428
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 3, 4, 2, 31) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: reg_alpha (index: 5)
#
# Already Trained and Tested combination (1, 0, 2, 3, 4, 0, 31), which had val score of 0.0047
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 1, 31), which had val score of 0.0107
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 31), which had val score of 0.0114
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 3, 31), which had val score of 0.0102
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 4, 31), which had val score of 0.0057
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 5, 31), which had val score of -0.0
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 3, 4, 2, 31) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: learning_rate (index: 4)
#
# Already Trained and Tested combination (1, 0, 2, 3, 0, 2, 31), which had val score of -0.0
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 1, 2, 31), which had val score of -0.0
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 2, 2, 31), which had val score of 0.0001
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 3, 2, 31), which had val score of 0.0067
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 31), which had val score of 0.0114
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 3, 4, 2, 31) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 2
# Hyperparameter: features (index: 6)
#
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 0), which had val score of -0.0069
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 1), which had val score of -0.0074
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 2), which had val score of -0.0096
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 3), which had val score of -0.0077
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 4), which had val score of -0.0047
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 5), which had val score of -0.0061
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 6), which had val score of -0.0098
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 7), which had val score of -0.0051
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 8), which had val score of -0.0039
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 9), which had val score of 0.0013
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 10), which had val score of -0.0026
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 11), which had val score of 0.0037
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 12), which had val score of 0.0017
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 13), which had val score of 0.003
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 14), which had val score of 0.0023
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 15), which had val score of 0.0036
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 16), which had val score of 0.0036
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 17), which had val score of 0.0021
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 18), which had val score of -0.0023
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 19), which had val score of 0.0023
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 20), which had val score of 0.0082
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 21), which had val score of 0.0029
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 22), which had val score of 0.007
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 23), which had val score of 0.0037
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 24), which had val score of 0.0068
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 25), which had val score of 0.0079
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 26), which had val score of 0.0014
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 27), which had val score of 0.0045
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 28), which had val score of 0.0062
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 29), which had val score of 0.0008
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 30), which had val score of 0.0064
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 31), which had val score of 0.0114
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 32), which had val score of 0.0066
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 33), which had val score of 0.0084
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 34), which had val score of 0.0113
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 35), which had val score of 0.0095
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 36), which had val score of 0.0055
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 37), which had val score of 0.0079
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 38), which had val score of 0.0086
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 39), which had val score of 0.0051
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 40), which had val score of 0.0071
#         Current best combo: (1, 0, 2, 3, 4, 2, 31) with val score 0.0114.
#         Has trained 228 of 940800 combinations so far
# As new Best Combo (1, 0, 2, 3, 4, 2, 41) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 41), which had val score of 0.0133
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 42), which had val score of 0.0094
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 43), which had val score of 0.0092
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 44), which had val score of 0.0077
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 45), which had val score of 0.0092
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 46), which had val score of 0.0074
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 47), which had val score of 0.008
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 48), which had val score of 0.0103
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 49), which had val score of 0.0094
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 50), which had val score of 0.0127
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 51), which had val score of 0.0074
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 52), which had val score of 0.013
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 53), which had val score of 0.0081
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 54), which had val score of 0.0088
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 55), which had val score of 0.0102
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 3, 4, 2, 41) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 41), which had val score of 0.0133
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 1, 2, 3, 4, 2, 41), which had val score of -0.0115
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 2, 2, 3, 4, 2, 41), which had val score of -0.0061
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 3, 2, 3, 4, 2, 41), which had val score of -0.0123
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 4, 2, 3, 4, 2, 41), which had val score of -0.0123
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 5, 2, 3, 4, 2, 41), which had val score of -0.0123
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 6, 2, 3, 4, 2, 41), which had val score of -0.0123
#         Current best combo: (1, 0, 2, 3, 4, 2, 41) with val score 0.0133.
#         Has trained 228 of 940800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 3, 4, 2, 41) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: colsample_bytree (index: 3)
#
# As new Best Combo (1, 0, 2, 0, 4, 2, 41) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 0, 2, 0, 4, 2, 41), which had val score of 0.0134
#         Current best combo: (1, 0, 2, 0, 4, 2, 41) with val score 0.0134.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 4, 2, 41), which had val score of 0.006
#         Current best combo: (1, 0, 2, 0, 4, 2, 41) with val score 0.0134.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 41), which had val score of 0.0098
#         Current best combo: (1, 0, 2, 0, 4, 2, 41) with val score 0.0134.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 41), which had val score of 0.0133
#         Current best combo: (1, 0, 2, 0, 4, 2, 41) with val score 0.0134.
#         Has trained 228 of 940800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 0, 4, 2, 41) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (1, 0, 0, 0, 4, 2, 41), which had val score of 0.0134
#         Current best combo: (1, 0, 2, 0, 4, 2, 41) with val score 0.0134.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 1, 0, 4, 2, 41), which had val score of 0.0134
#         Current best combo: (1, 0, 2, 0, 4, 2, 41) with val score 0.0134.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 0, 4, 2, 41), which had val score of 0.0134
#         Current best combo: (1, 0, 2, 0, 4, 2, 41) with val score 0.0134.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 3, 0, 4, 2, 41), which had val score of 0.0134
#         Current best combo: (1, 0, 2, 0, 4, 2, 41) with val score 0.0134.
#         Has trained 228 of 940800 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 0, 4, 2, 41) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# As new Best Combo (0, 0, 2, 0, 4, 2, 41) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 41), which had val score of 0.0155
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (1, 0, 2, 0, 4, 2, 41), which had val score of 0.0134
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (2, 0, 2, 0, 4, 2, 41), which had val score of 0.0016
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (3, 0, 2, 0, 4, 2, 41), which had val score of -0.0127
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (4, 0, 2, 0, 4, 2, 41), which had val score of -0.029
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 0, 4, 2, 41) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: reg_alpha (index: 5)
#
# Already Trained and Tested combination (0, 0, 2, 0, 4, 0, 41), which had val score of 0.0136
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 41), which had val score of 0.0137
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 41), which had val score of 0.0155
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 3, 41), which had val score of 0.0135
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 4, 41), which had val score of 0.0056
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 5, 41), which had val score of -0.0
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 0, 4, 2, 41) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: learning_rate (index: 4)
#
# Already Trained and Tested combination (0, 0, 2, 0, 0, 2, 41), which had val score of -0.0
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 1, 2, 41), which had val score of -0.0
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 2, 2, 41), which had val score of 0.0
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 3, 2, 41), which had val score of 0.0048
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 41), which had val score of 0.0155
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 0, 4, 2, 41) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 3
#
# Round 3
# Hyperparameter: features (index: 6)
#
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 0), which had val score of -0.0045
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 1), which had val score of -0.0002
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 2), which had val score of -0.0022
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 3), which had val score of -0.0016
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 4), which had val score of -0.0017
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 5), which had val score of 0.0006
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 6), which had val score of 0.004
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 7), which had val score of -0.0012
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 8), which had val score of 0.0023
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 9), which had val score of 0.0111
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 10), which had val score of 0.0088
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 11), which had val score of 0.009
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 12), which had val score of 0.0053
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 13), which had val score of 0.0086
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 14), which had val score of 0.0058
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 15), which had val score of 0.0009
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 16), which had val score of 0.0053
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 17), which had val score of 0.0088
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 18), which had val score of 0.0091
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 19), which had val score of 0.0084
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 20), which had val score of 0.0081
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 21), which had val score of 0.0129
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 22), which had val score of 0.0097
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 23), which had val score of 0.0104
#         Current best combo: (0, 0, 2, 0, 4, 2, 41) with val score 0.0155.
#         Has trained 228 of 940800 combinations so far
# ...
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 4, 2, 0, 4, 2, 164), which had val score of -0.0062
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 5, 2, 0, 4, 2, 164), which had val score of -0.0062
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 6, 2, 0, 4, 2, 164), which had val score of -0.0062
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 0, 4, 2, 164) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: colsample_bytree (index: 3)
#
# Already Trained and Tested combination (1, 0, 2, 0, 4, 2, 164), which had val score of 0.0266
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 4, 2, 164), which had val score of 0.018
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 164), which had val score of 0.018
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 164), which had val score of 0.017
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 0, 4, 2, 164) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (1, 0, 0, 0, 4, 2, 164), which had val score of 0.0266
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 0, 1, 0, 4, 2, 164), which had val score of 0.0266
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 0, 4, 2, 164), which had val score of 0.0266
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 0, 3, 0, 4, 2, 164), which had val score of 0.0266
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 0, 4, 2, 164) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 164), which had val score of 0.0224
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 0, 4, 2, 164), which had val score of 0.0266
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (2, 0, 2, 0, 4, 2, 164), which had val score of 0.0147
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (3, 0, 2, 0, 4, 2, 164), which had val score of -0.0065
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (4, 0, 2, 0, 4, 2, 164), which had val score of -0.0407
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 0, 4, 2, 164) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: reg_alpha (index: 5)
#
# Already Trained and Tested combination (1, 0, 2, 0, 4, 0, 164), which had val score of 0.0203
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 0, 4, 1, 164), which had val score of 0.0173
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 0, 4, 2, 164), which had val score of 0.0266
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 0, 4, 3, 164), which had val score of 0.0164
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 0, 4, 4, 164), which had val score of 0.007
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 0, 4, 5, 164), which had val score of -0.0005
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 0, 4, 2, 164) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: learning_rate (index: 4)
#
# Already Trained and Tested combination (1, 0, 2, 0, 0, 2, 164), which had val score of -0.0005
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 0, 1, 2, 164), which had val score of -0.0005
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 0, 2, 2, 164), which had val score of -0.0004
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 0, 3, 2, 164), which had val score of 0.0093
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 0, 4, 2, 164), which had val score of 0.0266
#         Current best combo: (1, 0, 2, 0, 4, 2, 164) with val score 0.0266.
#         Has trained 433 of 3225600 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 0, 4, 2, 164) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.026588
# Max Test Score:
#  -0.023709
# Max Combo Index:
#  (1, 0, 2, 0, 4, 2, 164) out of [5, 7, 4, 4, 5, 6, 192] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.7, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.01, 'features': 164}
# Max Combo Features:
#  ('pos_closePrice_lag_1', 'mean_log_ret_lag_1', 'log_ret_lag_1', 'log_ret_normalised_by_day_lag_7', 'closePrice_slope_20', 'log_ret_lag_9', 'log_ret_normalised_by_day_lag_3', 'log_ret_lag_8', 'log_ret_normalised_by_day_lag_10', 'log_ret_normalised_by_day_lag_1', 'log_ret_normalised_by_day_lag_9', 'log_ret_lag_10', 'log_ret_lag_6', 'log_ret_lag_7', 'log_ret_lag_3', 'log_ret_normalised_by_day_lag_2', 'log_ret_slope_5', 'log_ret_lag_2', 'log_ret_lag_4', 'pos_log_ret_normalised_by_day_lag_1', 'log_ret_normalised_by_day_lag_8', 'closePriceNorm_min_20', 'log_ret_lag_5', 'closePrice_slope_10', 'log_ret_min_20', 'log_ret_normalised_by_day_diff_std_3', 'log_ret_slope_3', 'log_ret_normalised_by_day_lag_5', 'pos_closePriceNorm_lag_1', 'log_ret_std_20', 'pos_log_ret_lag_1', 'log_ret_slope_20', 'closePriceNorm_slope_3', 'closePrice_std_20', 'log_ret_normalised_by_day_std_20', 'log_ret_skew_20', 'log_ret_normalised_by_day_slope_5', 'log_ret_mean_20', 'closePrice_slope_3', 'log_ret_normalised_by_day_abs_diff_mean_20', 'log_ret_normalised_by_day_slope_3', 'log_ret_skew_3', 'log_ret_diff_std_3', 'log_ret_normalised_by_day_min_20', 'log_ret_slope_10', 'log_ret_normalised_by_day_skew_20', 'log_ret_sum_20', 'closePriceNorm_slope_10', 'closePriceNorm_slope_20', 'closePrice_abs_diff_mean_20', 'closePriceNorm_slope_5', 'closePrice_std_10', 'log_ret_min_3', 'closePriceNorm_sum_20', 'closePriceNorm_std_5', 'log_ret_normalised_by_day_lag_4', 'closePrice_std_5', 'log_ret_normalised_by_day_lag_6', 'log_ret_max_20', 'log_ret_min_5', 'closePriceNorm_lag_3', 'log_ret_abs_diff_mean_3', 'closePriceNorm_lag_8', 'closePrice_diff_std_5', 'closePriceNorm_abs_diff_mean_20', 'log_ret_max_10', 'closePrice_skew_20', 'closePriceNorm_std_20', 'log_ret_normalised_by_day_slope_10', 'log_ret_normalised_by_day_abs_diff_mean_3', 'log_ret_normalised_by_day_min_3', 'closePriceNorm_std_10', 'log_ret_std_10', 'log_ret_normalised_by_day_std_5', 'closePrice_std_3', 'log_ret_normalised_by_day_sum_20', 'log_ret_normalised_by_day_skew_5', 'log_ret_std_5', 'closePrice_diff_std_20', 'closePriceNorm_skew_5', 'log_ret_normalised_by_day_diff_std_20', 'closePrice_diff_std_3', 'log_ret_normalised_by_day_max_20', 'log_ret_diff_std_20', 'log_ret_normalised_by_day_skew_10', 'log_ret_skew_10', 'log_ret_abs_diff_mean_20', 'closePrice_slope_5', 'closePriceNorm_lag_9', 'closePriceNorm_mean_20', 'log_ret_mean_10', 'log_ret_normalised_by_day_max_10', 'closePriceNorm_diff_std_3', 'closePriceNorm_skew_20', 'log_ret_normalised_by_day_slope_20', 'closePrice_skew_5', 'closePriceNorm_diff_std_20', 'log_ret_normalised_by_day_diff_std_5', 'closePriceNorm_std_3', 'closePriceNorm_lag_7', 'log_ret_normalised_by_day_std_3', 'log_ret_diff_std_5', 'closePriceNorm_lag_10', 'closePriceNorm_diff_std_10', 'closePriceNorm_abs_diff_mean_5', 'log_ret_skew_5', 'log_ret_std_3', 'closePrice_skew_10', 'log_ret_normalised_by_day_std_10', 'log_ret_normalised_by_day_skew_3', 'log_ret_diff_std_10', 'log_ret_normalised_by_day_abs_diff_mean_10', 'closePriceNorm_skew_10', 'log_ret_normalised_by_day_min_5', 'log_ret_normalised_by_day_mean_3', 'closePriceNorm_lag_4', 'log_ret_max_3', 'mean_closePriceNorm_lag_1', 'log_ret_normalised_by_day_min_10', 'closePrice_abs_diff_mean_10', 'closePriceNorm_skew_3', 'closePriceNorm_lag_6', 'closePriceNorm_abs_diff_mean_10', 'log_ret_normalised_by_day_mean_20', 'closePrice_diff_std_10', 'log_ret_normalised_by_day_abs_diff_mean_5', 'log_ret_sum_10', 'closePriceNorm_max_10', 'closePriceNorm_lag_1', 'log_ret_min_10', 'mean_closePrice_lag_1', 'closePrice_skew_3', 'log_ret_sum_5', 'log_ret_normalised_by_day_max_5', 'log_ret_normalised_by_day_sum_3', 'log_ret_abs_diff_mean_10', 'log_ret_mean_3', 'log_ret_normalised_by_day_mean_10', 'closePriceNorm_diff_std_5', 'log_ret_normalised_by_day_sum_5', 'log_ret_normalised_by_day_diff_std_10', 'log_ret_normalised_by_day_mean_5', 'closePrice_abs_diff_mean_5', 'log_ret_normalised_by_day_max_3', 'log_ret_abs_diff_mean_5', 'closePriceNorm_max_20', 'closePriceNorm_m ...
# % Combos Checked: 433 out of 3225600 which is 0.013423999999999998%
# Max Score:
#  0.026588
# Max Test Score:
#  -0.023709
# Max Combo Index:
#  (1, 0, 2, 0, 4, 2, 164) out of [5, 7, 4, 4, 5, 6, 192] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.7, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.01, 'features': 164}
# Max Combo Features:
#  ('pos_closePrice_lag_1', 'mean_log_ret_lag_1', 'log_ret_lag_1', 'log_ret_normalised_by_day_lag_7', 'closePrice_slope_20', 'log_ret_lag_9', 'log_ret_normalised_by_day_lag_3', 'log_ret_lag_8', 'log_ret_normalised_by_day_lag_10', 'log_ret_normalised_by_day_lag_1', 'log_ret_normalised_by_day_lag_9', 'log_ret_lag_10', 'log_ret_lag_6', 'log_ret_lag_7', 'log_ret_lag_3', 'log_ret_normalised_by_day_lag_2', 'log_ret_slope_5', 'log_ret_lag_2', 'log_ret_lag_4', 'pos_log_ret_normalised_by_day_lag_1', 'log_ret_normalised_by_day_lag_8', 'closePriceNorm_min_20', 'log_ret_lag_5', 'closePrice_slope_10', 'log_ret_min_20', 'log_ret_normalised_by_day_diff_std_3', 'log_ret_slope_3', 'log_ret_normalised_by_day_lag_5', 'pos_closePriceNorm_lag_1', 'log_ret_std_20', 'pos_log_ret_lag_1', 'log_ret_slope_20', 'closePriceNorm_slope_3', 'closePrice_std_20', 'log_ret_normalised_by_day_std_20', 'log_ret_skew_20', 'log_ret_normalised_by_day_slope_5', 'log_ret_mean_20', 'closePrice_slope_3', 'log_ret_normalised_by_day_abs_diff_mean_20', 'log_ret_normalised_by_day_slope_3', 'log_ret_skew_3', 'log_ret_diff_std_3', 'log_ret_normalised_by_day_min_20', 'log_ret_slope_10', 'log_ret_normalised_by_day_skew_20', 'log_ret_sum_20', 'closePriceNorm_slope_10', 'closePriceNorm_slope_20', 'closePrice_abs_diff_mean_20', 'closePriceNorm_slope_5', 'closePrice_std_10', 'log_ret_min_3', 'closePriceNorm_sum_20', 'closePriceNorm_std_5', 'log_ret_normalised_by_day_lag_4', 'closePrice_std_5', 'log_ret_normalised_by_day_lag_6', 'log_ret_max_20', 'log_ret_min_5', 'closePriceNorm_lag_3', 'log_ret_abs_diff_mean_3', 'closePriceNorm_lag_8', 'closePrice_diff_std_5', 'closePriceNorm_abs_diff_mean_20', 'log_ret_max_10', 'closePrice_skew_20', 'closePriceNorm_std_20', 'log_ret_normalised_by_day_slope_10', 'log_ret_normalised_by_day_abs_diff_mean_3', 'log_ret_normalised_by_day_min_3', 'closePriceNorm_std_10', 'log_ret_std_10', 'log_ret_normalised_by_day_std_5', 'closePrice_std_3', 'log_ret_normalised_by_day_sum_20', 'log_ret_normalised_by_day_skew_5', 'log_ret_std_5', 'closePrice_diff_std_20', 'closePriceNorm_skew_5', 'log_ret_normalised_by_day_diff_std_20', 'closePrice_diff_std_3', 'log_ret_normalised_by_day_max_20', 'log_ret_diff_std_20', 'log_ret_normalised_by_day_skew_10', 'log_ret_skew_10', 'log_ret_abs_diff_mean_20', 'closePrice_slope_5', 'closePriceNorm_lag_9', 'closePriceNorm_mean_20', 'log_ret_mean_10', 'log_ret_normalised_by_day_max_10', 'closePriceNorm_diff_std_3', 'closePriceNorm_skew_20', 'log_ret_normalised_by_day_slope_20', 'closePrice_skew_5', 'closePriceNorm_diff_std_20', 'log_ret_normalised_by_day_diff_std_5', 'closePriceNorm_std_3', 'closePriceNorm_lag_7', 'log_ret_normalised_by_day_std_3', 'log_ret_diff_std_5', 'closePriceNorm_lag_10', 'closePriceNorm_diff_std_10', 'closePriceNorm_abs_diff_mean_5', 'log_ret_skew_5', 'log_ret_std_3', 'closePrice_skew_10', 'log_ret_normalised_by_day_std_10', 'log_ret_normalised_by_day_skew_3', 'log_ret_diff_std_10', 'log_ret_normalised_by_day_abs_diff_mean_10', 'closePriceNorm_skew_10', 'log_ret_normalised_by_day_min_5', 'log_ret_normalised_by_day_mean_3', 'closePriceNorm_lag_4', 'log_ret_max_3', 'mean_closePriceNorm_lag_1', 'log_ret_normalised_by_day_min_10', 'closePrice_abs_diff_mean_10', 'closePriceNorm_skew_3', 'closePriceNorm_lag_6', 'closePriceNorm_abs_diff_mean_10', 'log_ret_normalised_by_day_mean_20', 'closePrice_diff_std_10', 'log_ret_normalised_by_day_abs_diff_mean_5', 'log_ret_sum_10', 'closePriceNorm_max_10', 'closePriceNorm_lag_1', 'log_ret_min_10', 'mean_closePrice_lag_1', 'closePrice_skew_3', 'log_ret_sum_5', 'log_ret_normalised_by_day_max_5', 'log_ret_normalised_by_day_sum_3', 'log_ret_abs_diff_mean_10', 'log_ret_mean_3', 'log_ret_normalised_by_day_mean_10', 'closePriceNorm_diff_std_5', 'log_ret_normalised_by_day_sum_5', 'log_ret_normalised_by_day_diff_std_10', 'log_ret_normalised_by_day_mean_5', 'closePrice_abs_diff_mean_5', 'log_ret_normalised_by_day_max_3', 'log_ret_abs_diff_mean_5', 'closePriceNorm_max_20', 'closePriceNorm_m ...
# % Combos Checked: 433 out of 3225600 which is 0.013423999999999998%
