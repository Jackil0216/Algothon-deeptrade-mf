# %%
import sys
import os
import pickle
import pandas as pd
import json
import datetime
import time
import copy

py_file_location = '../PrivatePackages'
sys.path.append(os.path.abspath(py_file_location))
from sklearn.model_selection import train_test_split

import JiaoCheng
import NingXiang
# Out:
# /Applications/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
LABEL = 'logret'
MODEL = 'lgbr'

# %%
curated_data = pd.read_csv('../data/curated_data.csv')
curated_data = curated_data.drop(columns=['closePrice', 'closePriceNorm', 'log_ret_normalised_by_day', 'trebd', 'stock'])
curated_data['date'] = pd.to_datetime(curated_data['date'])

# %%
date = [datetime.datetime(year=2022, month=12, day = 31) + datetime.timedelta(days=i) for i in range(250)]
val_date_start = date[175]
test_date_start = date[175+38]

# %%
function_map = ['min', 'max', 'std', 'mean', 'slope', 'skew', 'abs_diff_mean', 'diff_std', 'sum']

for i in [3, 5, 10, 20]:
    print('Max Lag:', i)

    tmp_curated_data = copy.deepcopy(curated_data)

    for j in range(i+1, 11):
        tmp_curated_data = tmp_curated_data.drop(columns=[f'log_ret_lag_{j}', f'log_ret_normalised_by_day_lag_{j}', f'closePriceNorm_lag_{j}', f'closePrice_lag_{j}'], axis = 1)
    
    for j in [3, 5, 10, 20]:
        if j > i:

            columns = []
            for col in ['log_ret', 'closePrice', 'closePriceNorm', 'log_ret_normalised_by_day']:
                for func in function_map:
                    columns.append(f'{col}_{func}_{j}')
            tmp_curated_data = tmp_curated_data.drop(columns=columns, axis = 1)

    tmp_curated_data = tmp_curated_data.dropna()

    train = tmp_curated_data[(tmp_curated_data['date'] < val_date_start)]
    val = tmp_curated_data[(tmp_curated_data['date'] < test_date_start) & (tmp_curated_data['date'] >= val_date_start)]

    ningxiang = NingXiang.NingXiang()

    train_x = train.drop(columns=['date', 'log_ret'], axis = 1)
    train_y = train['log_ret']

    val_x = val.drop(columns=['date', 'log_ret'], axis = 1)
    val_y = val['log_ret']

    ningxiang.read_in_train_data(train_x, train_y, val_x, val_y)

    ningxiang.set_model_type('Regression')

    ningxiang_output = ningxiang.get_rf_based_feature_combinations(1, 1, 4)

    ningxiang.export_ningxiang_output(f'../models/NingXiang_output_{LABEL}_lag_{i}')

    ningxiang.show_rf_stats()

    print('\n\n')
# Out:
# Max Lag: 1
# NingXiang Initialised
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Successfully recorded model type: Regression
# Begin fitting Random Forest
# Finished fitting Random Forest
# Successfully set object output address
# {'ret_lag_1': 0.08671875012201878, 'log_ret_lag_1': 0.08184859317825154, 'closePrice_lag_1': 0.024220277334418734, 'closePriceNorm_lag_1': 0.06059507313466973, 'closePrice_lag_2': 0.022292839825919314, 'closePriceNorm_lag_2': 0.055953951503429356, 'closePrice_lag_3': 0.020712271750098248, 'closePriceNorm_lag_3': 0.06517855898292883, 'closePrice_lag_4': 0.021170428361565498, 'closePriceNorm_lag_4': 0.06128337724478403, 'closePrice_lag_5': 0.01920319295430945, 'closePriceNorm_lag_5': 0.05819861346713399, 'closePrice_lag_6': 0.022037185476127315, 'closePriceNorm_lag_6': 0.05911953100531673, 'closePrice_lag_7': 0.01856142473924989, 'closePriceNorm_lag_7': 0.0658688893347243, 'closePrice_lag_8': 0.02039833843888111, 'closePriceNorm_lag_8': 0.06274793910585175, 'closePrice_lag_9': 0.02572172425066735, 'closePriceNorm_lag_9': 0.061893827058283876, 'closePrice_lag_10': 0.022731205723284353, 'closePriceNorm_lag_10': 0.06354400700808589}
# Validation score: -0.006049975977119759
#
#
#
# Max Lag: 2
# NingXiang Initialised
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Successfully recorded model type: Regression
# Begin fitting Random Forest
# Finished fitting Random Forest
# Successfully set object output address
# {'ret_lag_1': 0.07435017301582814, 'log_ret_lag_1': 0.07946541468942982, 'closePrice_lag_1': 0.0188440924074913, 'closePriceNorm_lag_1': 0.04983530165333525, 'ret_lag_2': 0.06912126903221233, 'log_ret_lag_2': 0.06561374268481233, 'closePrice_lag_2': 0.017155673558569243, 'closePriceNorm_lag_2': 0.04238753467623496, 'closePrice_lag_3': 0.015255650427968635, 'closePriceNorm_lag_3': 0.05869486059368678, 'closePrice_lag_4': 0.01629544823009081, 'closePriceNorm_lag_4': 0.04930767758484305, 'closePrice_lag_5': 0.016660117275334455, 'closePriceNorm_lag_5': 0.05129114905662859, 'closePrice_lag_6': 0.01614363475349741, 'closePriceNorm_lag_6': 0.05099051755364921, 'closePrice_lag_7': 0.017989864307159997, 'closePriceNorm_lag_7': 0.06338820610860008, 'closePrice_lag_8': 0.01740457214657679, 'closePriceNorm_lag_8': 0.06122567369825745, 'closePrice_lag_9': 0.01909087954723211, 'closePriceNorm_lag_9': 0.05077446430131964, 'closePrice_lag_10': 0.021069162133502815, 'closePriceNorm_lag_10': 0.05764492056373884}
# Validation score: -0.008190321913910337
#
#
#
# Max Lag: 3
# NingXiang Initialised
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Successfully recorded model type: Regression
# Begin fitting Random Forest
# Finished fitting Random Forest
# Successfully set object output address
# {'ret_lag_1': 0.07004456437028388, 'log_ret_lag_1': 0.06825755584470045, 'closePrice_lag_1': 0.01632560141043664, 'closePriceNorm_lag_1': 0.044701516926235536, 'ret_lag_2': 0.06044817407651418, 'log_ret_lag_2': 0.05872576381507713, 'closePrice_lag_2': 0.015638929232166185, 'closePriceNorm_lag_2': 0.03958541039655168, 'ret_lag_3': 0.06623999058598226, 'log_ret_lag_3': 0.06632056977338997, 'closePrice_lag_3': 0.01613997437298413, 'closePriceNorm_lag_3': 0.047682484619795316, 'closePrice_lag_4': 0.014795979980489472, 'closePriceNorm_lag_4': 0.038916843638886596, 'closePrice_lag_5': 0.015899822127202187, 'closePriceNorm_lag_5': 0.04070051688797745, 'closePrice_lag_6': 0.015187042672185038, 'closePriceNorm_lag_6': 0.038942509573992895, 'closePrice_lag_7': 0.013149944091505585, 'closePriceNorm_lag_7': 0.052616316042554796, 'closePrice_lag_8': 0.012584216501055324, 'closePriceNorm_lag_8': 0.046689456703691935, 'closePrice_lag_9': 0.016769018632200126, 'closePriceNorm_lag_9': 0.05135156385894782, 'closePrice_lag_10': 0.017207357110979184, 'closePriceNorm_lag_10': 0.055078876754214336}
# Validation score: 0.0006654542780148986
#
#
#
# Max Lag: 4
# NingXiang Initialised
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Successfully recorded model type: Regression
# Begin fitting Random Forest
# Finished fitting Random Forest
# Successfully set object output address
# {'ret_lag_1': 0.06061545697616558, 'log_ret_lag_1': 0.06025109290773893, 'closePrice_lag_1': 0.014646805052804699, 'closePriceNorm_lag_1': 0.04169501040706218, 'ret_lag_2': 0.055248559840781045, 'log_ret_lag_2': 0.053234157182247645, 'closePrice_lag_2': 0.015003246713899696, 'closePriceNorm_lag_2': 0.03328948659350639, 'ret_lag_3': 0.06540688945341779, 'log_ret_lag_3': 0.05855889676755365, 'closePrice_lag_3': 0.013775590235456582, 'closePriceNorm_lag_3': 0.04312081937909551, 'ret_lag_4': 0.049904196834818546, 'log_ret_lag_4': 0.05026270908456365, 'closePrice_lag_4': 0.01180873388695339, 'closePriceNorm_lag_4': 0.03321727926414433, 'closePrice_lag_5': 0.012006976972436408, 'closePriceNorm_lag_5': 0.033230451335261715, 'closePrice_lag_6': 0.011558589484808717, 'closePriceNorm_lag_6': 0.03732040976738036, 'closePrice_lag_7': 0.013737235680420777, 'closePriceNorm_lag_7': 0.04346055479646074, 'closePrice_lag_8': 0.012995072047829083, 'closePriceNorm_lag_8': 0.04644186405132557, 'closePrice_lag_9': 0.01571792379439379, 'closePriceNorm_lag_9': 0.046005467313532784, 'closePrice_lag_10': 0.017496205671945184, 'closePriceNorm_lag_10': 0.04999031850399539}
# Validation score: 0.0036756936062094514
#
#
#
# Max Lag: 5
# NingXiang Initialised
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Successfully recorded model type: Regression
# Begin fitting Random Forest
# Finished fitting Random Forest
# Successfully set object output address
# {'ret_lag_1': 0.0575852316336982, 'log_ret_lag_1': 0.05489175314745668, 'closePrice_lag_1': 0.013684858433801694, 'closePriceNorm_lag_1': 0.03501556383497931, 'ret_lag_2': 0.05384287945567399, 'log_ret_lag_2': 0.047228514509255096, 'closePrice_lag_2': 0.012549376028360976, 'closePriceNorm_lag_2': 0.02904370982245458, 'ret_lag_3': 0.05453605554910159, 'log_ret_lag_3': 0.05988555308920063, 'closePrice_lag_3': 0.011897544445136111, 'closePriceNorm_lag_3': 0.036148021644855415, 'ret_lag_4': 0.047090824108424405, 'log_ret_lag_4': 0.049881614423067155, 'closePrice_lag_4': 0.011033040225017363, 'closePriceNorm_lag_4': 0.03040696288587577, 'ret_lag_5': 0.052096600405987445, 'log_ret_lag_5': 0.04940650751157425, 'closePrice_lag_5': 0.01152478650335037, 'closePriceNorm_lag_5': 0.02758098980362379, 'closePrice_lag_6': 0.010412262577287713, 'closePriceNorm_lag_6': 0.029415000537908357, 'closePrice_lag_7': 0.012790889772240554, 'closePriceNorm_lag_7': 0.04163971870010928, 'closePrice_lag_8': 0.012455531328074296, 'closePriceNorm_lag_8': 0.041838191462258666, 'closePrice_lag_9': 0.013149500019281274, 'closePriceNorm_lag_9': 0.03755530739190319, 'closePrice_lag_10': 0.014019332035092895, 'closePriceNorm_lag_10': 0.04139387871494902}
# Validation score: 0.007947682045429061
#
#
#
# Max Lag: 6
# NingXiang Initialised
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Successfully recorded model type: Regression
# Begin fitting Random Forest
# Finished fitting Random Forest
# Successfully set object output address
# {'ret_lag_1': 0.05037298062410999, 'log_ret_lag_1': 0.053390619345354585, 'closePrice_lag_1': 0.011417257895896381, 'closePriceNorm_lag_1': 0.03395460410813373, 'ret_lag_2': 0.046131957900754667, 'log_ret_lag_2': 0.045896692472917174, 'closePrice_lag_2': 0.011826146387987353, 'closePriceNorm_lag_2': 0.02812582387761018, 'ret_lag_3': 0.05101026811860003, 'log_ret_lag_3': 0.05218871680730187, 'closePrice_lag_3': 0.009176204520689131, 'closePriceNorm_lag_3': 0.0347292433924433, 'ret_lag_4': 0.04445242500232177, 'log_ret_lag_4': 0.04411752661614796, 'closePrice_lag_4': 0.010028525890982678, 'closePriceNorm_lag_4': 0.027937638787477587, 'ret_lag_5': 0.047104673642871166, 'log_ret_lag_5': 0.042446990261997435, 'closePrice_lag_5': 0.009392180254152244, 'closePriceNorm_lag_5': 0.027194587877873364, 'ret_lag_6': 0.04507594012075973, 'log_ret_lag_6': 0.048779941238822316, 'closePrice_lag_6': 0.009882343675972141, 'closePriceNorm_lag_6': 0.023697241502928613, 'closePrice_lag_7': 0.010517423434301223, 'closePriceNorm_lag_7': 0.03704232245253989, 'closePrice_lag_8': 0.01045669444463617, 'closePriceNorm_lag_8': 0.038082333664036384, 'closePrice_lag_9': 0.012519537091489874, 'closePriceNorm_lag_9': 0.03289030958872597, 'closePrice_lag_10': 0.012913367653238974, 'closePriceNorm_lag_10': 0.03724748134692613}
# Validation score: 0.007104795934436359
#
#
#
# Max Lag: 7
# NingXiang Initialised
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Successfully recorded model type: Regression
# Begin fitting Random Forest
# Finished fitting Random Forest
# Successfully set object output address
# {'ret_lag_1': 0.04808139471751673, 'log_ret_lag_1': 0.04640436591701343, 'closePrice_lag_1': 0.010902656948934723, 'closePriceNorm_lag_1': 0.031110662299200308, 'ret_lag_2': 0.044898638127069464, 'log_ret_lag_2': 0.045176038969324046, 'closePrice_lag_2': 0.010643313744799371, 'closePriceNorm_lag_2': 0.0243308347246873, 'ret_lag_3': 0.050532010023701966, 'log_ret_lag_3': 0.04356307011804808, 'closePrice_lag_3': 0.009167145181082578, 'closePriceNorm_lag_3': 0.03407916114853502, 'ret_lag_4': 0.04005168032212055, 'log_ret_lag_4': 0.036016855879603314, 'closePrice_lag_4': 0.011159254902958956, 'closePriceNorm_lag_4': 0.02410922096742976, 'ret_lag_5': 0.040736509276967786, 'log_ret_lag_5': 0.042158938207157604, 'closePrice_lag_5': 0.008729043910887305, 'closePriceNorm_lag_5': 0.02093063456845522, 'ret_lag_6': 0.04245459498517517, 'log_ret_lag_6': 0.042239905074370726, 'closePrice_lag_6': 0.007411167290617233, 'closePriceNorm_lag_6': 0.02148490610452033, 'ret_lag_7': 0.04818657765198022, 'log_ret_lag_7': 0.044060343006615085, 'closePrice_lag_7': 0.010884792272261802, 'closePriceNorm_lag_7': 0.033836633522692464, 'closePrice_lag_8': 0.009284172534032131, 'closePriceNorm_lag_8': 0.027475457779883545, 'closePrice_lag_9': 0.011706956458651352, 'closePriceNorm_lag_9': 0.030543381750186366, 'closePrice_lag_10': 0.012869473251724176, 'closePriceNorm_lag_10': 0.03478020836179595}
# Validation score: 0.013778507960899078
#
#
#
# Max Lag: 8
# NingXiang Initialised
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Successfully recorded model type: Regression
# Begin fitting Random Forest
# Finished fitting Random Forest
# Successfully set object output address
# {'ret_lag_1': 0.040492549018505776, 'log_ret_lag_1': 0.04577302264578735, 'closePrice_lag_1': 0.00935381793806238, 'closePriceNorm_lag_1': 0.029391055215177278, 'ret_lag_2': 0.040364214653987505, 'log_ret_lag_2': 0.03857825505089709, 'closePrice_lag_2': 0.009618056984278856, 'closePriceNorm_lag_2': 0.022718000001819137, 'ret_lag_3': 0.04074758766558349, 'log_ret_lag_3': 0.043515051743973555, 'closePrice_lag_3': 0.00902062935132643, 'closePriceNorm_lag_3': 0.03092206173838476, 'ret_lag_4': 0.033305111218109286, 'log_ret_lag_4': 0.03622405931444128, 'closePrice_lag_4': 0.008708268567568652, 'closePriceNorm_lag_4': 0.021514270198632876, 'ret_lag_5': 0.04009617418515722, 'log_ret_lag_5': 0.034152531495600144, 'closePrice_lag_5': 0.008500111651238608, 'closePriceNorm_lag_5': 0.021662703271880513, 'ret_lag_6': 0.03724630589562948, 'log_ret_lag_6': 0.037054991124615085, 'closePrice_lag_6': 0.0077112852621736725, 'closePriceNorm_lag_6': 0.0234927704865174, 'ret_lag_7': 0.046191523806657545, 'log_ret_lag_7': 0.04286127299247022, 'closePrice_lag_7': 0.008750794120365496, 'closePriceNorm_lag_7': 0.029706420189305742, 'ret_lag_8': 0.04110351682678046, 'log_ret_lag_8': 0.042439359304232704, 'closePrice_lag_8': 0.00917830354920435, 'closePriceNorm_lag_8': 0.028694261562514124, 'closePrice_lag_9': 0.01098249380641087, 'closePriceNorm_lag_9': 0.026261421089390155, 'closePrice_lag_10': 0.011337346538348496, 'closePriceNorm_lag_10': 0.03233040153497204}
# Validation score: 0.017966628720102573
#
#
#
# Max Lag: 9
# NingXiang Initialised
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Successfully recorded model type: Regression
# Begin fitting Random Forest
# Finished fitting Random Forest
# Successfully set object output address
# {'ret_lag_1': 0.03996061568569205, 'log_ret_lag_1': 0.040135193441879824, 'closePrice_lag_1': 0.008751061546626256, 'closePriceNorm_lag_1': 0.02607004855890709, 'ret_lag_2': 0.034644493119782134, 'log_ret_lag_2': 0.03532602788155929, 'closePrice_lag_2': 0.007829164476366435, 'closePriceNorm_lag_2': 0.021071649001024984, 'ret_lag_3': 0.04038431745702553, 'log_ret_lag_3': 0.041684627692084184, 'closePrice_lag_3': 0.00847286434832313, 'closePriceNorm_lag_3': 0.029387306124788855, 'ret_lag_4': 0.03169353090271425, 'log_ret_lag_4': 0.03110811934754318, 'closePrice_lag_4': 0.008707828325352036, 'closePriceNorm_lag_4': 0.02084419367934119, 'ret_lag_5': 0.03428076716233253, 'log_ret_lag_5': 0.031992105451618257, 'closePrice_lag_5': 0.007019478671836035, 'closePriceNorm_lag_5': 0.019396883747204118, 'ret_lag_6': 0.03227236289863935, 'log_ret_lag_6': 0.03609424414698504, 'closePrice_lag_6': 0.00793033725860823, 'closePriceNorm_lag_6': 0.018742750380828878, 'ret_lag_7': 0.038390170141728526, 'log_ret_lag_7': 0.042285236438055304, 'closePrice_lag_7': 0.0076592741441907355, 'closePriceNorm_lag_7': 0.029232914434085225, 'ret_lag_8': 0.03993163885214762, 'log_ret_lag_8': 0.04264227510559407, 'closePrice_lag_8': 0.007499839881621808, 'closePriceNorm_lag_8': 0.02862211079181698, 'ret_lag_9': 0.04228195641138201, 'log_ret_lag_9': 0.039989362928677566, 'closePrice_lag_9': 0.008489132481003765, 'closePriceNorm_lag_9': 0.023685893181424972, 'closePrice_lag_10': 0.008076986189812493, 'closePriceNorm_lag_10': 0.027413237711396102}
# Validation score: 0.01609304356516017
#
#
#
# Max Lag: 10
# NingXiang Initialised
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Successfully recorded model type: Regression
# Begin fitting Random Forest
# Finished fitting Random Forest
# Successfully set object output address
# {'ret_lag_1': 0.04000879945035111, 'log_ret_lag_1': 0.03852778268175427, 'closePrice_lag_1': 0.009043626835772822, 'closePriceNorm_lag_1': 0.023780653187101514, 'ret_lag_2': 0.03250388585483217, 'log_ret_lag_2': 0.03159632424216232, 'closePrice_lag_2': 0.007706692664439857, 'closePriceNorm_lag_2': 0.01860201514085648, 'ret_lag_3': 0.034057162203970925, 'log_ret_lag_3': 0.03461446917867828, 'closePrice_lag_3': 0.008985926337136458, 'closePriceNorm_lag_3': 0.030064389944878308, 'ret_lag_4': 0.031628898403849345, 'log_ret_lag_4': 0.030352773609462484, 'closePrice_lag_4': 0.006666916582857201, 'closePriceNorm_lag_4': 0.01764105739589838, 'ret_lag_5': 0.03496931064028774, 'log_ret_lag_5': 0.030249734174314726, 'closePrice_lag_5': 0.00938679847063319, 'closePriceNorm_lag_5': 0.017972825070304118, 'ret_lag_6': 0.0331174243795195, 'log_ret_lag_6': 0.03351448140522481, 'closePrice_lag_6': 0.007964565787810666, 'closePriceNorm_lag_6': 0.019578429086730652, 'ret_lag_7': 0.035668070473732875, 'log_ret_lag_7': 0.0363787767001201, 'closePrice_lag_7': 0.006939427390281032, 'closePriceNorm_lag_7': 0.024697528381069086, 'ret_lag_8': 0.03532148927526712, 'log_ret_lag_8': 0.03612946346109445, 'closePrice_lag_8': 0.007609939549434398, 'closePriceNorm_lag_8': 0.025687505154924236, 'ret_lag_9': 0.033950188431096415, 'log_ret_lag_9': 0.03846426666561337, 'closePrice_lag_9': 0.009395914037395687, 'closePriceNorm_lag_9': 0.025845551159956116, 'ret_lag_10': 0.0347194854671472, 'log_ret_lag_10': 0.03276678706583054, 'closePrice_lag_10': 0.010674906661274675, 'closePriceNorm_lag_10': 0.023215757396935363}
# Validation score: 0.016652516397079098

# %%
function_map = ['min', 'max', 'std', 'mean', 'slope', 'skew', 'abs_diff_mean', 'diff_std', 'sum']

for i in [3, 5, 10, 20]:
    print('Max Lag:', i)

    tmp_curated_data = copy.deepcopy(curated_data)

    for j in range(i+1, 11):
        tmp_curated_data = tmp_curated_data.drop(columns=[f'log_ret_lag_{j}', f'log_ret_normalised_by_day_lag_{j}', f'closePriceNorm_lag_{j}', f'closePrice_lag_{j}'], axis = 1)
    
    for j in [3, 5, 10, 20]:
        if j > i:

            columns = []
            for col in ['log_ret', 'closePrice', 'closePriceNorm', 'log_ret_normalised_by_day']:
                for func in function_map:
                    columns.append(f'{col}_{func}_{j}')
            tmp_curated_data = tmp_curated_data.drop(columns=columns, axis = 1)

    tmp_curated_data = tmp_curated_data.dropna()

    train = tmp_curated_data[(tmp_curated_data['date'] < val_date_start)]
    val = tmp_curated_data[(tmp_curated_data['date'] < test_date_start) & (tmp_curated_data['date'] >= val_date_start)]
    test = tmp_curated_data[(tmp_curated_data['date'] >= test_date_start)]

    jiaocheng = JiaoCheng.JiaoCheng()

    train_x = train.drop(columns=['date', 'log_ret'], axis = 1)
    train_y = train['log_ret']

    val_x = val.drop(columns=['date', 'log_ret'], axis = 1)
    val_y = val['log_ret']
    
    test_x = test.drop(columns=['date', 'log_ret'], axis = 1)
    test_y = test['log_ret']

    with open(f'../models/NingXiang_output_{LABEL}_lag_{i}.pickle', 'rb') as f:
        ningxiang_output = pickle.load(f)

    ningxiang_output = list(ningxiang_output.items())
    ningxiang_output = dict(ningxiang_output)

    jiaocheng = JiaoCheng.JiaoCheng()

    from lightgbm import LGBMRegressor as LGBR

    jiaocheng.read_in_model(LGBR, 'Regression')

    jiaocheng.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

    del train_x
    del train_y
    del val_x
    del val_y

    parameter_choices = {
        'n_estimators': (25, 50, 100, 200, 400),
        'max_depth': (3, 6, 12, 24, 48, 96, 192),
        'subsample': (0.4, 0.55, 0.7, 0.85),
        'colsample_bytree': (0.4, 0.55, 0.7, 0.85),
        'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
        'reg_alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10)

    }

    jiaocheng.set_hyperparameters(parameter_choices)

    jiaocheng.set_non_tuneable_hyperparameters({'random_state': 19260817, 'n_jobs': -1})

    jiaocheng.set_features(ningxiang_output)

    jiaocheng.set_tuning_order(['features', 'max_depth', 'colsample_bytree', 'subsample', 'n_estimators', 'reg_alpha', 'learning_rate'])

    jiaocheng.set_hyperparameter_default_values({
        'features': 0,
        'n_estimators': 50,
        'max_depth': 12,
        'subsample': 0.7,
        'colsample_bytree': 0.7,
        'learning_rate': 0.1,
        'reg_alpha': 0.01}
    )

    try:
        jiaocheng.read_in_tuning_result_df(f'../models/tuning/jiaocheng_{MODEL}_{LABEL}_lag_{i}.csv')
    except:
        pass

    jiaocheng.set_tuning_result_saving_address(f'../models/tuning/jiaocheng_{MODEL}_{LABEL}_lag_{i}.csv')
    jiaocheng.set_best_model_saving_address(f'../models/tmp_models/jiaocheng_{MODEL}_{LABEL}_lag_{i}.pickle')

    jiaocheng.tune()

    jiaocheng.view_best_combo_and_score()

    print('\n\n')
# Out:
# Max Lag: 1
# JiaoCheng Initialised
# JiaoCheng Initialised
# Successfully read in model <class 'lightgbm.sklearn.LGBMRegressor'>, which is a Regression model
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# Successfully recorded hyperparameter choices
# Successfully recorded non_tuneable_hyperparameter choices
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# Successfully read in tuning result of 120 rows
# Successfully set tuning output address
# Successfully set best model output address
#
# Default combo: [1, 2, 2, 2, 4, 2, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 6)
#
# As new Best Combo (1, 2, 2, 2, 4, 2, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 0), which had val score of -0.0111
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0111.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 1), which had val score of -0.0119
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0111.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 2), which had val score of -0.0195
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0111.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 3), which had val score of -0.0247
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0111.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 4), which had val score of -0.023
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0111.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 5), which had val score of -0.0167
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0111.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 6), which had val score of -0.0162
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0111.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 7), which had val score of -0.0208
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0111.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 8), which had val score of -0.0129
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0111.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 9), which had val score of -0.0143
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0111.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 10), which had val score of -0.0134
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0111.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 11), which had val score of -0.0124
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0111.
#         Has trained 120 of 369600 combinations so far
# As new Best Combo (1, 2, 2, 2, 4, 2, 12) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 12), which had val score of -0.0106
#         Current best combo: (1, 2, 2, 2, 4, 2, 12) with val score -0.0106.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 13), which had val score of -0.0218
#         Current best combo: (1, 2, 2, 2, 4, 2, 12) with val score -0.0106.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 14), which had val score of -0.0183
#         Current best combo: (1, 2, 2, 2, 4, 2, 12) with val score -0.0106.
#         Has trained 120 of 369600 combinations so far
# As new Best Combo (1, 2, 2, 2, 4, 2, 15) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 15), which had val score of -0.0095
#         Current best combo: (1, 2, 2, 2, 4, 2, 15) with val score -0.0095.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 16), which had val score of -0.0148
#         Current best combo: (1, 2, 2, 2, 4, 2, 15) with val score -0.0095.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 17), which had val score of -0.022
#         Current best combo: (1, 2, 2, 2, 4, 2, 15) with val score -0.0095.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 18), which had val score of -0.0138
#         Current best combo: (1, 2, 2, 2, 4, 2, 15) with val score -0.0095.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 19), which had val score of -0.0254
#         Current best combo: (1, 2, 2, 2, 4, 2, 15) with val score -0.0095.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 20), which had val score of -0.0195
#         Current best combo: (1, 2, 2, 2, 4, 2, 15) with val score -0.0095.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 21), which had val score of -0.015
#         Current best combo: (1, 2, 2, 2, 4, 2, 15) with val score -0.0095.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 2, 15) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_depth (index: 1)
#
# As new Best Combo (1, 0, 2, 2, 4, 2, 15) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 15), which had val score of 0.0103
#         Current best combo: (1, 0, 2, 2, 4, 2, 15) with val score 0.0103.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 4, 2, 15), which had val score of -0.0172
#         Current best combo: (1, 0, 2, 2, 4, 2, 15) with val score 0.0103.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 15), which had val score of -0.0095
#         Current best combo: (1, 0, 2, 2, 4, 2, 15) with val score 0.0103.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 4, 2, 15), which had val score of -0.009
#         Current best combo: (1, 0, 2, 2, 4, 2, 15) with val score 0.0103.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 4, 2, 2, 4, 2, 15), which had val score of -0.009
#         Current best combo: (1, 0, 2, 2, 4, 2, 15) with val score 0.0103.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 5, 2, 2, 4, 2, 15), which had val score of -0.009
#         Current best combo: (1, 0, 2, 2, 4, 2, 15) with val score 0.0103.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 6, 2, 2, 4, 2, 15), which had val score of -0.009
#         Current best combo: (1, 0, 2, 2, 4, 2, 15) with val score 0.0103.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 4, 2, 15) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: colsample_bytree (index: 3)
#
# As new Best Combo (1, 0, 2, 0, 4, 2, 15) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 0, 2, 0, 4, 2, 15), which had val score of 0.0114
#         Current best combo: (1, 0, 2, 0, 4, 2, 15) with val score 0.0114.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 4, 2, 15), which had val score of 0.0087
#         Current best combo: (1, 0, 2, 0, 4, 2, 15) with val score 0.0114.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 15), which had val score of 0.0103
#         Current best combo: (1, 0, 2, 0, 4, 2, 15) with val score 0.0114.
#         Has trained 120 of 369600 combinations so far
# As new Best Combo (1, 0, 2, 3, 4, 2, 15) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 15), which had val score of 0.0117
#         Current best combo: (1, 0, 2, 3, 4, 2, 15) with val score 0.0117.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 3, 4, 2, 15) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (1, 0, 0, 3, 4, 2, 15), which had val score of 0.0117
#         Current best combo: (1, 0, 2, 3, 4, 2, 15) with val score 0.0117.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 0, 1, 3, 4, 2, 15), which had val score of 0.0117
#         Current best combo: (1, 0, 2, 3, 4, 2, 15) with val score 0.0117.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 15), which had val score of 0.0117
#         Current best combo: (1, 0, 2, 3, 4, 2, 15) with val score 0.0117.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 0, 3, 3, 4, 2, 15), which had val score of 0.0117
#         Current best combo: (1, 0, 2, 3, 4, 2, 15) with val score 0.0117.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 3, 4, 2, 15) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: n_estimators (index: 0)
#
# As new Best Combo (0, 0, 2, 3, 4, 2, 15) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 0, 2, 3, 4, 2, 15), which had val score of 0.012
#         Current best combo: (0, 0, 2, 3, 4, 2, 15) with val score 0.012.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 15), which had val score of 0.0117
#         Current best combo: (0, 0, 2, 3, 4, 2, 15) with val score 0.012.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (2, 0, 2, 3, 4, 2, 15), which had val score of 0.004
#         Current best combo: (0, 0, 2, 3, 4, 2, 15) with val score 0.012.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (3, 0, 2, 3, 4, 2, 15), which had val score of -0.0125
#         Current best combo: (0, 0, 2, 3, 4, 2, 15) with val score 0.012.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (4, 0, 2, 3, 4, 2, 15), which had val score of -0.0479
#         Current best combo: (0, 0, 2, 3, 4, 2, 15) with val score 0.012.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 3, 4, 2, 15) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: reg_alpha (index: 5)
#
# Already Trained and Tested combination (0, 0, 2, 3, 4, 0, 15), which had val score of 0.0113
#         Current best combo: (0, 0, 2, 3, 4, 2, 15) with val score 0.012.
#         Has trained 120 of 369600 combinations so far
# As new Best Combo (0, 0, 2, 3, 4, 1, 15) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 15), which had val score of 0.0127
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 2, 15), which had val score of 0.012
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 3, 15), which had val score of 0.0103
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 4, 15), which had val score of 0.0039
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 5, 15), which had val score of -0.0002
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 3, 4, 1, 15) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: learning_rate (index: 4)
#
# Already Trained and Tested combination (0, 0, 2, 3, 0, 1, 15), which had val score of -0.0002
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 1, 1, 15), which had val score of -0.0002
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 2, 1, 15), which had val score of -0.0001
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 3, 1, 15), which had val score of 0.0033
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 15), which had val score of 0.0127
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 3, 4, 1, 15) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 2
# Hyperparameter: features (index: 6)
#
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 0), which had val score of 0.0025
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 1), which had val score of 0.0024
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 2), which had val score of 0.0052
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 3), which had val score of 0.003
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 4), which had val score of 0.008
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 5), which had val score of 0.0092
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 6), which had val score of 0.0119
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 7), which had val score of 0.012
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 8), which had val score of 0.0112
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 9), which had val score of 0.0123
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 10), which had val score of 0.011
#         Current best combo: (0, 0, 2, 3, 4, 1, 15) with val score 0.0127.
#         Has trained 120 of 369600 combinations so far
# As new Best Combo (0, 0, 2, 3, 4, 1, 11) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 11), which had val score of 0.0143
#         Current best combo: (0, 0, 2, 3, 4, 1, 11) with val score 0.0143.
#         Has trained 120 of 369600 combinations so far
# As new Best Combo (0, 0, 2, 3, 4, 1, 12) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 12), which had val score of 0.0144
#         Current best combo: (0, 0, 2, 3, 4, 1, 12) with val score 0.0144.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 13), which had val score of 0.0123
#         Current best combo: (0, 0, 2, 3, 4, 1, 12) with val score 0.0144.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 14), which had val score of 0.0115
#         Current best combo: (0, 0, 2, 3, 4, 1, 12) with val score 0.0144.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 15), which had val score of 0.0127
#         Current best combo: (0, 0, 2, 3, 4, 1, 12) with val score 0.0144.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 16), which had val score of 0.0115
#         Current best combo: (0, 0, 2, 3, 4, 1, 12) with val score 0.0144.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 17), which had val score of 0.012
#         Current best combo: (0, 0, 2, 3, 4, 1, 12) with val score 0.0144.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 18), which had val score of 0.0132
#         Current best combo: (0, 0, 2, 3, 4, 1, 12) with val score 0.0144.
#         Has trained 120 of 369600 combinations so far
# As new Best Combo (0, 0, 2, 3, 4, 1, 19) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 19), which had val score of 0.0144
#         Current best combo: (0, 0, 2, 3, 4, 1, 19) with val score 0.0144.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 20), which had val score of 0.0131
#         Current best combo: (0, 0, 2, 3, 4, 1, 19) with val score 0.0144.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 21), which had val score of 0.0136
#         Current best combo: (0, 0, 2, 3, 4, 1, 19) with val score 0.0144.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 3, 4, 1, 19) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 19), which had val score of 0.0144
#         Current best combo: (0, 0, 2, 3, 4, 1, 19) with val score 0.0144.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 1, 2, 3, 4, 1, 19), which had val score of 0.0049
#         Current best combo: (0, 0, 2, 3, 4, 1, 19) with val score 0.0144.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 2, 2, 3, 4, 1, 19), which had val score of 0.0031
#         Current best combo: (0, 0, 2, 3, 4, 1, 19) with val score 0.0144.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 3, 2, 3, 4, 1, 19), which had val score of 0.0062
#         Current best combo: (0, 0, 2, 3, 4, 1, 19) with val score 0.0144.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 4, 2, 3, 4, 1, 19), which had val score of 0.0062
#         Current best combo: (0, 0, 2, 3, 4, 1, 19) with val score 0.0144.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 5, 2, 3, 4, 1, 19), which had val score of 0.0062
#         Current best combo: (0, 0, 2, 3, 4, 1, 19) with val score 0.0144.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 6, 2, 3, 4, 1, 19), which had val score of 0.0062
#         Current best combo: (0, 0, 2, 3, 4, 1, 19) with val score 0.0144.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 3, 4, 1, 19) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: colsample_bytree (index: 3)
#
# As new Best Combo (0, 0, 2, 0, 4, 1, 19) was read in, best_clf is set to None
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 19), which had val score of 0.0157
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 1, 4, 1, 19), which had val score of 0.0141
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 2, 4, 1, 19), which had val score of 0.0123
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 19), which had val score of 0.0144
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 0, 4, 1, 19) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (0, 0, 0, 0, 4, 1, 19), which had val score of 0.0157
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 4, 1, 19), which had val score of 0.0157
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 19), which had val score of 0.0157
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 3, 0, 4, 1, 19), which had val score of 0.0157
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 0, 4, 1, 19) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 19), which had val score of 0.0157
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 0, 4, 1, 19), which had val score of 0.0141
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (2, 0, 2, 0, 4, 1, 19), which had val score of 0.0038
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (3, 0, 2, 0, 4, 1, 19), which had val score of -0.0134
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (4, 0, 2, 0, 4, 1, 19), which had val score of -0.0318
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 0, 4, 1, 19) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: reg_alpha (index: 5)
#
# Already Trained and Tested combination (0, 0, 2, 0, 4, 0, 19), which had val score of 0.0123
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 19), which had val score of 0.0157
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 19), which had val score of 0.0126
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 3, 19), which had val score of 0.0088
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 4, 19), which had val score of 0.0033
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 5, 19), which had val score of -0.0002
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 0, 4, 1, 19) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: learning_rate (index: 4)
#
# Already Trained and Tested combination (0, 0, 2, 0, 0, 1, 19), which had val score of -0.0002
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 1, 1, 19), which had val score of -0.0002
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 2, 1, 19), which had val score of -0.0001
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 3, 1, 19), which had val score of 0.0039
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 19), which had val score of 0.0157
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 0, 4, 1, 19) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 3
#
# Round 3
# Hyperparameter: features (index: 6)
#
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 0), which had val score of 0.0025
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 1), which had val score of 0.0022
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 2), which had val score of 0.0091
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 3), which had val score of 0.0069
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 4), which had val score of 0.0108
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 5), which had val score of 0.0125
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 6), which had val score of 0.0128
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 7), which had val score of 0.0108
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 8), which had val score of 0.0154
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 9), which had val score of 0.0087
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 10), which had val score of 0.0127
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 11), which had val score of 0.0148
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 12), which had val score of 0.0119
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 13), which had val score of 0.0115
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 14), which had val score of 0.0106
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 15), which had val score of 0.0137
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 16), which had val score of 0.0137
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 17), which had val score of 0.012
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 18), which had val score of 0.014
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 19), which had val score of 0.0157
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 20), which had val score of 0.0133
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 21), which had val score of 0.0124
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 0, 4, 1, 19) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 19), which had val score of 0.0157
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 1, 2, 0, 4, 1, 19), which had val score of 0.0094
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 2, 2, 0, 4, 1, 19), which had val score of 0.0044
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 3, 2, 0, 4, 1, 19), which had val score of -0.0016
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 4, 2, 0, 4, 1, 19), which had val score of -0.0016
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 5, 2, 0, 4, 1, 19), which had val score of -0.0016
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 6, 2, 0, 4, 1, 19), which had val score of -0.0016
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 0, 4, 1, 19) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: colsample_bytree (index: 3)
#
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 19), which had val score of 0.0157
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 1, 4, 1, 19), which had val score of 0.0141
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 2, 4, 1, 19), which had val score of 0.0123
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 1, 19), which had val score of 0.0144
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 0, 4, 1, 19) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (0, 0, 0, 0, 4, 1, 19), which had val score of 0.0157
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 1, 0, 4, 1, 19), which had val score of 0.0157
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 19), which had val score of 0.0157
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 3, 0, 4, 1, 19), which had val score of 0.0157
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 0, 4, 1, 19) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 19), which had val score of 0.0157
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 0, 4, 1, 19), which had val score of 0.0141
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (2, 0, 2, 0, 4, 1, 19), which had val score of 0.0038
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (3, 0, 2, 0, 4, 1, 19), which had val score of -0.0134
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (4, 0, 2, 0, 4, 1, 19), which had val score of -0.0318
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 0, 4, 1, 19) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: reg_alpha (index: 5)
#
# Already Trained and Tested combination (0, 0, 2, 0, 4, 0, 19), which had val score of 0.0123
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 19), which had val score of 0.0157
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 2, 19), which had val score of 0.0126
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 3, 19), which had val score of 0.0088
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 4, 19), which had val score of 0.0033
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 5, 19), which had val score of -0.0002
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 0, 4, 1, 19) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: learning_rate (index: 4)
#
# Already Trained and Tested combination (0, 0, 2, 0, 0, 1, 19), which had val score of -0.0002
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 1, 1, 19), which had val score of -0.0002
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 2, 1, 19), which had val score of -0.0001
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 3, 1, 19), which had val score of 0.0039
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 0, 4, 1, 19), which had val score of 0.0157
#         Current best combo: (0, 0, 2, 0, 4, 1, 19) with val score 0.0157.
#         Has trained 120 of 369600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 0, 4, 1, 19) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.015669
# Max Test Score:
#  -0.021962
# Max Combo Index:
#  (0, 0, 2, 0, 4, 1, 19) out of [5, 7, 4, 4, 5, 6, 22] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.7, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 19}
# Max Combo Features:
#  ('ret_lag_1', 'log_ret_lag_1', 'closePriceNorm_lag_7', 'closePriceNorm_lag_3', 'closePriceNorm_lag_10', 'closePriceNorm_lag_8', 'closePriceNorm_lag_9', 'closePriceNorm_lag_4', 'closePriceNorm_lag_1', 'closePriceNorm_lag_6', 'closePriceNorm_lag_5', 'closePriceNorm_lag_2', 'closePrice_lag_9', 'closePrice_lag_1', 'closePrice_lag_10', 'closePrice_lag_2', 'closePrice_lag_6', 'closePrice_lag_4', 'closePrice_lag_3', 'closePrice_lag_8')
# % Combos Checked: 120 out of 369600 which is 0.032468%
# Max Score:
#  0.015669
# Max Test Score:
#  -0.021962
# Max Combo Index:
#  (0, 0, 2, 0, 4, 1, 19) out of [5, 7, 4, 4, 5, 6, 22] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.7, 'colsample_bytree': 0.4, 'learning_rate': 0.1, 'reg_alpha': 0.001, 'features': 19}
# Max Combo Features:
#  ('ret_lag_1', 'log_ret_lag_1', 'closePriceNorm_lag_7', 'closePriceNorm_lag_3', 'closePriceNorm_lag_10', 'closePriceNorm_lag_8', 'closePriceNorm_lag_9', 'closePriceNorm_lag_4', 'closePriceNorm_lag_1', 'closePriceNorm_lag_6', 'closePriceNorm_lag_5', 'closePriceNorm_lag_2', 'closePrice_lag_9', 'closePrice_lag_1', 'closePrice_lag_10', 'closePrice_lag_2', 'closePrice_lag_6', 'closePrice_lag_4', 'closePrice_lag_3', 'closePrice_lag_8')
# % Combos Checked: 120 out of 369600 which is 0.032468%
#
#
#
# Max Lag: 2
# JiaoCheng Initialised
# JiaoCheng Initialised
# Successfully read in model <class 'lightgbm.sklearn.LGBMRegressor'>, which is a Regression model
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# Successfully recorded hyperparameter choices
# Successfully recorded non_tuneable_hyperparameter choices
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# Successfully read in tuning result of 88 rows
# Successfully set tuning output address
# Successfully set best model output address
#
# Default combo: [1, 2, 2, 2, 4, 2, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 6)
#
# As new Best Combo (1, 2, 2, 2, 4, 2, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 0), which had val score of -0.0123
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0123.
#         Has trained 88 of 403200 combinations so far
# As new Best Combo (1, 2, 2, 2, 4, 2, 1) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 1), which had val score of -0.0119
#         Current best combo: (1, 2, 2, 2, 4, 2, 1) with val score -0.0119.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 2), which had val score of -0.0177
#         Current best combo: (1, 2, 2, 2, 4, 2, 1) with val score -0.0119.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 3), which had val score of -0.0178
#         Current best combo: (1, 2, 2, 2, 4, 2, 1) with val score -0.0119.
#         Has trained 88 of 403200 combinations so far
# As new Best Combo (1, 2, 2, 2, 4, 2, 4) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 4), which had val score of -0.0103
#         Current best combo: (1, 2, 2, 2, 4, 2, 4) with val score -0.0103.
#         Has trained 88 of 403200 combinations so far
# As new Best Combo (1, 2, 2, 2, 4, 2, 5) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 5), which had val score of -0.0057
#         Current best combo: (1, 2, 2, 2, 4, 2, 5) with val score -0.0057.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 6), which had val score of -0.0173
#         Current best combo: (1, 2, 2, 2, 4, 2, 5) with val score -0.0057.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 7), which had val score of -0.0204
#         Current best combo: (1, 2, 2, 2, 4, 2, 5) with val score -0.0057.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 8), which had val score of -0.0118
#         Current best combo: (1, 2, 2, 2, 4, 2, 5) with val score -0.0057.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 9), which had val score of -0.0155
#         Current best combo: (1, 2, 2, 2, 4, 2, 5) with val score -0.0057.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 10), which had val score of -0.0101
#         Current best combo: (1, 2, 2, 2, 4, 2, 5) with val score -0.0057.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 11), which had val score of -0.0063
#         Current best combo: (1, 2, 2, 2, 4, 2, 5) with val score -0.0057.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 12), which had val score of -0.0128
#         Current best combo: (1, 2, 2, 2, 4, 2, 5) with val score -0.0057.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 13), which had val score of -0.0117
#         Current best combo: (1, 2, 2, 2, 4, 2, 5) with val score -0.0057.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 14), which had val score of -0.0108
#         Current best combo: (1, 2, 2, 2, 4, 2, 5) with val score -0.0057.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 15), which had val score of -0.0175
#         Current best combo: (1, 2, 2, 2, 4, 2, 5) with val score -0.0057.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 16), which had val score of -0.016
#         Current best combo: (1, 2, 2, 2, 4, 2, 5) with val score -0.0057.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 17), which had val score of -0.0173
#         Current best combo: (1, 2, 2, 2, 4, 2, 5) with val score -0.0057.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 18), which had val score of -0.0144
#         Current best combo: (1, 2, 2, 2, 4, 2, 5) with val score -0.0057.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 19), which had val score of -0.0198
#         Current best combo: (1, 2, 2, 2, 4, 2, 5) with val score -0.0057.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 20), which had val score of -0.0115
#         Current best combo: (1, 2, 2, 2, 4, 2, 5) with val score -0.0057.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 21), which had val score of -0.0125
#         Current best combo: (1, 2, 2, 2, 4, 2, 5) with val score -0.0057.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 22), which had val score of -0.0171
#         Current best combo: (1, 2, 2, 2, 4, 2, 5) with val score -0.0057.
#         Has trained 88 of 403200 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 23), which had val score of -0.0178
# ...
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 12), which had val score of -0.0027
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 13), which had val score of -0.0031
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 14), which had val score of -0.0011
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 15), which had val score of -0.0047
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 16), which had val score of -0.0032
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 17), which had val score of -0.0009
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 18), which had val score of -0.0038
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 19), which had val score of -0.0043
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 20), which had val score of 0.0133
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 21), which had val score of 0.0145
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 22), which had val score of 0.0169
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 23), which had val score of 0.018
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 24), which had val score of 0.0185
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 25), which had val score of 0.0153
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 26), which had val score of 0.017
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 27), which had val score of 0.0186
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 28), which had val score of 0.0237
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 29), which had val score of 0.0184
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 30), which had val score of 0.0198
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 31), which had val score of 0.0213
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 32), which had val score of 0.0201
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 33), which had val score of 0.019
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 34), which had val score of 0.0213
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 35), which had val score of 0.0233
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 36), which had val score of 0.0203
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 37), which had val score of 0.0198
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 38), which had val score of 0.0163
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 39), which had val score of 0.0174
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 4, 2, 28) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: max_depth (index: 1)
#
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 28), which had val score of 0.0237
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 4, 2, 28), which had val score of 0.0038
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 28), which had val score of -0.0021
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 3, 2, 2, 4, 2, 28), which had val score of -0.0022
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 4, 2, 2, 4, 2, 28), which had val score of -0.0022
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 5, 2, 2, 4, 2, 28), which had val score of -0.0022
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 6, 2, 2, 4, 2, 28), which had val score of -0.0022
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 4, 2, 28) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: colsample_bytree (index: 3)
#
# Already Trained and Tested combination (1, 0, 2, 0, 4, 2, 28), which had val score of 0.0237
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 4, 2, 28), which had val score of 0.0215
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 28), which had val score of 0.0237
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 3, 4, 2, 28), which had val score of 0.0204
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 4, 2, 28) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (1, 0, 0, 2, 4, 2, 28), which had val score of 0.0237
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 1, 2, 4, 2, 28), which had val score of 0.0237
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 28), which had val score of 0.0237
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 3, 2, 4, 2, 28), which had val score of 0.0237
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 4, 2, 28) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 0, 2, 2, 4, 2, 28), which had val score of 0.0194
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 28), which had val score of 0.0237
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (2, 0, 2, 2, 4, 2, 28), which had val score of 0.0099
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (3, 0, 2, 2, 4, 2, 28), which had val score of -0.0093
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (4, 0, 2, 2, 4, 2, 28), which had val score of -0.0322
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 4, 2, 28) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: reg_alpha (index: 5)
#
# Already Trained and Tested combination (1, 0, 2, 2, 4, 0, 28), which had val score of 0.0219
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 1, 28), which had val score of 0.0206
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 28), which had val score of 0.0237
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 3, 28), which had val score of 0.0171
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 4, 28), which had val score of 0.0038
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 5, 28), which had val score of -0.0002
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 4, 2, 28) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: learning_rate (index: 4)
#
# Already Trained and Tested combination (1, 0, 2, 2, 0, 2, 28), which had val score of -0.0002
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 1, 2, 28), which had val score of -0.0002
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 2, 2, 28), which had val score of -0.0
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 3, 2, 28), which had val score of 0.0082
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 2, 28), which had val score of 0.0237
#         Current best combo: (1, 0, 2, 2, 4, 2, 28) with val score 0.0237.
#         Has trained 128 of 672000 combinations so far
#
# Best combo after this hyperparameter: (1, 0, 2, 2, 4, 2, 28) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.023725
# Max Test Score:
#  -0.028636
# Max Combo Index:
#  (1, 0, 2, 2, 4, 2, 28) out of [5, 7, 4, 4, 5, 6, 40] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.1, 'reg_alpha': 0.01, 'features': 28}
# Max Combo Features:
#  ('ret_lag_1', 'log_ret_lag_1', 'log_ret_lag_9', 'log_ret_lag_7', 'log_ret_lag_8', 'ret_lag_7', 'ret_lag_8', 'ret_lag_5', 'ret_lag_10', 'log_ret_lag_3', 'ret_lag_3', 'ret_lag_9', 'log_ret_lag_6', 'ret_lag_6', 'log_ret_lag_10', 'ret_lag_2', 'ret_lag_4', 'log_ret_lag_2', 'log_ret_lag_4', 'log_ret_lag_5', 'closePriceNorm_lag_3', 'closePriceNorm_lag_9', 'closePriceNorm_lag_8', 'closePriceNorm_lag_7', 'closePriceNorm_lag_1', 'closePriceNorm_lag_10', 'closePriceNorm_lag_6', 'closePriceNorm_lag_2', 'closePriceNorm_lag_5')
# % Combos Checked: 128 out of 672000 which is 0.019048%
# Max Score:
#  0.023725
# Max Test Score:
#  -0.028636
# Max Combo Index:
#  (1, 0, 2, 2, 4, 2, 28) out of [5, 7, 4, 4, 5, 6, 40] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 50, 'max_depth': 3, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.1, 'reg_alpha': 0.01, 'features': 28}
# Max Combo Features:
#  ('ret_lag_1', 'log_ret_lag_1', 'log_ret_lag_9', 'log_ret_lag_7', 'log_ret_lag_8', 'ret_lag_7', 'ret_lag_8', 'ret_lag_5', 'ret_lag_10', 'log_ret_lag_3', 'ret_lag_3', 'ret_lag_9', 'log_ret_lag_6', 'ret_lag_6', 'log_ret_lag_10', 'ret_lag_2', 'ret_lag_4', 'log_ret_lag_2', 'log_ret_lag_4', 'log_ret_lag_5', 'closePriceNorm_lag_3', 'closePriceNorm_lag_9', 'closePriceNorm_lag_8', 'closePriceNorm_lag_7', 'closePriceNorm_lag_1', 'closePriceNorm_lag_10', 'closePriceNorm_lag_6', 'closePriceNorm_lag_2', 'closePriceNorm_lag_5')
# % Combos Checked: 128 out of 672000 which is 0.019048%
