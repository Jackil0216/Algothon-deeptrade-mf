# %%
import sys
import os
import pickle
import pandas as pd
import json
import datetime
import time
import copy
import numpy as np

py_file_location = '../PrivatePackages'
sys.path.append(os.path.abspath(py_file_location))
from sklearn.model_selection import train_test_split

import JiaoCheng
import NingXiang
# Out:
# /Applications/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
LABEL = 'logret'
MODEL = 'lstmr'

# %%
curated_data = pd.read_csv('../data/curated_data.csv')
curated_data = curated_data[['date', 
                        'stock',
                        'log_ret',
                        'closePrice_lag_1', 
                        'log_ret_normalised_by_day_lag_1', 
                        'closePriceNorm_lag_1', 
                        'log_ret_lag_1', 
                        'mean_log_ret_lag_1',
                        'mean_closePrice_lag_1',
                        'mean_closePriceNorm_lag_1',
                        'mean_log_ret_normalised_by_day_lag_1', 
                        'pos_log_ret_lag_1',
                        'pos_closePrice_lag_1',
                        'pos_closePriceNorm_lag_1',
                        'pos_log_ret_normalised_by_day_lag_1']]
curated_data['date'] = pd.to_datetime(curated_data['date'])

# %%
date = [datetime.datetime(year=2022, month=12, day = 31) + datetime.timedelta(days=i) for i in range(250)]
val_date_start = date[175]
test_date_start = date[175+38]

# %%
curated_data['date'] = pd.to_datetime(curated_data['date'])
curated_data = curated_data.dropna()

train = curated_data[(curated_data['date'] < val_date_start)]
val = curated_data[(curated_data['date'] < test_date_start) & (curated_data['date'] >= val_date_start)]
test = curated_data[(curated_data['date'] >= test_date_start)]

# %%
def data_factory(data, lag):
    x_list, y_list = np.array([]), np.array([])

    for id, stock_data in data.groupby('stock'):
        stock_data.sort_values(by='date', inplace=True)
        stock_data.drop(['stock', 'date'], axis=1, inplace=True)
        stock_data.index = range(len(stock_data))

        for i in range(len(stock_data)):
            
            if i < lag-1:
                continue

            x = stock_data.iloc[i-lag+1:i+1].values.copy()
            x[-1:, 0] = 0 # mask last day's return
            y = stock_data.loc[i]['log_ret']
            
            # x_list.append(x)
            # y_list.append(y)

            x_list = np.append(x_list, x)
            y_list = np.append(y_list, y)
    
    return x_list, y_list

# %%
LAG = 5

train_x, train_y = data_factory(train, LAG)
val_x, val_y = data_factory(val, LAG)
test_x, test_y = data_factory(test, LAG)

# %%
jiaocheng = JiaoCheng.JiaoCheng()

from models.LSTM import LSTMR_pt as LSTMR

jiaocheng.read_in_model(LSTMR, 'Regression')

jiaocheng.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

parameter_choices = {
    'lstm_hidden_layer_n_neurons': [6, 12, 25, 50, 100],
    'lstm_n_hidden_layers': [1, 2, 3],
    'bi_lstm': [False, True],
    'n_hidden_layers': [1, 2, 3],
    'batch_size': [64, 128, 256, 512],
    'learning_rate': [0.001, 0.01, 0.1, 1],
    'dense_hidden_layer_n_neurons': [6, 12, 25, 50, 100],
    'activation': ['relu', 'sigmoid', 'tanh', 'softmax'],
    'dropout_prob': [0, 0.1, 0.3, 0.5],
    'batch_normalisation': [False, True],
    'dense_layer_type': ['Dense', 'Residual'],
    'attention_num_heads': [0, 1],

}

jiaocheng.set_hyperparameters(parameter_choices)

jiaocheng.set_non_tuneable_hyperparameters({'verbose' : True, 'random_state' : 19260817, 'loss_function':'MSE', 'num_epochs':250, 'grad_clip': False})

jiaocheng.set_tuning_order(['lstm_n_hidden_layers', 'n_hidden_layers', 'lstm_hidden_layer_n_neurons', 'dense_hidden_layer_n_neurons', 
                            'bi_lstm', 'attention_num_heads', 'activation', 'dense_layer_type',
                            'dropout_prob', 'batch_size', 'batch_normalisation', 'learning_rate'])

jiaocheng.set_hyperparameter_default_values({
    'lstm_hidden_layer_n_neurons': 6,
    'lstm_n_hidden_layers': 1,
    'bi_lstm': False,
    'n_hidden_layers': 1,
    'batch_size': 128,
    'learning_rate': 0.01,
    'dense_hidden_layer_n_neurons': 6,
    'activation': 'relu',
    'dropout_prob': 0.1,
    'batch_normalisation': False,
    'dense_layer_type': 'Dense',
    'attention_num_heads': 0}
)

try:
    jiaocheng.read_in_tuning_result_df(f'../models/tuning/jiaocheng_{MODEL}_{LABEL}.csv')
except:
    pass

jiaocheng.set_tuning_result_saving_address(f'../models/tuning/jiaocheng_{MODEL}_{LABEL}.csv')
jiaocheng.set_best_model_saving_address(f'../models/tmp_models/jiaocheng_{MODEL}_{LABEL}.pickle')

jiaocheng.tune()

jiaocheng.view_best_combo_and_score()

print('\n\n')
# Out:
# JiaoCheng Initialised
# Successfully read in model <class 'models.LSTM.LSTMR_pt'>, which is a Regression model
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# Successfully recorded hyperparameter choices
# Successfully recorded non_tuneable_hyperparameter choices
# Error message: 'dict' object is not callable
# Error Importing this Row: (0, lstm_hidden_layer_n_neurons                    50.0
# lstm_n_hidden_layers                            1.0
# bi_lstm                                         0.0
# n_hidden_layers                                 1.0
# batch_size                                    128.0
# learning_rate                                  0.01
# dense_hidden_layer_n_neurons                   50.0
# activation                                     relu
# num_epochs                                    100.0
# dropout_prob                                    0.1
# batch_normalisation                             0.0
# dense_layer_type                              Dense
# grad_clip                                       0.0
# Train r2                                   -0.23309
# Val r2                                    -0.198103
# Test r2                                   -0.191339
# Train RMSE                                 0.006767
# Val RMSE                                   0.006819
# Test RMSE                                  0.006882
# Train MAPE                      853893376639.712524
# Val MAPE                        891395777574.413086
# Test MAPE                       859427455276.224854
# Time                                          49.65
# verbose                                        True
# random_state                             19260817.0
# loss_function                                   MSE
# Name: 0, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (1, lstm_hidden_layer_n_neurons                    50.0
# lstm_n_hidden_layers                            2.0
# bi_lstm                                       False
# n_hidden_layers                                 1.0
# batch_size                                    128.0
# learning_rate                                  0.01
# dense_hidden_layer_n_neurons                   50.0
# activation                                     relu
# num_epochs                                    100.0
# dropout_prob                                    0.1
# batch_normalisation                           False
# dense_layer_type                              Dense
# grad_clip                                     False
# Train r2                                  -0.066136
# Val r2                                    -0.077677
# Test r2                                   -0.077147
# Train RMSE                                 0.006292
# Val RMSE                                   0.006467
# Test RMSE                                  0.006544
# Train MAPE                      393419397748.192688
# Val MAPE                         410698103021.53833
# Test MAPE                       395969146866.576721
# Time                                          68.85
# verbose                                        True
# random_state                             19260817.0
# loss_function                                   MSE
# Name: 1, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (2, lstm_hidden_layer_n_neurons                    50.0
# lstm_n_hidden_layers                            3.0
# bi_lstm                                       False
# n_hidden_layers                                 1.0
# batch_size                                    128.0
# learning_rate                                  0.01
# dense_hidden_layer_n_neurons                   50.0
# activation                                     relu
# num_epochs                                    100.0
# dropout_prob                                    0.1
# batch_normalisation                           False
# dense_layer_type                              Dense
# grad_clip                                     False
# Train r2                                  -0.143209
# Val r2                                    -0.117652
# Test r2                                    -0.11327
# Train RMSE                                 0.006516
# Val RMSE                                   0.006586
# Test RMSE                                  0.006653
# Train MAPE                      677973872202.741699
# Val MAPE                        707750011325.231812
# Test MAPE                       682367817424.602539
# Time                                          93.31
# verbose                                        True
# random_state                             19260817.0
# loss_function                                   MSE
# Name: 2, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (3, lstm_hidden_layer_n_neurons                    50.0
# lstm_n_hidden_layers                            2.0
# bi_lstm                                       False
# n_hidden_layers                                 2.0
# batch_size                                    128.0
# learning_rate                                  0.01
# dense_hidden_layer_n_neurons                   50.0
# activation                                     relu
# num_epochs                                    100.0
# dropout_prob                                    0.1
# batch_normalisation                           False
# dense_layer_type                              Dense
# grad_clip                                     False
# Train r2                                  -0.143401
# Val r2                                    -0.117822
# Test r2                                   -0.113435
# Train RMSE                                 0.006516
# Val RMSE                                   0.006587
# Test RMSE                                  0.006653
# Train MAPE                      678401512518.501343
# Val MAPE                        708196433305.091675
# Test MAPE                       682798229275.076172
# Time                                          74.42
# verbose                                        True
# random_state                             19260817.0
# loss_function                                   MSE
# Name: 3, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (4, lstm_hidden_layer_n_neurons                     50.0
# lstm_n_hidden_layers                             2.0
# bi_lstm                                        False
# n_hidden_layers                                  3.0
# batch_size                                     128.0
# learning_rate                                   0.01
# dense_hidden_layer_n_neurons                    50.0
# activation                                      relu
# num_epochs                                     100.0
# dropout_prob                                     0.1
# batch_normalisation                            False
# dense_layer_type                               Dense
# grad_clip                                      False
# Train r2                                   -0.442173
# Val r2                                     -0.388469
# Test r2                                    -0.376367
# Train RMSE                                  0.007318
# Val RMSE                                    0.007341
# Test RMSE                                   0.007397
# Train MAPE                      1160961278214.793701
# Val MAPE                        1211949886999.431152
# Test MAPE                       1168485462361.623047
# Time                                           82.25
# verbose                                         True
# random_state                              19260817.0
# loss_function                                    MSE
# Name: 4, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (5, lstm_hidden_layer_n_neurons                     6.0
# lstm_n_hidden_layers                            2.0
# bi_lstm                                       False
# n_hidden_layers                                 1.0
# batch_size                                    128.0
# learning_rate                                  0.01
# dense_hidden_layer_n_neurons                   50.0
# activation                                     relu
# num_epochs                                    100.0
# dropout_prob                                    0.1
# batch_normalisation                           False
# dense_layer_type                              Dense
# grad_clip                                     False
# Train r2                                  -0.065576
# Val r2                                    -0.076955
# Test r2                                   -0.076514
# Train RMSE                                 0.006291
# Val RMSE                                   0.006465
# Test RMSE                                  0.006542
# Train MAPE                      391261371133.853516
# Val MAPE                        408376607877.929626
# Test MAPE                       393730908012.521606
# Time                                          36.68
# verbose                                        True
# random_state                             19260817.0
# loss_function                                   MSE
# Name: 5, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (6, lstm_hidden_layer_n_neurons                    12.0
# lstm_n_hidden_layers                            2.0
# bi_lstm                                       False
# n_hidden_layers                                 1.0
# batch_size                                    128.0
# learning_rate                                  0.01
# dense_hidden_layer_n_neurons                   50.0
# activation                                     relu
# num_epochs                                    100.0
# dropout_prob                                    0.1
# batch_normalisation                           False
# dense_layer_type                              Dense
# grad_clip                                     False
# Train r2                                  -0.064418
# Val r2                                    -0.075854
# Test r2                                   -0.075352
# Train RMSE                                 0.006287
# Val RMSE                                   0.006462
# Test RMSE                                  0.006538
# Train MAPE                      387752358518.605652
# Val MAPE                        404782171385.574951
# Test MAPE                       390265379584.529114
# Time                                          37.13
# verbose                                        True
# random_state                             19260817.0
# loss_function                                   MSE
# Name: 6, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (7, lstm_hidden_layer_n_neurons                    25.0
# lstm_n_hidden_layers                            2.0
# bi_lstm                                       False
# n_hidden_layers                                 1.0
# batch_size                                    128.0
# learning_rate                                  0.01
# dense_hidden_layer_n_neurons                   50.0
# activation                                     relu
# num_epochs                                    100.0
# dropout_prob                                    0.1
# batch_normalisation                           False
# dense_layer_type                              Dense
# grad_clip                                     False
# Train r2                                  -0.065556
# Val r2                                    -0.077061
# Test r2                                    -0.07654
# Train RMSE                                  0.00629
# Val RMSE                                   0.006466
# Test RMSE                                  0.006542
# Train MAPE                      391512115499.539673
# Val MAPE                        408707054268.141846
# Test MAPE                       394049503531.358398
# Time                                          65.95
# verbose                                        True
# random_state                             19260817.0
# loss_function                                   MSE
# Name: 7, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (8, lstm_hidden_layer_n_neurons                     6.0
# lstm_n_hidden_layers                            1.0
# bi_lstm                                       False
# n_hidden_layers                                 1.0
# batch_size                                    128.0
# learning_rate                                  0.01
# dense_hidden_layer_n_neurons                    6.0
# activation                                     relu
# num_epochs                                    100.0
# dropout_prob                                    0.1
# batch_normalisation                           False
# dense_layer_type                              Dense
# grad_clip                                     False
# Train r2                                  -0.236213
# Val r2                                    -0.202662
# Test r2                                   -0.196159
# Train RMSE                                 0.006775
# Val RMSE                                   0.006832
# Test RMSE                                  0.006896
# Train MAPE                      869749261895.736206
# Val MAPE                        911255654662.504761
# Test MAPE                       889406678434.157104
# Time                                          26.82
# verbose                                        True
# random_state                             19260817.0
# loss_function                                   MSE
# Name: 8, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (9, lstm_hidden_layer_n_neurons                     6.0
# lstm_n_hidden_layers                            2.0
# bi_lstm                                       False
# n_hidden_layers                                 1.0
# batch_size                                    128.0
# learning_rate                                  0.01
# dense_hidden_layer_n_neurons                    6.0
# activation                                     relu
# num_epochs                                    100.0
# dropout_prob                                    0.1
# batch_normalisation                           False
# dense_layer_type                              Dense
# grad_clip                                     False
# Train r2                                  -0.059879
# Val r2                                    -0.071027
# Test r2                                   -0.070598
# Train RMSE                                 0.006274
# Val RMSE                                   0.006448
# Test RMSE                                  0.006524
# Train MAPE                       372402357512.84552
# Val MAPE                        388758009052.633728
# Test MAPE                       374815895300.222778
# Time                                          45.41
# verbose                                        True
# random_state                             19260817.0
# loss_function                                   MSE
# Name: 9, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (10, lstm_hidden_layer_n_neurons                     6.0
# lstm_n_hidden_layers                            3.0
# bi_lstm                                       False
# n_hidden_layers                                 1.0
# batch_size                                    128.0
# learning_rate                                  0.01
# dense_hidden_layer_n_neurons                    6.0
# activation                                     relu
# num_epochs                                    100.0
# dropout_prob                                    0.1
# batch_normalisation                           False
# dense_layer_type                              Dense
# grad_clip                                     False
# Train r2                                  -0.078874
# Val r2                                    -0.061282
# Test r2                                    -0.05868
# Train RMSE                                  0.00633
# Val RMSE                                   0.006418
# Test RMSE                                  0.006487
# Train MAPE                      513479963828.684021
# Val MAPE                        536031645340.977783
# Test MAPE                       516807824865.942871
# Time                                           57.8
# verbose                                        True
# random_state                             19260817.0
# loss_function                                   MSE
# Name: 10, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (11, lstm_hidden_layer_n_neurons                      6.0
# lstm_n_hidden_layers                             3.0
# bi_lstm                                        False
# n_hidden_layers                                  2.0
# batch_size                                     128.0
# learning_rate                                   0.01
# dense_hidden_layer_n_neurons                     6.0
# activation                                      relu
# num_epochs                                     100.0
# dropout_prob                                     0.1
# batch_normalisation                            False
# dense_layer_type                               Dense
# grad_clip                                      False
# Train r2                                   -0.432616
# Val r2                                     -0.379709
# Test r2                                    -0.367847
# Train RMSE                                  0.007294
# Val RMSE                                    0.007318
# Test RMSE                                   0.007374
# Train MAPE                        1148777912883.7854
# Val MAPE                        1199231598903.328369
# Test MAPE                       1156223456560.634521
# Time                                           56.18
# verbose                                         True
# random_state                              19260817.0
# loss_function                                    MSE
# Name: 11, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (12, lstm_hidden_layer_n_neurons                    6.0
# lstm_n_hidden_layers                           3.0
# bi_lstm                                      False
# n_hidden_layers                                3.0
# batch_size                                   128.0
# learning_rate                                 0.01
# dense_hidden_layer_n_neurons                   6.0
# activation                                    relu
# num_epochs                                   100.0
# dropout_prob                                   0.1
# batch_normalisation                          False
# dense_layer_type                             Dense
# grad_clip                                    False
# Train r2                                  -0.00585
# Val r2                                   -0.010398
# Test r2                                  -0.010634
# Train RMSE                                0.006112
# Val RMSE                                  0.006262
# Test RMSE                                 0.006339
# Train MAPE                      88848458351.373001
# Val MAPE                        92750620610.319244
# Test MAPE                       89424284758.624832
# Time                                         48.92
# verbose                                       True
# random_state                            19260817.0
# loss_function                                  MSE
# Name: 12, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (13, lstm_hidden_layer_n_neurons                   12.0
# lstm_n_hidden_layers                           3.0
# bi_lstm                                      False
# n_hidden_layers                                3.0
# batch_size                                   128.0
# learning_rate                                 0.01
# dense_hidden_layer_n_neurons                   6.0
# activation                                    relu
# num_epochs                                   100.0
# dropout_prob                                   0.1
# batch_normalisation                          False
# dense_layer_type                             Dense
# grad_clip                                    False
# Train r2                                 -0.000262
# Val r2                                   -0.000128
# Test r2                                  -0.000184
# Train RMSE                                0.006095
# Val RMSE                                   0.00623
# Test RMSE                                 0.006306
# Train MAPE                      67348100834.447319
# Val MAPE                         70305982402.28154
# Test MAPE                       67784583533.837143
# Time                                         66.24
# verbose                                       True
# random_state                            19260817.0
# loss_function                                  MSE
# Name: 13, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (14, lstm_hidden_layer_n_neurons                   25.0
# lstm_n_hidden_layers                           3.0
# bi_lstm                                      False
# n_hidden_layers                                3.0
# batch_size                                   128.0
# learning_rate                                 0.01
# dense_hidden_layer_n_neurons                   6.0
# activation                                    relu
# num_epochs                                   100.0
# dropout_prob                                   0.1
# batch_normalisation                          False
# dense_layer_type                             Dense
# grad_clip                                    False
# Train r2                                 -0.006063
# Val r2                                   -0.010675
# Test r2                                  -0.010911
# Train RMSE                                0.006112
# Val RMSE                                  0.006263
# Test RMSE                                 0.006339
# Train MAPE                      91179065870.428223
# Val MAPE                        95183586784.438583
# Test MAPE                        91769996933.17244
# Time                                         71.25
# verbose                                       True
# random_state                            19260817.0
# loss_function                                  MSE
# Name: 14, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (15, lstm_hidden_layer_n_neurons                  50.0
# lstm_n_hidden_layers                          3.0
# bi_lstm                                     False
# n_hidden_layers                               3.0
# batch_size                                  128.0
# learning_rate                                0.01
# dense_hidden_layer_n_neurons                  6.0
# activation                                   relu
# num_epochs                                  100.0
# dropout_prob                                  0.1
# batch_normalisation                         False
# dense_layer_type                            Dense
# grad_clip                                   False
# Train r2                                -0.000728
# Val r2                                  -0.002867
# Test r2                                 -0.003055
# Train RMSE                               0.006096
# Val RMSE                                 0.006239
# Test RMSE                                0.006315
# Train MAPE                      5397155684.855823
# Val MAPE                        5634194994.329763
# Test MAPE                       5432134623.427318
# Time                                        104.1
# verbose                                      True
# random_state                           19260817.0
# loss_function                                 MSE
# Name: 15, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (16, lstm_hidden_layer_n_neurons                  100.0
# lstm_n_hidden_layers                           3.0
# bi_lstm                                      False
# n_hidden_layers                                3.0
# batch_size                                   128.0
# learning_rate                                 0.01
# dense_hidden_layer_n_neurons                   6.0
# activation                                    relu
# num_epochs                                   100.0
# dropout_prob                                   0.1
# batch_normalisation                          False
# dense_layer_type                             Dense
# grad_clip                                    False
# Train r2                                 -0.006008
# Val r2                                   -0.010603
# Test r2                                  -0.010839
# Train RMSE                                0.006112
# Val RMSE                                  0.006263
# Test RMSE                                 0.006339
# Train MAPE                      90579596584.421555
# Val MAPE                        94557789225.925201
# Test MAPE                       91166642489.768265
# Time                                        213.83
# verbose                                       True
# random_state                            19260817.0
# loss_function                                  MSE
# Name: 16, dtype: object)
# Error message: 200.0
# Error Importing this Row: (17, lstm_hidden_layer_n_neurons                  200.0
# lstm_n_hidden_layers                           3.0
# bi_lstm                                      False
# n_hidden_layers                                3.0
# batch_size                                   128.0
# learning_rate                                 0.01
# dense_hidden_layer_n_neurons                   6.0
# activation                                    relu
# num_epochs                                   100.0
# dropout_prob                                   0.1
# batch_normalisation                          False
# dense_layer_type                             Dense
# grad_clip                                    False
# Train r2                                 -0.006021
# Val r2                                   -0.010621
# Test r2                                  -0.010857
# Train RMSE                                0.006112
# Val RMSE                                  0.006263
# Test RMSE                                 0.006339
# Train MAPE                      90725825099.019562
# Val MAPE                        94710439994.791183
# Test MAPE                       91313818710.626602
# Time                                        437.46
# verbose                                       True
# random_state                            19260817.0
# loss_function                                  MSE
# Name: 17, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (18, lstm_hidden_layer_n_neurons                   12.0
# lstm_n_hidden_layers                           3.0
# bi_lstm                                      False
# n_hidden_layers                                3.0
# batch_size                                   128.0
# learning_rate                                 0.01
# dense_hidden_layer_n_neurons                  12.0
# activation                                    relu
# num_epochs                                   100.0
# dropout_prob                                   0.1
# batch_normalisation                          False
# dense_layer_type                             Dense
# grad_clip                                    False
# Train r2                                 -0.005916
# Val r2                                   -0.010484
# Test r2                                   -0.01072
# Train RMSE                                0.006112
# Val RMSE                                  0.006263
# Test RMSE                                 0.006339
# Train MAPE                      89573852897.528397
# Val MAPE                        93507873978.489166
# Test MAPE                       90154380583.149124
# Time                                         63.79
# verbose                                       True
# random_state                            19260817.0
# loss_function                                  MSE
# Name: 18, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (19, lstm_hidden_layer_n_neurons                   12.0
# lstm_n_hidden_layers                           3.0
# bi_lstm                                      False
# n_hidden_layers                                3.0
# batch_size                                   128.0
# learning_rate                                 0.01
# dense_hidden_layer_n_neurons                  25.0
# activation                                    relu
# num_epochs                                   100.0
# dropout_prob                                   0.1
# batch_normalisation                          False
# dense_layer_type                             Dense
# grad_clip                                    False
# Train r2                                 -0.005862
# Val r2                                   -0.010414
# Test r2                                   -0.01065
# Train RMSE                                0.006112
# Val RMSE                                  0.006262
# Test RMSE                                 0.006339
# Train MAPE                      88985090720.331207
# Val MAPE                        92893253777.528717
# Test MAPE                       89561802641.272247
# Time                                         72.44
# verbose                                       True
# random_state                            19260817.0
# loss_function                                  MSE
# Name: 19, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (20, lstm_hidden_layer_n_neurons                   12.0
# lstm_n_hidden_layers                           3.0
# bi_lstm                                      False
# n_hidden_layers                                3.0
# batch_size                                   128.0
# learning_rate                                 0.01
# dense_hidden_layer_n_neurons                  50.0
# activation                                    relu
# num_epochs                                   100.0
# dropout_prob                                   0.1
# batch_normalisation                          False
# dense_layer_type                             Dense
# grad_clip                                    False
# Train r2                                  -0.00602
# Val r2                                   -0.010619
# Test r2                                  -0.010855
# Train RMSE                                0.006112
# Val RMSE                                  0.006263
# Test RMSE                                 0.006339
# Train MAPE                      90708693724.924393
# Val MAPE                        94692556222.706482
# Test MAPE                       91296576308.182922
# Time                                         59.91
# verbose                                       True
# random_state                            19260817.0
# loss_function                                  MSE
# Name: 20, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (21, lstm_hidden_layer_n_neurons                   12.0
# lstm_n_hidden_layers                           3.0
# bi_lstm                                      False
# n_hidden_layers                                3.0
# batch_size                                   128.0
# learning_rate                                 0.01
# dense_hidden_layer_n_neurons                 100.0
# activation                                    relu
# num_epochs                                   100.0
# dropout_prob                                   0.1
# batch_normalisation                          False
# dense_layer_type                             Dense
# grad_clip                                    False
# Train r2                                 -0.005806
# Val r2                                    -0.01034
# Test r2                                  -0.010576
# Train RMSE                                0.006112
# Val RMSE                                  0.006262
# Test RMSE                                 0.006338
# Train MAPE                      88359215932.899719
# Val MAPE                        92239891006.403564
# Test MAPE                       88931871562.522552
# Time                                         59.02
# verbose                                       True
# random_state                            19260817.0
# loss_function                                  MSE
# Name: 21, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (22, lstm_hidden_layer_n_neurons                   12.0
# lstm_n_hidden_layers                           3.0
# bi_lstm                                      False
# n_hidden_layers                                3.0
# batch_size                                   128.0
# learning_rate                                 0.01
# dense_hidden_layer_n_neurons                 200.0
# activation                                    relu
# num_epochs                                   100.0
# dropout_prob                                   0.1
# batch_normalisation                          False
# dense_layer_type                             Dense
# grad_clip                                    False
# Train r2                                 -0.002724
# Val r2                                   -0.006116
# Test r2                                  -0.006343
# Train RMSE                                0.006102
# Val RMSE                                  0.006249
# Test RMSE                                 0.006325
# Train MAPE                      47899579585.633911
# Val MAPE                        50003295678.685959
# Test MAPE                       48210016517.609802
# Time                                         91.05
# verbose                                       True
# random_state                            19260817.0
# loss_function                                  MSE
# Name: 22, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (23, lstm_hidden_layer_n_neurons                   12.0
# lstm_n_hidden_layers                           3.0
# bi_lstm                                       True
# n_hidden_layers                                3.0
# batch_size                                   128.0
# learning_rate                                 0.01
# dense_hidden_layer_n_neurons                   6.0
# activation                                    relu
# num_epochs                                   100.0
# dropout_prob                                   0.1
# batch_normalisation                          False
# dense_layer_type                             Dense
# grad_clip                                    False
# Train r2                                      -0.0
# Val r2                                   -0.000738
# Test r2                                  -0.000853
# Train RMSE                                0.006094
# Val RMSE                                  0.006232
# Test RMSE                                 0.006308
# Train MAPE                      40068786624.336685
# Val MAPE                        41828579757.804199
# Test MAPE                       40328472226.902527
# Time                                        111.13
# verbose                                       True
# random_state                            19260817.0
# loss_function                                  MSE
# Name: 23, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (24, lstm_hidden_layer_n_neurons                 12.0
# lstm_n_hidden_layers                         3.0
# bi_lstm                                    False
# n_hidden_layers                              3.0
# batch_size                                 128.0
# learning_rate                               0.01
# dense_hidden_layer_n_neurons                 6.0
# activation                               sigmoid
# num_epochs                                 100.0
# dropout_prob                                 0.1
# batch_normalisation                        False
# dense_layer_type                           Dense
# grad_clip                                  False
# Train r2                               -0.000591
# Val r2                                 -0.002594
# Test r2                                -0.002776
# Train RMSE                              0.006096
# Val RMSE                                0.006238
# Test RMSE                               0.006314
# Train MAPE                      893189602.037054
# Val MAPE                        932416833.387802
# Test MAPE                       898985910.465763
# Time                                       62.04
# verbose                                     True
# random_state                          19260817.0
# loss_function                                MSE
# Name: 24, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (25, lstm_hidden_layer_n_neurons                   12.0
# lstm_n_hidden_layers                           3.0
# bi_lstm                                      False
# n_hidden_layers                                3.0
# batch_size                                   128.0
# learning_rate                                 0.01
# dense_hidden_layer_n_neurons                   6.0
# activation                                 softmax
# num_epochs                                   100.0
# dropout_prob                                   0.1
# batch_normalisation                          False
# dense_layer_type                             Dense
# grad_clip                                    False
# Train r2                                 -0.000293
# Val r2                                   -0.001927
# Test r2                                  -0.002092
# Train RMSE                                0.006095
# Val RMSE                                  0.006236
# Test RMSE                                 0.006312
# Train MAPE                      11224922241.389891
# Val MAPE                        11717912899.795103
# Test MAPE                       11297670967.857944
# Time                                         56.31
# verbose                                       True
# random_state                            19260817.0
# loss_function                                  MSE
# Name: 25, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (26, lstm_hidden_layer_n_neurons                   12.0
# lstm_n_hidden_layers                           3.0
# bi_lstm                                      False
# n_hidden_layers                                3.0
# batch_size                                   128.0
# learning_rate                                 0.01
# dense_hidden_layer_n_neurons                   6.0
# activation                                    tanh
# num_epochs                                   100.0
# dropout_prob                                   0.1
# batch_normalisation                          False
# dense_layer_type                             Dense
# grad_clip                                    False
# Train r2                                 -0.003258
# Val r2                                   -0.006877
# Test r2                                  -0.007114
# Train RMSE                                0.006104
# Val RMSE                                  0.006251
# Test RMSE                                 0.006327
# Train MAPE                      56199756463.823402
# Val MAPE                         58642438940.05349
# Test MAPE                       56579914029.332413
# Time                                         56.15
# verbose                                       True
# random_state                            19260817.0
# loss_function                                  MSE
# Name: 26, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (27, lstm_hidden_layer_n_neurons                    12.0
# lstm_n_hidden_layers                            3.0
# bi_lstm                                       False
# n_hidden_layers                                 3.0
# batch_size                                    128.0
# learning_rate                                  0.01
# dense_hidden_layer_n_neurons                    6.0
# activation                                     relu
# num_epochs                                    100.0
# dropout_prob                                    0.1
# batch_normalisation                           False
# dense_layer_type                           Residual
# grad_clip                                     False
# Train r2                                  -0.061344
# Val r2                                    -0.046272
# Test r2                                   -0.044177
# Train RMSE                                 0.006278
# Val RMSE                                   0.006373
# Test RMSE                                  0.006443
# Train MAPE                      457572368505.681213
# Val MAPE                        477668627464.693176
# Test MAPE                       460537892701.642212
# Time                                          58.98
# verbose                                        True
# random_state                             19260817.0
# loss_function                                   MSE
# Name: 27, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (28, lstm_hidden_layer_n_neurons                    12.0
# lstm_n_hidden_layers                            3.0
# bi_lstm                                       False
# n_hidden_layers                                 3.0
# batch_size                                    128.0
# learning_rate                                  0.01
# dense_hidden_layer_n_neurons                    6.0
# activation                                     relu
# num_epochs                                    100.0
# dropout_prob                                    0.0
# batch_normalisation                           False
# dense_layer_type                              Dense
# grad_clip                                     False
# Train r2                                    -0.2014
# Val r2                                    -0.169592
# Test r2                                   -0.163653
# Train RMSE                                 0.006679
# Val RMSE                                   0.006738
# Test RMSE                                  0.006801
# Train MAPE                      796683963044.427368
# Val MAPE                        831613092034.901489
# Test MAPE                       801810240220.036499
# Time                                          54.24
# verbose                                        True
# random_state                             19260817.0
# loss_function                                   MSE
# Name: 28, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (29, lstm_hidden_layer_n_neurons                   12.0
# lstm_n_hidden_layers                           3.0
# bi_lstm                                      False
# n_hidden_layers                                3.0
# batch_size                                   128.0
# learning_rate                                 0.01
# dense_hidden_layer_n_neurons                   6.0
# activation                                    relu
# num_epochs                                   100.0
# dropout_prob                                   0.2
# batch_normalisation                          False
# dense_layer_type                             Dense
# grad_clip                                    False
# Train r2                                 -0.005571
# Val r2                                   -0.010033
# Test r2                                  -0.010269
# Train RMSE                                0.006111
# Val RMSE                                  0.006261
# Test RMSE                                 0.006337
# Train MAPE                      85739999503.453888
# Val MAPE                        89505640420.048737
# Test MAPE                       86295680004.701965
# Time                                         54.24
# verbose                                       True
# random_state                            19260817.0
# loss_function                                  MSE
# Name: 29, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (30, lstm_hidden_layer_n_neurons                   12.0
# lstm_n_hidden_layers                           3.0
# bi_lstm                                      False
# n_hidden_layers                                3.0
# batch_size                                   128.0
# learning_rate                                 0.01
# dense_hidden_layer_n_neurons                   6.0
# activation                                    relu
# num_epochs                                   100.0
# dropout_prob                                   0.3
# batch_normalisation                          False
# dense_layer_type                             Dense
# grad_clip                                    False
# Train r2                                 -0.000024
# Val r2                                   -0.001018
# Test r2                                  -0.001149
# Train RMSE                                0.006094
# Val RMSE                                  0.006233
# Test RMSE                                 0.006309
# Train MAPE                      31883483705.522362
# Val MAPE                        33283784049.570332
# Test MAPE                       32090120401.450813
# Time                                         46.69
# verbose                                       True
# random_state                            19260817.0
# loss_function                                  MSE
# Name: 30, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (31, lstm_hidden_layer_n_neurons                   12.0
# lstm_n_hidden_layers                           3.0
# bi_lstm                                      False
# n_hidden_layers                                3.0
# batch_size                                   128.0
# learning_rate                                 0.01
# dense_hidden_layer_n_neurons                   6.0
# activation                                    relu
# num_epochs                                   100.0
# dropout_prob                                   0.4
# batch_normalisation                          False
# dense_layer_type                             Dense
# grad_clip                                    False
# Train r2                                 -0.000005
# Val r2                                   -0.000856
# Test r2                                  -0.000978
# Train RMSE                                0.006094
# Val RMSE                                  0.006233
# Test RMSE                                 0.006308
# Train MAPE                      36455274258.924156
# Val MAPE                        38056364452.167191
# Test MAPE                       36691540706.205589
# Time                                         69.55
# verbose                                       True
# random_state                            19260817.0
# loss_function                                  MSE
# Name: 31, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (32, lstm_hidden_layer_n_neurons                   12.0
# lstm_n_hidden_layers                           3.0
# bi_lstm                                      False
# n_hidden_layers                                3.0
# batch_size                                   128.0
# learning_rate                                 0.01
# dense_hidden_layer_n_neurons                   6.0
# activation                                    relu
# num_epochs                                   100.0
# dropout_prob                                   0.5
# batch_normalisation                          False
# dense_layer_type                             Dense
# grad_clip                                    False
# Train r2                                 -0.000017
# Val r2                                   -0.000973
# Test r2                                  -0.001101
# Train RMSE                                0.006094
# Val RMSE                                  0.006233
# Test RMSE                                 0.006309
# Train MAPE                      33120227227.135281
# Val MAPE                        34574844483.188942
# Test MAPE                        33334879251.54493
# Time                                         66.01
# verbose                                       True
# random_state                            19260817.0
# loss_function                                  MSE
# Name: 32, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (33, lstm_hidden_layer_n_neurons                     12.0
# lstm_n_hidden_layers                             3.0
# bi_lstm                                        False
# ...
# Name: 40, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (41, lstm_hidden_layer_n_neurons                   12.0
# lstm_n_hidden_layers                           3.0
# bi_lstm                                      False
# n_hidden_layers                                3.0
# batch_size                                   128.0
# learning_rate                                 0.01
# dense_hidden_layer_n_neurons                   6.0
# activation                                    relu
# num_epochs                                   100.0
# dropout_prob                                   0.1
# batch_normalisation                          False
# dense_layer_type                             Dense
# grad_clip                                     True
# Train r2                                 -0.000262
# Val r2                                   -0.000128
# Test r2                                  -0.000184
# Train RMSE                                0.006095
# Val RMSE                                   0.00623
# Test RMSE                                 0.006306
# Train MAPE                      67348100834.447319
# Val MAPE                         70305982402.28154
# Test MAPE                       67784583533.837143
# Time                                         76.66
# verbose                                       True
# random_state                            19260817.0
# loss_function                                  MSE
# Name: 41, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (42, lstm_hidden_layer_n_neurons                   12.0
# lstm_n_hidden_layers                           3.0
# bi_lstm                                      False
# n_hidden_layers                                3.0
# batch_size                                   128.0
# learning_rate                                0.001
# dense_hidden_layer_n_neurons                   6.0
# activation                                    relu
# num_epochs                                   100.0
# dropout_prob                                   0.1
# batch_normalisation                          False
# dense_layer_type                             Dense
# grad_clip                                    False
# Train r2                                  -0.00032
# Val r2                                   -0.001994
# Test r2                                  -0.002161
# Train RMSE                                0.006095
# Val RMSE                                  0.006236
# Test RMSE                                 0.006312
# Train MAPE                       9928021736.274986
# Val MAPE                        10364053519.390623
# Test MAPE                        9992365194.709299
# Time                                         66.35
# verbose                                       True
# random_state                            19260817.0
# loss_function                                  MSE
# Name: 42, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (43, lstm_hidden_layer_n_neurons                    12.0
# lstm_n_hidden_layers                            3.0
# bi_lstm                                       False
# n_hidden_layers                                 3.0
# batch_size                                    128.0
# learning_rate                                   0.1
# dense_hidden_layer_n_neurons                    6.0
# activation                                     relu
# num_epochs                                    100.0
# dropout_prob                                    0.1
# batch_normalisation                           False
# dense_layer_type                              Dense
# grad_clip                                     False
# Train r2                                  -0.119482
# Val r2                                    -0.133417
# Test r2                                   -0.131972
# Train RMSE                                 0.006448
# Val RMSE                                   0.006633
# Test RMSE                                  0.006708
# Train MAPE                       542584300710.29187
# Val MAPE                        566414224378.473511
# Test MAPE                       546100786807.071594
# Time                                          77.22
# verbose                                        True
# random_state                             19260817.0
# loss_function                                   MSE
# Name: 43, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (44, lstm_hidden_layer_n_neurons                      12.0
# lstm_n_hidden_layers                              3.0
# bi_lstm                                         False
# n_hidden_layers                                   3.0
# batch_size                                      128.0
# learning_rate                                     1.0
# dense_hidden_layer_n_neurons                      6.0
# activation                                       relu
# num_epochs                                      100.0
# dropout_prob                                      0.1
# batch_normalisation                             False
# dense_layer_type                                Dense
# grad_clip                                       False
# Train r2                                   -57.145556
# Val r2                                     -55.077433
# Test r2                                    -53.808644
# Train RMSE                                   0.046468
# Val RMSE                                     0.046654
# Test RMSE                                    0.046678
# Train MAPE                      12702473370535.507812
# Val MAPE                        13260357132415.486328
# Test MAPE                       12784798035925.943359
# Time                                            63.05
# verbose                                          True
# random_state                               19260817.0
# loss_function                                     MSE
# Name: 44, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (45, lstm_hidden_layer_n_neurons                    12.0
# lstm_n_hidden_layers                            1.0
# bi_lstm                                       False
# n_hidden_layers                                 3.0
# batch_size                                    128.0
# learning_rate                                  0.01
# dense_hidden_layer_n_neurons                    6.0
# activation                                     relu
# num_epochs                                    100.0
# dropout_prob                                    0.1
# batch_normalisation                           False
# dense_layer_type                              Dense
# grad_clip                                     False
# Train r2                                  -0.099133
# Val r2                                    -0.078858
# Test r2                                   -0.075685
# Train RMSE                                 0.006389
# Val RMSE                                   0.006471
# Test RMSE                                  0.006539
# Train MAPE                      570805985403.842407
# Val MAPE                        595875385760.101074
# Test MAPE                       574505376095.733032
# Time                                          50.61
# verbose                                        True
# random_state                             19260817.0
# loss_function                                   MSE
# Name: 45, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (46, lstm_hidden_layer_n_neurons                     12.0
# lstm_n_hidden_layers                             2.0
# bi_lstm                                        False
# n_hidden_layers                                  3.0
# batch_size                                     128.0
# learning_rate                                   0.01
# dense_hidden_layer_n_neurons                     6.0
# activation                                      relu
# num_epochs                                     100.0
# dropout_prob                                     0.1
# batch_normalisation                            False
# dense_layer_type                               Dense
# grad_clip                                      False
# Train r2                                    -0.43237
# Val r2                                     -0.379484
# Test r2                                    -0.367629
# Train RMSE                                  0.007293
# Val RMSE                                    0.007317
# Test RMSE                                   0.007374
# Train MAPE                      1148466967784.469238
# Val MAPE                        1198906835178.226807
# Test MAPE                       1155910176368.866211
# Time                                           54.03
# verbose                                         True
# random_state                              19260817.0
# loss_function                                    MSE
# Name: 46, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (47, lstm_hidden_layer_n_neurons                    12.0
# lstm_n_hidden_layers                            3.0
# bi_lstm                                       False
# n_hidden_layers                                 1.0
# batch_size                                    128.0
# learning_rate                                  0.01
# dense_hidden_layer_n_neurons                    6.0
# activation                                     relu
# num_epochs                                    100.0
# dropout_prob                                    0.1
# batch_normalisation                           False
# dense_layer_type                              Dense
# grad_clip                                     False
# Train r2                                  -0.131147
# Val r2                                    -0.106976
# Test r2                                   -0.102921
# Train RMSE                                 0.006481
# Val RMSE                                   0.006555
# Test RMSE                                  0.006622
# Train MAPE                      650517947050.419678
# Val MAPE                        679088241109.269653
# Test MAPE                       654733950560.834106
# Time                                          54.12
# verbose                                        True
# random_state                             19260817.0
# loss_function                                   MSE
# Name: 47, dtype: object)
# Error message: 'dict' object is not callable
# Error Importing this Row: (48, lstm_hidden_layer_n_neurons                     12.0
# lstm_n_hidden_layers                             3.0
# bi_lstm                                        False
# n_hidden_layers                                  2.0
# batch_size                                     128.0
# learning_rate                                   0.01
# dense_hidden_layer_n_neurons                     6.0
# activation                                      relu
# num_epochs                                     100.0
# dropout_prob                                     0.1
# batch_normalisation                            False
# dense_layer_type                               Dense
# grad_clip                                      False
# Train r2                                   -0.442289
# Val r2                                     -0.388575
# Test r2                                    -0.376471
# Train RMSE                                  0.007318
# Val RMSE                                    0.007341
# Test RMSE                                   0.007397
# Train MAPE                      1161108633793.476807
# Val MAPE                        1212103714332.250488
# Test MAPE                       1168633772951.063232
# Time                                           57.02
# verbose                                         True
# random_state                              19260817.0
# loss_function                                    MSE
# Name: 48, dtype: object)
# Successfully read in tuning result of 49 rows
# Successfully set tuning output address
# Successfully set best model output address
#
# Default combo: [0, 0, 0, 0, 1, 1, 0, 0, 1, 0, 0, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: lstm_n_hidden_layers (index: 1)
# /Applications/anaconda3/lib/python3.9/site-packages/torch/nn/modules/rnn.py:67: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# /Users/tg.chenny/Desktop/3. Self Projects/2. PythonProject/Incomplete/DeepTrade/PrivatePackages/models/LSTM.py:15: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:233.)
#   self.x = torch.FloatTensor(x)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/xg/8w_3dndd6l5c3n99vd7vd3f40000gn/T/ipykernel_9982/3191248874.py in <module>
#      54 jiaocheng.set_best_model_saving_address(f'../models/tmp_models/jiaocheng_{MODEL}_{LABEL}.pickle')
#      55
# ---> 56 jiaocheng.tune()
#      57
#      58 jiaocheng.view_best_combo_and_score()
#
# ~/Desktop/3. Self Projects/2. PythonProject/Incomplete/DeepTrade/PrivatePackages/JiaoCheng.py in tune(self, key_stats_only)
#     373                     if not self.checked[tuple(combo)]:
#     374                         self._up_to += 1
# --> 375                         self._train_and_test_combo(combo)
#     376                     else:
#     377                         self._check_already_trained_best_score(combo)
#
# ~/Desktop/3. Self Projects/2. PythonProject/Incomplete/DeepTrade/PrivatePackages/JiaoCheng.py in _train_and_test_combo(self, combo)
#     584         # get time and fit
#     585         start = time.time()
# --> 586         clf.fit(tmp_train_x, self.train_y)
#     587         end = time.time()
#     588
#
# ~/Desktop/3. Self Projects/2. PythonProject/Incomplete/DeepTrade/PrivatePackages/models/LSTM.py in fit(self, train_x, train_y, initial_model)
#     625             total_loss = 0
#     626
# --> 627             for batch_idx, (batch_train_x, batch_train_y) in enumerate(train_loader):
#     628
#     629
#
# /Applications/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     626                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627                 self._reset()  # type: ignore[call-arg]
# --> 628             data = self._next_data()
#     629             self._num_yielded += 1
#     630             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /Applications/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     669     def _next_data(self):
#     670         index = self._next_index()  # may raise StopIteration
# --> 671         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672         if self._pin_memory:
#     673             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /Applications/anaconda3/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
# ---> 61         return self.collate_fn(data)
#
# /Applications/anaconda3/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py in default_collate(batch)
#     263             >>> default_collate(batch)  # Handle `CustomType` automatically
#     264     """
# --> 265     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# /Applications/anaconda3/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py in collate(batch, collate_fn_map)
#     149                 return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]
#     150
# --> 151     raise TypeError(default_collate_err_msg_format.format(elem_type))
#     152
#     153
#
# TypeError: default_collate: batch must contain tensors, numpy arrays, numbers, dicts or lists; found <class 'NoneType'>
