# %%
import json
import pandas as pd

# %%
with open('../data/stock_std_above_1.json', 'r') as f:
    stocks_std_above_1 = json.load(f)

with open('../data/stock_std_above_1_5.json', 'r') as f:
    stocks_std_above_1_5 = json.load(f)

with open('../data/stock_std_below_1.json', 'r') as f:
    stocks_std_below_1 = json.load(f)

with open('../data/stock_std_below_1_5.json', 'r') as f:
    stocks_std_below_1_5 = json.load(f)

# %%
curated_data = pd.read_csv('../data/curated_data.csv')

# %%
data_std_above_1 = curated_data[curated_data['stock'].isin(stocks_std_above_1)]
data_std_above_1_5 = curated_data[curated_data['stock'].isin(stocks_std_above_1_5)]
data_std_below_1 = curated_data[curated_data['stock'].isin(stocks_std_below_1)]
data_std_below_1_5 = curated_data[curated_data['stock'].isin(stocks_std_below_1_5)]

# %%
data_std_above_1
# Out:
#              date  stock  closePrice   log_ret  trend  closePriceNorm  \
# 0      2022-12-31      0       60.17       NaN    NaN       -0.982328
# 1      2023-01-01      0       59.99 -0.002996   -1.0       -1.094387
# 2      2023-01-02      0       59.66 -0.005516   -1.0       -1.299827
# 3      2023-01-03      0       59.38 -0.004704   -1.0       -1.474140
# 4      2023-01-04      0       59.21 -0.002867   -1.0       -1.579973
# ...           ...    ...         ...       ...    ...             ...
# 12495  2023-09-02     49       43.02 -0.005332   -1.0        0.076374
# 12496  2023-09-03     49       43.03  0.000232    1.0        0.083701
# 12497  2023-09-04     49       43.57  0.012471    1.0        0.479346
# 12498  2023-09-05     49       43.13 -0.010150   -1.0        0.156968
# 12499  2023-09-06     49       43.33  0.004626    1.0        0.303504
#
#        log_ret_normalised_by_day  closePrice_min_3  closePrice_max_3  \
# 0                            NaN               NaN               NaN
# 1                      -0.571724               NaN               NaN
# 2                      -0.808744               NaN               NaN
# 3                      -0.676304               NaN               NaN
# 4                      -0.299596               NaN               NaN
# ...                          ...               ...               ...
# 12495                  -0.607055             43.11             43.66
# 12496                   0.275513             43.25             43.66
# 12497                   2.341185             43.02             43.61
# 12498                  -1.511910             43.02             43.25
# 12499                   0.989107             43.02             43.57
#
#        closePrice_std_3  ...  closePriceNorm_lag_10  \
# 0                   NaN  ...                    NaN
# 1                   NaN  ...                    NaN
# 2                   NaN  ...                    NaN
# 3                   NaN  ...                    NaN
# 4                   NaN  ...                    NaN
# ...                 ...  ...                    ...
# 12495          0.248328  ...              -0.136102
# 12496          0.182635  ...              -0.539073
# 12497          0.242808  ...              -0.377885
# 12498          0.106145  ...              -0.363231
# 12499          0.256948  ...              -0.326598
#
#        log_ret_normalised_by_day_lag_10  mean_log_ret_lag_1  \
# 0                                   NaN                 NaN
# 1                                   NaN                 NaN
# 2                                   NaN            0.000525
# 3                                   NaN           -0.000065
# 4                                   NaN           -0.000623
# ...                                 ...                 ...
# 12495                         -2.032099           -0.002123
# 12496                         -1.515743           -0.001491
# 12497                          0.765811           -0.001420
# 12498                          0.030813           -0.000048
# 12499                          0.102353           -0.000252
#
#        mean_closePrice_lag_1  mean_closePriceNorm_lag_1  \
# 0                        NaN                        NaN
# 1                    40.6170                   0.241356
# 2                    40.6472                   0.247020
# 3                    40.6172                   0.231342
# 4                    40.5886                   0.211599
# ...                      ...                        ...
# 12495                39.4416                  -0.655234
# 12496                39.3646                  -0.690649
# 12497                39.3096                  -0.716371
# 12498                39.2904                  -0.714126
# 12499                39.2810                  -0.713713
#
#        mean_log_ret_normalised_by_day_lag_1  pos_log_ret_lag_1  \
# 0                                       NaN                NaN
# 1                                       NaN                NaN
# 2                             -4.440892e-18           0.000569
# 3                             -8.881784e-18          -0.001615
# 4                              1.776357e-17          -0.000616
# ...                                     ...                ...
# 12495                          5.773160e-17          -0.003932
# 12496                          4.662937e-17          -0.001368
# 12497                          8.770762e-17          -0.004381
# 12498                         -1.776357e-17          -0.001478
# 12499                          3.552714e-17          -0.002505
#
#        pos_closePrice_lag_1  pos_closePriceNorm_lag_1  \
# 0                       NaN                       NaN
# 1                 33.787500                  0.529432
# 2                 33.838750                  0.535137
# 3                 33.735000                  0.482227
# 4                 33.710000                  0.455742
# ...                     ...                       ...
# 12495             35.979231                 -0.815362
# 12496             35.899231                 -0.860295
# 12497             35.692308                 -0.931225
# 12498             35.616923                 -0.974622
# 12499             35.506154                 -1.026466
#
#        pos_log_ret_normalised_by_day_lag_1
# 0                                      NaN
# 1                                      NaN
# 2                                 0.007178
# 3                                -0.229975
# 4                                 0.001161
# ...                                    ...
# 12495                            -0.320944
# 12496                             0.019382
# 12497                            -0.493615
# 12498                            -0.267420
# 12499                            -0.344069
#
# [8000 rows x 199 columns]

# %%
data_std_above_1_5
# Out:
#              date  stock  closePrice   log_ret  trend  closePriceNorm  \
# 0      2022-12-31      0       60.17       NaN    NaN       -0.982328
# 1      2023-01-01      0       59.99 -0.002996   -1.0       -1.094387
# 2      2023-01-02      0       59.66 -0.005516   -1.0       -1.299827
# 3      2023-01-03      0       59.38 -0.004704   -1.0       -1.474140
# 4      2023-01-04      0       59.21 -0.002867   -1.0       -1.579973
# ...           ...    ...         ...       ...    ...             ...
# 11995  2023-09-02     47       63.56  0.001102    1.0       -0.629153
# 11996  2023-09-03     47       63.56  0.000000    1.0       -0.629153
# 11997  2023-09-04     47       63.55 -0.000157   -1.0       -0.633425
# 11998  2023-09-05     47       64.20  0.010176    1.0       -0.355735
# 11999  2023-09-06     47       64.29  0.001401    1.0       -0.317285
#
#        log_ret_normalised_by_day  closePrice_min_3  closePrice_max_3  \
# 0                            NaN               NaN               NaN
# 1                      -0.571724               NaN               NaN
# 2                      -0.808744               NaN               NaN
# 3                      -0.676304               NaN               NaN
# 4                      -0.299596               NaN               NaN
# ...                          ...               ...               ...
# 11995                   0.409670             63.22             63.80
# 11996                   0.236761             63.22             63.62
# 11997                  -0.020429             63.22             63.56
# 11998                   1.593023             63.49             63.56
# 11999                   0.475796             63.55             63.56
#
#        closePrice_std_3  ...  closePriceNorm_lag_10  \
# 0                   NaN  ...                    NaN
# 1                   NaN  ...                    NaN
# 2                   NaN  ...                    NaN
# 3                   NaN  ...                    NaN
# 4                   NaN  ...                    NaN
# ...                 ...  ...                    ...
# 11995          0.242395  ...              -0.577887
# 11996          0.166600  ...              -0.667603
# 11997          0.146591  ...              -0.659058
# 11998          0.032998  ...              -0.543710
# 11999          0.004714  ...              -0.535165
#
#        log_ret_normalised_by_day_lag_10  mean_log_ret_lag_1  \
# 0                                   NaN                 NaN
# 1                                   NaN                 NaN
# 2                                   NaN            0.000525
# 3                                   NaN           -0.000065
# 4                                   NaN           -0.000623
# ...                                 ...                 ...
# 11995                         -0.240826           -0.002123
# 11996                         -0.159905           -0.001491
# 11997                          0.079729           -0.001420
# 11998                          0.664223           -0.000048
# 11999                         -0.051938           -0.000252
#
#        mean_closePrice_lag_1  mean_closePriceNorm_lag_1  \
# 0                        NaN                        NaN
# 1                    40.6170                   0.241356
# 2                    40.6472                   0.247020
# 3                    40.6172                   0.231342
# 4                    40.5886                   0.211599
# ...                      ...                        ...
# 11995                39.4416                  -0.655234
# 11996                39.3646                  -0.690649
# 11997                39.3096                  -0.716371
# 11998                39.2904                  -0.714126
# 11999                39.2810                  -0.713713
#
#        mean_log_ret_normalised_by_day_lag_1  pos_log_ret_lag_1  \
# 0                                       NaN                NaN
# 1                                       NaN                NaN
# 2                             -4.440892e-18           0.000569
# 3                             -8.881784e-18          -0.001615
# 4                              1.776357e-17          -0.000616
# ...                                     ...                ...
# 11995                          5.773160e-17          -0.002818
# 11996                          4.662937e-17          -0.002514
# 11997                          8.770762e-17          -0.002656
# 11998                         -1.776357e-17          -0.000922
# 11999                          3.552714e-17           0.001453
#
#        pos_closePrice_lag_1  pos_closePriceNorm_lag_1  \
# 0                       NaN                       NaN
# 1                 33.787500                  0.529432
# 2                 33.838750                  0.535137
# 3                 33.735000                  0.482227
# 4                 33.710000                  0.455742
# ...                     ...                       ...
# 11995             38.496923                 -0.926365
# 11996             38.377692                 -0.965141
# 11997             38.246154                 -1.042571
# 11998             38.204615                 -1.076276
# 11999             38.277692                 -1.016702
#
#        pos_log_ret_normalised_by_day_lag_1
# 0                                      NaN
# 1                                      NaN
# 2                                 0.007178
# 3                                -0.229975
# 4                                 0.001161
# ...                                    ...
# 11995                            -0.123400
# 11996                            -0.161711
# 11997                            -0.206147
# 11998                            -0.163491
# 11999                             0.260572
#
# [5750 rows x 199 columns]

# %%
data_std_below_1
# Out:
#              date  stock  closePrice   log_ret  trend  closePriceNorm  \
# 250    2022-12-31      1       10.11       NaN    NaN       -0.928533
# 251    2023-01-01      1       10.08 -0.002972   -1.0       -1.013719
# 252    2023-01-02      1       10.23  0.014771    1.0       -0.587787
# 253    2023-01-03      1       10.22 -0.000978   -1.0       -0.616182
# 254    2023-01-04      1       10.20 -0.001959   -1.0       -0.672973
# ...           ...    ...         ...       ...    ...             ...
# 11745  2023-09-02     46       52.44  0.000381    1.0       -0.397471
# 11746  2023-09-03     46       52.44  0.000000    1.0       -0.397471
# 11747  2023-09-04     46       52.40 -0.000763   -1.0       -0.478290
# 11748  2023-09-05     46       52.53  0.002478    1.0       -0.215627
# 11749  2023-09-06     46       52.53  0.000000    1.0       -0.215627
#
#        log_ret_normalised_by_day  closePrice_min_3  closePrice_max_3  \
# 250                          NaN               NaN               NaN
# 251                    -0.567789               NaN               NaN
# 252                     2.201286               NaN               NaN
# 253                    -0.058795               NaN               NaN
# 254                    -0.154041               NaN               NaN
# ...                          ...               ...               ...
# 11745                   0.295820             52.48             52.53
# 11746                   0.236761             52.42             52.53
# 11747                  -0.133702             52.42             52.48
# 11748                   0.417060             52.42             52.44
# 11749                   0.252859             52.40             52.44
#
#        closePrice_std_3  ...  closePriceNorm_lag_10  \
# 250                 NaN  ...                    NaN
# 251                 NaN  ...                    NaN
# 252                 NaN  ...                    NaN
# 253                 NaN  ...                    NaN
# 254                 NaN  ...                    NaN
# ...                 ...  ...                    ...
# 11745          0.023570  ...              -0.215627
# 11746          0.044969  ...              -0.276241
# 11747          0.024944  ...              -0.458085
# 11748          0.009428  ...              -0.397471
# 11749          0.018856  ...              -0.276241
#
#        log_ret_normalised_by_day_lag_10  mean_log_ret_lag_1  \
# 250                                 NaN                 NaN
# 251                                 NaN                 NaN
# 252                                 NaN            0.000525
# 253                                 NaN           -0.000065
# 254                                 NaN           -0.000623
# ...                                 ...                 ...
# 11745                          0.308318           -0.002123
# 11746                          0.223859           -0.001491
# 11747                         -0.205369           -0.001420
# 11748                          0.047716           -0.000048
# 11749                          0.096197           -0.000252
#
#        mean_closePrice_lag_1  mean_closePriceNorm_lag_1  \
# 250                      NaN                        NaN
# 251                  40.6170                   0.241356
# 252                  40.6472                   0.247020
# 253                  40.6172                   0.231342
# 254                  40.5886                   0.211599
# ...                      ...                        ...
# 11745                39.4416                  -0.655234
# 11746                39.3646                  -0.690649
# 11747                39.3096                  -0.716371
# 11748                39.2904                  -0.714126
# 11749                39.2810                  -0.713713
#
#        mean_log_ret_normalised_by_day_lag_1  pos_log_ret_lag_1  \
# 250                                     NaN                NaN
# 251                                     NaN                NaN
# 252                           -4.440892e-18           0.000012
# 253                           -8.881784e-18           0.001370
# 254                            1.776357e-17          -0.001306
# ...                                     ...                ...
# 11745                          5.773160e-17          -0.001887
# 11746                          4.662937e-17          -0.001291
# 11747                          8.770762e-17          -0.001069
# 11748                         -1.776357e-17          -0.000292
# 11749                          3.552714e-17           0.000907
#
#        pos_closePrice_lag_1  pos_closePriceNorm_lag_1  \
# 250                     NaN                       NaN
# 251               38.293889                  0.786598
# 252               38.312778                  0.779233
# 253               38.352222                  0.803459
# 254               38.291111                  0.769140
# ...                     ...                       ...
# 11745             35.994762                 -0.795357
# 11746             35.933810                 -0.839830
# 11747             35.917619                 -0.876950
# 11748             35.910476                 -0.880514
# 11749             35.964762                 -0.858619
#
#        pos_log_ret_normalised_by_day_lag_1
# 250                                    NaN
# 251                                    NaN
# 252                              -0.083336
# 253                               0.212962
# 254                              -0.113109
# ...                                    ...
# 11745                             0.041780
# 11746                             0.031514
# 11747                             0.058540
# 11748                            -0.045620
# 11749                             0.177051
#
# [4500 rows x 199 columns]

# %%
data_std_below_1_5
# Out:
#              date  stock  closePrice   log_ret  trend  closePriceNorm  \
# 0      2022-12-31      0       60.17       NaN    NaN       -0.982328
# 1      2023-01-01      0       59.99 -0.002996   -1.0       -1.094387
# 2      2023-01-02      0       59.66 -0.005516   -1.0       -1.299827
# 3      2023-01-03      0       59.38 -0.004704   -1.0       -1.474140
# 4      2023-01-04      0       59.21 -0.002867   -1.0       -1.579973
# ...           ...    ...         ...       ...    ...             ...
# 11995  2023-09-02     47       63.56  0.001102    1.0       -0.629153
# 11996  2023-09-03     47       63.56  0.000000    1.0       -0.629153
# 11997  2023-09-04     47       63.55 -0.000157   -1.0       -0.633425
# 11998  2023-09-05     47       64.20  0.010176    1.0       -0.355735
# 11999  2023-09-06     47       64.29  0.001401    1.0       -0.317285
#
#        log_ret_normalised_by_day  closePrice_min_3  closePrice_max_3  \
# 0                            NaN               NaN               NaN
# 1                      -0.571724               NaN               NaN
# 2                      -0.808744               NaN               NaN
# 3                      -0.676304               NaN               NaN
# 4                      -0.299596               NaN               NaN
# ...                          ...               ...               ...
# 11995                   0.409670             63.22             63.80
# 11996                   0.236761             63.22             63.62
# 11997                  -0.020429             63.22             63.56
# 11998                   1.593023             63.49             63.56
# 11999                   0.475796             63.55             63.56
#
#        closePrice_std_3  ...  closePriceNorm_lag_10  \
# 0                   NaN  ...                    NaN
# 1                   NaN  ...                    NaN
# 2                   NaN  ...                    NaN
# 3                   NaN  ...                    NaN
# 4                   NaN  ...                    NaN
# ...                 ...  ...                    ...
# 11995          0.242395  ...              -0.577887
# 11996          0.166600  ...              -0.667603
# 11997          0.146591  ...              -0.659058
# 11998          0.032998  ...              -0.543710
# 11999          0.004714  ...              -0.535165
#
#        log_ret_normalised_by_day_lag_10  mean_log_ret_lag_1  \
# 0                                   NaN                 NaN
# 1                                   NaN                 NaN
# 2                                   NaN            0.000525
# 3                                   NaN           -0.000065
# 4                                   NaN           -0.000623
# ...                                 ...                 ...
# 11995                         -0.240826           -0.002123
# 11996                         -0.159905           -0.001491
# 11997                          0.079729           -0.001420
# 11998                          0.664223           -0.000048
# 11999                         -0.051938           -0.000252
#
#        mean_closePrice_lag_1  mean_closePriceNorm_lag_1  \
# 0                        NaN                        NaN
# 1                    40.6170                   0.241356
# 2                    40.6472                   0.247020
# 3                    40.6172                   0.231342
# 4                    40.5886                   0.211599
# ...                      ...                        ...
# 11995                39.4416                  -0.655234
# 11996                39.3646                  -0.690649
# 11997                39.3096                  -0.716371
# 11998                39.2904                  -0.714126
# 11999                39.2810                  -0.713713
#
#        mean_log_ret_normalised_by_day_lag_1  pos_log_ret_lag_1  \
# 0                                       NaN                NaN
# 1                                       NaN                NaN
# 2                             -4.440892e-18           0.000569
# 3                             -8.881784e-18          -0.001615
# 4                              1.776357e-17          -0.000616
# ...                                     ...                ...
# 11995                          5.773160e-17          -0.002818
# 11996                          4.662937e-17          -0.002514
# 11997                          8.770762e-17          -0.002656
# 11998                         -1.776357e-17          -0.000922
# 11999                          3.552714e-17           0.001453
#
#        pos_closePrice_lag_1  pos_closePriceNorm_lag_1  \
# 0                       NaN                       NaN
# 1                 33.787500                  0.529432
# 2                 33.838750                  0.535137
# 3                 33.735000                  0.482227
# 4                 33.710000                  0.455742
# ...                     ...                       ...
# 11995             38.496923                 -0.926365
# 11996             38.377692                 -0.965141
# 11997             38.246154                 -1.042571
# 11998             38.204615                 -1.076276
# 11999             38.277692                 -1.016702
#
#        pos_log_ret_normalised_by_day_lag_1
# 0                                      NaN
# 1                                      NaN
# 2                                 0.007178
# 3                                -0.229975
# 4                                 0.001161
# ...                                    ...
# 11995                            -0.123400
# 11996                            -0.161711
# 11997                            -0.206147
# 11998                            -0.163491
# 11999                             0.260572
#
# [5750 rows x 199 columns]

# %%
data_std_above_1.to_parquet('../data/curated_data_std_above_1.parquet', index=False)
data_std_above_1_5.to_parquet('../data/curated_data_std_above_1_5.parquet', index=False)
data_std_below_1.to_parquet('../data/curated_data_std_below_1.parquet', index=False)
data_std_below_1_5.to_parquet('../data/curated_data_std_below_1_5.parquet', index=False)
