# %%
import pandas as pd
import numpy as np
import datetime

# %%
date = [datetime.date(year=2023, month=1, day = 1) + datetime.timedelta(days=i) for i in range(250)]

# %%
basic_data = pd.read_csv('../data/basic_data.csv')

# get ret
basic_data['ret'] = basic_data.groupby('stock')['closePrice'].pct_change() 
basic_data['ret'] = basic_data['ret'] + 1

# get log ret
basic_data['log_ret'] = np.log(basic_data['ret'])

# get dates
basic_data['date'] = date*50

# get trend
basic_data['trend'] = [1 if ret >= 1 else -1 if ret < 1 else np.nan for ret in basic_data['ret']]


# get closed price normalised by stock
basic_data['closePriceNorm'] = basic_data.groupby('stock')['closePrice'].apply(lambda x: (x - x.mean()) / x.std())

# %%
basic_data
# Out:
#              date  stock  closePrice       ret   log_ret  trend  \
# 0      2023-01-01      0       60.17       NaN       NaN    NaN
# 1      2023-01-02      0       59.99  0.997008 -0.002996   -1.0
# 2      2023-01-03      0       59.66  0.994499 -0.005516   -1.0
# 3      2023-01-04      0       59.38  0.995307 -0.004704   -1.0
# 4      2023-01-05      0       59.21  0.997137 -0.002867   -1.0
# ...           ...    ...         ...       ...       ...    ...
# 12495  2023-09-03     49       43.02  0.994682 -0.005332   -1.0
# 12496  2023-09-04     49       43.03  1.000232  0.000232    1.0
# 12497  2023-09-05     49       43.57  1.012549  0.012471    1.0
# 12498  2023-09-06     49       43.13  0.989901 -0.010150   -1.0
# 12499  2023-09-07     49       43.33  1.004637  0.004626    1.0
#
#        closePriceNorm
# 0           -0.982328
# 1           -1.094387
# 2           -1.299827
# 3           -1.474140
# 4           -1.579973
# ...               ...
# 12495        0.076374
# 12496        0.083701
# 12497        0.479346
# 12498        0.156968
# 12499        0.303504
#
# [12500 rows x 7 columns]

# %%
# get lag
for i in range(1, 11):
    basic_data['ret_lag_{}'.format(i)] = basic_data.groupby('stock')['ret'].shift(i)

    basic_data['log_ret_lag_{}'.format(i)] = basic_data.groupby('stock')['log_ret'].shift(i)

    basic_data['closePrice_lag_{}'.format(i)] = basic_data.groupby('stock')['closePrice'].shift(i)

    basic_data['closePriceNorm_lag_{}'.format(i)] = basic_data.groupby('stock')['closePriceNorm'].shift(i)

# %%
basic_data.to_csv('../data/curated_data.csv', index=False)
