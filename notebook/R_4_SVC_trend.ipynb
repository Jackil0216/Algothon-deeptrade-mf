# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os
import pickle
import pandas as pd
import json
import datetime
import time
import copy

py_file_location = './drive/My Drive/PrivatePackages'
sys.path.append(os.path.abspath(py_file_location))
from sklearn.model_selection import train_test_split

import JiaoCheng
import NingXiang

# %%
LABEL = 'trend'
MODEL = 'svc'

# %%
curated_data = pd.read_csv('./drive/My Drive/LAB/Hackathon/data/curated_data.csv')
curated_data = curated_data.drop(columns=['closePrice', 'closePriceNorm', 'log_ret_normalised_by_day', 'log_ret', 'stock'])
curated_data['date'] = pd.to_datetime(curated_data['date'])

# %%
curated_data
# Out:
#             date  trend  closePrice_min_3  closePrice_max_3  closePrice_std_3  \
# 0     2022-12-31    NaN               NaN               NaN               NaN
# 1     2023-01-01   -1.0               NaN               NaN               NaN
# 2     2023-01-02   -1.0               NaN               NaN               NaN
# 3     2023-01-03   -1.0               NaN               NaN               NaN
# 4     2023-01-04   -1.0               NaN               NaN               NaN
# ...          ...    ...               ...               ...               ...
# 12495 2023-09-02   -1.0             43.11             43.66          0.248328
# 12496 2023-09-03    1.0             43.25             43.66          0.182635
# 12497 2023-09-04    1.0             43.02             43.61          0.242808
# 12498 2023-09-05   -1.0             43.02             43.25          0.106145
# 12499 2023-09-06    1.0             43.02             43.57          0.256948
#
#        closePrice_mean_3  closePrice_slope_3  closePrice_skew_3  \
# 0                    NaN                 NaN                NaN
# 1                    NaN                 NaN                NaN
# 2                    NaN                 NaN                NaN
# 3                    NaN                 NaN                NaN
# 4                    NaN                 NaN                NaN
# ...                  ...                 ...                ...
# 12495          43.460000            0.011598          -0.685668
# 12496          43.506667           -0.009391          -0.667566
# 12497          43.293333           -0.013529           0.262017
# 12498          43.100000           -0.005087           0.702403
# 12499          43.206667            0.012785           0.706304
#
#        closePrice_abs_diff_mean_3  closePrice_diff_std_3  ...  \
# 0                             NaN                    NaN  ...
# 1                             NaN                    NaN  ...
# 2                             NaN                    NaN  ...
# 3                             NaN                    NaN  ...
# 4                             NaN                    NaN  ...
# ...                           ...                    ...  ...
# 12495                       0.300                  0.300  ...
# 12496                       0.205                  0.155  ...
# 12497                       0.295                  0.065  ...
# 12498                       0.120                  0.120  ...
# 12499                       0.275                  0.265  ...
#
#        closePriceNorm_lag_10  log_ret_normalised_by_day_lag_10  \
# 0                        NaN                               NaN
# 1                        NaN                               NaN
# 2                        NaN                               NaN
# 3                        NaN                               NaN
# 4                        NaN                               NaN
# ...                      ...                               ...
# 12495              -0.136102                         -2.032099
# 12496              -0.539073                         -1.515743
# 12497              -0.377885                          0.765811
# 12498              -0.363231                          0.030813
# 12499              -0.326598                          0.102353
#
#        mean_log_ret_lag_1  mean_closePrice_lag_1  mean_closePriceNorm_lag_1  \
# 0                     NaN                    NaN                        NaN
# 1                     NaN                40.6170                   0.241356
# 2                0.000525                40.6472                   0.247020
# 3               -0.000065                40.6172                   0.231342
# 4               -0.000623                40.5886                   0.211599
# ...                   ...                    ...                        ...
# 12495           -0.002123                39.4416                  -0.655234
# 12496           -0.001491                39.3646                  -0.690649
# 12497           -0.001420                39.3096                  -0.716371
# 12498           -0.000048                39.2904                  -0.714126
# 12499           -0.000252                39.2810                  -0.713713
#
#        mean_log_ret_normalised_by_day_lag_1  pos_log_ret_lag_1  \
# 0                                       NaN                NaN
# 1                                       NaN                NaN
# 2                             -4.440892e-18           0.000569
# 3                             -8.881784e-18          -0.001615
# 4                              1.776357e-17          -0.000616
# ...                                     ...                ...
# 12495                          5.773160e-17          -0.003932
# 12496                          4.662937e-17          -0.001368
# 12497                          8.770762e-17          -0.004381
# 12498                         -1.776357e-17          -0.001478
# 12499                          3.552714e-17          -0.002505
#
#        pos_closePrice_lag_1  pos_closePriceNorm_lag_1  \
# 0                       NaN                       NaN
# 1                 33.787500                  0.529432
# 2                 33.838750                  0.535137
# 3                 33.735000                  0.482227
# 4                 33.710000                  0.455742
# ...                     ...                       ...
# 12495             35.979231                 -0.815362
# 12496             35.899231                 -0.860295
# 12497             35.692308                 -0.931225
# 12498             35.616923                 -0.974622
# 12499             35.506154                 -1.026466
#
#        pos_log_ret_normalised_by_day_lag_1
# 0                                      NaN
# 1                                      NaN
# 2                                 0.007178
# 3                                -0.229975
# 4                                 0.001161
# ...                                    ...
# 12495                            -0.320944
# 12496                             0.019382
# 12497                            -0.493615
# 12498                            -0.267420
# 12499                            -0.344069
#
# [12500 rows x 194 columns]

# %%
date = [datetime.datetime(year=2023, month=1, day = 1) + datetime.timedelta(days=i) for i in range(250)]
val_date_start = date[175]
test_date_start = date[175+38]

# %%
function_map = ['min', 'max', 'std', 'mean', 'slope', 'skew', 'abs_diff_mean', 'diff_std', 'sum']

for i in [3, 5, 10, 20]:
    print('Max Lag:', i)

    tmp_curated_data = copy.deepcopy(curated_data)

    for j in range(i+1, 11):
        tmp_curated_data = tmp_curated_data.drop(columns=[f'log_ret_lag_{j}', f'log_ret_normalised_by_day_lag_{j}', f'closePriceNorm_lag_{j}', f'closePrice_lag_{j}'], axis = 1)

    for j in [3, 5, 10, 20]:
        if j > i:

            columns = []
            for col in ['log_ret', 'closePrice', 'closePriceNorm', 'log_ret_normalised_by_day']:
                for func in function_map:
                    columns.append(f'{col}_{func}_{j}')
            tmp_curated_data = tmp_curated_data.drop(columns=columns, axis = 1)

    tmp_curated_data = tmp_curated_data.dropna()

    train = tmp_curated_data[(tmp_curated_data['date'] < val_date_start)]
    val = tmp_curated_data[(tmp_curated_data['date'] < test_date_start) & (tmp_curated_data['date'] >= val_date_start)]
    test = tmp_curated_data[(tmp_curated_data['date'] >= test_date_start)]

    jiaocheng = JiaoCheng.JiaoCheng()

    train_x = train.drop(columns=['date', 'trend'], axis = 1)
    train_y = train['trend']

    val_x = val.drop(columns=['date', 'trend'], axis = 1)
    val_y = val['trend']

    test_x = test.drop(columns=['date', 'trend'], axis = 1)
    test_y = test['trend']

    with open(f'./drive/My Drive/LAB/Hackathon/models/NingXiang_output_{LABEL}_lag_{i}.pickle', 'rb') as f:
        ningxiang_output = pickle.load(f)

    ningxiang_output = list(ningxiang_output.items())
    ningxiang_output = dict(ningxiang_output)

    jiaocheng = JiaoCheng.JiaoCheng()

    from sklearn.svm import SVC

    jiaocheng.read_in_model(SVC, 'Classification')

    jiaocheng.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

    del train_x
    del train_y
    del val_x
    del val_y

    parameter_choices = {
        'C': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
        'kernel': ('poly', 'rbf'),
        'degree': (1, 2, 3)


    }

    jiaocheng.set_hyperparameters(parameter_choices)

    jiaocheng.set_non_tuneable_hyperparameters({'max_iter': -1})

    jiaocheng.set_features(ningxiang_output)

    jiaocheng.set_tuning_order(['features', 'kernel', 'degree', 'C'])

    jiaocheng.set_hyperparameter_default_values({
        'features': 0,
        'C': 1,
        'degree': 1,
        'kernel': 'poly'}
    )

    try:
        jiaocheng.read_in_tuning_result_df(f'./drive/My Drive/LAB/Hackathon/models/tuning/jiaocheng_{MODEL}_{LABEL}_lag_{i}.csv')
    except:
        pass

    jiaocheng.set_tuning_result_saving_address(f'./drive/My Drive/LAB/Hackathon/models/tuning/jiaocheng_{MODEL}_{LABEL}_lag_{i}.csv')
    jiaocheng.set_best_model_saving_address(f'./drive/My Drive/LAB/Hackathon/models/tmp_models/jiaocheng_{MODEL}_{LABEL}_lag_{i}.pickle')

    jiaocheng.tune()

    jiaocheng.view_best_combo_and_score()

    print('\n\n')
# Out:
# Max Lag: 3
# JiaoCheng Initialised
# JiaoCheng Initialised
# Successfully read in model <class 'sklearn.svm._classes.SVC'>, which is a Classification model
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# Successfully recorded hyperparameter choices
# Successfully recorded non_tuneable_hyperparameter choices
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# Successfully set tuning output address
# Successfully set best model output address
#
# Default combo: [4, 0, 0, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 3)
#
# Trained and Tested combination 1 of 2352: (4, 0, 0, 0), taking 1.6 seconds to get val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 2 of 2352: (4, 0, 0, 1), taking 1.34 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 3 of 2352: (4, 0, 0, 2), taking 1.38 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 4 of 2352: (4, 0, 0, 3), taking 2.5 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 5 of 2352: (4, 0, 0, 4), taking 1.46 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 6 of 2352: (4, 0, 0, 5), taking 1.61 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 7 of 2352: (4, 0, 0, 6), taking 1.6 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 8 of 2352: (4, 0, 0, 7), taking 1.97 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 9 of 2352: (4, 0, 0, 8), taking 1.87 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 10 of 2352: (4, 0, 0, 9), taking 1.94 seconds to get val score of 0.5179
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 11 of 2352: (4, 0, 0, 10), taking 2.33 seconds to get val score of 0.5179
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 12 of 2352: (4, 0, 0, 11), taking 2.05 seconds to get val score of 0.5179
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 13 of 2352: (4, 0, 0, 12), taking 2.13 seconds to get val score of 0.5179
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 14 of 2352: (4, 0, 0, 13), taking 2.21 seconds to get val score of 0.5179
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 15 of 2352: (4, 0, 0, 14), taking 2.27 seconds to get val score of 0.5179
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 16 of 2352: (4, 0, 0, 15), taking 2.88 seconds to get val score of 0.5179
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 17 of 2352: (4, 0, 0, 16), taking 2.21 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 18 of 2352: (4, 0, 0, 17), taking 2.18 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 19 of 2352: (4, 0, 0, 18), taking 3.34 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 20 of 2352: (4, 0, 0, 19), taking 2.27 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 21 of 2352: (4, 0, 0, 20), taking 2.43 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 22 of 2352: (4, 0, 0, 21), taking 2.45 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 23 of 2352: (4, 0, 0, 22), taking 2.51 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 24 of 2352: (4, 0, 0, 23), taking 3.6 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 25 of 2352: (4, 0, 0, 24), taking 2.6 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 26 of 2352: (4, 0, 0, 25), taking 3.2 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 27 of 2352: (4, 0, 0, 26), taking 2.71 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 28 of 2352: (4, 0, 0, 27), taking 2.83 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 29 of 2352: (4, 0, 0, 28), taking 3.34 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 30 of 2352: (4, 0, 0, 29), taking 2.98 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 31 of 2352: (4, 0, 0, 30), taking 3.03 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 32 of 2352: (4, 0, 0, 31), taking 2.41 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 33 of 2352: (4, 0, 0, 32), taking 2.73 seconds to get val score of 0.5211
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 34 of 2352: (4, 0, 0, 33), taking 2.48 seconds to get val score of 0.5216
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 35 of 2352: (4, 0, 0, 34), taking 3.59 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 36 of 2352: (4, 0, 0, 35), taking 2.45 seconds to get val score of 0.5216
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 37 of 2352: (4, 0, 0, 36), taking 2.69 seconds to get val score of 0.5211
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 38 of 2352: (4, 0, 0, 37), taking 2.63 seconds to get val score of 0.5205
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 39 of 2352: (4, 0, 0, 38), taking 2.97 seconds to get val score of 0.5132
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 40 of 2352: (4, 0, 0, 39), taking 2.99 seconds to get val score of 0.5142
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 41 of 2352: (4, 0, 0, 40), taking 3.01 seconds to get val score of 0.5142
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 42 of 2352: (4, 0, 0, 41), taking 3.16 seconds to get val score of 0.5142
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 43 of 2352: (4, 0, 0, 42), taking 3.01 seconds to get val score of 0.5137
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 44 of 2352: (4, 0, 0, 43), taking 3.37 seconds to get val score of 0.5137
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 45 of 2352: (4, 0, 0, 44), taking 3.13 seconds to get val score of 0.5137
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 46 of 2352: (4, 0, 0, 45), taking 3.05 seconds to get val score of 0.5137
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 47 of 2352: (4, 0, 0, 46), taking 3.17 seconds to get val score of 0.5216
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 48 of 2352: (4, 0, 0, 47), taking 2.63 seconds to get val score of 0.5047
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 49 of 2352: (4, 0, 0, 48), taking 2.73 seconds to get val score of 0.5053
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 50 of 2352: (4, 0, 0, 49), taking 2.93 seconds to get val score of 0.5042
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 51 of 2352: (4, 0, 0, 50), taking 2.67 seconds to get val score of 0.5068
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 52 of 2352: (4, 0, 0, 51), taking 3.88 seconds to get val score of 0.5105
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 53 of 2352: (4, 0, 0, 52), taking 2.73 seconds to get val score of 0.5105
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 54 of 2352: (4, 0, 0, 53), taking 3.76 seconds to get val score of 0.5095
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 55 of 2352: (4, 0, 0, 54), taking 3.22 seconds to get val score of 0.5153
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 56 of 2352: (4, 0, 0, 55), taking 3.94 seconds to get val score of 0.5147
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
#
# Best combo after this hyperparameter: (4, 0, 0, 0) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: kernel (index: 1)
#
# Already Trained and Tested combination (4, 0, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 56 of 2352 combinations so far
# Trained and Tested combination 57 of 2352: (4, 1, 0, 0), taking 2.23 seconds to get val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
#
# Best combo after this hyperparameter: (4, 0, 0, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: degree (index: 2)
#
# Already Trained and Tested combination (4, 0, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 57 of 2352 combinations so far
# Trained and Tested combination 58 of 2352: (4, 0, 1, 0), taking 2.01 seconds to get val score of 0.5195
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 59 of 2352: (4, 0, 2, 0), taking 1.92 seconds to get val score of 0.5395
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
#
# Best combo after this hyperparameter: (4, 0, 0, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: C (index: 0)
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 60 of 2352: (0, 0, 0, 0), taking 1.41 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 61 of 2352: (1, 0, 0, 0), taking 1.41 seconds to get val score of 0.5511
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 62 of 2352: (2, 0, 0, 0), taking 2.51 seconds to get val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 63 of 2352: (3, 0, 0, 0), taking 1.45 seconds to get val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Already Trained and Tested combination (4, 0, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 63 of 2352 combinations so far
# Trained and Tested combination 64 of 2352: (5, 0, 0, 0), taking 1.85 seconds to get val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 65 of 2352: (6, 0, 0, 0), taking 3.72 seconds to get val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
#
# Best combo after this hyperparameter: (4, 0, 0, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 2
# Hyperparameter: features (index: 3)
#
# Already Trained and Tested combination (4, 0, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 1), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 2), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 3), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 4), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 5), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 6), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 7), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 8), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 9), which had val score of 0.5179
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 10), which had val score of 0.5179
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 11), which had val score of 0.5179
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 12), which had val score of 0.5179
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 13), which had val score of 0.5179
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 14), which had val score of 0.5179
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 15), which had val score of 0.5179
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 16), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 17), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 18), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 19), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 20), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 21), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 22), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 23), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 24), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 25), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 26), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 27), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 28), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 29), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 30), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 31), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 32), which had val score of 0.5211
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 33), which had val score of 0.5216
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 34), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 35), which had val score of 0.5216
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 36), which had val score of 0.5211
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 37), which had val score of 0.5205
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 38), which had val score of 0.5132
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 39), which had val score of 0.5142
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 40), which had val score of 0.5142
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 41), which had val score of 0.5142
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 42), which had val score of 0.5137
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 43), which had val score of 0.5137
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 44), which had val score of 0.5137
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 45), which had val score of 0.5137
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 46), which had val score of 0.5216
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 47), which had val score of 0.5047
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 48), which had val score of 0.5053
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 49), which had val score of 0.5042
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 50), which had val score of 0.5068
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 51), which had val score of 0.5105
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 52), which had val score of 0.5105
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 53), which had val score of 0.5095
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 54), which had val score of 0.5153
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 55), which had val score of 0.5147
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
#
# Best combo after this hyperparameter: (4, 0, 0, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: kernel (index: 1)
#
# Already Trained and Tested combination (4, 0, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 1, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
#
# Best combo after this hyperparameter: (4, 0, 0, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: degree (index: 2)
#
# Already Trained and Tested combination (4, 0, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 1, 0), which had val score of 0.5195
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 2, 0), which had val score of 0.5395
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
#
# Best combo after this hyperparameter: (4, 0, 0, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: C (index: 0)
#
# Already Trained and Tested combination (0, 0, 0, 0), which had val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (1, 0, 0, 0), which had val score of 0.5511
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (2, 0, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
# Already Trained and Tested combination (6, 0, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 65 of 2352 combinations so far
#
# Best combo after this hyperparameter: (4, 0, 0, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.5521052631578948
# Max Test Score:
#  0.550556
# Max Combo Index:
#  (4, 0, 0, 0) out of [7, 2, 3, 56] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 1, 'kernel': 'poly', 'degree': 1, 'features': 0}
# Max Combo Features:
#  ('mean_log_ret_lag_1',)
# % Combos Checked: 65 out of 2352 which is 2.763605%
# Max Score:
#  0.5521052631578948
# Max Test Score:
#  0.550556
# Max Combo Index:
#  (4, 0, 0, 0) out of [7, 2, 3, 56] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 1, 'kernel': 'poly', 'degree': 1, 'features': 0}
# Max Combo Features:
#  ('mean_log_ret_lag_1',)
# % Combos Checked: 65 out of 2352 which is 2.763605%
#
#
#
# Max Lag: 5
# JiaoCheng Initialised
# JiaoCheng Initialised
# Successfully read in model <class 'sklearn.svm._classes.SVC'>, which is a Classification model
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# Successfully recorded hyperparameter choices
# Successfully recorded non_tuneable_hyperparameter choices
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# Successfully set tuning output address
# Successfully set best model output address
#
# Default combo: [4, 0, 0, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 3)
#
# Trained and Tested combination 1 of 4200: (4, 0, 0, 0), taking 1.53 seconds to get val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 2 of 4200: (4, 0, 0, 1), taking 1.32 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 3 of 4200: (4, 0, 0, 2), taking 1.38 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 4 of 4200: (4, 0, 0, 3), taking 2.37 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 5 of 4200: (4, 0, 0, 4), taking 1.47 seconds to get val score of 0.5189
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 6 of 4200: (4, 0, 0, 5), taking 1.51 seconds to get val score of 0.5184
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 7 of 4200: (4, 0, 0, 6), taking 1.74 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 8 of 4200: (4, 0, 0, 7), taking 2.31 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 9 of 4200: (4, 0, 0, 8), taking 1.96 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 10 of 4200: (4, 0, 0, 9), taking 1.91 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 11 of 4200: (4, 0, 0, 10), taking 2.74 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 12 of 4200: (4, 0, 0, 11), taking 1.91 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 13 of 4200: (4, 0, 0, 12), taking 2.1 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 14 of 4200: (4, 0, 0, 13), taking 2.8 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 15 of 4200: (4, 0, 0, 14), taking 2.19 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 16 of 4200: (4, 0, 0, 15), taking 2.09 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 17 of 4200: (4, 0, 0, 16), taking 2.24 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 18 of 4200: (4, 0, 0, 17), taking 2.12 seconds to get val score of 0.5179
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 19 of 4200: (4, 0, 0, 18), taking 2.52 seconds to get val score of 0.5168
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 20 of 4200: (4, 0, 0, 19), taking 2.3 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 21 of 4200: (4, 0, 0, 20), taking 2.37 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 22 of 4200: (4, 0, 0, 21), taking 3.44 seconds to get val score of 0.5168
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 23 of 4200: (4, 0, 0, 22), taking 2.42 seconds to get val score of 0.5168
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 24 of 4200: (4, 0, 0, 23), taking 2.61 seconds to get val score of 0.5168
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 25 of 4200: (4, 0, 0, 24), taking 2.62 seconds to get val score of 0.5168
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 26 of 4200: (4, 0, 0, 25), taking 3.14 seconds to get val score of 0.5168
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 27 of 4200: (4, 0, 0, 26), taking 2.74 seconds to get val score of 0.5168
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 28 of 4200: (4, 0, 0, 27), taking 2.77 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 29 of 4200: (4, 0, 0, 28), taking 3.4 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 30 of 4200: (4, 0, 0, 29), taking 2.9 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 31 of 4200: (4, 0, 0, 30), taking 5.09 seconds to get val score of 0.5174
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 32 of 4200: (4, 0, 0, 31), taking 2.77 seconds to get val score of 0.5168
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 33 of 4200: (4, 0, 0, 32), taking 2.92 seconds to get val score of 0.5168
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 34 of 4200: (4, 0, 0, 33), taking 2.72 seconds to get val score of 0.5163
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# Trained and Tested combination 35 of 4200: (4, 0, 0, 34), taking 3.72 seconds to get val score of 0.5163
#         Current best combo: (4, 0, 0, 0) with val score 0.5521
# ...
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 131), which had val score of 0.5242
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 132), which had val score of 0.5242
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 133), which had val score of 0.5242
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 134), which had val score of 0.5242
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 135), which had val score of 0.5242
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 136), which had val score of 0.5242
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 137), which had val score of 0.5242
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 138), which had val score of 0.5242
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 139), which had val score of 0.5237
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 140), which had val score of 0.5237
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 141), which had val score of 0.5242
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 142), which had val score of 0.5242
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 143), which had val score of 0.5242
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 144), which had val score of 0.5242
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 145), which had val score of 0.5242
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 146), which had val score of 0.5242
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 147), which had val score of 0.5242
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 148), which had val score of 0.5242
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 149), which had val score of 0.5242
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 150), which had val score of 0.5237
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 151), which had val score of 0.5237
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 152), which had val score of 0.5237
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 153), which had val score of 0.5237
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 154), which had val score of 0.5237
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 155), which had val score of 0.5237
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 156), which had val score of 0.5237
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 157), which had val score of 0.5237
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 158), which had val score of 0.5237
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 159), which had val score of 0.5284
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 160), which had val score of 0.5279
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 161), which had val score of 0.5279
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 162), which had val score of 0.5279
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 163), which had val score of 0.5279
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 164), which had val score of 0.5279
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 165), which had val score of 0.5279
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 166), which had val score of 0.5279
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 167), which had val score of 0.5279
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 168), which had val score of 0.5274
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 169), which had val score of 0.5274
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 170), which had val score of 0.5274
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 171), which had val score of 0.5274
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 172), which had val score of 0.5279
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 173), which had val score of 0.5295
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 174), which had val score of 0.5247
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 175), which had val score of 0.5253
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 176), which had val score of 0.4821
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 177), which had val score of 0.4821
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 178), which had val score of 0.4821
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 179), which had val score of 0.4821
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 180), which had val score of 0.4821
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 181), which had val score of 0.4821
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 182), which had val score of 0.4821
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 183), which had val score of 0.4821
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 184), which had val score of 0.4821
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 185), which had val score of 0.4821
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 186), which had val score of 0.4821
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 187), which had val score of 0.4821
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 188), which had val score of 0.4821
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 189), which had val score of 0.4821
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 190), which had val score of 0.4821
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 191), which had val score of 0.4821
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
#
# Best combo after this hyperparameter: (4, 0, 0, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: kernel (index: 1)
#
# Already Trained and Tested combination (4, 0, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 1, 0, 0), which had val score of 0.5489
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
#
# Best combo after this hyperparameter: (4, 0, 0, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: degree (index: 2)
#
# Already Trained and Tested combination (4, 0, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 1, 0), which had val score of 0.5268
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 2, 0), which had val score of 0.5395
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
#
# Best combo after this hyperparameter: (4, 0, 0, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: C (index: 0)
#
# Already Trained and Tested combination (0, 0, 0, 0), which had val score of 0.4826
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (1, 0, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (2, 0, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (3, 0, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (4, 0, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (5, 0, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
# Already Trained and Tested combination (6, 0, 0, 0), which had val score of 0.5521
#         Current best combo: (4, 0, 0, 0) with val score 0.5521.
#         Has trained 201 of 8064 combinations so far
#
# Best combo after this hyperparameter: (4, 0, 0, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.5521052631578948
# Max Test Score:
#  0.550556
# Max Combo Index:
#  (4, 0, 0, 0) out of [7, 2, 3, 192] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 1, 'kernel': 'poly', 'degree': 1, 'features': 0}
# Max Combo Features:
#  ('mean_log_ret_lag_1',)
# % Combos Checked: 201 out of 8064 which is 2.49256%
# Max Score:
#  0.5521052631578948
# Max Test Score:
#  0.550556
# Max Combo Index:
#  (4, 0, 0, 0) out of [7, 2, 3, 192] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 1, 'kernel': 'poly', 'degree': 1, 'features': 0}
# Max Combo Features:
#  ('mean_log_ret_lag_1',)
# % Combos Checked: 201 out of 8064 which is 2.49256%
