# %%
import sys
import os
import pickle
import pandas as pd
import json
import datetime
import time
import copy

py_file_location = '../PrivatePackages'
sys.path.append(os.path.abspath(py_file_location))
from sklearn.model_selection import train_test_split

import JiaoCheng
import NingXiang
# Out:
# /Applications/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
LABEL = 'logret_normalised_by_day'
MODEL = 'lgbr'

# %%
curated_data = pd.read_csv('../data/curated_data.csv')
curated_data = curated_data.drop(columns=['closePrice', 'closePriceNorm', 'log_ret', 'trend', 'stock'])
curated_data['date'] = pd.to_datetime(curated_data['date'])

# %%
date = [datetime.datetime(year=2022, month=12, day = 31) + datetime.timedelta(days=i) for i in range(250)]
val_date_start = date[175]
test_date_start = date[175+38]

# %%
function_map = ['min', 'max', 'std', 'mean', 'slope', 'skew', 'abs_diff_mean', 'diff_std', 'sum']

for i in [3, 5, 10, 20]:
    print('Max Lag:', i)

    tmp_curated_data = copy.deepcopy(curated_data)

    for j in range(i+1, 11):
        tmp_curated_data = tmp_curated_data.drop(columns=[f'log_ret_lag_{j}', f'log_ret_normalised_by_day_lag_{j}', f'closePriceNorm_lag_{j}', f'closePrice_lag_{j}'], axis = 1)
    
    for j in [3, 5, 10, 20]:
        if j > i:

            columns = []
            for col in ['log_ret', 'closePrice', 'closePriceNorm', 'log_ret_normalised_by_day']:
                for func in function_map:
                    columns.append(f'{col}_{func}_{j}')
            tmp_curated_data = tmp_curated_data.drop(columns=columns, axis = 1)

    tmp_curated_data = tmp_curated_data.dropna()

    train = tmp_curated_data[(tmp_curated_data['date'] < val_date_start)]
    val = tmp_curated_data[(tmp_curated_data['date'] < test_date_start) & (tmp_curated_data['date'] >= val_date_start)]

    ningxiang = NingXiang.NingXiang()

    train_x = train.drop(columns=['date', 'log_ret_normalised_by_day'], axis = 1)
    train_y = train['log_ret_normalised_by_day']

    val_x = val.drop(columns=['date', 'log_ret_normalised_by_day'], axis = 1)
    val_y = val['log_ret_normalised_by_day']

    ningxiang.read_in_train_data(train_x, train_y, val_x, val_y)

    ningxiang.set_model_type('Regression')

    ningxiang_output = ningxiang.get_rf_based_feature_combinations(1, 1, 4)

    ningxiang.export_ningxiang_output(f'../models/NingXiang_output_{LABEL}_lag_{i}')

    ningxiang.show_rf_stats()

    print('\n\n')
# Out:
# Max Lag: 3
# NingXiang Initialised
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Successfully recorded model type: Regression
# Begin fitting Random Forest
# Finished fitting Random Forest
# Successfully set object output address
# {'closePrice_min_3': 0.005829613519227752, 'closePrice_max_3': 0.004944034632687473, 'closePrice_std_3': 0.019660108226298406, 'closePrice_mean_3': 0.004514557203188895, 'closePrice_slope_3': 0.01978432046524659, 'closePrice_skew_3': 0.0144597640018246, 'closePrice_abs_diff_mean_3': 0.012009169424183248, 'closePrice_diff_std_3': 0.017953765685460893, 'closePrice_sum_3': 0.0047269431721787885, 'log_ret_min_3': 0.01832661899928576, 'log_ret_max_3': 0.01922644242839247, 'log_ret_std_3': 0.020247177468693013, 'log_ret_mean_3': 0.013074199585033726, 'log_ret_slope_3': 0.021148167657593083, 'log_ret_skew_3': 0.01837555557150615, 'log_ret_abs_diff_mean_3': 0.01429804290309087, 'log_ret_diff_std_3': 0.02135243621165246, 'log_ret_sum_3': 0.013454507363826479, 'closePriceNorm_min_3': 0.0147868238950362, 'closePriceNorm_max_3': 0.015807683074256305, 'closePriceNorm_std_3': 0.020455452716303894, 'closePriceNorm_mean_3': 0.009561630170128631, 'closePriceNorm_slope_3': 0.021528164795976433, 'closePriceNorm_skew_3': 0.014054546696959318, 'closePriceNorm_abs_diff_mean_3': 0.015828691125727573, 'closePriceNorm_diff_std_3': 0.017352118060006663, 'closePriceNorm_sum_3': 0.00777841613876467, 'log_ret_normalised_by_day_min_3': 0.017599762635859998, 'log_ret_normalised_by_day_max_3': 0.015293597784051887, 'log_ret_normalised_by_day_std_3': 0.02192499374784789, 'log_ret_normalised_by_day_mean_3': 0.01082994887033296, 'log_ret_normalised_by_day_slope_3': 0.02357891323550978, 'log_ret_normalised_by_day_skew_3': 0.018377585397080086, 'log_ret_normalised_by_day_abs_diff_mean_3': 0.018122054730813332, 'log_ret_normalised_by_day_diff_std_3': 0.020582825370353133, 'log_ret_normalised_by_day_sum_3': 0.011388412978084494, 'log_ret_lag_1': 0.03323636918833591, 'closePrice_lag_1': 0.008175844537055766, 'closePriceNorm_lag_1': 0.031287703595865544, 'log_ret_normalised_by_day_lag_1': 0.03336708767166666, 'log_ret_lag_2': 0.02263614217571062, 'closePrice_lag_2': 0.005744822745767498, 'closePriceNorm_lag_2': 0.0162086154566303, 'log_ret_normalised_by_day_lag_2': 0.0253266455199426, 'log_ret_lag_3': 0.02261732664446658, 'closePrice_lag_3': 0.005714261626164191, 'closePriceNorm_lag_3': 0.020025901292444196, 'log_ret_normalised_by_day_lag_3': 0.02575316576386247, 'mean_log_ret_lag_1': 0.02143955995832823, 'mean_closePrice_lag_1': 0.017740352157443656, 'mean_closePriceNorm_lag_1': 0.01455981204193748, 'mean_log_ret_normalised_by_day_lag_1': 0.0, 'pos_log_ret_lag_1': 0.025317315320762184, 'pos_closePrice_lag_1': 0.05647744051388201, 'pos_closePriceNorm_lag_1': 0.026782998750213536, 'pos_log_ret_normalised_by_day_lag_1': 0.029351589097056686}
# Validation score: 0.0002150359345429731
#
#
#
# Max Lag: 5
# NingXiang Initialised
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Successfully recorded model type: Regression
# Begin fitting Random Forest
# Finished fitting Random Forest
# Successfully set object output address
# {'closePrice_min_3': 0.0013056577736863138, 'closePrice_max_3': 0.001974622379105955, 'closePrice_std_3': 0.010222956325018673, 'closePrice_mean_3': 0.0020007603611923754, 'closePrice_slope_3': 0.01160615928128271, 'closePrice_skew_3': 0.009283881252167961, 'closePrice_abs_diff_mean_3': 0.006691481341039365, 'closePrice_diff_std_3': 0.0108700969140065, 'closePrice_sum_3': 0.002128247259913275, 'log_ret_min_3': 0.009053942707660132, 'log_ret_max_3': 0.008418853824146987, 'log_ret_std_3': 0.011466724454057511, 'log_ret_mean_3': 0.0059211383599451824, 'log_ret_slope_3': 0.011096213673161943, 'log_ret_skew_3': 0.010769986505644667, 'log_ret_abs_diff_mean_3': 0.010383118282172088, 'log_ret_diff_std_3': 0.010665834109621443, 'log_ret_sum_3': 0.008017001124003107, 'closePriceNorm_min_3': 0.006716411737598266, 'closePriceNorm_max_3': 0.006177841201226395, 'closePriceNorm_std_3': 0.00929858276812777, 'closePriceNorm_mean_3': 0.005103429837423363, 'closePriceNorm_slope_3': 0.012462413570101588, 'closePriceNorm_skew_3': 0.00650494929106054, 'closePriceNorm_abs_diff_mean_3': 0.007811286254707533, 'closePriceNorm_diff_std_3': 0.010633310695260169, 'closePriceNorm_sum_3': 0.0030877596348756, 'log_ret_normalised_by_day_min_3': 0.00848185231496186, 'log_ret_normalised_by_day_max_3': 0.008426262879522783, 'log_ret_normalised_by_day_std_3': 0.013068666517948604, 'log_ret_normalised_by_day_mean_3': 0.006646769446686581, 'log_ret_normalised_by_day_slope_3': 0.012937488311962914, 'log_ret_normalised_by_day_skew_3': 0.01116607591130689, 'log_ret_normalised_by_day_abs_diff_mean_3': 0.011917811311176085, 'log_ret_normalised_by_day_diff_std_3': 0.011560871505716266, 'log_ret_normalised_by_day_sum_3': 0.006263958346921946, 'closePrice_min_5': 0.0011336333198907114, 'closePrice_max_5': 0.0023055847514245197, 'closePrice_std_5': 0.013304218721793113, 'closePrice_mean_5': 0.0018837128980764878, 'closePrice_slope_5': 0.009018684966217015, 'closePrice_skew_5': 0.007849903999000816, 'closePrice_abs_diff_mean_5': 0.009302881659011157, 'closePrice_diff_std_5': 0.010860473163778653, 'closePrice_sum_5': 0.0019276381802098364, 'log_ret_min_5': 0.007645301831675849, 'log_ret_max_5': 0.012975564870068597, 'log_ret_std_5': 0.011365739087414116, 'log_ret_mean_5': 0.0068067803294375815, 'log_ret_slope_5': 0.016239997888228722, 'log_ret_skew_5': 0.009919716832119129, 'log_ret_abs_diff_mean_5': 0.011194462244863432, 'log_ret_diff_std_5': 0.010884362832782957, 'log_ret_sum_5': 0.00858259525331763, 'closePriceNorm_min_5': 0.007718241315246841, 'closePriceNorm_max_5': 0.00681652302140868, 'closePriceNorm_std_5': 0.016878025234981085, 'closePriceNorm_mean_5': 0.005320125957330188, 'closePriceNorm_slope_5': 0.010527080217805794, 'closePriceNorm_skew_5': 0.009736245294531787, 'closePriceNorm_abs_diff_mean_5': 0.008690274819098572, 'closePriceNorm_diff_std_5': 0.010580493407440517, 'closePriceNorm_sum_5': 0.004463828783023346, 'log_ret_normalised_by_day_min_5': 0.009168377558823526, 'log_ret_normalised_by_day_max_5': 0.012091632404999893, 'log_ret_normalised_by_day_std_5': 0.018237629156257946, 'log_ret_normalised_by_day_mean_5': 0.009164750846334738, 'log_ret_normalised_by_day_slope_5': 0.01607607461099021, 'log_ret_normalised_by_day_skew_5': 0.011122693802219343, 'log_ret_normalised_by_day_abs_diff_mean_5': 0.011743195190289152, 'log_ret_normalised_by_day_diff_std_5': 0.010183137135124865, 'log_ret_normalised_by_day_sum_5': 0.007789685617133996, 'log_ret_lag_1': 0.0278932643842575, 'closePrice_lag_1': 0.0032303090352819707, 'closePriceNorm_lag_1': 0.016593204219951002, 'log_ret_normalised_by_day_lag_1': 0.02329289108631315, 'log_ret_lag_2': 0.01208048382242486, 'closePrice_lag_2': 0.0028072723883850294, 'closePriceNorm_lag_2': 0.009498131652310332, 'log_ret_normalised_by_day_lag_2': 0.014321297407101662, 'log_ret_lag_3': 0.016687879199333046, 'closePrice_lag_3': 0.002850426921506315, 'closePriceNorm_lag_3': 0.012525942810834776, 'log_ret_normalised_by_day_lag_3': 0.016736929 ...
# Validation score: 0.00987605329754826
#
#
#
# Max Lag: 10
# NingXiang Initialised
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Successfully recorded model type: Regression
# Begin fitting Random Forest
# Finished fitting Random Forest
# Successfully set object output address
# {'closePrice_min_3': 0.0009206248465135948, 'closePrice_max_3': 0.0010220902163942823, 'closePrice_std_3': 0.006993495655476731, 'closePrice_mean_3': 0.0005079162970650503, 'closePrice_slope_3': 0.007963217020523047, 'closePrice_skew_3': 0.006457424989453729, 'closePrice_abs_diff_mean_3': 0.00498549032305478, 'closePrice_diff_std_3': 0.006193161167234864, 'closePrice_sum_3': 0.0005380224071438031, 'log_ret_min_3': 0.006292730344661884, 'log_ret_max_3': 0.0033576458015727763, 'log_ret_std_3': 0.006873541810430163, 'log_ret_mean_3': 0.00409891092160262, 'log_ret_slope_3': 0.010396859132195676, 'log_ret_skew_3': 0.007688474087529319, 'log_ret_abs_diff_mean_3': 0.0057582417800996774, 'log_ret_diff_std_3': 0.006713111758047782, 'log_ret_sum_3': 0.004842252195763191, 'closePriceNorm_min_3': 0.003135774682667431, 'closePriceNorm_max_3': 0.003220333413102539, 'closePriceNorm_std_3': 0.007954083638849932, 'closePriceNorm_mean_3': 0.0016544258086445326, 'closePriceNorm_slope_3': 0.007132344367459012, 'closePriceNorm_skew_3': 0.005049889900972224, 'closePriceNorm_abs_diff_mean_3': 0.004856916408003302, 'closePriceNorm_diff_std_3': 0.006820970935742757, 'closePriceNorm_sum_3': 0.001982723290514115, 'log_ret_normalised_by_day_min_3': 0.00427285302098082, 'log_ret_normalised_by_day_max_3': 0.005167631897368329, 'log_ret_normalised_by_day_std_3': 0.008252919454852042, 'log_ret_normalised_by_day_mean_3': 0.003627725941780657, 'log_ret_normalised_by_day_slope_3': 0.010472447811943937, 'log_ret_normalised_by_day_skew_3': 0.009985942994204565, 'log_ret_normalised_by_day_abs_diff_mean_3': 0.007424222973786947, 'log_ret_normalised_by_day_diff_std_3': 0.009881689174393107, 'log_ret_normalised_by_day_sum_3': 0.003832745253957974, 'closePrice_min_5': 0.0003666092400676595, 'closePrice_max_5': 0.0006216034345190006, 'closePrice_std_5': 0.005961211854107043, 'closePrice_mean_5': 0.0004763314560500447, 'closePrice_slope_5': 0.0065928902361087355, 'closePrice_skew_5': 0.006639631268235146, 'closePrice_abs_diff_mean_5': 0.005028306359760633, 'closePrice_diff_std_5': 0.006757684508313062, 'closePrice_sum_5': 0.0008291660709913552, 'log_ret_min_5': 0.004121086730725627, 'log_ret_max_5': 0.004636996125252213, 'log_ret_std_5': 0.0053847263110136465, 'log_ret_mean_5': 0.004808957904838755, 'log_ret_slope_5': 0.010737420373212682, 'log_ret_skew_5': 0.006560344502547169, 'log_ret_abs_diff_mean_5': 0.0058396908968512415, 'log_ret_diff_std_5': 0.0048093045924337404, 'log_ret_sum_5': 0.0031791727464488776, 'closePriceNorm_min_5': 0.0023076506652557516, 'closePriceNorm_max_5': 0.0032216726104485945, 'closePriceNorm_std_5': 0.00851185085580765, 'closePriceNorm_mean_5': 0.0028517590479042, 'closePriceNorm_slope_5': 0.008565878069368862, 'closePriceNorm_skew_5': 0.007332584080948741, 'closePriceNorm_abs_diff_mean_5': 0.006575598521088519, 'closePriceNorm_diff_std_5': 0.006537201833079158, 'closePriceNorm_sum_5': 0.0019512946378761672, 'log_ret_normalised_by_day_min_5': 0.0053065188793145635, 'log_ret_normalised_by_day_max_5': 0.005996681528478411, 'log_ret_normalised_by_day_std_5': 0.008857157955659334, 'log_ret_normalised_by_day_mean_5': 0.004388663011937341, 'log_ret_normalised_by_day_slope_5': 0.008636193817008874, 'log_ret_normalised_by_day_skew_5': 0.007516373204443906, 'log_ret_normalised_by_day_abs_diff_mean_5': 0.006502335947246847, 'log_ret_normalised_by_day_diff_std_5': 0.007145676211216647, 'log_ret_normalised_by_day_sum_5': 0.003808775629372528, 'closePrice_min_10': 0.0009096363262650087, 'closePrice_max_10': 0.0007024026810005824, 'closePrice_std_10': 0.005756727585305048, 'closePrice_mean_10': 0.0007206986072136212, 'closePrice_slope_10': 0.01392321360883573, 'closePrice_skew_10': 0.007161505819680843, 'closePrice_abs_diff_mean_10': 0.005632446509086193, 'closePrice_diff_std_10': 0.005445795066926358, 'closePrice_sum_10': 0.0005974085545688621, 'log_ret_min_10': 0.01015731044508793, 'log_ret_max_10': 0.008129424579186022, 'log_ret_std_10': 0.0071970175823 ...
# Validation score: 0.017712086570798924
#
#
#
# Max Lag: 20
# NingXiang Initialised
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Successfully recorded model type: Regression
# Begin fitting Random Forest
# Finished fitting Random Forest
# Successfully set object output address
# {'closePrice_min_3': 0.0005652499131351214, 'closePrice_max_3': 0.0006468978776968323, 'closePrice_std_3': 0.004738118056352083, 'closePrice_mean_3': 0.0005016579458292062, 'closePrice_slope_3': 0.007403343015217607, 'closePrice_skew_3': 0.004978145897868992, 'closePrice_abs_diff_mean_3': 0.003509630857398844, 'closePrice_diff_std_3': 0.005983926359687459, 'closePrice_sum_3': 0.0005628058573308403, 'log_ret_min_3': 0.005827238572445838, 'log_ret_max_3': 0.00524513097916667, 'log_ret_std_3': 0.0056558491173041795, 'log_ret_mean_3': 0.004044827853889189, 'log_ret_slope_3': 0.007826798502103653, 'log_ret_skew_3': 0.006576756792159033, 'log_ret_abs_diff_mean_3': 0.0045562246918853565, 'log_ret_diff_std_3': 0.006459623097933497, 'log_ret_sum_3': 0.0028616328341884733, 'closePriceNorm_min_3': 0.0028943217808533915, 'closePriceNorm_max_3': 0.002238867059094969, 'closePriceNorm_std_3': 0.005400726505583245, 'closePriceNorm_mean_3': 0.0011654375253433462, 'closePriceNorm_slope_3': 0.006393779504669929, 'closePriceNorm_skew_3': 0.004467893075597377, 'closePriceNorm_abs_diff_mean_3': 0.0035440867780054987, 'closePriceNorm_diff_std_3': 0.007018574282200976, 'closePriceNorm_sum_3': 0.0018932564149962872, 'log_ret_normalised_by_day_min_3': 0.004251427708004481, 'log_ret_normalised_by_day_max_3': 0.004585102584258185, 'log_ret_normalised_by_day_std_3': 0.0059115607551181535, 'log_ret_normalised_by_day_mean_3': 0.0039517793330640805, 'log_ret_normalised_by_day_slope_3': 0.006658614351183249, 'log_ret_normalised_by_day_skew_3': 0.006603280313706717, 'log_ret_normalised_by_day_abs_diff_mean_3': 0.007536806394034757, 'log_ret_normalised_by_day_diff_std_3': 0.008821052924905483, 'log_ret_normalised_by_day_sum_3': 0.003584963569953692, 'closePrice_min_5': 0.0007451522235865028, 'closePrice_max_5': 0.000579395494543495, 'closePrice_std_5': 0.0068055819917072005, 'closePrice_mean_5': 0.0007101793447864733, 'closePrice_slope_5': 0.005376740415209333, 'closePrice_skew_5': 0.005336900297100823, 'closePrice_abs_diff_mean_5': 0.004149880428009984, 'closePrice_diff_std_5': 0.005768160962950336, 'closePrice_sum_5': 0.0005024383339640806, 'log_ret_min_5': 0.005414557330284953, 'log_ret_max_5': 0.0030816559126488376, 'log_ret_std_5': 0.004776966183424891, 'log_ret_mean_5': 0.0038560665526747116, 'log_ret_slope_5': 0.01354610142672988, 'log_ret_skew_5': 0.006179679958850981, 'log_ret_abs_diff_mean_5': 0.0038840382508929117, 'log_ret_diff_std_5': 0.003938509138707161, 'log_ret_sum_5': 0.0029760403796478953, 'closePriceNorm_min_5': 0.00147850133895745, 'closePriceNorm_max_5': 0.002909762931319974, 'closePriceNorm_std_5': 0.005999903946985155, 'closePriceNorm_mean_5': 0.002721633025336268, 'closePriceNorm_slope_5': 0.005676683733317407, 'closePriceNorm_skew_5': 0.0053589070184545265, 'closePriceNorm_abs_diff_mean_5': 0.005653652759441201, 'closePriceNorm_diff_std_5': 0.00514239457646952, 'closePriceNorm_sum_5': 0.0018796481662131488, 'log_ret_normalised_by_day_min_5': 0.004284275326784076, 'log_ret_normalised_by_day_max_5': 0.004574325386899898, 'log_ret_normalised_by_day_std_5': 0.005955173848898803, 'log_ret_normalised_by_day_mean_5': 0.004150194461877016, 'log_ret_normalised_by_day_slope_5': 0.009803774259791025, 'log_ret_normalised_by_day_skew_5': 0.005284039999887663, 'log_ret_normalised_by_day_abs_diff_mean_5': 0.005207085603588596, 'log_ret_normalised_by_day_diff_std_5': 0.0046365911449209405, 'log_ret_normalised_by_day_sum_5': 0.004182571388230458, 'closePrice_min_10': 0.0004950995578608086, 'closePrice_max_10': 0.0003054704269284149, 'closePrice_std_10': 0.007083992372899878, 'closePrice_mean_10': 0.0010306856502734082, 'closePrice_slope_10': 0.012566053920465234, 'closePrice_skew_10': 0.003562361931466128, 'closePrice_abs_diff_mean_10': 0.005753950472100097, 'closePrice_diff_std_10': 0.004089155590404603, 'closePrice_sum_10': 0.0005584962404185524, 'log_ret_min_10': 0.004257284575817696, 'log_ret_max_10': 0.003659451224238368, 'log_ret_std_10': 0.00530 ...
# Validation score: 0.008191388120288745

# %%
function_map = ['min', 'max', 'std', 'mean', 'slope', 'skew', 'abs_diff_mean', 'diff_std', 'sum']

for i in [3, 5, 10, 20]:
    print('Max Lag:', i)

    tmp_curated_data = copy.deepcopy(curated_data)

    for j in range(i+1, 11):
        tmp_curated_data = tmp_curated_data.drop(columns=[f'log_ret_lag_{j}', f'log_ret_normalised_by_day_lag_{j}', f'closePriceNorm_lag_{j}', f'closePrice_lag_{j}'], axis = 1)
    
    for j in [3, 5, 10, 20]:
        if j > i:

            columns = []
            for col in ['log_ret', 'closePrice', 'closePriceNorm', 'log_ret_normalised_by_day']:
                for func in function_map:
                    columns.append(f'{col}_{func}_{j}')
            tmp_curated_data = tmp_curated_data.drop(columns=columns, axis = 1)

    tmp_curated_data = tmp_curated_data.dropna()

    train = tmp_curated_data[(tmp_curated_data['date'] < val_date_start)]
    val = tmp_curated_data[(tmp_curated_data['date'] < test_date_start) & (tmp_curated_data['date'] >= val_date_start)]
    test = tmp_curated_data[(tmp_curated_data['date'] >= test_date_start)]

    jiaocheng = JiaoCheng.JiaoCheng()

    train_x = train.drop(columns=['date', 'log_ret_normalised_by_day'], axis = 1)
    train_y = train['log_ret_normalised_by_day']

    val_x = val.drop(columns=['date', 'log_ret_normalised_by_day'], axis = 1)
    val_y = val['log_ret_normalised_by_day']
    
    test_x = test.drop(columns=['date', 'log_ret_normalised_by_day'], axis = 1)
    test_y = test['log_ret_normalised_by_day']

    with open(f'../models/NingXiang_output_{LABEL}_lag_{i}.pickle', 'rb') as f:
        ningxiang_output = pickle.load(f)

    ningxiang_output = list(ningxiang_output.items())
    ningxiang_output = dict(ningxiang_output)

    jiaocheng = JiaoCheng.JiaoCheng()

    from lightgbm import LGBMRegressor as LGBR

    jiaocheng.read_in_model(LGBR, 'Regression')

    jiaocheng.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

    del train_x
    del train_y
    del val_x
    del val_y

    parameter_choices = {
        'n_estimators': (25, 50, 100, 200, 400),
        'max_depth': (3, 6, 12, 24, 48, 96, 192),
        'subsample': (0.4, 0.55, 0.7, 0.85),
        'colsample_bytree': (0.4, 0.55, 0.7, 0.85),
        'learning_rate': (0.00000001, 0.000001, 0.0001, 0.01, 0.1),
        'reg_alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10)

    }

    jiaocheng.set_hyperparameters(parameter_choices)

    jiaocheng.set_non_tuneable_hyperparameters({'random_state': 19260817, 'n_jobs': -1})

    jiaocheng.set_features(ningxiang_output)

    jiaocheng.set_tuning_order(['features', 'max_depth', 'colsample_bytree', 'subsample', 'n_estimators', 'reg_alpha', 'learning_rate'])

    jiaocheng.set_hyperparameter_default_values({
        'features': 0,
        'n_estimators': 50,
        'max_depth': 12,
        'subsample': 0.7,
        'colsample_bytree': 0.7,
        'learning_rate': 0.1,
        'reg_alpha': 0.01}
    )

    try:
        jiaocheng.read_in_tuning_result_df(f'../models/tuning/jiaocheng_{MODEL}_{LABEL}_lag_{i}.csv')
    except:
        pass

    jiaocheng.set_tuning_result_saving_address(f'../models/tuning/jiaocheng_{MODEL}_{LABEL}_lag_{i}.csv')
    jiaocheng.set_best_model_saving_address(f'../models/tmp_models/jiaocheng_{MODEL}_{LABEL}_lag_{i}.pickle')

    jiaocheng.tune()

    jiaocheng.view_best_combo_and_score()

    print('\n\n')
# Out:
# Max Lag: 3
# JiaoCheng Initialised
# JiaoCheng Initialised
# Successfully read in model <class 'lightgbm.sklearn.LGBMRegressor'>, which is a Regression model
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# Successfully recorded hyperparameter choices
# Successfully recorded non_tuneable_hyperparameter choices
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# Successfully set tuning output address
# Successfully set best model output address
#
# Default combo: [1, 2, 2, 2, 4, 2, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 6)
#
# Trained and Tested combination 1 of 940800: (1, 2, 2, 2, 4, 2, 0), taking 1.44 seconds to get val score of -0.0169
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0169
# Trained and Tested combination 2 of 940800: (1, 2, 2, 2, 4, 2, 1), taking 1.76 seconds to get val score of -0.0252
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0169
# Trained and Tested combination 3 of 940800: (1, 2, 2, 2, 4, 2, 2), taking 1.52 seconds to get val score of -0.0254
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0169
# Trained and Tested combination 4 of 940800: (1, 2, 2, 2, 4, 2, 3), taking 1.5 seconds to get val score of -0.0366
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0169
# Trained and Tested combination 5 of 940800: (1, 2, 2, 2, 4, 2, 4), taking 2.26 seconds to get val score of -0.0325
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0169
# Trained and Tested combination 6 of 940800: (1, 2, 2, 2, 4, 2, 5), taking 1.52 seconds to get val score of -0.0477
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0169
# Trained and Tested combination 7 of 940800: (1, 2, 2, 2, 4, 2, 6), taking 2.06 seconds to get val score of -0.0373
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0169
# Trained and Tested combination 8 of 940800: (1, 2, 2, 2, 4, 2, 7), taking 2.58 seconds to get val score of -0.0321
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0169
# Trained and Tested combination 9 of 940800: (1, 2, 2, 2, 4, 2, 8), taking 2.79 seconds to get val score of -0.0468
#         Current best combo: (1, 2, 2, 2, 4, 2, 0) with val score -0.0169
# Trained and Tested combination 10 of 940800: (1, 2, 2, 2, 4, 2, 9), taking 1.74 seconds to get val score of -0.016
#         Current best combo: (1, 2, 2, 2, 4, 2, 9) with val score -0.016
# Trained and Tested combination 11 of 940800: (1, 2, 2, 2, 4, 2, 10), taking 2.28 seconds to get val score of -0.0347
#         Current best combo: (1, 2, 2, 2, 4, 2, 9) with val score -0.016
# Trained and Tested combination 12 of 940800: (1, 2, 2, 2, 4, 2, 11), taking 1.86 seconds to get val score of -0.0372
#         Current best combo: (1, 2, 2, 2, 4, 2, 9) with val score -0.016
# Trained and Tested combination 13 of 940800: (1, 2, 2, 2, 4, 2, 12), taking 1.86 seconds to get val score of -0.0175
#         Current best combo: (1, 2, 2, 2, 4, 2, 9) with val score -0.016
# Trained and Tested combination 14 of 940800: (1, 2, 2, 2, 4, 2, 13), taking 1.86 seconds to get val score of -0.0312
#         Current best combo: (1, 2, 2, 2, 4, 2, 9) with val score -0.016
# Trained and Tested combination 15 of 940800: (1, 2, 2, 2, 4, 2, 14), taking 1.71 seconds to get val score of -0.028
#         Current best combo: (1, 2, 2, 2, 4, 2, 9) with val score -0.016
# Trained and Tested combination 16 of 940800: (1, 2, 2, 2, 4, 2, 15), taking 2.06 seconds to get val score of -0.031
#         Current best combo: (1, 2, 2, 2, 4, 2, 9) with val score -0.016
# Trained and Tested combination 17 of 940800: (1, 2, 2, 2, 4, 2, 16), taking 2.03 seconds to get val score of -0.0236
#         Current best combo: (1, 2, 2, 2, 4, 2, 9) with val score -0.016
# Trained and Tested combination 18 of 940800: (1, 2, 2, 2, 4, 2, 17), taking 1.75 seconds to get val score of -0.0275
#         Current best combo: (1, 2, 2, 2, 4, 2, 9) with val score -0.016
# Trained and Tested combination 19 of 940800: (1, 2, 2, 2, 4, 2, 18), taking 2.44 seconds to get val score of -0.0234
#         Current best combo: (1, 2, 2, 2, 4, 2, 9) with val score -0.016
# Trained and Tested combination 20 of 940800: (1, 2, 2, 2, 4, 2, 19), taking 1.76 seconds to get val score of -0.0213
#         Current best combo: (1, 2, 2, 2, 4, 2, 9) with val score -0.016
# Trained and Tested combination 21 of 940800: (1, 2, 2, 2, 4, 2, 20), taking 2.35 seconds to get val score of -0.0338
#         Current best combo: (1, 2, 2, 2, 4, 2, 9) with val score -0.016
# Trained and Tested combination 22 of 940800: (1, 2, 2, 2, 4, 2, 21), taking 1.85 seconds to get val score of -0.0188
#         Current best combo: (1, 2, 2, 2, 4, 2, 9) with val score -0.016
# Trained and Tested combination 23 of 940800: (1, 2, 2, 2, 4, 2, 22), taking 1.64 seconds to get val score of -0.027
#         Current best combo: (1, 2, 2, 2, 4, 2, 9) with val score -0.016
# Trained and Tested combination 24 of 940800: (1, 2, 2, 2, 4, 2, 23), taking 2.42 seconds to get val score of -0.0237
#         Current best combo: (1, 2, 2, 2, 4, 2, 9) with val score -0.016
# Trained and Tested combination 25 of 940800: (1, 2, 2, 2, 4, 2, 24), taking 2.01 seconds to get val score of -0.021
#         Current best combo: (1, 2, 2, 2, 4, 2, 9) with val score -0.016
# Trained and Tested combination 26 of 940800: (1, 2, 2, 2, 4, 2, 25), taking 1.96 seconds to get val score of -0.0117
#         Current best combo: (1, 2, 2, 2, 4, 2, 25) with val score -0.0117
# Trained and Tested combination 27 of 940800: (1, 2, 2, 2, 4, 2, 26), taking 3.04 seconds to get val score of -0.0108
#         Current best combo: (1, 2, 2, 2, 4, 2, 26) with val score -0.0108
# Trained and Tested combination 28 of 940800: (1, 2, 2, 2, 4, 2, 27), taking 2.28 seconds to get val score of -0.0141
#         Current best combo: (1, 2, 2, 2, 4, 2, 26) with val score -0.0108
# Trained and Tested combination 29 of 940800: (1, 2, 2, 2, 4, 2, 28), taking 1.48 seconds to get val score of 0.0029
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 30 of 940800: (1, 2, 2, 2, 4, 2, 29), taking 1.33 seconds to get val score of -0.0193
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 31 of 940800: (1, 2, 2, 2, 4, 2, 30), taking 1.39 seconds to get val score of -0.012
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 32 of 940800: (1, 2, 2, 2, 4, 2, 31), taking 1.33 seconds to get val score of -0.01
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 33 of 940800: (1, 2, 2, 2, 4, 2, 32), taking 1.63 seconds to get val score of -0.0145
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 34 of 940800: (1, 2, 2, 2, 4, 2, 33), taking 2.49 seconds to get val score of -0.0138
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 35 of 940800: (1, 2, 2, 2, 4, 2, 34), taking 2.15 seconds to get val score of -0.0143
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 36 of 940800: (1, 2, 2, 2, 4, 2, 35), taking 2.39 seconds to get val score of -0.0114
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 37 of 940800: (1, 2, 2, 2, 4, 2, 36), taking 2.06 seconds to get val score of -0.0185
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 38 of 940800: (1, 2, 2, 2, 4, 2, 37), taking 1.91 seconds to get val score of -0.0093
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 39 of 940800: (1, 2, 2, 2, 4, 2, 38), taking 2.06 seconds to get val score of -0.0116
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 40 of 940800: (1, 2, 2, 2, 4, 2, 39), taking 1.84 seconds to get val score of -0.0141
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 41 of 940800: (1, 2, 2, 2, 4, 2, 40), taking 2.53 seconds to get val score of -0.0221
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 42 of 940800: (1, 2, 2, 2, 4, 2, 41), taking 2.12 seconds to get val score of -0.0111
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 43 of 940800: (1, 2, 2, 2, 4, 2, 42), taking 1.93 seconds to get val score of -0.0166
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 44 of 940800: (1, 2, 2, 2, 4, 2, 43), taking 2.3 seconds to get val score of -0.0152
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 45 of 940800: (1, 2, 2, 2, 4, 2, 44), taking 2.21 seconds to get val score of -0.008
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 46 of 940800: (1, 2, 2, 2, 4, 2, 45), taking 2.07 seconds to get val score of -0.0175
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 47 of 940800: (1, 2, 2, 2, 4, 2, 46), taking 2.07 seconds to get val score of -0.0147
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 48 of 940800: (1, 2, 2, 2, 4, 2, 47), taking 2.21 seconds to get val score of -0.0032
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 49 of 940800: (1, 2, 2, 2, 4, 2, 48), taking 2.01 seconds to get val score of -0.013
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 50 of 940800: (1, 2, 2, 2, 4, 2, 49), taking 2.33 seconds to get val score of -0.0092
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 51 of 940800: (1, 2, 2, 2, 4, 2, 50), taking 2.18 seconds to get val score of -0.0095
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 52 of 940800: (1, 2, 2, 2, 4, 2, 51), taking 2.41 seconds to get val score of -0.0164
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 53 of 940800: (1, 2, 2, 2, 4, 2, 52), taking 2.17 seconds to get val score of -0.007
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 54 of 940800: (1, 2, 2, 2, 4, 2, 53), taking 2.05 seconds to get val score of -0.0225
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 55 of 940800: (1, 2, 2, 2, 4, 2, 54), taking 2.26 seconds to get val score of -0.0088
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 56 of 940800: (1, 2, 2, 2, 4, 2, 55), taking 2.68 seconds to get val score of -0.0021
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 2, 28) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_depth (index: 1)
#
# Trained and Tested combination 57 of 940800: (1, 0, 2, 2, 4, 2, 28), taking 0.43 seconds to get val score of 0.0
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 58 of 940800: (1, 1, 2, 2, 4, 2, 28), taking 1.15 seconds to get val score of -0.0189
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 28), which had val score of 0.0029
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029.
#         Has trained 58 of 940800 combinations so far
# Trained and Tested combination 59 of 940800: (1, 3, 2, 2, 4, 2, 28), taking 1.7 seconds to get val score of -0.0183
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 60 of 940800: (1, 4, 2, 2, 4, 2, 28), taking 1.96 seconds to get val score of -0.0183
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 61 of 940800: (1, 5, 2, 2, 4, 2, 28), taking 1.93 seconds to get val score of -0.0183
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 62 of 940800: (1, 6, 2, 2, 4, 2, 28), taking 1.95 seconds to get val score of -0.0183
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 2, 28) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: colsample_bytree (index: 3)
#
# Trained and Tested combination 63 of 940800: (1, 2, 2, 0, 4, 2, 28), taking 2.06 seconds to get val score of -0.0207
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 64 of 940800: (1, 2, 2, 1, 4, 2, 28), taking 2.34 seconds to get val score of -0.0148
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 28), which had val score of 0.0029
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029.
#         Has trained 64 of 940800 combinations so far
# Trained and Tested combination 65 of 940800: (1, 2, 2, 3, 4, 2, 28), taking 1.96 seconds to get val score of -0.0264
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 2, 28) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: subsample (index: 2)
#
# Trained and Tested combination 66 of 940800: (1, 2, 0, 2, 4, 2, 28), taking 2.07 seconds to get val score of 0.0029
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Trained and Tested combination 67 of 940800: (1, 2, 1, 2, 4, 2, 28), taking 1.64 seconds to get val score of 0.0029
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 28), which had val score of 0.0029
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029.
#         Has trained 67 of 940800 combinations so far
# Trained and Tested combination 68 of 940800: (1, 2, 3, 2, 4, 2, 28), taking 1.79 seconds to get val score of 0.0029
#         Current best combo: (1, 2, 2, 2, 4, 2, 28) with val score 0.0029
#
# Best combo after this hyperparameter: (1, 2, 2, 2, 4, 2, 28) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: n_estimators (index: 0)
#
# Trained and Tested combination 69 of 940800: (0, 2, 2, 2, 4, 2, 28), taking 1.49 seconds to get val score of 0.0059
#         Current best combo: (0, 2, 2, 2, 4, 2, 28) with val score 0.0059
# Already Trained and Tested combination (1, 2, 2, 2, 4, 2, 28), which had val score of 0.0029
#         Current best combo: (0, 2, 2, 2, 4, 2, 28) with val score 0.0059.
#         Has trained 69 of 940800 combinations so far
# Trained and Tested combination 70 of 940800: (2, 2, 2, 2, 4, 2, 28), taking 3.55 seconds to get val score of -0.0297
#         Current best combo: (0, 2, 2, 2, 4, 2, 28) with val score 0.0059
# Trained and Tested combination 71 of 940800: (3, 2, 2, 2, 4, 2, 28), taking 7.69 seconds to get val score of -0.0712
#         Current best combo: (0, 2, 2, 2, 4, 2, 28) with val score 0.0059
# Trained and Tested combination 72 of 940800: (4, 2, 2, 2, 4, 2, 28), taking 15.09 seconds to get val score of -0.1073
#         Current best combo: (0, 2, 2, 2, 4, 2, 28) with val score 0.0059
#
# Best combo after this hyperparameter: (0, 2, 2, 2, 4, 2, 28) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: reg_alpha (index: 5)
#
# Trained and Tested combination 73 of 940800: (0, 2, 2, 2, 4, 0, 28), taking 1.07 seconds to get val score of 0.0004
#         Current best combo: (0, 2, 2, 2, 4, 2, 28) with val score 0.0059
# Trained and Tested combination 74 of 940800: (0, 2, 2, 2, 4, 1, 28), taking 1.2 seconds to get val score of 0.0004
#         Current best combo: (0, 2, 2, 2, 4, 2, 28) with val score 0.0059
# Already Trained and Tested combination (0, 2, 2, 2, 4, 2, 28), which had val score of 0.0059
#         Current best combo: (0, 2, 2, 2, 4, 2, 28) with val score 0.0059.
#         Has trained 74 of 940800 combinations so far
# Trained and Tested combination 75 of 940800: (0, 2, 2, 2, 4, 3, 28), taking 0.77 seconds to get val score of 0.0062
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 76 of 940800: (0, 2, 2, 2, 4, 4, 28), taking 0.99 seconds to get val score of 0.001
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 77 of 940800: (0, 2, 2, 2, 4, 5, 28), taking 1.18 seconds to get val score of -0.0023
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
#
# Best combo after this hyperparameter: (0, 2, 2, 2, 4, 3, 28) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: learning_rate (index: 4)
#
# Trained and Tested combination 78 of 940800: (0, 2, 2, 2, 0, 3, 28), taking 0.72 seconds to get val score of 0.0
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 79 of 940800: (0, 2, 2, 2, 1, 3, 28), taking 1.55 seconds to get val score of 0.0
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 80 of 940800: (0, 2, 2, 2, 2, 3, 28), taking 0.91 seconds to get val score of 0.0001
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 81 of 940800: (0, 2, 2, 2, 3, 3, 28), taking 0.8 seconds to get val score of 0.0041
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 28), which had val score of 0.0062
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062.
#         Has trained 81 of 940800 combinations so far
#
# Best combo after this hyperparameter: (0, 2, 2, 2, 4, 3, 28) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 2
# Hyperparameter: features (index: 6)
#
# Trained and Tested combination 82 of 940800: (0, 2, 2, 2, 4, 3, 0), taking 0.74 seconds to get val score of -0.0107
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 83 of 940800: (0, 2, 2, 2, 4, 3, 1), taking 0.82 seconds to get val score of -0.0173
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 84 of 940800: (0, 2, 2, 2, 4, 3, 2), taking 0.83 seconds to get val score of -0.0191
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 85 of 940800: (0, 2, 2, 2, 4, 3, 3), taking 1.06 seconds to get val score of -0.018
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 86 of 940800: (0, 2, 2, 2, 4, 3, 4), taking 0.83 seconds to get val score of -0.012
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 87 of 940800: (0, 2, 2, 2, 4, 3, 5), taking 1.41 seconds to get val score of -0.028
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 88 of 940800: (0, 2, 2, 2, 4, 3, 6), taking 1.18 seconds to get val score of -0.0184
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 89 of 940800: (0, 2, 2, 2, 4, 3, 7), taking 0.95 seconds to get val score of -0.0129
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 90 of 940800: (0, 2, 2, 2, 4, 3, 8), taking 0.93 seconds to get val score of -0.0144
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 91 of 940800: (0, 2, 2, 2, 4, 3, 9), taking 0.76 seconds to get val score of -0.0115
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 92 of 940800: (0, 2, 2, 2, 4, 3, 10), taking 1.29 seconds to get val score of -0.0054
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 93 of 940800: (0, 2, 2, 2, 4, 3, 11), taking 0.76 seconds to get val score of -0.0108
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 94 of 940800: (0, 2, 2, 2, 4, 3, 12), taking 1.11 seconds to get val score of -0.0014
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 95 of 940800: (0, 2, 2, 2, 4, 3, 13), taking 0.91 seconds to get val score of -0.0152
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 96 of 940800: (0, 2, 2, 2, 4, 3, 14), taking 0.97 seconds to get val score of -0.0115
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 97 of 940800: (0, 2, 2, 2, 4, 3, 15), taking 0.85 seconds to get val score of -0.0014
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 98 of 940800: (0, 2, 2, 2, 4, 3, 16), taking 0.83 seconds to get val score of 0.0039
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 99 of 940800: (0, 2, 2, 2, 4, 3, 17), taking 1.03 seconds to get val score of -0.0009
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 100 of 940800: (0, 2, 2, 2, 4, 3, 18), taking 1.09 seconds to get val score of -0.0049
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 101 of 940800: (0, 2, 2, 2, 4, 3, 19), taking 0.71 seconds to get val score of -0.003
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 102 of 940800: (0, 2, 2, 2, 4, 3, 20), taking 0.78 seconds to get val score of -0.0112
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 103 of 940800: (0, 2, 2, 2, 4, 3, 21), taking 0.79 seconds to get val score of -0.0041
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 104 of 940800: (0, 2, 2, 2, 4, 3, 22), taking 0.94 seconds to get val score of -0.0049
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 105 of 940800: (0, 2, 2, 2, 4, 3, 23), taking 0.77 seconds to get val score of -0.0013
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 106 of 940800: (0, 2, 2, 2, 4, 3, 24), taking 0.95 seconds to get val score of -0.0036
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 107 of 940800: (0, 2, 2, 2, 4, 3, 25), taking 0.88 seconds to get val score of -0.0056
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 108 of 940800: (0, 2, 2, 2, 4, 3, 26), taking 0.86 seconds to get val score of -0.0052
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 109 of 940800: (0, 2, 2, 2, 4, 3, 27), taking 1.07 seconds to get val score of -0.0066
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 28), which had val score of 0.0062
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062.
#         Has trained 109 of 940800 combinations so far
# Trained and Tested combination 110 of 940800: (0, 2, 2, 2, 4, 3, 29), taking 0.97 seconds to get val score of -0.0114
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 111 of 940800: (0, 2, 2, 2, 4, 3, 30), taking 0.99 seconds to get val score of -0.005
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 112 of 940800: (0, 2, 2, 2, 4, 3, 31), taking 1.1 seconds to get val score of 0.0004
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 113 of 940800: (0, 2, 2, 2, 4, 3, 32), taking 1.05 seconds to get val score of 0.0004
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 114 of 940800: (0, 2, 2, 2, 4, 3, 33), taking 1.16 seconds to get val score of 0.003
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 115 of 940800: (0, 2, 2, 2, 4, 3, 34), taking 0.75 seconds to get val score of -0.0
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 116 of 940800: (0, 2, 2, 2, 4, 3, 35), taking 0.78 seconds to get val score of -0.0042
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 117 of 940800: (0, 2, 2, 2, 4, 3, 36), taking 0.7 seconds to get val score of 0.0037
#         Current best combo: (0, 2, 2, 2, 4, 3, 28) with val score 0.0062
# Trained and Tested combination 118 of 940800: (0, 2, 2, 2, 4, 3, 37), taking 0.96 seconds to get val score of 0.0071
#         Current best combo: (0, 2, 2, 2, 4, 3, 37) with val score 0.0071
# Trained and Tested combination 119 of 940800: (0, 2, 2, 2, 4, 3, 38), taking 0.78 seconds to get val score of 0.0028
#         Current best combo: (0, 2, 2, 2, 4, 3, 37) with val score 0.0071
# Trained and Tested combination 120 of 940800: (0, 2, 2, 2, 4, 3, 39), taking 0.99 seconds to get val score of -0.0035
#         Current best combo: (0, 2, 2, 2, 4, 3, 37) with val score 0.0071
# Trained and Tested combination 121 of 940800: (0, 2, 2, 2, 4, 3, 40), taking 1.5 seconds to get val score of -0.0107
#         Current best combo: (0, 2, 2, 2, 4, 3, 37) with val score 0.0071
# Trained and Tested combination 122 of 940800: (0, 2, 2, 2, 4, 3, 41), taking 1.63 seconds to get val score of -0.0039
#         Current best combo: (0, 2, 2, 2, 4, 3, 37) with val score 0.0071
# Trained and Tested combination 123 of 940800: (0, 2, 2, 2, 4, 3, 42), taking 0.91 seconds to get val score of -0.0001
#         Current best combo: (0, 2, 2, 2, 4, 3, 37) with val score 0.0071
# Trained and Tested combination 124 of 940800: (0, 2, 2, 2, 4, 3, 43), taking 1.08 seconds to get val score of 0.0042
#         Current best combo: (0, 2, 2, 2, 4, 3, 37) with val score 0.0071
# Trained and Tested combination 125 of 940800: (0, 2, 2, 2, 4, 3, 44), taking 0.8 seconds to get val score of -0.0032
#         Current best combo: (0, 2, 2, 2, 4, 3, 37) with val score 0.0071
# Trained and Tested combination 126 of 940800: (0, 2, 2, 2, 4, 3, 45), taking 0.83 seconds to get val score of 0.0017
#         Current best combo: (0, 2, 2, 2, 4, 3, 37) with val score 0.0071
# Trained and Tested combination 127 of 940800: (0, 2, 2, 2, 4, 3, 46), taking 0.82 seconds to get val score of -0.0021
#         Current best combo: (0, 2, 2, 2, 4, 3, 37) with val score 0.0071
# Trained and Tested combination 128 of 940800: (0, 2, 2, 2, 4, 3, 47), taking 0.93 seconds to get val score of 0.0055
#         Current best combo: (0, 2, 2, 2, 4, 3, 37) with val score 0.0071
# Trained and Tested combination 129 of 940800: (0, 2, 2, 2, 4, 3, 48), taking 1.02 seconds to get val score of -0.0001
#         Current best combo: (0, 2, 2, 2, 4, 3, 37) with val score 0.0071
# Trained and Tested combination 130 of 940800: (0, 2, 2, 2, 4, 3, 49), taking 1.02 seconds to get val score of -0.0023
#         Current best combo: (0, 2, 2, 2, 4, 3, 37) with val score 0.0071
# Trained and Tested combination 131 of 940800: (0, 2, 2, 2, 4, 3, 50), taking 0.89 seconds to get val score of -0.0016
#         Current best combo: (0, 2, 2, 2, 4, 3, 37) with val score 0.0071
# Trained and Tested combination 132 of 940800: (0, 2, 2, 2, 4, 3, 51), taking 0.9 seconds to get val score of 0.0095
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Trained and Tested combination 133 of 940800: (0, 2, 2, 2, 4, 3, 52), taking 1.1 seconds to get val score of 0.0023
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Trained and Tested combination 134 of 940800: (0, 2, 2, 2, 4, 3, 53), taking 0.88 seconds to get val score of -0.0005
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Trained and Tested combination 135 of 940800: (0, 2, 2, 2, 4, 3, 54), taking 1.9 seconds to get val score of -0.0041
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Trained and Tested combination 136 of 940800: (0, 2, 2, 2, 4, 3, 55), taking 0.95 seconds to get val score of 0.007
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
#
# Best combo after this hyperparameter: (0, 2, 2, 2, 4, 3, 51) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_depth (index: 1)
#
# Trained and Tested combination 137 of 940800: (0, 0, 2, 2, 4, 3, 51), taking 0.31 seconds to get val score of 0.0075
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Trained and Tested combination 138 of 940800: (0, 1, 2, 2, 4, 3, 51), taking 1.15 seconds to get val score of -0.0018
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 51), which had val score of 0.0095
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 138 of 940800 combinations so far
# Trained and Tested combination 139 of 940800: (0, 3, 2, 2, 4, 3, 51), taking 1.22 seconds to get val score of -0.0033
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Trained and Tested combination 140 of 940800: (0, 4, 2, 2, 4, 3, 51), taking 0.83 seconds to get val score of -0.0033
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Trained and Tested combination 141 of 940800: (0, 5, 2, 2, 4, 3, 51), taking 0.92 seconds to get val score of -0.0033
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Trained and Tested combination 142 of 940800: (0, 6, 2, 2, 4, 3, 51), taking 1.71 seconds to get val score of -0.0033
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
#
# Best combo after this hyperparameter: (0, 2, 2, 2, 4, 3, 51) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: colsample_bytree (index: 3)
#
# Trained and Tested combination 143 of 940800: (0, 2, 2, 0, 4, 3, 51), taking 1.46 seconds to get val score of 0.0085
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Trained and Tested combination 144 of 940800: (0, 2, 2, 1, 4, 3, 51), taking 1.33 seconds to get val score of 0.0046
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 51), which had val score of 0.0095
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 144 of 940800 combinations so far
# Trained and Tested combination 145 of 940800: (0, 2, 2, 3, 4, 3, 51), taking 1.7 seconds to get val score of 0.0005
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
#
# Best combo after this hyperparameter: (0, 2, 2, 2, 4, 3, 51) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: subsample (index: 2)
#
# Trained and Tested combination 146 of 940800: (0, 2, 0, 2, 4, 3, 51), taking 0.94 seconds to get val score of 0.0095
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Trained and Tested combination 147 of 940800: (0, 2, 1, 2, 4, 3, 51), taking 1.6 seconds to get val score of 0.0095
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 51), which had val score of 0.0095
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 147 of 940800 combinations so far
# Trained and Tested combination 148 of 940800: (0, 2, 3, 2, 4, 3, 51), taking 1.04 seconds to get val score of 0.0095
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
#
# Best combo after this hyperparameter: (0, 2, 2, 2, 4, 3, 51) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 51), which had val score of 0.0095
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 148 of 940800 combinations so far
# Trained and Tested combination 149 of 940800: (1, 2, 2, 2, 4, 3, 51), taking 2.24 seconds to get val score of 0.0013
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Trained and Tested combination 150 of 940800: (2, 2, 2, 2, 4, 3, 51), taking 4.2 seconds to get val score of -0.0272
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Trained and Tested combination 151 of 940800: (3, 2, 2, 2, 4, 3, 51), taking 8.31 seconds to get val score of -0.0595
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Trained and Tested combination 152 of 940800: (4, 2, 2, 2, 4, 3, 51), taking 16.05 seconds to get val score of -0.0942
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
#
# Best combo after this hyperparameter: (0, 2, 2, 2, 4, 3, 51) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: reg_alpha (index: 5)
#
# Trained and Tested combination 153 of 940800: (0, 2, 2, 2, 4, 0, 51), taking 1.03 seconds to get val score of -0.002
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Trained and Tested combination 154 of 940800: (0, 2, 2, 2, 4, 1, 51), taking 1.05 seconds to get val score of -0.002
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Trained and Tested combination 155 of 940800: (0, 2, 2, 2, 4, 2, 51), taking 1.22 seconds to get val score of 0.0017
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 51), which had val score of 0.0095
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 155 of 940800 combinations so far
# Trained and Tested combination 156 of 940800: (0, 2, 2, 2, 4, 4, 51), taking 0.9 seconds to get val score of 0.0061
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Trained and Tested combination 157 of 940800: (0, 2, 2, 2, 4, 5, 51), taking 1.7 seconds to get val score of 0.0006
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
#
# Best combo after this hyperparameter: (0, 2, 2, 2, 4, 3, 51) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: learning_rate (index: 4)
#
# Trained and Tested combination 158 of 940800: (0, 2, 2, 2, 0, 3, 51), taking 0.97 seconds to get val score of 0.0
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Trained and Tested combination 159 of 940800: (0, 2, 2, 2, 1, 3, 51), taking 0.87 seconds to get val score of 0.0
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Trained and Tested combination 160 of 940800: (0, 2, 2, 2, 2, 3, 51), taking 1.35 seconds to get val score of 0.0001
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Trained and Tested combination 161 of 940800: (0, 2, 2, 2, 3, 3, 51), taking 0.89 seconds to get val score of 0.0063
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 51), which had val score of 0.0095
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
#
# Best combo after this hyperparameter: (0, 2, 2, 2, 4, 3, 51) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 3
#
# Round 3
# Hyperparameter: features (index: 6)
#
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 0), which had val score of -0.0107
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 1), which had val score of -0.0173
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 2), which had val score of -0.0191
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 3), which had val score of -0.018
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 4), which had val score of -0.012
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 5), which had val score of -0.028
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 6), which had val score of -0.0184
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 7), which had val score of -0.0129
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 8), which had val score of -0.0144
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 9), which had val score of -0.0115
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 10), which had val score of -0.0054
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 11), which had val score of -0.0108
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 12), which had val score of -0.0014
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 13), which had val score of -0.0152
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 14), which had val score of -0.0115
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 15), which had val score of -0.0014
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 16), which had val score of 0.0039
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 17), which had val score of -0.0009
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 18), which had val score of -0.0049
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 19), which had val score of -0.003
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 20), which had val score of -0.0112
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 21), which had val score of -0.0041
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 22), which had val score of -0.0049
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 23), which had val score of -0.0013
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 24), which had val score of -0.0036
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 25), which had val score of -0.0056
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 26), which had val score of -0.0052
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 27), which had val score of -0.0066
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 28), which had val score of 0.0062
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 29), which had val score of -0.0114
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 30), which had val score of -0.005
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 31), which had val score of 0.0004
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 32), which had val score of 0.0004
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 33), which had val score of 0.003
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 34), which had val score of -0.0
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 35), which had val score of -0.0042
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 36), which had val score of 0.0037
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 37), which had val score of 0.0071
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 38), which had val score of 0.0028
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 39), which had val score of -0.0035
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 40), which had val score of -0.0107
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 41), which had val score of -0.0039
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 42), which had val score of -0.0001
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 43), which had val score of 0.0042
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 44), which had val score of -0.0032
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 45), which had val score of 0.0017
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 46), which had val score of -0.0021
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 47), which had val score of 0.0055
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 48), which had val score of -0.0001
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 49), which had val score of -0.0023
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 50), which had val score of -0.0016
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 51), which had val score of 0.0095
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# Already Trained and Tested combination (0, 2, 2, 2, 4, 3, 52), which had val score of 0.0023
#         Current best combo: (0, 2, 2, 2, 4, 3, 51) with val score 0.0095.
#         Has trained 161 of 940800 combinations so far
# ...
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (0, 4, 2, 2, 4, 0, 168), which had val score of 0.0083
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (0, 5, 2, 2, 4, 0, 168), which had val score of 0.0083
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (0, 6, 2, 2, 4, 0, 168), which had val score of 0.0083
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 2, 4, 0, 168) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: colsample_bytree (index: 3)
#
# Already Trained and Tested combination (0, 0, 2, 0, 4, 0, 168), which had val score of 0.0171
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 1, 4, 0, 168), which had val score of 0.0087
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 2, 4, 0, 168), which had val score of 0.025
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 3, 4, 0, 168), which had val score of 0.0192
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 2, 4, 0, 168) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: subsample (index: 2)
#
# Already Trained and Tested combination (0, 0, 0, 2, 4, 0, 168), which had val score of 0.025
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (0, 0, 1, 2, 4, 0, 168), which had val score of 0.025
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 2, 4, 0, 168), which had val score of 0.025
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (0, 0, 3, 2, 4, 0, 168), which had val score of 0.025
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 2, 4, 0, 168) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 0, 2, 2, 4, 0, 168), which had val score of 0.025
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (1, 0, 2, 2, 4, 0, 168), which had val score of 0.0174
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (2, 0, 2, 2, 4, 0, 168), which had val score of 0.0035
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (3, 0, 2, 2, 4, 0, 168), which had val score of -0.0349
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (4, 0, 2, 2, 4, 0, 168), which had val score of -0.0644
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 2, 4, 0, 168) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: reg_alpha (index: 5)
#
# Already Trained and Tested combination (0, 0, 2, 2, 4, 0, 168), which had val score of 0.025
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 2, 4, 1, 168), which had val score of 0.025
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 2, 4, 2, 168), which had val score of 0.025
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 2, 4, 3, 168), which had val score of 0.0207
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 2, 4, 4, 168), which had val score of 0.0232
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 2, 4, 5, 168), which had val score of 0.0142
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 2, 4, 0, 168) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: learning_rate (index: 4)
#
# Already Trained and Tested combination (0, 0, 2, 2, 0, 0, 168), which had val score of 0.0
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 2, 1, 0, 168), which had val score of 0.0
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 2, 2, 0, 168), which had val score of 0.0001
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 2, 3, 0, 168), which had val score of 0.0074
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
# Already Trained and Tested combination (0, 0, 2, 2, 4, 0, 168), which had val score of 0.025
#         Current best combo: (0, 0, 2, 2, 4, 0, 168) with val score 0.025.
#         Has trained 433 of 3225600 combinations so far
#
# Best combo after this hyperparameter: (0, 0, 2, 2, 4, 0, 168) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.024978888543690236
# Max Test Score:
#  -0.008458
# Max Combo Index:
#  (0, 0, 2, 2, 4, 0, 168) out of [5, 7, 4, 4, 5, 6, 192] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 168}
# Max Combo Features:
#  ('pos_closePrice_lag_1', 'log_ret_slope_5', 'log_ret_normalised_by_day_lag_1', 'log_ret_lag_1', 'closePrice_slope_10', 'closePrice_slope_20', 'log_ret_normalised_by_day_lag_7', 'log_ret_lag_6', 'log_ret_normalised_by_day_lag_2', 'log_ret_lag_8', 'log_ret_lag_10', 'log_ret_lag_9', 'log_ret_normalised_by_day_lag_10', 'log_ret_normalised_by_day_slope_5', 'log_ret_normalised_by_day_lag_3', 'log_ret_normalised_by_day_lag_9', 'log_ret_normalised_by_day_lag_8', 'log_ret_normalised_by_day_lag_4', 'pos_closePriceNorm_lag_1', 'pos_log_ret_normalised_by_day_lag_1', 'pos_log_ret_lag_1', 'log_ret_lag_7', 'log_ret_normalised_by_day_diff_std_3', 'log_ret_normalised_by_day_lag_5', 'log_ret_lag_3', 'log_ret_normalised_by_day_lag_6', 'log_ret_min_20', 'log_ret_slope_3', 'log_ret_slope_20', 'closePriceNorm_slope_20', 'log_ret_lag_4', 'log_ret_normalised_by_day_std_20', 'log_ret_normalised_by_day_abs_diff_mean_3', 'closePrice_std_20', 'closePrice_slope_3', 'log_ret_mean_20', 'log_ret_std_20', 'closePriceNorm_lag_3', 'log_ret_skew_20', 'closePrice_std_10', 'log_ret_lag_2', 'closePriceNorm_diff_std_3', 'log_ret_slope_10', 'log_ret_normalised_by_day_slope_10', 'closePriceNorm_lag_8', 'log_ret_lag_5', 'closePrice_std_5', 'closePriceNorm_lag_7', 'log_ret_normalised_by_day_slope_3', 'log_ret_normalised_by_day_skew_3', 'log_ret_skew_3', 'closePriceNorm_slope_10', 'log_ret_diff_std_3', 'mean_log_ret_lag_1', 'closePriceNorm_lag_1', 'closePriceNorm_slope_3', 'log_ret_normalised_by_day_slope_20', 'log_ret_normalised_by_day_min_20', 'log_ret_skew_5', 'closePriceNorm_std_20', 'closePriceNorm_std_5', 'closePrice_diff_std_3', 'log_ret_normalised_by_day_mean_20', 'log_ret_normalised_by_day_std_5', 'log_ret_skew_10', 'log_ret_normalised_by_day_sum_20', 'log_ret_normalised_by_day_std_3', 'closePriceNorm_skew_20', 'log_ret_normalised_by_day_skew_20', 'log_ret_min_3', 'log_ret_sum_20', 'log_ret_max_20', 'closePrice_diff_std_5', 'closePrice_abs_diff_mean_10', 'log_ret_normalised_by_day_sum_10', 'log_ret_normalised_by_day_skew_10', 'log_ret_normalised_by_day_max_20', 'closePriceNorm_slope_5', 'closePriceNorm_abs_diff_mean_20', 'log_ret_std_3', 'closePriceNorm_abs_diff_mean_5', 'log_ret_normalised_by_day_abs_diff_mean_20', 'log_ret_min_5', 'closePriceNorm_std_3', 'mean_closePriceNorm_lag_1', 'closePrice_slope_5', 'closePriceNorm_mean_20', 'closePriceNorm_skew_5', 'closePrice_skew_5', 'log_ret_std_10', 'log_ret_normalised_by_day_skew_5', 'log_ret_max_3', 'log_ret_normalised_by_day_abs_diff_mean_5', 'closePriceNorm_min_20', 'closePriceNorm_diff_std_5', 'closePriceNorm_diff_std_20', 'log_ret_normalised_by_day_std_10', 'closePrice_skew_3', 'log_ret_normalised_by_day_abs_diff_mean_10', 'closePriceNorm_std_10', 'closePriceNorm_lag_5', 'log_ret_diff_std_20', 'closePriceNorm_sum_20', 'log_ret_std_5', 'closePriceNorm_skew_10', 'closePrice_std_3', 'log_ret_normalised_by_day_diff_std_20', 'log_ret_normalised_by_day_diff_std_5', 'closePriceNorm_abs_diff_mean_10', 'closePriceNorm_diff_std_10', 'log_ret_normalised_by_day_max_3', 'log_ret_normalised_by_day_max_5', 'closePriceNorm_lag_6', 'log_ret_abs_diff_mean_3', 'closePrice_abs_diff_mean_20', 'log_ret_normalised_by_day_mean_10', 'closePrice_skew_20', 'closePrice_diff_std_20', 'closePriceNorm_skew_3', 'log_ret_mean_10', 'log_ret_normalised_by_day_min_5', 'log_ret_min_10', 'log_ret_normalised_by_day_min_3', 'log_ret_normalised_by_day_sum_5', 'closePriceNorm_max_20', 'log_ret_abs_diff_mean_20', 'log_ret_normalised_by_day_mean_5', 'closePrice_abs_diff_mean_5', 'mean_closePrice_lag_1', 'closePrice_diff_std_10', 'log_ret_mean_3', 'closePriceNorm_lag_10', 'log_ret_normalised_by_day_mean_3', 'log_ret_diff_std_5', 'log_ret_abs_diff_mean_5', 'log_ret_mean_5', 'log_ret_normalised_by_day_diff_std_10', 'closePriceNorm_lag_4', 'log_ret_abs_diff_mean_10', 'log_ret_sum_10', 'log_ret_max_10', 'closePriceNorm_lag_2', 'log_ret_normalised_by_day_sum_3', 'closePrice_skew_10', 'closePriceNorm_abs_diff_mean_3', 'closePrice_abs_diff_mean_3', 'log_ret_nor ...
# % Combos Checked: 433 out of 3225600 which is 0.013423999999999998%
# Max Score:
#  0.024978888543690236
# Max Test Score:
#  -0.008458
# Max Combo Index:
#  (0, 0, 2, 2, 4, 0, 168) out of [5, 7, 4, 4, 5, 6, 192] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 25, 'max_depth': 3, 'subsample': 0.7, 'colsample_bytree': 0.7, 'learning_rate': 0.1, 'reg_alpha': 0.0001, 'features': 168}
# Max Combo Features:
#  ('pos_closePrice_lag_1', 'log_ret_slope_5', 'log_ret_normalised_by_day_lag_1', 'log_ret_lag_1', 'closePrice_slope_10', 'closePrice_slope_20', 'log_ret_normalised_by_day_lag_7', 'log_ret_lag_6', 'log_ret_normalised_by_day_lag_2', 'log_ret_lag_8', 'log_ret_lag_10', 'log_ret_lag_9', 'log_ret_normalised_by_day_lag_10', 'log_ret_normalised_by_day_slope_5', 'log_ret_normalised_by_day_lag_3', 'log_ret_normalised_by_day_lag_9', 'log_ret_normalised_by_day_lag_8', 'log_ret_normalised_by_day_lag_4', 'pos_closePriceNorm_lag_1', 'pos_log_ret_normalised_by_day_lag_1', 'pos_log_ret_lag_1', 'log_ret_lag_7', 'log_ret_normalised_by_day_diff_std_3', 'log_ret_normalised_by_day_lag_5', 'log_ret_lag_3', 'log_ret_normalised_by_day_lag_6', 'log_ret_min_20', 'log_ret_slope_3', 'log_ret_slope_20', 'closePriceNorm_slope_20', 'log_ret_lag_4', 'log_ret_normalised_by_day_std_20', 'log_ret_normalised_by_day_abs_diff_mean_3', 'closePrice_std_20', 'closePrice_slope_3', 'log_ret_mean_20', 'log_ret_std_20', 'closePriceNorm_lag_3', 'log_ret_skew_20', 'closePrice_std_10', 'log_ret_lag_2', 'closePriceNorm_diff_std_3', 'log_ret_slope_10', 'log_ret_normalised_by_day_slope_10', 'closePriceNorm_lag_8', 'log_ret_lag_5', 'closePrice_std_5', 'closePriceNorm_lag_7', 'log_ret_normalised_by_day_slope_3', 'log_ret_normalised_by_day_skew_3', 'log_ret_skew_3', 'closePriceNorm_slope_10', 'log_ret_diff_std_3', 'mean_log_ret_lag_1', 'closePriceNorm_lag_1', 'closePriceNorm_slope_3', 'log_ret_normalised_by_day_slope_20', 'log_ret_normalised_by_day_min_20', 'log_ret_skew_5', 'closePriceNorm_std_20', 'closePriceNorm_std_5', 'closePrice_diff_std_3', 'log_ret_normalised_by_day_mean_20', 'log_ret_normalised_by_day_std_5', 'log_ret_skew_10', 'log_ret_normalised_by_day_sum_20', 'log_ret_normalised_by_day_std_3', 'closePriceNorm_skew_20', 'log_ret_normalised_by_day_skew_20', 'log_ret_min_3', 'log_ret_sum_20', 'log_ret_max_20', 'closePrice_diff_std_5', 'closePrice_abs_diff_mean_10', 'log_ret_normalised_by_day_sum_10', 'log_ret_normalised_by_day_skew_10', 'log_ret_normalised_by_day_max_20', 'closePriceNorm_slope_5', 'closePriceNorm_abs_diff_mean_20', 'log_ret_std_3', 'closePriceNorm_abs_diff_mean_5', 'log_ret_normalised_by_day_abs_diff_mean_20', 'log_ret_min_5', 'closePriceNorm_std_3', 'mean_closePriceNorm_lag_1', 'closePrice_slope_5', 'closePriceNorm_mean_20', 'closePriceNorm_skew_5', 'closePrice_skew_5', 'log_ret_std_10', 'log_ret_normalised_by_day_skew_5', 'log_ret_max_3', 'log_ret_normalised_by_day_abs_diff_mean_5', 'closePriceNorm_min_20', 'closePriceNorm_diff_std_5', 'closePriceNorm_diff_std_20', 'log_ret_normalised_by_day_std_10', 'closePrice_skew_3', 'log_ret_normalised_by_day_abs_diff_mean_10', 'closePriceNorm_std_10', 'closePriceNorm_lag_5', 'log_ret_diff_std_20', 'closePriceNorm_sum_20', 'log_ret_std_5', 'closePriceNorm_skew_10', 'closePrice_std_3', 'log_ret_normalised_by_day_diff_std_20', 'log_ret_normalised_by_day_diff_std_5', 'closePriceNorm_abs_diff_mean_10', 'closePriceNorm_diff_std_10', 'log_ret_normalised_by_day_max_3', 'log_ret_normalised_by_day_max_5', 'closePriceNorm_lag_6', 'log_ret_abs_diff_mean_3', 'closePrice_abs_diff_mean_20', 'log_ret_normalised_by_day_mean_10', 'closePrice_skew_20', 'closePrice_diff_std_20', 'closePriceNorm_skew_3', 'log_ret_mean_10', 'log_ret_normalised_by_day_min_5', 'log_ret_min_10', 'log_ret_normalised_by_day_min_3', 'log_ret_normalised_by_day_sum_5', 'closePriceNorm_max_20', 'log_ret_abs_diff_mean_20', 'log_ret_normalised_by_day_mean_5', 'closePrice_abs_diff_mean_5', 'mean_closePrice_lag_1', 'closePrice_diff_std_10', 'log_ret_mean_3', 'closePriceNorm_lag_10', 'log_ret_normalised_by_day_mean_3', 'log_ret_diff_std_5', 'log_ret_abs_diff_mean_5', 'log_ret_mean_5', 'log_ret_normalised_by_day_diff_std_10', 'closePriceNorm_lag_4', 'log_ret_abs_diff_mean_10', 'log_ret_sum_10', 'log_ret_max_10', 'closePriceNorm_lag_2', 'log_ret_normalised_by_day_sum_3', 'closePrice_skew_10', 'closePriceNorm_abs_diff_mean_3', 'closePrice_abs_diff_mean_3', 'log_ret_nor ...
# % Combos Checked: 433 out of 3225600 which is 0.013423999999999998%
