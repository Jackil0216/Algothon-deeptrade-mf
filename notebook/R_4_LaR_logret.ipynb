# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
import pickle
import pandas as pd
import json
import datetime
import time
import copy

py_file_location = './drive/My Drive/PrivatePackages'
sys.path.append(os.path.abspath(py_file_location))
from sklearn.model_selection import train_test_split

import JiaoCheng
import NingXiang

# %%
LABEL = 'logret'
MODEL = 'lar'

# %%
curated_data = pd.read_csv('./drive/My Drive/LAB/Hackathon/data/curated_data.csv')
curated_data = curated_data.drop(columns=['closePrice', 'closePriceNorm', 'log_ret_normalised_by_day', 'trend', 'stock'])
curated_data['date'] = pd.to_datetime(curated_data['date'])

# %%
curated_data
# Out:
#             date   log_ret  closePrice_min_3  closePrice_max_3  \
# 0     2022-12-31       NaN               NaN               NaN
# 1     2023-01-01 -0.002996               NaN               NaN
# 2     2023-01-02 -0.005516               NaN               NaN
# 3     2023-01-03 -0.004704               NaN               NaN
# 4     2023-01-04 -0.002867               NaN               NaN
# ...          ...       ...               ...               ...
# 12495 2023-09-02 -0.005332             43.11             43.66
# 12496 2023-09-03  0.000232             43.25             43.66
# 12497 2023-09-04  0.012471             43.02             43.61
# 12498 2023-09-05 -0.010150             43.02             43.25
# 12499 2023-09-06  0.004626             43.02             43.57
#
#        closePrice_std_3  closePrice_mean_3  closePrice_slope_3  \
# 0                   NaN                NaN                 NaN
# 1                   NaN                NaN                 NaN
# 2                   NaN                NaN                 NaN
# 3                   NaN                NaN                 NaN
# 4                   NaN                NaN                 NaN
# ...                 ...                ...                 ...
# 12495          0.248328          43.460000            0.011598
# 12496          0.182635          43.506667           -0.009391
# 12497          0.242808          43.293333           -0.013529
# 12498          0.106145          43.100000           -0.005087
# 12499          0.256948          43.206667            0.012785
#
#        closePrice_skew_3  closePrice_abs_diff_mean_3  closePrice_diff_std_3  \
# 0                    NaN                         NaN                    NaN
# 1                    NaN                         NaN                    NaN
# 2                    NaN                         NaN                    NaN
# 3                    NaN                         NaN                    NaN
# 4                    NaN                         NaN                    NaN
# ...                  ...                         ...                    ...
# 12495          -0.685668                       0.300                  0.300
# 12496          -0.667566                       0.205                  0.155
# 12497           0.262017                       0.295                  0.065
# 12498           0.702403                       0.120                  0.120
# 12499           0.706304                       0.275                  0.265
#
#        ...  closePriceNorm_lag_10  log_ret_normalised_by_day_lag_10  \
# 0      ...                    NaN                               NaN
# 1      ...                    NaN                               NaN
# 2      ...                    NaN                               NaN
# 3      ...                    NaN                               NaN
# 4      ...                    NaN                               NaN
# ...    ...                    ...                               ...
# 12495  ...              -0.136102                         -2.032099
# 12496  ...              -0.539073                         -1.515743
# 12497  ...              -0.377885                          0.765811
# 12498  ...              -0.363231                          0.030813
# 12499  ...              -0.326598                          0.102353
#
#        mean_log_ret_lag_1  mean_closePrice_lag_1  mean_closePriceNorm_lag_1  \
# 0                     NaN                    NaN                        NaN
# 1                     NaN                40.6170                   0.241356
# 2                0.000525                40.6472                   0.247020
# 3               -0.000065                40.6172                   0.231342
# 4               -0.000623                40.5886                   0.211599
# ...                   ...                    ...                        ...
# 12495           -0.002123                39.4416                  -0.655234
# 12496           -0.001491                39.3646                  -0.690649
# 12497           -0.001420                39.3096                  -0.716371
# 12498           -0.000048                39.2904                  -0.714126
# 12499           -0.000252                39.2810                  -0.713713
#
#        mean_log_ret_normalised_by_day_lag_1  pos_log_ret_lag_1  \
# 0                                       NaN                NaN
# 1                                       NaN                NaN
# 2                             -4.440892e-18           0.000569
# 3                             -8.881784e-18          -0.001615
# 4                              1.776357e-17          -0.000616
# ...                                     ...                ...
# 12495                          5.773160e-17          -0.003932
# 12496                          4.662937e-17          -0.001368
# 12497                          8.770762e-17          -0.004381
# 12498                         -1.776357e-17          -0.001478
# 12499                          3.552714e-17          -0.002505
#
#        pos_closePrice_lag_1  pos_closePriceNorm_lag_1  \
# 0                       NaN                       NaN
# 1                 33.787500                  0.529432
# 2                 33.838750                  0.535137
# 3                 33.735000                  0.482227
# 4                 33.710000                  0.455742
# ...                     ...                       ...
# 12495             35.979231                 -0.815362
# 12496             35.899231                 -0.860295
# 12497             35.692308                 -0.931225
# 12498             35.616923                 -0.974622
# 12499             35.506154                 -1.026466
#
#        pos_log_ret_normalised_by_day_lag_1
# 0                                      NaN
# 1                                      NaN
# 2                                 0.007178
# 3                                -0.229975
# 4                                 0.001161
# ...                                    ...
# 12495                            -0.320944
# 12496                             0.019382
# 12497                            -0.493615
# 12498                            -0.267420
# 12499                            -0.344069
#
# [12500 rows x 194 columns]

# %%
date = [datetime.datetime(year=2023, month=1, day = 1) + datetime.timedelta(days=i) for i in range(250)]
val_date_start = date[175]
test_date_start = date[175+38]

# %%
function_map = ['min', 'max', 'std', 'mean', 'slope', 'skew', 'abs_diff_mean', 'diff_std', 'sum']

for i in [3, 5, 10, 20]:
    print('Max Lag:', i)

    tmp_curated_data = copy.deepcopy(curated_data)

    for j in range(i+1, 11):
        tmp_curated_data = tmp_curated_data.drop(columns=[f'log_ret_lag_{j}', f'log_ret_normalised_by_day_lag_{j}', f'closePriceNorm_lag_{j}', f'closePrice_lag_{j}'], axis = 1)

    for j in [3, 5, 10, 20]:
        if j > i:

            columns = []
            for col in ['log_ret', 'closePrice', 'closePriceNorm', 'log_ret_normalised_by_day']:
                for func in function_map:
                    columns.append(f'{col}_{func}_{j}')
            tmp_curated_data = tmp_curated_data.drop(columns=columns, axis = 1)

    tmp_curated_data = tmp_curated_data.dropna()

    train = tmp_curated_data[(tmp_curated_data['date'] < val_date_start)]
    val = tmp_curated_data[(tmp_curated_data['date'] < test_date_start) & (tmp_curated_data['date'] >= val_date_start)]
    test = tmp_curated_data[(tmp_curated_data['date'] >= test_date_start)]

    jiaocheng = JiaoCheng.JiaoCheng()

    train_x = train.drop(columns=['date', 'log_ret'], axis = 1)
    train_y = train['log_ret']

    val_x = val.drop(columns=['date', 'log_ret'], axis = 1)
    val_y = val['log_ret']

    test_x = test.drop(columns=['date', 'log_ret'], axis = 1)
    test_y = test['log_ret']

    with open(f'./drive/My Drive/LAB/Hackathon/models/NingXiang_output_{LABEL}_lag_{i}.pickle', 'rb') as f:
        ningxiang_output = pickle.load(f)

    ningxiang_output = list(ningxiang_output.items())
    ningxiang_output = dict(ningxiang_output)

    jiaocheng = JiaoCheng.JiaoCheng()

    from sklearn.linear_model import Lasso as LaR

    jiaocheng.read_in_model(LaR, 'Regression')

    jiaocheng.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

    del train_x
    del train_y
    del val_x
    del val_y

    parameter_choices = {
        'alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100),


    }

    jiaocheng.set_hyperparameters(parameter_choices)

    jiaocheng.set_non_tuneable_hyperparameters({'max_iter': 10000, 'random_state': 19260817})

    jiaocheng.set_features(ningxiang_output)

    jiaocheng.set_tuning_order(['features', 'alpha'])

    jiaocheng.set_hyperparameter_default_values({
        'features': 0,
        'alpha': 1,}
    )

    try:
        jiaocheng.read_in_tuning_result_df(f'./drive/My Drive/LAB/Hackathon/models/tuning/jiaocheng_{MODEL}_{LABEL}_lag_{i}.csv')
    except:
        pass

    jiaocheng.set_tuning_result_saving_address(f'./drive/My Drive/LAB/Hackathon/models/tuning/jiaocheng_{MODEL}_{LABEL}_lag_{i}.csv')
    jiaocheng.set_best_model_saving_address(f'./drive/My Drive/LAB/Hackathon/models/tmp_models/jiaocheng_{MODEL}_{LABEL}_lag_{i}.pickle')

    jiaocheng.tune()

    jiaocheng.view_best_combo_and_score()

    print('\n\n')
# Out:
# Max Lag: 3
# JiaoCheng Initialised
# JiaoCheng Initialised
# Successfully read in model <class 'sklearn.linear_model._coordinate_descent.Lasso'>, which is a Regression model
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# Successfully recorded hyperparameter choices
# Successfully recorded non_tuneable_hyperparameter choices
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# Successfully set tuning output address
# Successfully set best model output address
#
# Default combo: [4, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 1)
#
# Trained and Tested combination 1 of 392: (4, 0), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 2 of 392: (4, 1), taking 0.0 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 3 of 392: (4, 2), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 4 of 392: (4, 3), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 5 of 392: (4, 4), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 6 of 392: (4, 5), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 7 of 392: (4, 6), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 8 of 392: (4, 7), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 9 of 392: (4, 8), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 10 of 392: (4, 9), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 11 of 392: (4, 10), taking 0.0 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 12 of 392: (4, 11), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 13 of 392: (4, 12), taking 0.0 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 14 of 392: (4, 13), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 15 of 392: (4, 14), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 16 of 392: (4, 15), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 17 of 392: (4, 16), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 18 of 392: (4, 17), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 19 of 392: (4, 18), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 20 of 392: (4, 19), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 21 of 392: (4, 20), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 22 of 392: (4, 21), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 23 of 392: (4, 22), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 24 of 392: (4, 23), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 25 of 392: (4, 24), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 26 of 392: (4, 25), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 27 of 392: (4, 26), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 28 of 392: (4, 27), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 29 of 392: (4, 28), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 30 of 392: (4, 29), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 31 of 392: (4, 30), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 32 of 392: (4, 31), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 33 of 392: (4, 32), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 34 of 392: (4, 33), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 35 of 392: (4, 34), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 36 of 392: (4, 35), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 37 of 392: (4, 36), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 38 of 392: (4, 37), taking 0.03 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 39 of 392: (4, 38), taking 0.03 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 40 of 392: (4, 39), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 41 of 392: (4, 40), taking 0.03 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 42 of 392: (4, 41), taking 0.03 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 43 of 392: (4, 42), taking 0.03 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 44 of 392: (4, 43), taking 0.03 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 45 of 392: (4, 44), taking 0.03 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 46 of 392: (4, 45), taking 0.03 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 47 of 392: (4, 46), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 48 of 392: (4, 47), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 49 of 392: (4, 48), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 50 of 392: (4, 49), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 51 of 392: (4, 50), taking 0.04 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 52 of 392: (4, 51), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 53 of 392: (4, 52), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 54 of 392: (4, 53), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 55 of 392: (4, 54), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 56 of 392: (4, 55), taking 0.04 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
#
# Best combo after this hyperparameter: (4, 0) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: alpha (index: 0)
#
# Trained and Tested combination 57 of 392: (0, 0), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (0, 0) with val score -0.0
# Trained and Tested combination 58 of 392: (1, 0), taking 0.0 seconds to get val score of -0.0
#         Current best combo: (0, 0) with val score -0.0
# Trained and Tested combination 59 of 392: (2, 0), taking 0.0 seconds to get val score of -0.0
#         Current best combo: (0, 0) with val score -0.0
# Trained and Tested combination 60 of 392: (3, 0), taking 0.0 seconds to get val score of -0.0
#         Current best combo: (0, 0) with val score -0.0
# Already Trained and Tested combination (4, 0), which had val score of -0.0
#         Current best combo: (0, 0) with val score -0.0.
#         Has trained 60 of 392 combinations so far
# Trained and Tested combination 61 of 392: (5, 0), taking 0.0 seconds to get val score of -0.0
#         Current best combo: (0, 0) with val score -0.0
# Trained and Tested combination 62 of 392: (6, 0), taking 0.0 seconds to get val score of -0.0
#         Current best combo: (0, 0) with val score -0.0
#
# Best combo after this hyperparameter: (0, 0) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 2
# Hyperparameter: features (index: 1)
#
# Already Trained and Tested combination (0, 0), which had val score of -0.0
#         Current best combo: (0, 0) with val score -0.0.
#         Has trained 62 of 392 combinations so far
# Trained and Tested combination 63 of 392: (0, 1), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (0, 0) with val score -0.0
# Trained and Tested combination 64 of 392: (0, 2), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (0, 0) with val score -0.0
# Trained and Tested combination 65 of 392: (0, 3), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (0, 0) with val score -0.0
# Trained and Tested combination 66 of 392: (0, 4), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (0, 0) with val score -0.0
# Trained and Tested combination 67 of 392: (0, 5), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (0, 0) with val score -0.0
# Trained and Tested combination 68 of 392: (0, 6), taking 0.02 seconds to get val score of 0.0004
#         Current best combo: (0, 6) with val score 0.0004
# Trained and Tested combination 69 of 392: (0, 7), taking 0.02 seconds to get val score of 0.0004
#         Current best combo: (0, 6) with val score 0.0004
# Trained and Tested combination 70 of 392: (0, 8), taking 0.01 seconds to get val score of 0.0004
#         Current best combo: (0, 6) with val score 0.0004
# Trained and Tested combination 71 of 392: (0, 9), taking 0.02 seconds to get val score of 0.0004
#         Current best combo: (0, 6) with val score 0.0004
# Trained and Tested combination 72 of 392: (0, 10), taking 0.01 seconds to get val score of 0.0004
#         Current best combo: (0, 6) with val score 0.0004
# Trained and Tested combination 73 of 392: (0, 11), taking 0.02 seconds to get val score of 0.0004
#         Current best combo: (0, 6) with val score 0.0004
# Trained and Tested combination 74 of 392: (0, 12), taking 0.02 seconds to get val score of 0.0012
#         Current best combo: (0, 12) with val score 0.0012
# Trained and Tested combination 75 of 392: (0, 13), taking 0.02 seconds to get val score of 0.0012
#         Current best combo: (0, 12) with val score 0.0012
# Trained and Tested combination 76 of 392: (0, 14), taking 0.02 seconds to get val score of 0.0012
#         Current best combo: (0, 12) with val score 0.0012
# Trained and Tested combination 77 of 392: (0, 15), taking 0.02 seconds to get val score of 0.001
#         Current best combo: (0, 12) with val score 0.0012
# Trained and Tested combination 78 of 392: (0, 16), taking 0.03 seconds to get val score of 0.001
#         Current best combo: (0, 12) with val score 0.0012
# Trained and Tested combination 79 of 392: (0, 17), taking 0.01 seconds to get val score of 0.001
#         Current best combo: (0, 12) with val score 0.0012
# Trained and Tested combination 80 of 392: (0, 18), taking 0.02 seconds to get val score of 0.001
#         Current best combo: (0, 12) with val score 0.0012
# Trained and Tested combination 81 of 392: (0, 19), taking 0.02 seconds to get val score of 0.001
#         Current best combo: (0, 12) with val score 0.0012
# Trained and Tested combination 82 of 392: (0, 20), taking 0.02 seconds to get val score of 0.001
#         Current best combo: (0, 12) with val score 0.0012
# Trained and Tested combination 83 of 392: (0, 21), taking 0.01 seconds to get val score of 0.001
#         Current best combo: (0, 12) with val score 0.0012
# Trained and Tested combination 84 of 392: (0, 22), taking 0.02 seconds to get val score of 0.001
#         Current best combo: (0, 12) with val score 0.0012
# Trained and Tested combination 85 of 392: (0, 23), taking 0.02 seconds to get val score of 0.001
#         Current best combo: (0, 12) with val score 0.0012
# Trained and Tested combination 86 of 392: (0, 24), taking 0.02 seconds to get val score of 0.001
#         Current best combo: (0, 12) with val score 0.0012
# Trained and Tested combination 87 of 392: (0, 25), taking 0.02 seconds to get val score of 0.0011
#         Current best combo: (0, 12) with val score 0.0012
# Trained and Tested combination 88 of 392: (0, 26), taking 0.02 seconds to get val score of 0.0011
#         Current best combo: (0, 12) with val score 0.0012
# Trained and Tested combination 89 of 392: (0, 27), taking 0.02 seconds to get val score of 0.0011
#         Current best combo: (0, 12) with val score 0.0012
# Trained and Tested combination 90 of 392: (0, 28), taking 0.02 seconds to get val score of 0.0011
#         Current best combo: (0, 12) with val score 0.0012
# Trained and Tested combination 91 of 392: (0, 29), taking 0.02 seconds to get val score of 0.0014
#         Current best combo: (0, 29) with val score 0.0014
# Trained and Tested combination 92 of 392: (0, 30), taking 0.02 seconds to get val score of 0.0014
#         Current best combo: (0, 29) with val score 0.0014
# Trained and Tested combination 93 of 392: (0, 31), taking 0.01 seconds to get val score of 0.0014
#         Current best combo: (0, 29) with val score 0.0014
# Trained and Tested combination 94 of 392: (0, 32), taking 0.03 seconds to get val score of 0.0014
#         Current best combo: (0, 29) with val score 0.0014
# Trained and Tested combination 95 of 392: (0, 33), taking 0.03 seconds to get val score of 0.0014
#         Current best combo: (0, 29) with val score 0.0014
# Trained and Tested combination 96 of 392: (0, 34), taking 0.03 seconds to get val score of 0.0014
#         Current best combo: (0, 29) with val score 0.0014
# Trained and Tested combination 97 of 392: (0, 35), taking 0.03 seconds to get val score of 0.0014
#         Current best combo: (0, 29) with val score 0.0014
# Trained and Tested combination 98 of 392: (0, 36), taking 0.02 seconds to get val score of 0.0014
#         Current best combo: (0, 36) with val score 0.0014
# Trained and Tested combination 99 of 392: (0, 37), taking 0.02 seconds to get val score of 0.0016
#         Current best combo: (0, 37) with val score 0.0016
# Trained and Tested combination 100 of 392: (0, 38), taking 0.02 seconds to get val score of 0.0016
#         Current best combo: (0, 37) with val score 0.0016
# Trained and Tested combination 101 of 392: (0, 39), taking 0.02 seconds to get val score of 0.0016
#         Current best combo: (0, 37) with val score 0.0016
# Trained and Tested combination 102 of 392: (0, 40), taking 0.02 seconds to get val score of 0.0016
#         Current best combo: (0, 37) with val score 0.0016
# Trained and Tested combination 103 of 392: (0, 41), taking 0.07 seconds to get val score of 0.0024
#         Current best combo: (0, 41) with val score 0.0024
# Trained and Tested combination 104 of 392: (0, 42), taking 0.06 seconds to get val score of 0.0024
#         Current best combo: (0, 41) with val score 0.0024
# Trained and Tested combination 105 of 392: (0, 43), taking 0.06 seconds to get val score of 0.0024
#         Current best combo: (0, 41) with val score 0.0024
# Trained and Tested combination 106 of 392: (0, 44), taking 0.03 seconds to get val score of 0.0024
#         Current best combo: (0, 41) with val score 0.0024
# Trained and Tested combination 107 of 392: (0, 45), taking 0.08 seconds to get val score of 0.0024
#         Current best combo: (0, 41) with val score 0.0024
# Trained and Tested combination 108 of 392: (0, 46), taking 0.03 seconds to get val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026
# Trained and Tested combination 109 of 392: (0, 47), taking 0.02 seconds to get val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026
# Trained and Tested combination 110 of 392: (0, 48), taking 0.03 seconds to get val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026
# Trained and Tested combination 111 of 392: (0, 49), taking 0.03 seconds to get val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026
# Trained and Tested combination 112 of 392: (0, 50), taking 0.01 seconds to get val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026
# Trained and Tested combination 113 of 392: (0, 51), taking 0.03 seconds to get val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026
# Trained and Tested combination 114 of 392: (0, 52), taking 0.02 seconds to get val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026
# Trained and Tested combination 115 of 392: (0, 53), taking 0.02 seconds to get val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026
# Trained and Tested combination 116 of 392: (0, 54), taking 0.03 seconds to get val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026
# Trained and Tested combination 117 of 392: (0, 55), taking 0.02 seconds to get val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026
#
# Best combo after this hyperparameter: (0, 46) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: alpha (index: 0)
#
# Already Trained and Tested combination (0, 46), which had val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 117 of 392 combinations so far
# Trained and Tested combination 118 of 392: (1, 46), taking 0.02 seconds to get val score of 0.0017
#         Current best combo: (0, 46) with val score 0.0026
# Trained and Tested combination 119 of 392: (2, 46), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (0, 46) with val score 0.0026
# Trained and Tested combination 120 of 392: (3, 46), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (0, 46) with val score 0.0026
# Already Trained and Tested combination (4, 46), which had val score of -0.0
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 120 of 392 combinations so far
# Trained and Tested combination 121 of 392: (5, 46), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (0, 46) with val score 0.0026
# Trained and Tested combination 122 of 392: (6, 46), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (0, 46) with val score 0.0026
#
# Best combo after this hyperparameter: (0, 46) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 3
#
# Round 3
# Hyperparameter: features (index: 1)
#
# Already Trained and Tested combination (0, 0), which had val score of -0.0
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 1), which had val score of -0.0
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 2), which had val score of -0.0
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 3), which had val score of -0.0
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 4), which had val score of -0.0
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 5), which had val score of -0.0
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 6), which had val score of 0.0004
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 7), which had val score of 0.0004
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 8), which had val score of 0.0004
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 9), which had val score of 0.0004
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 10), which had val score of 0.0004
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 11), which had val score of 0.0004
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 12), which had val score of 0.0012
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 13), which had val score of 0.0012
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 14), which had val score of 0.0012
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 15), which had val score of 0.001
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 16), which had val score of 0.001
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 17), which had val score of 0.001
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 18), which had val score of 0.001
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 19), which had val score of 0.001
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 20), which had val score of 0.001
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 21), which had val score of 0.001
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 22), which had val score of 0.001
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 23), which had val score of 0.001
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 24), which had val score of 0.001
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 25), which had val score of 0.0011
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 26), which had val score of 0.0011
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 27), which had val score of 0.0011
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 28), which had val score of 0.0011
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 29), which had val score of 0.0014
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 30), which had val score of 0.0014
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 31), which had val score of 0.0014
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 32), which had val score of 0.0014
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 33), which had val score of 0.0014
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 34), which had val score of 0.0014
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 35), which had val score of 0.0014
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 36), which had val score of 0.0014
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 37), which had val score of 0.0016
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 38), which had val score of 0.0016
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 39), which had val score of 0.0016
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 40), which had val score of 0.0016
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 41), which had val score of 0.0024
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 42), which had val score of 0.0024
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 43), which had val score of 0.0024
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 44), which had val score of 0.0024
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 45), which had val score of 0.0024
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 46), which had val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 47), which had val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 48), which had val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 49), which had val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 50), which had val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 51), which had val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 52), which had val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 53), which had val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 54), which had val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (0, 55), which had val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
#
# Best combo after this hyperparameter: (0, 46) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: alpha (index: 0)
#
# Already Trained and Tested combination (0, 46), which had val score of 0.0026
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (1, 46), which had val score of 0.0017
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (2, 46), which had val score of -0.0
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (3, 46), which had val score of -0.0
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (4, 46), which had val score of -0.0
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (5, 46), which had val score of -0.0
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
# Already Trained and Tested combination (6, 46), which had val score of -0.0
#         Current best combo: (0, 46) with val score 0.0026.
#         Has trained 122 of 392 combinations so far
#
# Best combo after this hyperparameter: (0, 46) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.002614211101144903
# Max Test Score:
#  -0.000985
# Max Combo Index:
#  (0, 46) out of [7, 56] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'alpha': 0.0001, 'features': 46}
# Max Combo Features:
#  ('pos_closePrice_lag_1', 'mean_log_ret_lag_1', 'log_ret_normalised_by_day_lag_1', 'log_ret_lag_1', 'pos_log_ret_normalised_by_day_lag_1', 'pos_closePriceNorm_lag_1', 'closePriceNorm_lag_1', 'log_ret_normalised_by_day_lag_2', 'pos_log_ret_lag_1', 'log_ret_normalised_by_day_lag_3', 'log_ret_lag_3', 'log_ret_std_3', 'log_ret_slope_3', 'log_ret_lag_2', 'log_ret_normalised_by_day_diff_std_3', 'closePriceNorm_slope_3', 'closePrice_slope_3', 'log_ret_normalised_by_day_min_3', 'log_ret_normalised_by_day_std_3', 'closePrice_diff_std_3', 'closePriceNorm_std_3', 'log_ret_min_3', 'log_ret_diff_std_3', 'log_ret_max_3', 'log_ret_normalised_by_day_abs_diff_mean_3', 'log_ret_normalised_by_day_slope_3', 'closePriceNorm_lag_3', 'closePrice_std_3', 'log_ret_skew_3', 'mean_closePriceNorm_lag_1', 'log_ret_abs_diff_mean_3', 'log_ret_normalised_by_day_skew_3', 'closePriceNorm_lag_2', 'closePriceNorm_max_3', 'closePriceNorm_diff_std_3', 'closePrice_abs_diff_mean_3', 'mean_closePrice_lag_1', 'log_ret_normalised_by_day_max_3', 'closePriceNorm_abs_diff_mean_3', 'closePriceNorm_skew_3', 'log_ret_sum_3', 'closePriceNorm_min_3', 'log_ret_normalised_by_day_mean_3', 'log_ret_normalised_by_day_sum_3', 'closePrice_skew_3', 'log_ret_mean_3', 'closePriceNorm_sum_3')
# % Combos Checked: 122 out of 392 which is 31.122449000000003%
# Max Score:
#  0.002614211101144903
# Max Test Score:
#  -0.000985
# Max Combo Index:
#  (0, 46) out of [7, 56] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'alpha': 0.0001, 'features': 46}
# Max Combo Features:
#  ('pos_closePrice_lag_1', 'mean_log_ret_lag_1', 'log_ret_normalised_by_day_lag_1', 'log_ret_lag_1', 'pos_log_ret_normalised_by_day_lag_1', 'pos_closePriceNorm_lag_1', 'closePriceNorm_lag_1', 'log_ret_normalised_by_day_lag_2', 'pos_log_ret_lag_1', 'log_ret_normalised_by_day_lag_3', 'log_ret_lag_3', 'log_ret_std_3', 'log_ret_slope_3', 'log_ret_lag_2', 'log_ret_normalised_by_day_diff_std_3', 'closePriceNorm_slope_3', 'closePrice_slope_3', 'log_ret_normalised_by_day_min_3', 'log_ret_normalised_by_day_std_3', 'closePrice_diff_std_3', 'closePriceNorm_std_3', 'log_ret_min_3', 'log_ret_diff_std_3', 'log_ret_max_3', 'log_ret_normalised_by_day_abs_diff_mean_3', 'log_ret_normalised_by_day_slope_3', 'closePriceNorm_lag_3', 'closePrice_std_3', 'log_ret_skew_3', 'mean_closePriceNorm_lag_1', 'log_ret_abs_diff_mean_3', 'log_ret_normalised_by_day_skew_3', 'closePriceNorm_lag_2', 'closePriceNorm_max_3', 'closePriceNorm_diff_std_3', 'closePrice_abs_diff_mean_3', 'mean_closePrice_lag_1', 'log_ret_normalised_by_day_max_3', 'closePriceNorm_abs_diff_mean_3', 'closePriceNorm_skew_3', 'log_ret_sum_3', 'closePriceNorm_min_3', 'log_ret_normalised_by_day_mean_3', 'log_ret_normalised_by_day_sum_3', 'closePrice_skew_3', 'log_ret_mean_3', 'closePriceNorm_sum_3')
# % Combos Checked: 122 out of 392 which is 31.122449000000003%
#
#
#
# Max Lag: 5
# JiaoCheng Initialised
# JiaoCheng Initialised
# Successfully read in model <class 'sklearn.linear_model._coordinate_descent.Lasso'>, which is a Regression model
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# Successfully recorded hyperparameter choices
# Successfully recorded non_tuneable_hyperparameter choices
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# Successfully set tuning output address
# Successfully set best model output address
#
# Default combo: [4, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 1)
#
# Trained and Tested combination 1 of 700: (4, 0), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 2 of 700: (4, 1), taking 0.0 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 3 of 700: (4, 2), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 4 of 700: (4, 3), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 5 of 700: (4, 4), taking 0.0 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 6 of 700: (4, 5), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 7 of 700: (4, 6), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 8 of 700: (4, 7), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 9 of 700: (4, 8), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 10 of 700: (4, 9), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 11 of 700: (4, 10), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 12 of 700: (4, 11), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 13 of 700: (4, 12), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 14 of 700: (4, 13), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 15 of 700: (4, 14), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 16 of 700: (4, 15), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 17 of 700: (4, 16), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 18 of 700: (4, 17), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 19 of 700: (4, 18), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 20 of 700: (4, 19), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 21 of 700: (4, 20), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 22 of 700: (4, 21), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 23 of 700: (4, 22), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 24 of 700: (4, 23), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 25 of 700: (4, 24), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 26 of 700: (4, 25), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 27 of 700: (4, 26), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 28 of 700: (4, 27), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 29 of 700: (4, 28), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 30 of 700: (4, 29), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 31 of 700: (4, 30), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 32 of 700: (4, 31), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 33 of 700: (4, 32), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 34 of 700: (4, 33), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 35 of 700: (4, 34), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 36 of 700: (4, 35), taking 0.03 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 37 of 700: (4, 36), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 38 of 700: (4, 37), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 39 of 700: (4, 38), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 40 of 700: (4, 39), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 41 of 700: (4, 40), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 42 of 700: (4, 41), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 43 of 700: (4, 42), taking 0.03 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 44 of 700: (4, 43), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 45 of 700: (4, 44), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 46 of 700: (4, 45), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 47 of 700: (4, 46), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 48 of 700: (4, 47), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 49 of 700: (4, 48), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 50 of 700: (4, 49), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 51 of 700: (4, 50), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 52 of 700: (4, 51), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 53 of 700: (4, 52), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 54 of 700: (4, 53), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 55 of 700: (4, 54), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 56 of 700: (4, 55), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 57 of 700: (4, 56), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 58 of 700: (4, 57), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 59 of 700: (4, 58), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 60 of 700: (4, 59), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 61 of 700: (4, 60), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 62 of 700: (4, 61), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 63 of 700: (4, 62), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 64 of 700: (4, 63), taking 0.01 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 65 of 700: (4, 64), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 66 of 700: (4, 65), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 67 of 700: (4, 66), taking 0.03 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 68 of 700: (4, 67), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 69 of 700: (4, 68), taking 0.03 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 70 of 700: (4, 69), taking 0.03 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 71 of 700: (4, 70), taking 0.03 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 72 of 700: (4, 71), taking 0.03 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 73 of 700: (4, 72), taking 0.03 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 74 of 700: (4, 73), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 75 of 700: (4, 74), taking 0.03 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 76 of 700: (4, 75), taking 0.02 seconds to get val score of -0.0
#         Current best combo: (4, 0) with val score -0.0
# Trained and Tested combination 77 of 700: (4, 76), taking 0.03 seconds to get val score of -0.0
# ...
# Already Trained and Tested combination (4, 120), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 121), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 122), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 123), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 124), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 125), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 126), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 127), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 128), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 129), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 130), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 131), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 132), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 133), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 134), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 135), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 136), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 137), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 138), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 139), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 140), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 141), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 142), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 143), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 144), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 145), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 146), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 147), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 148), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 149), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 150), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 151), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 152), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 153), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 154), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 155), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 156), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 157), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 158), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 159), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 160), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 161), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 162), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 163), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 164), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 165), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 166), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 167), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 168), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 169), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 170), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 171), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 172), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 173), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 174), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 175), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 176), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 177), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 178), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 179), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 180), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 181), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 182), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 183), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 184), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 185), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 186), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 187), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 188), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 189), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 190), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 191), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
#
# Best combo after this hyperparameter: (4, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: alpha (index: 0)
#
# Already Trained and Tested combination (0, 0), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (1, 0), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (2, 0), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (3, 0), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (4, 0), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (5, 0), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
# Already Trained and Tested combination (6, 0), which had val score of -0.0003
#         Current best combo: (4, 0) with val score -0.0003.
#         Has trained 198 of 1344 combinations so far
#
# Best combo after this hyperparameter: (4, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  -0.00030837907082092997
# Max Test Score:
#  -0.000276
# Max Combo Index:
#  (4, 0) out of [7, 192] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'alpha': 1, 'features': 0}
# Max Combo Features:
#  ('pos_closePrice_lag_1',)
# % Combos Checked: 198 out of 1344 which is 14.732143%
# Max Score:
#  -0.00030837907082092997
# Max Test Score:
#  -0.000276
# Max Combo Index:
#  (4, 0) out of [7, 192] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'alpha': 1, 'features': 0}
# Max Combo Features:
#  ('pos_closePrice_lag_1',)
# % Combos Checked: 198 out of 1344 which is 14.732143%
