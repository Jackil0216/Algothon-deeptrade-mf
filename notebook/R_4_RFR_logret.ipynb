# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os
import pickle
import pandas as pd
import json
import datetime
import time
import copy

py_file_location = './drive/My Drive/PrivatePackages'
sys.path.append(os.path.abspath(py_file_location))
from sklearn.model_selection import train_test_split

import JiaoCheng
import NingXiang

# %%
LABEL = 'logret'
MODEL = 'rfr'

# %%
curated_data = pd.read_csv('./drive/My Drive/LAB/Hackathon/data/curated_data.csv')
curated_data = curated_data.drop(columns=['closePrice', 'closePriceNorm', 'log_ret_normalised_by_day', 'trend', 'stock'])
curated_data['date'] = pd.to_datetime(curated_data['date'])

# %%
curated_data
# Out:
#             date   log_ret  closePrice_min_3  closePrice_max_3  \
# 0     2022-12-31       NaN               NaN               NaN
# 1     2023-01-01 -0.002996               NaN               NaN
# 2     2023-01-02 -0.005516               NaN               NaN
# 3     2023-01-03 -0.004704               NaN               NaN
# 4     2023-01-04 -0.002867               NaN               NaN
# ...          ...       ...               ...               ...
# 12495 2023-09-02 -0.005332             43.11             43.66
# 12496 2023-09-03  0.000232             43.25             43.66
# 12497 2023-09-04  0.012471             43.02             43.61
# 12498 2023-09-05 -0.010150             43.02             43.25
# 12499 2023-09-06  0.004626             43.02             43.57
#
#        closePrice_std_3  closePrice_mean_3  closePrice_slope_3  \
# 0                   NaN                NaN                 NaN
# 1                   NaN                NaN                 NaN
# 2                   NaN                NaN                 NaN
# 3                   NaN                NaN                 NaN
# 4                   NaN                NaN                 NaN
# ...                 ...                ...                 ...
# 12495          0.248328          43.460000            0.011598
# 12496          0.182635          43.506667           -0.009391
# 12497          0.242808          43.293333           -0.013529
# 12498          0.106145          43.100000           -0.005087
# 12499          0.256948          43.206667            0.012785
#
#        closePrice_skew_3  closePrice_abs_diff_mean_3  closePrice_diff_std_3  \
# 0                    NaN                         NaN                    NaN
# 1                    NaN                         NaN                    NaN
# 2                    NaN                         NaN                    NaN
# 3                    NaN                         NaN                    NaN
# 4                    NaN                         NaN                    NaN
# ...                  ...                         ...                    ...
# 12495          -0.685668                       0.300                  0.300
# 12496          -0.667566                       0.205                  0.155
# 12497           0.262017                       0.295                  0.065
# 12498           0.702403                       0.120                  0.120
# 12499           0.706304                       0.275                  0.265
#
#        ...  closePriceNorm_lag_10  log_ret_normalised_by_day_lag_10  \
# 0      ...                    NaN                               NaN
# 1      ...                    NaN                               NaN
# 2      ...                    NaN                               NaN
# 3      ...                    NaN                               NaN
# 4      ...                    NaN                               NaN
# ...    ...                    ...                               ...
# 12495  ...              -0.136102                         -2.032099
# 12496  ...              -0.539073                         -1.515743
# 12497  ...              -0.377885                          0.765811
# 12498  ...              -0.363231                          0.030813
# 12499  ...              -0.326598                          0.102353
#
#        mean_log_ret_lag_1  mean_closePrice_lag_1  mean_closePriceNorm_lag_1  \
# 0                     NaN                    NaN                        NaN
# 1                     NaN                40.6170                   0.241356
# 2                0.000525                40.6472                   0.247020
# 3               -0.000065                40.6172                   0.231342
# 4               -0.000623                40.5886                   0.211599
# ...                   ...                    ...                        ...
# 12495           -0.002123                39.4416                  -0.655234
# 12496           -0.001491                39.3646                  -0.690649
# 12497           -0.001420                39.3096                  -0.716371
# 12498           -0.000048                39.2904                  -0.714126
# 12499           -0.000252                39.2810                  -0.713713
#
#        mean_log_ret_normalised_by_day_lag_1  pos_log_ret_lag_1  \
# 0                                       NaN                NaN
# 1                                       NaN                NaN
# 2                             -4.440892e-18           0.000569
# 3                             -8.881784e-18          -0.001615
# 4                              1.776357e-17          -0.000616
# ...                                     ...                ...
# 12495                          5.773160e-17          -0.003932
# 12496                          4.662937e-17          -0.001368
# 12497                          8.770762e-17          -0.004381
# 12498                         -1.776357e-17          -0.001478
# 12499                          3.552714e-17          -0.002505
#
#        pos_closePrice_lag_1  pos_closePriceNorm_lag_1  \
# 0                       NaN                       NaN
# 1                 33.787500                  0.529432
# 2                 33.838750                  0.535137
# 3                 33.735000                  0.482227
# 4                 33.710000                  0.455742
# ...                     ...                       ...
# 12495             35.979231                 -0.815362
# 12496             35.899231                 -0.860295
# 12497             35.692308                 -0.931225
# 12498             35.616923                 -0.974622
# 12499             35.506154                 -1.026466
#
#        pos_log_ret_normalised_by_day_lag_1
# 0                                      NaN
# 1                                      NaN
# 2                                 0.007178
# 3                                -0.229975
# 4                                 0.001161
# ...                                    ...
# 12495                            -0.320944
# 12496                             0.019382
# 12497                            -0.493615
# 12498                            -0.267420
# 12499                            -0.344069
#
# [12500 rows x 194 columns]

# %%
date = [datetime.datetime(year=2023, month=1, day = 1) + datetime.timedelta(days=i) for i in range(250)]
val_date_start = date[175]
test_date_start = date[175+38]

# %%
function_map = ['min', 'max', 'std', 'mean', 'slope', 'skew', 'abs_diff_mean', 'diff_std', 'sum']

for i in [3, 5, 10, 20]:
    print('Max Lag:', i)

    tmp_curated_data = copy.deepcopy(curated_data)

    for j in range(i+1, 11):
        tmp_curated_data = tmp_curated_data.drop(columns=[f'log_ret_lag_{j}', f'log_ret_normalised_by_day_lag_{j}', f'closePriceNorm_lag_{j}', f'closePrice_lag_{j}'], axis = 1)

    for j in [3, 5, 10, 20]:
        if j > i:

            columns = []
            for col in ['log_ret', 'closePrice', 'closePriceNorm', 'log_ret_normalised_by_day']:
                for func in function_map:
                    columns.append(f'{col}_{func}_{j}')
            tmp_curated_data = tmp_curated_data.drop(columns=columns, axis = 1)

    tmp_curated_data = tmp_curated_data.dropna()

    train = tmp_curated_data[(tmp_curated_data['date'] < val_date_start)]
    val = tmp_curated_data[(tmp_curated_data['date'] < test_date_start) & (tmp_curated_data['date'] >= val_date_start)]
    test = tmp_curated_data[(tmp_curated_data['date'] >= test_date_start)]

    jiaocheng = JiaoCheng.JiaoCheng()

    train_x = train.drop(columns=['date', 'log_ret'], axis = 1)
    train_y = train['log_ret']

    val_x = val.drop(columns=['date', 'log_ret'], axis = 1)
    val_y = val['log_ret']

    test_x = test.drop(columns=['date', 'log_ret'], axis = 1)
    test_y = test['log_ret']

    with open(f'./drive/My Drive/LAB/Hackathon/models/NingXiang_output_{LABEL}_lag_{i}.pickle', 'rb') as f:
        ningxiang_output = pickle.load(f)

    ningxiang_output = list(ningxiang_output.items())
    ningxiang_output = dict(ningxiang_output)

    jiaocheng = JiaoCheng.JiaoCheng()

    from sklearn.ensemble import RandomForestRegressor as RFR

    jiaocheng.read_in_model(RFR, 'Regression')

    jiaocheng.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

    del train_x
    del train_y
    del val_x
    del val_y

    parameter_choices = {
        'n_estimators': (25, 50, 100, 200, 400),
        'criterion': ('absolute_error', 'squared_error'),
        'max_features': (0.4, 0.55, 0.7, 0.85),
        'max_samples': (0.4, 0.55, 0.7, 0.85),
        'ccp_alpha': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100)

    }

    jiaocheng.set_hyperparameters(parameter_choices)

    jiaocheng.set_non_tuneable_hyperparameters({'n_jobs': -1, 'random_state': 19260817})

    jiaocheng.set_features(ningxiang_output)

    jiaocheng.set_tuning_order(['features', 'criterion', 'max_features', 'max_samples', 'n_estimators', 'ccp_alpha'])

    jiaocheng.set_hyperparameter_default_values({
        'features': 0,
        'criterion': 'squared_error',
        'max_features': 0.7,
        'max_samples': 0.7,
        'n_estimators': 50,
        'ccp_alpha': 0.01}
    )

    try:
        jiaocheng.read_in_tuning_result_df(f'./drive/My Drive/LAB/Hackathon/models/tuning/jiaocheng_{MODEL}_{LABEL}_lag_{i}.csv')
    except:
        pass

    jiaocheng.set_tuning_result_saving_address(f'./drive/My Drive/LAB/Hackathon/models/tuning/jiaocheng_{MODEL}_{LABEL}_lag_{i}.csv')
    jiaocheng.set_best_model_saving_address(f'./drive/My Drive/LAB/Hackathon/models/tmp_models/jiaocheng_{MODEL}_{LABEL}_lag_{i}.pickle')

    jiaocheng.tune()

    jiaocheng.view_best_combo_and_score()

    print('\n\n')
# Out:
# Max Lag: 3
# JiaoCheng Initialised
# JiaoCheng Initialised
# Successfully read in model <class 'sklearn.ensemble._forest.RandomForestRegressor'>, which is a Regression model
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# Successfully recorded hyperparameter choices
# Successfully recorded non_tuneable_hyperparameter choices
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# Successfully read in tuning result of 203 rows
# Successfully set tuning output address
# Successfully set best model output address
#
# Default combo: [1, 1, 2, 2, 2, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 5)
#
# As new Best Combo (1, 1, 2, 2, 2, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 2, 0), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 1), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 2), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 3), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 4), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 5), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 6), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 7), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 8), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 9), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 10), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 11), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 12), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 13), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 14), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 15), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 16), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 17), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 18), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 19), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 20), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 21), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 22), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 23), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 24), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 25), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 26), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 27), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 28), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 29), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 30), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 31), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 32), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 33), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 34), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 35), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 36), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 37), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 38), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 39), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 40), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 41), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 42), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 43), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 44), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 45), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 46), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 47), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 48), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 49), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 50), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 51), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 52), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 53), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 54), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 55), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 2, 0) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: criterion (index: 1)
#
# Already Trained and Tested combination (1, 0, 2, 2, 2, 0), which had val score of -0.0001
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 0), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_features (index: 2)
#
# Already Trained and Tested combination (1, 1, 0, 2, 2, 0), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 1, 2, 2, 0), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 0), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 3, 2, 2, 0), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 2, 2, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: max_samples (index: 3)
#
# As new Best Combo (1, 1, 2, 0, 2, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 0, 2, 0), which had val score of -0.0
#         Current best combo: (1, 1, 2, 0, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# As new Best Combo (1, 1, 2, 1, 2, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 1, 2, 0), which had val score of -0.0
#         Current best combo: (1, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 0), which had val score of -0.0
#         Current best combo: (1, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 3, 2, 0), which had val score of -0.0
#         Current best combo: (1, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
#
# Best combo after this hyperparameter: (1, 1, 2, 1, 2, 0) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 1, 2, 1, 2, 0), which had val score of -0.0
#         Current best combo: (1, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 1, 2, 0), which had val score of -0.0
#         Current best combo: (1, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# As new Best Combo (2, 1, 2, 1, 2, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (2, 1, 2, 1, 2, 0), which had val score of -0.0
#         Current best combo: (2, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# As new Best Combo (3, 1, 2, 1, 2, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (3, 1, 2, 1, 2, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (4, 1, 2, 1, 2, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 1, 2, 0) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: ccp_alpha (index: 4)
#
# Already Trained and Tested combination (3, 1, 2, 1, 0, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 1, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 3, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 4, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 5, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 6, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 1, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 2
# Hyperparameter: features (index: 5)
#
# Already Trained and Tested combination (3, 1, 2, 1, 2, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 1), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 2), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 3), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 4), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 5), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 6), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 7), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 8), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 9), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 10), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 11), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 12), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 13), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 14), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 15), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 16), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 17), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 18), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 19), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 20), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 21), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 22), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 23), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 24), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 25), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 26), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 27), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 28), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 29), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 30), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 31), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 32), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 33), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 34), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 35), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 36), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 37), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 38), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 39), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 40), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 41), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 42), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 43), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 44), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 45), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 46), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 47), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 48), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 49), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 50), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 51), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 52), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 53), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 54), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 55), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 1, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: criterion (index: 1)
#
# Already Trained and Tested combination (3, 0, 2, 1, 2, 0), which had val score of -0.0001
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 1, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_features (index: 2)
#
# Already Trained and Tested combination (3, 1, 0, 1, 2, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 1, 1, 2, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 3, 1, 2, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 1, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: max_samples (index: 3)
#
# Already Trained and Tested combination (3, 1, 2, 0, 2, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 2, 2, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 3, 2, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 1, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: n_estimators (index: 0)
#
# Already Trained and Tested combination (0, 1, 2, 1, 2, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (1, 1, 2, 1, 2, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (2, 1, 2, 1, 2, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (4, 1, 2, 1, 2, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 1, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: ccp_alpha (index: 4)
#
# Already Trained and Tested combination (3, 1, 2, 1, 0, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 1, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 2, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 3, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 4, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 5, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
# Already Trained and Tested combination (3, 1, 2, 1, 6, 0), which had val score of -0.0
#         Current best combo: (3, 1, 2, 1, 2, 0) with val score -0.0.
#         Has trained 203 of 62720 combinations so far
#
# Best combo after this hyperparameter: (3, 1, 2, 1, 2, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  -5e-06
# Max Test Score:
#  -0.001012
# Max Combo Index:
#  (3, 1, 2, 1, 2, 0) out of [5, 2, 4, 4, 7, 56] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 200, 'criterion': 'squared_error', 'max_features': 0.7, 'max_samples': 0.55, 'ccp_alpha': 0.01, 'features': 0}
# Max Combo Features:
#  ('pos_closePrice_lag_1',)
# % Combos Checked: 203 out of 62720 which is 0.323661%
# Max Score:
#  -5e-06
# Max Test Score:
#  -0.001012
# Max Combo Index:
#  (3, 1, 2, 1, 2, 0) out of [5, 2, 4, 4, 7, 56] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'n_estimators': 200, 'criterion': 'squared_error', 'max_features': 0.7, 'max_samples': 0.55, 'ccp_alpha': 0.01, 'features': 0}
# Max Combo Features:
#  ('pos_closePrice_lag_1',)
# % Combos Checked: 203 out of 62720 which is 0.323661%
#
#
#
# Max Lag: 5
# JiaoCheng Initialised
# JiaoCheng Initialised
# Successfully read in model <class 'sklearn.ensemble._forest.RandomForestRegressor'>, which is a Regression model
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# Successfully recorded hyperparameter choices
# Successfully recorded non_tuneable_hyperparameter choices
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# Successfully read in tuning result of 337 rows
# Successfully set tuning output address
# Successfully set best model output address
#
# Default combo: [1, 1, 2, 2, 2, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 5)
#
# As new Best Combo (1, 1, 2, 2, 2, 0) was read in, best_clf is set to None
# Already Trained and Tested combination (1, 1, 2, 2, 2, 0), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 1), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 2), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 3), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 4), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 5), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 6), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 7), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 8), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 9), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 10), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 11), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 12), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 13), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 14), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 15), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 16), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 17), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 18), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 19), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 20), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 21), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 22), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 23), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 24), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 25), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 26), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 27), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 28), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 29), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 30), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 31), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 32), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 33), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 34), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 35), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 36), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 37), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 38), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 39), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 40), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 41), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 42), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 43), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 44), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 45), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 46), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 47), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 48), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 49), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 50), which had val score of -0.0
#         Current best combo: (1, 1, 2, 2, 2, 0) with val score -0.0.
#         Has trained 337 of 112000 combinations so far
# Already Trained and Tested combination (1, 1, 2, 2, 2, 51), which had val score of -0.0
# ...
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 24), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 25), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 26), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 27), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 28), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 29), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 30), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 31), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 32), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 33), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 34), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 35), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 36), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 37), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 38), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 39), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 40), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 41), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 42), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 43), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 44), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 45), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 46), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 47), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 48), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 49), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 50), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 51), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 52), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 53), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 54), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 55), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 56), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 57), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 58), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 59), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 60), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 61), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 62), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 63), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 64), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 65), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 66), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 67), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Already Trained and Tested combination (1, 0, 2, 1, 2, 68), which had val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0.
#         Has trained 241 of 174720 combinations so far
# Trained and Tested combination 242 of 174720: (1, 0, 2, 1, 2, 69), taking 413.74 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 243 of 174720: (1, 0, 2, 1, 2, 70), taking 412.15 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 244 of 174720: (1, 0, 2, 1, 2, 71), taking 425.75 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 245 of 174720: (1, 0, 2, 1, 2, 72), taking 431.31 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 246 of 174720: (1, 0, 2, 1, 2, 73), taking 425.58 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 247 of 174720: (1, 0, 2, 1, 2, 74), taking 454.24 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 248 of 174720: (1, 0, 2, 1, 2, 75), taking 457.12 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 249 of 174720: (1, 0, 2, 1, 2, 76), taking 445.31 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 250 of 174720: (1, 0, 2, 1, 2, 77), taking 449.65 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 251 of 174720: (1, 0, 2, 1, 2, 78), taking 473.58 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 252 of 174720: (1, 0, 2, 1, 2, 79), taking 469.45 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 253 of 174720: (1, 0, 2, 1, 2, 80), taking 455.95 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 254 of 174720: (1, 0, 2, 1, 2, 81), taking 470.42 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 255 of 174720: (1, 0, 2, 1, 2, 82), taking 490.37 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 256 of 174720: (1, 0, 2, 1, 2, 83), taking 484.96 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 257 of 174720: (1, 0, 2, 1, 2, 84), taking 485.41 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 258 of 174720: (1, 0, 2, 1, 2, 85), taking 509.99 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 259 of 174720: (1, 0, 2, 1, 2, 86), taking 505.76 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 260 of 174720: (1, 0, 2, 1, 2, 87), taking 509.92 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 261 of 174720: (1, 0, 2, 1, 2, 88), taking 533.74 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 262 of 174720: (1, 0, 2, 1, 2, 89), taking 502.24 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 263 of 174720: (1, 0, 2, 1, 2, 90), taking 528.73 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 264 of 174720: (1, 0, 2, 1, 2, 91), taking 571.61 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 265 of 174720: (1, 0, 2, 1, 2, 92), taking 562.67 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 266 of 174720: (1, 0, 2, 1, 2, 93), taking 559.41 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 267 of 174720: (1, 0, 2, 1, 2, 94), taking 598.42 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 268 of 174720: (1, 0, 2, 1, 2, 95), taking 551.12 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 269 of 174720: (1, 0, 2, 1, 2, 96), taking 551.61 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 270 of 174720: (1, 0, 2, 1, 2, 97), taking 553.7 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 271 of 174720: (1, 0, 2, 1, 2, 98), taking 581.96 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 272 of 174720: (1, 0, 2, 1, 2, 99), taking 576.11 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 273 of 174720: (1, 0, 2, 1, 2, 100), taking 593.1 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 274 of 174720: (1, 0, 2, 1, 2, 101), taking 564.78 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 275 of 174720: (1, 0, 2, 1, 2, 102), taking 595.55 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
# Trained and Tested combination 276 of 174720: (1, 0, 2, 1, 2, 103), taking 599.08 seconds to get val score of -0.0
#         Current best combo: (1, 0, 2, 1, 2, 0) with val score -0.0
