# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os
import pickle
import pandas as pd
import json
import datetime
import time
import copy

py_file_location = './drive/My Drive/PrivatePackages'
sys.path.append(os.path.abspath(py_file_location))
from sklearn.model_selection import train_test_split

import JiaoCheng
import NingXiang

# %%
LABEL = 'trend'
MODEL = 'svc'

# %%
curated_data = pd.read_csv('./drive/My Drive/LAB/Hackathon/data/curated_data.csv')
curated_data = curated_data.drop(columns=['closePrice', 'closePriceNorm', 'ret', 'log_ret', 'stock'])
curated_data['date'] = pd.to_datetime(curated_data['date'])

# %%
curated_data
# Out:
#             date  trend  ret_lag_1  log_ret_lag_1  closePrice_lag_1  \
# 0     2023-01-01    NaN        NaN            NaN               NaN
# 1     2023-01-02   -1.0        NaN            NaN             60.17
# 2     2023-01-03   -1.0   0.997008      -0.002996             59.99
# 3     2023-01-04   -1.0   0.994499      -0.005516             59.66
# 4     2023-01-05   -1.0   0.995307      -0.004704             59.38
# ...          ...    ...        ...            ...               ...
# 12495 2023-09-03   -1.0   0.991745      -0.008289             43.25
# 12496 2023-09-04    1.0   0.994682      -0.005332             43.02
# 12497 2023-09-05    1.0   1.000232       0.000232             43.03
# 12498 2023-09-06   -1.0   1.012549       0.012471             43.57
# 12499 2023-09-07    1.0   0.989901      -0.010150             43.13
#
#        closePriceNorm_lag_1  ret_lag_2  log_ret_lag_2  closePrice_lag_2  \
# 0                       NaN        NaN            NaN               NaN
# 1                 -0.982328        NaN            NaN               NaN
# 2                 -1.094387        NaN            NaN             60.17
# 3                 -1.299827   0.997008      -0.002996             59.99
# 4                 -1.474140   0.994499      -0.005516             59.66
# ...                     ...        ...            ...               ...
# 12495              0.244890   0.998855      -0.001146             43.61
# 12496              0.076374   0.991745      -0.008289             43.25
# 12497              0.083701   0.994682      -0.005332             43.02
# 12498              0.479346   1.000232       0.000232             43.03
# 12499              0.156968   1.012549       0.012471             43.57
#
#        closePriceNorm_lag_2  ...  closePrice_lag_8  closePriceNorm_lag_8  \
# 0                       NaN  ...               NaN                   NaN
# 1                       NaN  ...               NaN                   NaN
# 2                 -0.982328  ...               NaN                   NaN
# 3                 -1.094387  ...               NaN                   NaN
# 4                 -1.299827  ...               NaN                   NaN
# ...                     ...  ...               ...                   ...
# 12495              0.508653  ...             42.40             -0.377885
# 12496              0.244890  ...             42.42             -0.363231
# 12497              0.076374  ...             42.47             -0.326598
# 12498              0.083701  ...             42.52             -0.289964
# 12499              0.479346  ...             43.11              0.142315
#
#        ret_lag_9  log_ret_lag_9  closePrice_lag_9  closePriceNorm_lag_9  \
# 0            NaN            NaN               NaN                   NaN
# 1            NaN            NaN               NaN                   NaN
# 2            NaN            NaN               NaN                   NaN
# 3            NaN            NaN               NaN                   NaN
# 4            NaN            NaN               NaN                   NaN
# ...          ...            ...               ...                   ...
# 12495   0.987128      -0.012955             42.18             -0.539073
# 12496   1.005216       0.005202             42.40             -0.377885
# 12497   1.000472       0.000472             42.42             -0.363231
# 12498   1.001179       0.001178             42.47             -0.326598
# 12499   1.001177       0.001177             42.52             -0.289964
#
#        ret_lag_10  log_ret_lag_10  closePrice_lag_10  closePriceNorm_lag_10
# 0             NaN             NaN                NaN                    NaN
# 1             NaN             NaN                NaN                    NaN
# 2             NaN             NaN                NaN                    NaN
# 3             NaN             NaN                NaN                    NaN
# 4             NaN             NaN                NaN                    NaN
# ...           ...             ...                ...                    ...
# 12495    0.987748       -0.012327              42.73              -0.136102
# 12496    0.987128       -0.012955              42.18              -0.539073
# 12497    1.005216        0.005202              42.40              -0.377885
# 12498    1.000472        0.000472              42.42              -0.363231
# 12499    1.001179        0.001178              42.47              -0.326598
#
# [12500 rows x 42 columns]

# %%
date = [datetime.datetime(year=2023, month=1, day = 1) + datetime.timedelta(days=i) for i in range(250)]
val_date_start = date[175]
test_date_start = date[175+38]

# %%
for i in range(1, 11):
    print('Max Lag:', i)

    tmp_curated_data = copy.deepcopy(curated_data)

    for j in range(i+1, 11):
        tmp_curated_data = tmp_curated_data.drop(columns=[f'log_ret_lag_{j}', f'ret_lag_{j}'], axis = 1)

    tmp_curated_data = tmp_curated_data.dropna()

    train = tmp_curated_data[(tmp_curated_data['date'] < val_date_start)]
    val = tmp_curated_data[(tmp_curated_data['date'] < test_date_start) & (tmp_curated_data['date'] >= val_date_start)]
    test = tmp_curated_data[(tmp_curated_data['date'] >= test_date_start)]

    jiaocheng = JiaoCheng.JiaoCheng()

    train_x = train.drop(columns=['date', 'trend'], axis = 1)
    train_y = train['trend']

    val_x = val.drop(columns=['date', 'trend'], axis = 1)
    val_y = val['trend']

    test_x = test.drop(columns=['date', 'trend'], axis = 1)
    test_y = test['trend']

    with open(f'./drive/My Drive/LAB/Hackathon/models/NingXiang_output_{LABEL}_lag_{i}.pickle', 'rb') as f:
        ningxiang_output = pickle.load(f)

    ningxiang_output = list(ningxiang_output.items())
    ningxiang_output = dict(ningxiang_output)

    jiaocheng = JiaoCheng.JiaoCheng()

    from sklearn.svm import SVC

    jiaocheng.read_in_model(SVC, 'Classification')

    jiaocheng.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)

    del train_x
    del train_y
    del val_x
    del val_y

    parameter_choices = {
        'C': (0.0001, 0.001, 0.01, 0.1, 1, 10, 100),
        'kernel': ('poly', 'rbf'),
        'degree': (1, 2, 3)


    }

    jiaocheng.set_hyperparameters(parameter_choices)

    jiaocheng.set_non_tuneable_hyperparameters({'max_iter': -1})

    jiaocheng.set_features(ningxiang_output)

    jiaocheng.set_tuning_order(['features', 'kernel', 'degree', 'C'])

    jiaocheng.set_hyperparameter_default_values({
        'features': 0,
        'C': 1,
        'degree': 1,
        'kernel': 'poly'}
    )

    try:
        jiaocheng.read_in_tuning_result_df(f'./drive/My Drive/LAB/Hackathon/models/tuning/jiaocheng_{MODEL}_{LABEL}_lag_{i}.csv')
    except:
        pass

    jiaocheng.set_tuning_result_saving_address(f'./drive/My Drive/LAB/Hackathon/models/tuning/jiaocheng_{MODEL}_{LABEL}_lag_{i}.csv')
    jiaocheng.set_best_model_saving_address(f'./drive/My Drive/LAB/Hackathon/models/tmp_models/jiaocheng_{MODEL}_{LABEL}_lag_{i}.pickle')

    jiaocheng.tune()

    jiaocheng.view_best_combo_and_score()

    print('\n\n')
# Out:
# Max Lag: 1
# JiaoCheng Initialised
# JiaoCheng Initialised
# Successfully read in model <class 'sklearn.svm._classes.SVC'>, which is a Classification model
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# Successfully recorded hyperparameter choices
# Successfully recorded non_tuneable_hyperparameter choices
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# Successfully set tuning output address
# Successfully set best model output address
#
# Default combo: [4, 0, 0, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 3)
#
# Trained and Tested combination 1 of 924: (4, 0, 0, 0), taking 4.48 seconds to get val score of 0.5126
#         Current best combo: (4, 0, 0, 0) with val score 0.5126
# Trained and Tested combination 2 of 924: (4, 0, 0, 1), taking 1.79 seconds to get val score of 0.5284
#         Current best combo: (4, 0, 0, 1) with val score 0.5284
# Trained and Tested combination 3 of 924: (4, 0, 0, 2), taking 1.57 seconds to get val score of 0.53
#         Current best combo: (4, 0, 0, 2) with val score 0.53
# Trained and Tested combination 4 of 924: (4, 0, 0, 3), taking 1.86 seconds to get val score of 0.5295
#         Current best combo: (4, 0, 0, 2) with val score 0.53
# Trained and Tested combination 5 of 924: (4, 0, 0, 4), taking 1.61 seconds to get val score of 0.5316
#         Current best combo: (4, 0, 0, 4) with val score 0.5316
# Trained and Tested combination 6 of 924: (4, 0, 0, 5), taking 1.63 seconds to get val score of 0.5326
#         Current best combo: (4, 0, 0, 5) with val score 0.5326
# Trained and Tested combination 7 of 924: (4, 0, 0, 6), taking 1.89 seconds to get val score of 0.5321
#         Current best combo: (4, 0, 0, 5) with val score 0.5326
# Trained and Tested combination 8 of 924: (4, 0, 0, 7), taking 1.74 seconds to get val score of 0.53
#         Current best combo: (4, 0, 0, 5) with val score 0.5326
# Trained and Tested combination 9 of 924: (4, 0, 0, 8), taking 1.8 seconds to get val score of 0.5316
#         Current best combo: (4, 0, 0, 5) with val score 0.5326
# Trained and Tested combination 10 of 924: (4, 0, 0, 9), taking 1.82 seconds to get val score of 0.5326
#         Current best combo: (4, 0, 0, 5) with val score 0.5326
# Trained and Tested combination 11 of 924: (4, 0, 0, 10), taking 2.57 seconds to get val score of 0.5326
#         Current best combo: (4, 0, 0, 5) with val score 0.5326
# Trained and Tested combination 12 of 924: (4, 0, 0, 11), taking 1.94 seconds to get val score of 0.5326
#         Current best combo: (4, 0, 0, 5) with val score 0.5326
# Trained and Tested combination 13 of 924: (4, 0, 0, 12), taking 1.86 seconds to get val score of 0.5184
#         Current best combo: (4, 0, 0, 5) with val score 0.5326
# Trained and Tested combination 14 of 924: (4, 0, 0, 13), taking 1.86 seconds to get val score of 0.5153
#         Current best combo: (4, 0, 0, 5) with val score 0.5326
# Trained and Tested combination 15 of 924: (4, 0, 0, 14), taking 1.89 seconds to get val score of 0.5132
#         Current best combo: (4, 0, 0, 5) with val score 0.5326
# Trained and Tested combination 16 of 924: (4, 0, 0, 15), taking 1.81 seconds to get val score of 0.5163
#         Current best combo: (4, 0, 0, 5) with val score 0.5326
# Trained and Tested combination 17 of 924: (4, 0, 0, 16), taking 1.83 seconds to get val score of 0.5158
#         Current best combo: (4, 0, 0, 5) with val score 0.5326
# Trained and Tested combination 18 of 924: (4, 0, 0, 17), taking 1.87 seconds to get val score of 0.5163
#         Current best combo: (4, 0, 0, 5) with val score 0.5326
# Trained and Tested combination 19 of 924: (4, 0, 0, 18), taking 1.97 seconds to get val score of 0.5153
#         Current best combo: (4, 0, 0, 5) with val score 0.5326
# Trained and Tested combination 20 of 924: (4, 0, 0, 19), taking 1.98 seconds to get val score of 0.5179
#         Current best combo: (4, 0, 0, 5) with val score 0.5326
# Trained and Tested combination 21 of 924: (4, 0, 0, 20), taking 2.11 seconds to get val score of 0.5258
#         Current best combo: (4, 0, 0, 5) with val score 0.5326
# Trained and Tested combination 22 of 924: (4, 0, 0, 21), taking 2.52 seconds to get val score of 0.5305
#         Current best combo: (4, 0, 0, 5) with val score 0.5326
#
# Best combo after this hyperparameter: (4, 0, 0, 5) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: kernel (index: 1)
#
# Already Trained and Tested combination (4, 0, 0, 5), which had val score of 0.5326
#         Current best combo: (4, 0, 0, 5) with val score 0.5326.
#         Has trained 22 of 924 combinations so far
# Trained and Tested combination 23 of 924: (4, 1, 0, 5), taking 1.89 seconds to get val score of 0.5389
#         Current best combo: (4, 1, 0, 5) with val score 0.5389
#
# Best combo after this hyperparameter: (4, 1, 0, 5) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: degree (index: 2)
#
# Already Trained and Tested combination (4, 1, 0, 5), which had val score of 0.5389
#         Current best combo: (4, 1, 0, 5) with val score 0.5389.
#         Has trained 23 of 924 combinations so far
# Trained and Tested combination 24 of 924: (4, 1, 1, 5), taking 1.88 seconds to get val score of 0.5389
#         Current best combo: (4, 1, 0, 5) with val score 0.5389
# Trained and Tested combination 25 of 924: (4, 1, 2, 5), taking 3.05 seconds to get val score of 0.5389
#         Current best combo: (4, 1, 0, 5) with val score 0.5389
#
# Best combo after this hyperparameter: (4, 1, 0, 5) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: C (index: 0)
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 26 of 924: (0, 1, 0, 5), taking 1.8 seconds to get val score of 0.4784
#         Current best combo: (4, 1, 0, 5) with val score 0.5389
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 27 of 924: (1, 1, 0, 5), taking 1.79 seconds to get val score of 0.4784
#         Current best combo: (4, 1, 0, 5) with val score 0.5389
# Trained and Tested combination 28 of 924: (2, 1, 0, 5), taking 1.84 seconds to get val score of 0.5358
#         Current best combo: (4, 1, 0, 5) with val score 0.5389
# Trained and Tested combination 29 of 924: (3, 1, 0, 5), taking 1.91 seconds to get val score of 0.5379
#         Current best combo: (4, 1, 0, 5) with val score 0.5389
# Already Trained and Tested combination (4, 1, 0, 5), which had val score of 0.5389
#         Current best combo: (4, 1, 0, 5) with val score 0.5389.
#         Has trained 29 of 924 combinations so far
# Trained and Tested combination 30 of 924: (5, 1, 0, 5), taking 2.18 seconds to get val score of 0.5458
#         Current best combo: (5, 1, 0, 5) with val score 0.5458
# Trained and Tested combination 31 of 924: (6, 1, 0, 5), taking 3.85 seconds to get val score of 0.5437
#         Current best combo: (5, 1, 0, 5) with val score 0.5458
#
# Best combo after this hyperparameter: (5, 1, 0, 5) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 2
# Hyperparameter: features (index: 3)
#
# Trained and Tested combination 32 of 924: (5, 1, 0, 0), taking 2.09 seconds to get val score of 0.55
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 33 of 924: (5, 1, 0, 1), taking 3.18 seconds to get val score of 0.5405
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 34 of 924: (5, 1, 0, 2), taking 2.04 seconds to get val score of 0.5421
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 35 of 924: (5, 1, 0, 3), taking 2.76 seconds to get val score of 0.5437
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 36 of 924: (5, 1, 0, 4), taking 2.09 seconds to get val score of 0.5421
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Already Trained and Tested combination (5, 1, 0, 5), which had val score of 0.5458
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 36 of 924 combinations so far
# Trained and Tested combination 37 of 924: (5, 1, 0, 6), taking 2.15 seconds to get val score of 0.5447
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 38 of 924: (5, 1, 0, 7), taking 2.73 seconds to get val score of 0.55
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 39 of 924: (5, 1, 0, 8), taking 2.22 seconds to get val score of 0.5463
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 40 of 924: (5, 1, 0, 9), taking 3.93 seconds to get val score of 0.5495
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 41 of 924: (5, 1, 0, 10), taking 3.51 seconds to get val score of 0.5495
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 42 of 924: (5, 1, 0, 11), taking 2.52 seconds to get val score of 0.5484
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 43 of 924: (5, 1, 0, 12), taking 2.54 seconds to get val score of 0.5221
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 44 of 924: (5, 1, 0, 13), taking 2.36 seconds to get val score of 0.5174
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 45 of 924: (5, 1, 0, 14), taking 2.47 seconds to get val score of 0.5158
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 46 of 924: (5, 1, 0, 15), taking 2.25 seconds to get val score of 0.5158
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 47 of 924: (5, 1, 0, 16), taking 2.28 seconds to get val score of 0.5184
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 48 of 924: (5, 1, 0, 17), taking 3.03 seconds to get val score of 0.5184
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 49 of 924: (5, 1, 0, 18), taking 2.4 seconds to get val score of 0.5184
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 50 of 924: (5, 1, 0, 19), taking 3.25 seconds to get val score of 0.5195
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 51 of 924: (5, 1, 0, 20), taking 2.61 seconds to get val score of 0.5184
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 52 of 924: (5, 1, 0, 21), taking 2.56 seconds to get val score of 0.5184
#         Current best combo: (5, 1, 0, 0) with val score 0.55
#
# Best combo after this hyperparameter: (5, 1, 0, 0) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: kernel (index: 1)
#
# Trained and Tested combination 53 of 924: (5, 0, 0, 0), taking 3.16 seconds to get val score of 0.5126
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Already Trained and Tested combination (5, 1, 0, 0), which had val score of 0.55
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 53 of 924 combinations so far
#
# Best combo after this hyperparameter: (5, 1, 0, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: degree (index: 2)
#
# Already Trained and Tested combination (5, 1, 0, 0), which had val score of 0.55
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 53 of 924 combinations so far
# Trained and Tested combination 54 of 924: (5, 1, 1, 0), taking 2.35 seconds to get val score of 0.55
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 55 of 924: (5, 1, 2, 0), taking 2.33 seconds to get val score of 0.55
#         Current best combo: (5, 1, 0, 0) with val score 0.55
#
# Best combo after this hyperparameter: (5, 1, 0, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 2
# Hyperparameter: C (index: 0)
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 56 of 924: (0, 1, 0, 0), taking 1.69 seconds to get val score of 0.4784
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 57 of 924: (1, 1, 0, 0), taking 1.59 seconds to get val score of 0.4784
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 58 of 924: (2, 1, 0, 0), taking 2.74 seconds to get val score of 0.5358
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 59 of 924: (3, 1, 0, 0), taking 1.84 seconds to get val score of 0.5405
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Trained and Tested combination 60 of 924: (4, 1, 0, 0), taking 2.13 seconds to get val score of 0.5411
#         Current best combo: (5, 1, 0, 0) with val score 0.55
# Already Trained and Tested combination (5, 1, 0, 0), which had val score of 0.55
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 60 of 924 combinations so far
# Trained and Tested combination 61 of 924: (6, 1, 0, 0), taking 2.9 seconds to get val score of 0.5411
#         Current best combo: (5, 1, 0, 0) with val score 0.55
#
# Best combo after this hyperparameter: (5, 1, 0, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 3
#
# Round 3
# Hyperparameter: features (index: 3)
#
# Already Trained and Tested combination (5, 1, 0, 0), which had val score of 0.55
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 1), which had val score of 0.5405
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 2), which had val score of 0.5421
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 3), which had val score of 0.5437
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 4), which had val score of 0.5421
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 5), which had val score of 0.5458
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 6), which had val score of 0.5447
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 7), which had val score of 0.55
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 8), which had val score of 0.5463
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 9), which had val score of 0.5495
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 10), which had val score of 0.5495
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 11), which had val score of 0.5484
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 12), which had val score of 0.5221
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 13), which had val score of 0.5174
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 14), which had val score of 0.5158
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 15), which had val score of 0.5158
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 16), which had val score of 0.5184
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 17), which had val score of 0.5184
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 18), which had val score of 0.5184
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 19), which had val score of 0.5195
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 20), which had val score of 0.5184
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 21), which had val score of 0.5184
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
#
# Best combo after this hyperparameter: (5, 1, 0, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: kernel (index: 1)
#
# Already Trained and Tested combination (5, 0, 0, 0), which had val score of 0.5126
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 0), which had val score of 0.55
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
#
# Best combo after this hyperparameter: (5, 1, 0, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: degree (index: 2)
#
# Already Trained and Tested combination (5, 1, 0, 0), which had val score of 0.55
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 1, 0), which had val score of 0.55
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 2, 0), which had val score of 0.55
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
#
# Best combo after this hyperparameter: (5, 1, 0, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 3
# Hyperparameter: C (index: 0)
#
# Already Trained and Tested combination (0, 1, 0, 0), which had val score of 0.4784
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (1, 1, 0, 0), which had val score of 0.4784
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (2, 1, 0, 0), which had val score of 0.5358
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (3, 1, 0, 0), which had val score of 0.5405
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (4, 1, 0, 0), which had val score of 0.5411
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (5, 1, 0, 0), which had val score of 0.55
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
# Already Trained and Tested combination (6, 1, 0, 0), which had val score of 0.5411
#         Current best combo: (5, 1, 0, 0) with val score 0.55.
#         Has trained 61 of 924 combinations so far
#
# Best combo after this hyperparameter: (5, 1, 0, 0) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
# Max Score:
#  0.55
# Max Test Score:
#  0.497297
# Max Combo Index:
#  (5, 1, 0, 0) out of [7, 2, 3, 22] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 10, 'kernel': 'rbf', 'degree': 1, 'features': 0}
# Max Combo Features:
#  ('closePriceNorm_lag_1',)
# % Combos Checked: 61 out of 924 which is 6.601732%
# Max Score:
#  0.55
# Max Test Score:
#  0.497297
# Max Combo Index:
#  (5, 1, 0, 0) out of [7, 2, 3, 22] (note best combo is 0-indexed)
# Max Combo Hyperparamer Combination:
#  {'C': 10, 'kernel': 'rbf', 'degree': 1, 'features': 0}
# Max Combo Features:
#  ('closePriceNorm_lag_1',)
# % Combos Checked: 61 out of 924 which is 6.601732%
#
#
#
# Max Lag: 2
# JiaoCheng Initialised
# JiaoCheng Initialised
# Successfully read in model <class 'sklearn.svm._classes.SVC'>, which is a Classification model
# Read in Train X data
# Read in Train y data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data
# Successfully recorded hyperparameter choices
# Successfully recorded non_tuneable_hyperparameter choices
# Successfully recorded tuneable feature combination choices and updated relevant internal structures
# Successfully set tuning output address
# Successfully set best model output address
#
# Default combo: [4, 0, 0, 0]
#
#
# ROUND 1
#
# Round 1
# Hyperparameter: features (index: 3)
#
# Trained and Tested combination 1 of 1008: (4, 0, 0, 0), taking 1.66 seconds to get val score of 0.5295
#         Current best combo: (4, 0, 0, 0) with val score 0.5295
# Trained and Tested combination 2 of 1008: (4, 0, 0, 1), taking 2.39 seconds to get val score of 0.5284
#         Current best combo: (4, 0, 0, 0) with val score 0.5295
# Trained and Tested combination 3 of 1008: (4, 0, 0, 2), taking 1.76 seconds to get val score of 0.53
#         Current best combo: (4, 0, 0, 2) with val score 0.53
# Trained and Tested combination 4 of 1008: (4, 0, 0, 3), taking 1.58 seconds to get val score of 0.5311
#         Current best combo: (4, 0, 0, 3) with val score 0.5311
# Trained and Tested combination 5 of 1008: (4, 0, 0, 4), taking 1.79 seconds to get val score of 0.5316
#         Current best combo: (4, 0, 0, 4) with val score 0.5316
# Trained and Tested combination 6 of 1008: (4, 0, 0, 5), taking 1.85 seconds to get val score of 0.5326
#         Current best combo: (4, 0, 0, 5) with val score 0.5326
# Trained and Tested combination 7 of 1008: (4, 0, 0, 6), taking 1.7 seconds to get val score of 0.5332
#         Current best combo: (4, 0, 0, 6) with val score 0.5332
# Trained and Tested combination 8 of 1008: (4, 0, 0, 7), taking 1.83 seconds to get val score of 0.5321
#         Current best combo: (4, 0, 0, 6) with val score 0.5332
# Trained and Tested combination 9 of 1008: (4, 0, 0, 8), taking 2.91 seconds to get val score of 0.5316
#         Current best combo: (4, 0, 0, 6) with val score 0.5332
# Trained and Tested combination 10 of 1008: (4, 0, 0, 9), taking 2.3 seconds to get val score of 0.5326
#         Current best combo: (4, 0, 0, 6) with val score 0.5332
# Trained and Tested combination 11 of 1008: (4, 0, 0, 10), taking 1.95 seconds to get val score of 0.5326
#         Current best combo: (4, 0, 0, 6) with val score 0.5332
# Trained and Tested combination 12 of 1008: (4, 0, 0, 11), taking 3.14 seconds to get val score of 0.5326
#         Current best combo: (4, 0, 0, 6) with val score 0.5332
# Trained and Tested combination 13 of 1008: (4, 0, 0, 12), taking 2.11 seconds to get val score of 0.5326
#         Current best combo: (4, 0, 0, 6) with val score 0.5332
# Trained and Tested combination 14 of 1008: (4, 0, 0, 13), taking 2.12 seconds to get val score of 0.5326
#         Current best combo: (4, 0, 0, 6) with val score 0.5332
# Trained and Tested combination 15 of 1008: (4, 0, 0, 14), taking 2.8 seconds to get val score of 0.5189
#         Current best combo: (4, 0, 0, 6) with val score 0.5332
# Trained and Tested combination 16 of 1008: (4, 0, 0, 15), taking 1.72 seconds to get val score of 0.5147
#         Current best combo: (4, 0, 0, 6) with val score 0.5332
# Trained and Tested combination 17 of 1008: (4, 0, 0, 16), taking 1.92 seconds to get val score of 0.5147
#         Current best combo: (4, 0, 0, 6) with val score 0.5332
# Trained and Tested combination 18 of 1008: (4, 0, 0, 17), taking 3.07 seconds to get val score of 0.5168
#         Current best combo: (4, 0, 0, 6) with val score 0.5332
# Trained and Tested combination 19 of 1008: (4, 0, 0, 18), taking 2.25 seconds to get val score of 0.5147
#         Current best combo: (4, 0, 0, 6) with val score 0.5332
# Trained and Tested combination 20 of 1008: (4, 0, 0, 19), taking 2.18 seconds to get val score of 0.5163
#         Current best combo: (4, 0, 0, 6) with val score 0.5332
# Trained and Tested combination 21 of 1008: (4, 0, 0, 20), taking 2.79 seconds to get val score of 0.5153
#         Current best combo: (4, 0, 0, 6) with val score 0.5332
# Trained and Tested combination 22 of 1008: (4, 0, 0, 21), taking 2.29 seconds to get val score of 0.5237
#         Current best combo: (4, 0, 0, 6) with val score 0.5332
# Trained and Tested combination 23 of 1008: (4, 0, 0, 22), taking 2.76 seconds to get val score of 0.5289
#         Current best combo: (4, 0, 0, 6) with val score 0.5332
# Trained and Tested combination 24 of 1008: (4, 0, 0, 23), taking 2.4 seconds to get val score of 0.5305
#         Current best combo: (4, 0, 0, 6) with val score 0.5332
#
# Best combo after this hyperparameter: (4, 0, 0, 6) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: kernel (index: 1)
#
# Already Trained and Tested combination (4, 0, 0, 6), which had val score of 0.5332
#         Current best combo: (4, 0, 0, 6) with val score 0.5332.
#         Has trained 24 of 1008 combinations so far
# Trained and Tested combination 25 of 1008: (4, 1, 0, 6), taking 2.06 seconds to get val score of 0.5453
#         Current best combo: (4, 1, 0, 6) with val score 0.5453
#
# Best combo after this hyperparameter: (4, 1, 0, 6) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: degree (index: 2)
#
# Already Trained and Tested combination (4, 1, 0, 6), which had val score of 0.5453
#         Current best combo: (4, 1, 0, 6) with val score 0.5453.
#         Has trained 25 of 1008 combinations so far
# Trained and Tested combination 26 of 1008: (4, 1, 1, 6), taking 2.22 seconds to get val score of 0.5453
#         Current best combo: (4, 1, 0, 6) with val score 0.5453
# Trained and Tested combination 27 of 1008: (4, 1, 2, 6), taking 2.08 seconds to get val score of 0.5453
#         Current best combo: (4, 1, 0, 6) with val score 0.5453
#
# Best combo after this hyperparameter: (4, 1, 0, 6) , NOT UPDATED SINCE LAST HYPERPARAMETER
#
#
# Round 1
# Hyperparameter: C (index: 0)
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 28 of 1008: (0, 1, 0, 6), taking 3.48 seconds to get val score of 0.4784
#         Current best combo: (4, 1, 0, 6) with val score 0.5453
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Trained and Tested combination 29 of 1008: (1, 1, 0, 6), taking 2.01 seconds to get val score of 0.4784
#         Current best combo: (4, 1, 0, 6) with val score 0.5453
# Trained and Tested combination 30 of 1008: (2, 1, 0, 6), taking 3.01 seconds to get val score of 0.5347
#         Current best combo: (4, 1, 0, 6) with val score 0.5453
# Trained and Tested combination 31 of 1008: (3, 1, 0, 6), taking 1.87 seconds to get val score of 0.5358
#         Current best combo: (4, 1, 0, 6) with val score 0.5453
# Already Trained and Tested combination (4, 1, 0, 6), which had val score of 0.5453
#         Current best combo: (4, 1, 0, 6) with val score 0.5453.
#         Has trained 31 of 1008 combinations so far
# Trained and Tested combination 32 of 1008: (5, 1, 0, 6), taking 2.64 seconds to get val score of 0.5474
#         Current best combo: (5, 1, 0, 6) with val score 0.5474
# Trained and Tested combination 33 of 1008: (6, 1, 0, 6), taking 3.14 seconds to get val score of 0.5416
#         Current best combo: (5, 1, 0, 6) with val score 0.5474
#
# Best combo after this hyperparameter: (5, 1, 0, 6) , UPDATED SINCE LAST HYPERPARAMETER
#
#
# ROUND 2
#
# Round 2
# Hyperparameter: features (index: 3)
#
# Trained and Tested combination 34 of 1008: (5, 1, 0, 0), taking 3.04 seconds to get val score of 0.5311
#         Current best combo: (5, 1, 0, 6) with val score 0.5474
# Trained and Tested combination 35 of 1008: (5, 1, 0, 1), taking 2.28 seconds to get val score of 0.5405
#         Current best combo: (5, 1, 0, 6) with val score 0.5474
# Trained and Tested combination 36 of 1008: (5, 1, 0, 2), taking 2.27 seconds to get val score of 0.5421
#         Current best combo: (5, 1, 0, 6) with val score 0.5474
# Trained and Tested combination 37 of 1008: (5, 1, 0, 3), taking 2.29 seconds to get val score of 0.5426
#         Current best combo: (5, 1, 0, 6) with val score 0.5474
# Trained and Tested combination 38 of 1008: (5, 1, 0, 4), taking 2.33 seconds to get val score of 0.5421
#         Current best combo: (5, 1, 0, 6) with val score 0.5474
# Trained and Tested combination 39 of 1008: (5, 1, 0, 5), taking 2.38 seconds to get val score of 0.5458
#         Current best combo: (5, 1, 0, 6) with val score 0.5474
# Already Trained and Tested combination (5, 1, 0, 6), which had val score of 0.5474
#         Current best combo: (5, 1, 0, 6) with val score 0.5474.
#         Has trained 39 of 1008 combinations so far
# Trained and Tested combination 40 of 1008: (5, 1, 0, 7), taking 2.33 seconds to get val score of 0.5453
#         Current best combo: (5, 1, 0, 6) with val score 0.5474
# Trained and Tested combination 41 of 1008: (5, 1, 0, 8), taking 2.37 seconds to get val score of 0.55
#         Current best combo: (5, 1, 0, 8) with val score 0.55
# Trained and Tested combination 42 of 1008: (5, 1, 0, 9), taking 2.46 seconds to get val score of 0.5495
#         Current best combo: (5, 1, 0, 8) with val score 0.55
# Trained and Tested combination 43 of 1008: (5, 1, 0, 10), taking 2.43 seconds to get val score of 0.5495
#         Current best combo: (5, 1, 0, 8) with val score 0.55
# Trained and Tested combination 44 of 1008: (5, 1, 0, 11), taking 2.54 seconds to get val score of 0.5484
#         Current best combo: (5, 1, 0, 8) with val score 0.55
# Trained and Tested combination 45 of 1008: (5, 1, 0, 12), taking 2.65 seconds to get val score of 0.55
#         Current best combo: (5, 1, 0, 8) with val score 0.55
# Trained and Tested combination 46 of 1008: (5, 1, 0, 13), taking 2.59 seconds to get val score of 0.5495
#         Current best combo: (5, 1, 0, 8) with val score 0.55
# Trained and Tested combination 47 of 1008: (5, 1, 0, 14), taking 2.44 seconds to get val score of 0.5216
#         Current best combo: (5, 1, 0, 8) with val score 0.55
# Trained and Tested combination 48 of 1008: (5, 1, 0, 15), taking 2.64 seconds to get val score of 0.5174
#         Current best combo: (5, 1, 0, 8) with val score 0.55
# Trained and Tested combination 49 of 1008: (5, 1, 0, 16), taking 2.31 seconds to get val score of 0.5195
#         Current best combo: (5, 1, 0, 8) with val score 0.55
